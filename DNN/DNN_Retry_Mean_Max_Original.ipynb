# %% [markdown]
# ## DNN Retry with Mean + Max
# (Data from 2020-2021, 2021-2022 also included)

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
# %matplotlib inline
from statistics import mean
from statistics import mean
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.callbacks import EarlyStopping

# %%
import seaborn as sns
import numpy as np
import pandas as pd
from statistics import mean
import math

FUTURE_PREDICTION = 4

def findmax(x):
    maximum = 0
    for number in x:
        maximum = max(x)
    return maximum

def findmean(x):
    m = 0
    m = mean(x)
    return m


def CreateMean(dataframe,title,city):

    dataframe = dataframe.iloc[522:3924:1]
    dataframe.rename(columns = {f'{city}' : f'{title}_Mean'}, inplace = True)
    dataframe = dataframe.reset_index(drop=True)
    for x in dataframe.index:
        if x % 7 == 6:
            list = []
            mean = 0
            for y in range(x-6,x+1,1):
                list.append(dataframe.iloc[y][f'{title}_Mean'])
            mean = findmean(list)
            dataframe.at[x,f'{title}_Mean'] = mean
    for x in dataframe.index:
        if x % 7 != 6:
            dataframe.drop(index= x, inplace=True)
    dataframe = dataframe.reset_index(drop=True)
    return dataframe

def CreateMax(dataframe,title,city):

    dataframe = dataframe.iloc[522:3924:1]
    dataframe.rename(columns = {f'{city}' : f'{title}_Max'}, inplace = True)
    dataframe = dataframe.reset_index(drop=True)
    for x in dataframe.index:
        if x % 7 == 6:
            list = []
            maximum = 0
            for y in range(x-6,x+1,1):
                list.append(dataframe.iloc[y][f'{title}_Max'])
            maximum = findmax(list)
            dataframe.at[x,f'{title}_Max'] = maximum
    for x in dataframe.index:
        if x % 7 != 6:
            dataframe.drop(index= x, inplace=True)
    dataframe = dataframe.reset_index(drop=True)
    return dataframe

def CreateMin(dataframe,title,city):

    dataframe = dataframe.iloc[522:3924:1]
    dataframe.rename(columns = {f'{city}' : f'{title}_Min'}, inplace = True)
    dataframe = dataframe.reset_index(drop=True)
    for x in dataframe.index:
        if x % 7 == 6:
            list = []
            minimum = 0
            for y in range(x-6,x+1,1):
                list.append(dataframe.iloc[y][f'{title}_Min'])
            minimum = findmin(list)
            dataframe.at[x,f'{title}_Min'] = minimum
    for x in dataframe.index:
        if x % 7 != 6:
            dataframe.drop(index= x, inplace=True)
    dataframe = dataframe.reset_index(drop=True)
    return dataframe
    
def DataPreprocess(city):
    virus_df = pd.read_csv('Data/virus.csv')
    virus_df['Date'] = pd.to_datetime(virus_df['Date'])
    virus_df['year'] = virus_df['Date'].apply(lambda date: date.year)
    virus_df['month'] = virus_df['Date'].apply(lambda date: date.month)
    virus_df_new = virus_df[['Date','month','year',f'{city}']]
    virus_df_new.rename(columns = {f'{city}' : f'Virus_Count_{city}'}, inplace = True)

    temp_df = pd.read_csv(f'Data/{city}_temp.csv')
    pressure_df = pd.read_csv(f'Data/{city}_pressure.csv')
    hours_df = pd.read_csv(f'Data/{city}_hours.csv')
    rainfall_df = pd.read_csv(f'Data/{city}_rainfall.csv')

    temp_df['Date'] = pd.to_datetime(temp_df['Date'])
    temp_df['year'] = temp_df['Date'].apply(lambda date: date.year)
    temp_df['month'] = temp_df['Date'].apply(lambda date: date.month)

    pressure_df['Date'] = pd.to_datetime(pressure_df['Date'])
    pressure_df['year'] = pressure_df['Date'].apply(lambda date: date.year)
    pressure_df['month'] = pressure_df['Date'].apply(lambda date: date.month)
    pressure_df = pressure_df.sort_values(by="Date")
    pressure_df = pressure_df.reset_index(drop=True)

    hours_df['Date'] = pd.to_datetime(hours_df['Date'])
    hours_df['year'] = hours_df['Date'].apply(lambda date: date.year)
    hours_df['month'] = hours_df['Date'].apply(lambda date: date.month)
    hours_df = hours_df.sort_values(by="Date")
    hours_df = hours_df.reset_index(drop=True)

    rainfall_df['Date'] = pd.to_datetime(rainfall_df['Date'])
    rainfall_df['year'] = rainfall_df['Date'].apply(lambda date: date.year)
    rainfall_df['month'] = rainfall_df['Date'].apply(lambda date: date.month)
    rainfall_df = rainfall_df.sort_values(by="Date")
    rainfall_df = rainfall_df.reset_index(drop=True)
    
    list = []
    for x in temp_df.index:
        t = temp_df.iloc[x][f'{city}']
        svp = 6.1078*10**(7.5*t/(t+237.3))
        e = pressure_df.iloc[x][f'{city}']
        h = e/svp*100
        list.append(h)
        
    humidity_df = pd.DataFrame(data=list)
    humidity_df.rename(columns = {0:f'{city}'}, inplace = True)

    mean_temp_df = CreateMean(temp_df, 'Temperature',f'{city}')
    mean_pressure_df = CreateMean(pressure_df, 'Pressure',f'{city}')
    mean_hours_df = CreateMean(hours_df, 'Hours',f'{city}')
    mean_rainfall_df = CreateMean(rainfall_df, 'Rainfall',f'{city}')
    mean_humidity_df = CreateMean(humidity_df, 'Humidity',f'{city}')
    
    max_temp_df = CreateMax(temp_df, 'Temperature',f'{city}')
    max_pressure_df = CreateMax(pressure_df, 'Pressure',f'{city}')
    max_hours_df = CreateMax(hours_df, 'Hours',f'{city}')
    max_rainfall_df = CreateMax(rainfall_df, 'Rainfall',f'{city}')
    max_humidity_df = CreateMax(humidity_df, 'Humidity',f'{city}')
    

    df = pd.concat([virus_df_new,mean_humidity_df,mean_temp_df,mean_pressure_df,mean_hours_df,mean_rainfall_df,max_temp_df,max_pressure_df,max_hours_df,max_rainfall_df,max_humidity_df], axis=1)
    df = df.loc[:,~df.columns.duplicated()]

    df['VirusCRM'] = df['Virus_Count_Tokyo'].rolling(14, center = True).mean()

    for i in df.index:
        if i == 0:
            df.at[i,'Gradient'] = 1
        else:
            if df.iloc[i-1]['VirusCRM'] == 0:
                if df.at[i,'VirusCDM'] > 0:
                    df.at[i,'Gradient'] = 1
                else:
                    df.at[i,'Gradient'] = 0
            else:
                grd = df.iloc[i]['VirusCRM']/(df.iloc[i-1]['VirusCRM'])
                df.at[i,'Gradient'] = grd
    
    for i in df.index:
        if (df.iloc[i]['Gradient'] >= 1.1) and (df.iloc[i+1]['Gradient'] >= 1.1) and (df.iloc[i+2]['Gradient'] >= 1.1):
            df.at[i,'Spreading'] = 1
        else:
            df.at[i,'Spreading'] = 0
    df = df.astype({'Spreading':'int8'})

    df_virus_count = df[f'Virus_Count_{city}']
    df.drop(columns=['year','Gradient','VirusCRM',f'Virus_Count_{city}'], axis=1, inplace=True)
    df_labels = df[['Date']]
    
    FUTURE_PREDICTION = 4
    for i in range(FUTURE_PREDICTION):
        df_labels[f"T+{(i+1)*7}"] = df_labels["Date"] + pd.DateOffset(days = (i+1)*7)
    temp = df[["Date", "Spreading"]]
    for i in range(FUTURE_PREDICTION):
        target_column = f"T+{(i+1)*7}"
        df_labels = df_labels.merge(temp, 
                                how ="left",
                                left_on = (target_column),
                                right_on=("Date"),
                                suffixes = ("","_y")
        )
        df_labels.rename(columns={"Spreading":f"{target_column}_Spreading"},inplace=True)
    df_labels.drop(columns=["Date_y"],inplace=True)

    for i in range(FUTURE_PREDICTION):
        df_labels.drop(columns =[f"T+{(i+1)*7}"],inplace=True,axis=1 )

    df = df.merge(df_labels,
             how='left',
             on = ["Date"])
    df.dropna(inplace=True)

    X = df.drop(columns=['T+7_Spreading','T+14_Spreading','T+21_Spreading','T+28_Spreading'],axis=1)
    y1 = df['T+21_Spreading']
    y2 = df['T+7_Spreading']
    y3 = df['T+14_Spreading']
    y4 = df['T+28_Spreading']

    return X, y1, y2, y3, y4, df, df_virus_count

# %%
X, y1, y2, y3, y4, df, df_virus_count = DataPreprocess('Tokyo')
# Out:
# /Users/miyanishio/opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py:5039: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(
# /var/folders/k5/3yc13bs57f7637937yjlstth0000gn/T/ipykernel_86668/2635125380.py:168: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_labels[f"T+{(i+1)*7}"] = df_labels["Date"] + pd.DateOffset(days = (i+1)*7)

# %%
X = X.drop(columns=['Date'])

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

scaler = StandardScaler()
scaler1 = StandardScaler()
X_train, X_test = X[0:336], X[336:482] #70-30 Split
y1_train, y1_test = y1[0:336], y1[336:482]

# %%
scaled_X_train = scaler1.fit_transform(X_train)
scaled_X_test = scaler1.transform(X_test)

# %%
model = Sequential()

model.add(Dense(12,activation="sigmoid"))
model.add(Dense(6,activation="sigmoid"))
model.add(Dense(3,activation="sigmoid"))

model.add(Dense(1, activation='sigmoid'))
model.compile(optimizer='rmsprop',loss='binary_crossentropy',metrics=['accuracy'])
# Out:
# 2022-11-14 17:03:21.367196: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
early_stop = EarlyStopping(monitor='val_loss',mode='min',verbose=1,patience=50)

# %%
model.fit(scaled_X_train,y1_train,epochs=400,validation_data=(scaled_X_test,y1_test),callbacks=[early_stop])
# Out:
# Epoch 1/400
# 11/11 [==============================] - 2s 73ms/step - loss: 0.7290 - accuracy: 0.1548 - val_loss: 0.7117 - val_accuracy: 0.1575
# Epoch 2/400
# 11/11 [==============================] - 0s 11ms/step - loss: 0.7061 - accuracy: 0.1696 - val_loss: 0.6940 - val_accuracy: 0.5274
# Epoch 3/400
# 11/11 [==============================] - 0s 7ms/step - loss: 0.6887 - accuracy: 0.6786 - val_loss: 0.6780 - val_accuracy: 0.8425
# Epoch 4/400
# 11/11 [==============================] - 0s 9ms/step - loss: 0.6726 - accuracy: 0.8452 - val_loss: 0.6639 - val_accuracy: 0.8425
# Epoch 5/400
# 11/11 [==============================] - 0s 10ms/step - loss: 0.6579 - accuracy: 0.8452 - val_loss: 0.6499 - val_accuracy: 0.8425
# Epoch 6/400
# 11/11 [==============================] - 0s 12ms/step - loss: 0.6437 - accuracy: 0.8452 - val_loss: 0.6367 - val_accuracy: 0.8425
# Epoch 7/400
# 11/11 [==============================] - 0s 8ms/step - loss: 0.6301 - accuracy: 0.8452 - val_loss: 0.6241 - val_accuracy: 0.8425
# Epoch 8/400
# 11/11 [==============================] - 0s 14ms/step - loss: 0.6169 - accuracy: 0.8452 - val_loss: 0.6114 - val_accuracy: 0.8425
# Epoch 9/400
# 11/11 [==============================] - 0s 10ms/step - loss: 0.6044 - accuracy: 0.8452 - val_loss: 0.6001 - val_accuracy: 0.8425
# Epoch 10/400
# 11/11 [==============================] - 0s 16ms/step - loss: 0.5926 - accuracy: 0.8452 - val_loss: 0.5888 - val_accuracy: 0.8425
# Epoch 11/400
# 11/11 [==============================] - 0s 9ms/step - loss: 0.5813 - accuracy: 0.8452 - val_loss: 0.5786 - val_accuracy: 0.8425
# Epoch 12/400
# 11/11 [==============================] - 0s 7ms/step - loss: 0.5710 - accuracy: 0.8452 - val_loss: 0.5688 - val_accuracy: 0.8425
# Epoch 13/400
# 11/11 [==============================] - 0s 7ms/step - loss: 0.5609 - accuracy: 0.8452 - val_loss: 0.5592 - val_accuracy: 0.8425
# Epoch 14/400
# 11/11 [==============================] - 0s 8ms/step - loss: 0.5513 - accuracy: 0.8452 - val_loss: 0.5506 - val_accuracy: 0.8425
# Epoch 15/400
# 11/11 [==============================] - 0s 10ms/step - loss: 0.5425 - accuracy: 0.8452 - val_loss: 0.5418 - val_accuracy: 0.8425
# Epoch 16/400
# 11/11 [==============================] - 0s 13ms/step - loss: 0.5338 - accuracy: 0.8452 - val_loss: 0.5338 - val_accuracy: 0.8425
# Epoch 17/400
# 11/11 [==============================] - 0s 16ms/step - loss: 0.5258 - accuracy: 0.8452 - val_loss: 0.5263 - val_accuracy: 0.8425
# Epoch 18/400
# 11/11 [==============================] - 0s 10ms/step - loss: 0.5183 - accuracy: 0.8452 - val_loss: 0.5193 - val_accuracy: 0.8425
# Epoch 19/400
# 11/11 [==============================] - 0s 32ms/step - loss: 0.5114 - accuracy: 0.8452 - val_loss: 0.5130 - val_accuracy: 0.8425
# Epoch 20/400
# 11/11 [==============================] - 0s 11ms/step - loss: 0.5049 - accuracy: 0.8452 - val_loss: 0.5072 - val_accuracy: 0.8425
# Epoch 21/400
# 11/11 [==============================] - 0s 6ms/step - loss: 0.4990 - accuracy: 0.8452 - val_loss: 0.5012 - val_accuracy: 0.8425
# Epoch 22/400
# 11/11 [==============================] - 0s 10ms/step - loss: 0.4931 - accuracy: 0.8452 - val_loss: 0.4960 - val_accuracy: 0.8425
# Epoch 23/400
# 11/11 [==============================] - 0s 5ms/step - loss: 0.4876 - accuracy: 0.8452 - val_loss: 0.4907 - val_accuracy: 0.8425
# Epoch 24/400
# 11/11 [==============================] - 0s 5ms/step - loss: 0.4822 - accuracy: 0.8452 - val_loss: 0.4858 - val_accuracy: 0.8425
# Epoch 25/400
# 11/11 [==============================] - 0s 7ms/step - loss: 0.4774 - accuracy: 0.8452 - val_loss: 0.4815 - val_accuracy: 0.8425
# Epoch 26/400
# 11/11 [==============================] - 0s 7ms/step - loss: 0.4727 - accuracy: 0.8452 - val_loss: 0.4774 - val_accuracy: 0.8425
# Epoch 27/400
# 11/11 [==============================] - 0s 4ms/step - loss: 0.4685 - accuracy: 0.8452 - val_loss: 0.4735 - val_accuracy: 0.8425
# Epoch 28/400
# 11/11 [==============================] - 0s 6ms/step - loss: 0.4645 - accuracy: 0.8452 - val_loss: 0.4702 - val_accuracy: 0.8425
# Epoch 29/400
# 11/11 [==============================] - 0s 6ms/step - loss: 0.4608 - accuracy: 0.8452 - val_loss: 0.4669 - val_accuracy: 0.8425
# Epoch 30/400
# 11/11 [==============================] - 0s 10ms/step - loss: 0.4571 - accuracy: 0.8452 - val_loss: 0.4638 - val_accuracy: 0.8425
# Epoch 31/400
# 11/11 [==============================] - 0s 6ms/step - loss: 0.4537 - accuracy: 0.8452 - val_loss: 0.4606 - val_accuracy: 0.8425
# Epoch 32/400
# 11/11 [==============================] - 0s 7ms/step - loss: 0.4503 - accuracy: 0.8452 - val_loss: 0.4583 - val_accuracy: 0.8425
# Epoch 33/400
# 11/11 [==============================] - 0s 5ms/step - loss: 0.4476 - accuracy: 0.8452 - val_loss: 0.4560 - val_accuracy: 0.8425
# Epoch 34/400
# 11/11 [==============================] - 0s 5ms/step - loss: 0.4447 - accuracy: 0.8452 - val_loss: 0.4539 - val_accuracy: 0.8425
# Epoch 35/400
# 11/11 [==============================] - 0s 7ms/step - loss: 0.4420 - accuracy: 0.8452 - val_loss: 0.4518 - val_accuracy: 0.8425
# Epoch 36/400
# 11/11 [==============================] - 0s 12ms/step - loss: 0.4394 - accuracy: 0.8452 - val_loss: 0.4499 - val_accuracy: 0.8425
# Epoch 37/400
# 11/11 [==============================] - 0s 8ms/step - loss: 0.4369 - accuracy: 0.8452 - val_loss: 0.4485 - val_accuracy: 0.8425
# Epoch 38/400
# 11/11 [==============================] - 0s 7ms/step - loss: 0.4347 - accuracy: 0.8452 - val_loss: 0.4469 - val_accuracy: 0.8425
# Epoch 39/400
# 11/11 [==============================] - 0s 8ms/step - loss: 0.4323 - accuracy: 0.8452 - val_loss: 0.4455 - val_accuracy: 0.8425
# Epoch 40/400
# 11/11 [==============================] - 0s 7ms/step - loss: 0.4300 - accuracy: 0.8452 - val_loss: 0.4443 - val_accuracy: 0.8425
# Epoch 41/400
# 11/11 [==============================] - 0s 24ms/step - loss: 0.4280 - accuracy: 0.8452 - val_loss: 0.4435 - val_accuracy: 0.8425
# Epoch 42/400
# 11/11 [==============================] - 0s 15ms/step - loss: 0.4262 - accuracy: 0.8452 - val_loss: 0.4424 - val_accuracy: 0.8425
# Epoch 43/400
# 11/11 [==============================] - 0s 7ms/step - loss: 0.4243 - accuracy: 0.8452 - val_loss: 0.4418 - val_accuracy: 0.8425
# Epoch 44/400
# 11/11 [==============================] - 0s 13ms/step - loss: 0.4227 - accuracy: 0.8452 - val_loss: 0.4414 - val_accuracy: 0.8425
# Epoch 45/400
# 11/11 [==============================] - 0s 11ms/step - loss: 0.4212 - accuracy: 0.8452 - val_loss: 0.4408 - val_accuracy: 0.8425
# Epoch 46/400
# 11/11 [==============================] - 0s 18ms/step - loss: 0.4195 - accuracy: 0.8452 - val_loss: 0.4402 - val_accuracy: 0.8425
# Epoch 47/400
# 11/11 [==============================] - 0s 26ms/step - loss: 0.4179 - accuracy: 0.8452 - val_loss: 0.4397 - val_accuracy: 0.8425
# Epoch 48/400
# 11/11 [==============================] - 0s 16ms/step - loss: 0.4162 - accuracy: 0.8452 - val_loss: 0.4394 - val_accuracy: 0.8425
# Epoch 49/400
# 11/11 [==============================] - 0s 9ms/step - loss: 0.4147 - accuracy: 0.8452 - val_loss: 0.4391 - val_accuracy: 0.8425
# Epoch 50/400
# 11/11 [==============================] - 0s 14ms/step - loss: 0.4131 - accuracy: 0.8452 - val_loss: 0.4390 - val_accuracy: 0.8425
# Epoch 51/400
# 11/11 [==============================] - 0s 8ms/step - loss: 0.4117 - accuracy: 0.8452 - val_loss: 0.4389 - val_accuracy: 0.8425
# Epoch 52/400
# 11/11 [==============================] - 0s 6ms/step - loss: 0.4103 - accuracy: 0.8452 - val_loss: 0.4388 - val_accuracy: 0.8425
# Epoch 53/400
# 11/11 [==============================] - 0s 6ms/step - loss: 0.4087 - accuracy: 0.8452 - val_loss: 0.4386 - val_accuracy: 0.8425
# Epoch 54/400
# 11/11 [==============================] - 0s 16ms/step - loss: 0.4071 - accuracy: 0.8452 - val_loss: 0.4386 - val_accuracy: 0.8425
# Epoch 55/400
# 11/11 [==============================] - 0s 15ms/step - loss: 0.4054 - accuracy: 0.8452 - val_loss: 0.4387 - val_accuracy: 0.8425
# Epoch 56/400
# 11/11 [==============================] - 0s 7ms/step - loss: 0.4039 - accuracy: 0.8452 - val_loss: 0.4387 - val_accuracy: 0.8425
# Epoch 57/400
# 11/11 [==============================] - 0s 7ms/step - loss: 0.4023 - accuracy: 0.8452 - val_loss: 0.4388 - val_accuracy: 0.8425
# Epoch 58/400
# 11/11 [==============================] - 0s 11ms/step - loss: 0.4008 - accuracy: 0.8452 - val_loss: 0.4387 - val_accuracy: 0.8425
# Epoch 59/400
# 11/11 [==============================] - 0s 6ms/step - loss: 0.3991 - accuracy: 0.8452 - val_loss: 0.4387 - val_accuracy: 0.8425
# Epoch 60/400
# 11/11 [==============================] - 0s 6ms/step - loss: 0.3975 - accuracy: 0.8452 - val_loss: 0.4388 - val_accuracy: 0.8425
# Epoch 61/400
# 11/11 [==============================] - 0s 6ms/step - loss: 0.3959 - accuracy: 0.8452 - val_loss: 0.4389 - val_accuracy: 0.8425
# Epoch 62/400
# 11/11 [==============================] - 0s 6ms/step - loss: 0.3942 - accuracy: 0.8452 - val_loss: 0.4391 - val_accuracy: 0.8425
# Epoch 63/400
# 11/11 [==============================] - 0s 8ms/step - loss: 0.3927 - accuracy: 0.8452 - val_loss: 0.4393 - val_accuracy: 0.8425
# Epoch 64/400
# 11/11 [==============================] - 0s 6ms/step - loss: 0.3909 - accuracy: 0.8452 - val_loss: 0.4394 - val_accuracy: 0.8425
# Epoch 65/400
# 11/11 [==============================] - 0s 7ms/step - loss: 0.3893 - accuracy: 0.8452 - val_loss: 0.4397 - val_accuracy: 0.8425
# Epoch 66/400
# 11/11 [==============================] - 0s 12ms/step - loss: 0.3876 - accuracy: 0.8452 - val_loss: 0.4399 - val_accuracy: 0.8425
# Epoch 67/400
# 11/11 [==============================] - 0s 12ms/step - loss: 0.3859 - accuracy: 0.8452 - val_loss: 0.4400 - val_accuracy: 0.8425
# Epoch 68/400
# 11/11 [==============================] - 0s 5ms/step - loss: 0.3842 - accuracy: 0.8452 - val_loss: 0.4402 - val_accuracy: 0.8425
# Epoch 69/400
# 11/11 [==============================] - 0s 7ms/step - loss: 0.3825 - accuracy: 0.8452 - val_loss: 0.4404 - val_accuracy: 0.8425
# Epoch 70/400
# 11/11 [==============================] - 0s 5ms/step - loss: 0.3809 - accuracy: 0.8452 - val_loss: 0.4406 - val_accuracy: 0.8425
# Epoch 71/400
# 11/11 [==============================] - 0s 5ms/step - loss: 0.3792 - accuracy: 0.8452 - val_loss: 0.4406 - val_accuracy: 0.8425
# Epoch 72/400
# 11/11 [==============================] - 0s 5ms/step - loss: 0.3777 - accuracy: 0.8452 - val_loss: 0.4410 - val_accuracy: 0.8425
# Epoch 73/400
# 11/11 [==============================] - 0s 5ms/step - loss: 0.3761 - accuracy: 0.8452 - val_loss: 0.4412 - val_accuracy: 0.8425
# Epoch 74/400
# 11/11 [==============================] - 0s 7ms/step - loss: 0.3746 - accuracy: 0.8452 - val_loss: 0.4412 - val_accuracy: 0.8425
# Epoch 75/400
# 11/11 [==============================] - 0s 6ms/step - loss: 0.3731 - accuracy: 0.8452 - val_loss: 0.4413 - val_accuracy: 0.8425
# Epoch 76/400
# 11/11 [==============================] - 0s 5ms/step - loss: 0.3715 - accuracy: 0.8452 - val_loss: 0.4416 - val_accuracy: 0.8425
# Epoch 77/400
# 11/11 [==============================] - 0s 7ms/step - loss: 0.3699 - accuracy: 0.8452 - val_loss: 0.4416 - val_accuracy: 0.8425
# Epoch 78/400
# 11/11 [==============================] - 0s 23ms/step - loss: 0.3685 - accuracy: 0.8452 - val_loss: 0.4418 - val_accuracy: 0.8425
# Epoch 79/400
# 11/11 [==============================] - 0s 5ms/step - loss: 0.3670 - accuracy: 0.8452 - val_loss: 0.4418 - val_accuracy: 0.8425
# Epoch 80/400
# 11/11 [==============================] - 0s 7ms/step - loss: 0.3656 - accuracy: 0.8452 - val_loss: 0.4418 - val_accuracy: 0.8425
# Epoch 81/400
# 11/11 [==============================] - 0s 6ms/step - loss: 0.3641 - accuracy: 0.8452 - val_loss: 0.4419 - val_accuracy: 0.8425
# Epoch 82/400
# 11/11 [==============================] - 0s 5ms/step - loss: 0.3626 - accuracy: 0.8452 - val_loss: 0.4420 - val_accuracy: 0.8425
# Epoch 83/400
# 11/11 [==============================] - 0s 9ms/step - loss: 0.3611 - accuracy: 0.8452 - val_loss: 0.4420 - val_accuracy: 0.8425
# Epoch 84/400
# 11/11 [==============================] - 0s 5ms/step - loss: 0.3596 - accuracy: 0.8452 - val_loss: 0.4419 - val_accuracy: 0.8425
# Epoch 85/400
# 11/11 [==============================] - 0s 5ms/step - loss: 0.3580 - accuracy: 0.8452 - val_loss: 0.4419 - val_accuracy: 0.8425
# Epoch 86/400
# 11/11 [==============================] - 0s 10ms/step - loss: 0.3566 - accuracy: 0.8452 - val_loss: 0.4419 - val_accuracy: 0.8425
# Epoch 87/400
# 11/11 [==============================] - 0s 7ms/step - loss: 0.3550 - accuracy: 0.8452 - val_loss: 0.4421 - val_accuracy: 0.8425
# Epoch 88/400
# 11/11 [==============================] - 0s 6ms/step - loss: 0.3533 - accuracy: 0.8452 - val_loss: 0.4422 - val_accuracy: 0.8425
# Epoch 89/400
# 11/11 [==============================] - 0s 6ms/step - loss: 0.3518 - accuracy: 0.8452 - val_loss: 0.4422 - val_accuracy: 0.8425
# Epoch 90/400
# 11/11 [==============================] - 0s 7ms/step - loss: 0.3502 - accuracy: 0.8452 - val_loss: 0.4420 - val_accuracy: 0.8425
# Epoch 91/400
# 11/11 [==============================] - 0s 7ms/step - loss: 0.3488 - accuracy: 0.8452 - val_loss: 0.4418 - val_accuracy: 0.8425
# Epoch 92/400
# 11/11 [==============================] - 0s 6ms/step - loss: 0.3473 - accuracy: 0.8452 - val_loss: 0.4418 - val_accuracy: 0.8425
# Epoch 93/400
# 11/11 [==============================] - 0s 6ms/step - loss: 0.3458 - accuracy: 0.8452 - val_loss: 0.4417 - val_accuracy: 0.8425
# Epoch 94/400
# 11/11 [==============================] - 0s 6ms/step - loss: 0.3443 - accuracy: 0.8452 - val_loss: 0.4416 - val_accuracy: 0.8425
# Epoch 95/400
# 11/11 [==============================] - 0s 11ms/step - loss: 0.3429 - accuracy: 0.8452 - val_loss: 0.4416 - val_accuracy: 0.8425
# Epoch 96/400
# 11/11 [==============================] - 0s 9ms/step - loss: 0.3415 - accuracy: 0.8452 - val_loss: 0.4414 - val_accuracy: 0.8425
# Epoch 97/400
# 11/11 [==============================] - 0s 13ms/step - loss: 0.3402 - accuracy: 0.8452 - val_loss: 0.4411 - val_accuracy: 0.8425
# Epoch 98/400
# 11/11 [==============================] - 0s 5ms/step - loss: 0.3387 - accuracy: 0.8452 - val_loss: 0.4407 - val_accuracy: 0.8425
# Epoch 99/400
# 11/11 [==============================] - 0s 4ms/step - loss: 0.3374 - accuracy: 0.8452 - val_loss: 0.4403 - val_accuracy: 0.8425
# Epoch 100/400
# 11/11 [==============================] - 0s 9ms/step - loss: 0.3362 - accuracy: 0.8452 - val_loss: 0.4401 - val_accuracy: 0.8425
# Epoch 101/400
# 11/11 [==============================] - 0s 9ms/step - loss: 0.3347 - accuracy: 0.8452 - val_loss: 0.4400 - val_accuracy: 0.8425
# Epoch 102/400
# 11/11 [==============================] - 0s 6ms/step - loss: 0.3332 - accuracy: 0.8452 - val_loss: 0.4400 - val_accuracy: 0.8425
# Epoch 103/400
# 11/11 [==============================] - 0s 9ms/step - loss: 0.3318 - accuracy: 0.8452 - val_loss: 0.4399 - val_accuracy: 0.8425
# Epoch 104/400
# 11/11 [==============================] - 0s 25ms/step - loss: 0.3303 - accuracy: 0.8452 - val_loss: 0.4396 - val_accuracy: 0.8425
# Epoch 104: early stopping

# %%
predictions = model.predict(scaled_X_test)

# %%
preds = []
for x in predictions:
    if x >= 0.5:
        preds.append(1)
    else:
        preds.append(0)

# %%
from sklearn.metrics import classification_report,confusion_matrix

# %%
print(classification_report(y1_test,preds))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.84      1.00      0.91       123
#          1.0       0.00      0.00      0.00        23
#
#     accuracy                           0.84       146
#    macro avg       0.42      0.50      0.46       146
# weighted avg       0.71      0.84      0.77       146
# /Users/miyanishio/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/miyanishio/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/miyanishio/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
