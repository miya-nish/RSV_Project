# %% [markdown]
# ## DNN Retry Max
# Included the minimum, as well as took out the data from 2020-2021, 2021-2022.

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
# %matplotlib inline
from statistics import mean
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.callbacks import EarlyStopping

# %%
import seaborn as sns
import numpy as np
import pandas as pd
from statistics import mean
import math

FUTURE_PREDICTION = 4

def findmax(x):
    maximum = 0
    for number in x:
        maximum = max(x)
    return maximum

def findmean(x):
    m = 0
    m = mean(x)
    return m

def findmin(x):
    m = 0
    m = min(x)
    return m

def CreateMean(dataframe,title,city):

    dataframe = dataframe.iloc[522:3924:1]
    dataframe.rename(columns = {f'{city}' : f'{title}_Mean'}, inplace = True)
    dataframe = dataframe.reset_index(drop=True)
    for x in dataframe.index:
        if x % 7 == 6:
            list = []
            mean = 0
            for y in range(x-6,x+1,1):
                list.append(dataframe.iloc[y][f'{title}_Mean'])
            mean = findmean(list)
            dataframe.at[x,f'{title}_Mean'] = mean
    for x in dataframe.index:
        if x % 7 != 6:
            dataframe.drop(index= x, inplace=True)
    dataframe = dataframe.reset_index(drop=True)
    return dataframe

def CreateMax(dataframe,title,city):

    dataframe = dataframe.iloc[522:3924:1]
    dataframe.rename(columns = {f'{city}' : f'{title}_Max'}, inplace = True)
    dataframe = dataframe.reset_index(drop=True)
    for x in dataframe.index:
        if x % 7 == 6:
            list = []
            maximum = 0
            for y in range(x-6,x+1,1):
                list.append(dataframe.iloc[y][f'{title}_Max'])
            maximum = findmax(list)
            dataframe.at[x,f'{title}_Max'] = maximum
    for x in dataframe.index:
        if x % 7 != 6:
            dataframe.drop(index= x, inplace=True)
    dataframe = dataframe.reset_index(drop=True)
    return dataframe

def CreateMin(dataframe,title,city):

    dataframe = dataframe.iloc[522:3924:1]
    dataframe.rename(columns = {f'{city}' : f'{title}_Min'}, inplace = True)
    dataframe = dataframe.reset_index(drop=True)
    for x in dataframe.index:
        if x % 7 == 6:
            list = []
            minimum = 0
            for y in range(x-6,x+1,1):
                list.append(dataframe.iloc[y][f'{title}_Min'])
            minimum = findmin(list)
            dataframe.at[x,f'{title}_Min'] = minimum
    for x in dataframe.index:
        if x % 7 != 6:
            dataframe.drop(index= x, inplace=True)
    dataframe = dataframe.reset_index(drop=True)
    return dataframe
    
def DataPreprocess(city):
    virus_df = pd.read_csv('Data/virus.csv')
    virus_df['Date'] = pd.to_datetime(virus_df['Date'])
    virus_df['year'] = virus_df['Date'].apply(lambda date: date.year)
    virus_df['month'] = virus_df['Date'].apply(lambda date: date.month)
    virus_df_new = virus_df[['Date','month','year',f'{city}']]
    virus_df_new.rename(columns = {f'{city}' : f'Virus_Count_{city}'}, inplace = True)

    temp_df = pd.read_csv(f'Data/{city}_temp.csv')
    pressure_df = pd.read_csv(f'Data/{city}_pressure.csv')
    hours_df = pd.read_csv(f'Data/{city}_hours.csv')
    rainfall_df = pd.read_csv(f'Data/{city}_rainfall.csv')

    temp_df['Date'] = pd.to_datetime(temp_df['Date'])
    temp_df['year'] = temp_df['Date'].apply(lambda date: date.year)
    temp_df['month'] = temp_df['Date'].apply(lambda date: date.month)

    pressure_df['Date'] = pd.to_datetime(pressure_df['Date'])
    pressure_df['year'] = pressure_df['Date'].apply(lambda date: date.year)
    pressure_df['month'] = pressure_df['Date'].apply(lambda date: date.month)
    pressure_df = pressure_df.sort_values(by="Date")
    pressure_df = pressure_df.reset_index(drop=True)

    hours_df['Date'] = pd.to_datetime(hours_df['Date'])
    hours_df['year'] = hours_df['Date'].apply(lambda date: date.year)
    hours_df['month'] = hours_df['Date'].apply(lambda date: date.month)
    hours_df = hours_df.sort_values(by="Date")
    hours_df = hours_df.reset_index(drop=True)

    rainfall_df['Date'] = pd.to_datetime(rainfall_df['Date'])
    rainfall_df['year'] = rainfall_df['Date'].apply(lambda date: date.year)
    rainfall_df['month'] = rainfall_df['Date'].apply(lambda date: date.month)
    rainfall_df = rainfall_df.sort_values(by="Date")
    rainfall_df = rainfall_df.reset_index(drop=True)

    list = []
    for x in temp_df.index:
        t = temp_df.iloc[x][f'{city}']
        svp = 6.1078*10**(7.5*t/(t+237.3))
        e = pressure_df.iloc[x][f'{city}']
        h = e/svp*100
        list.append(h)
        
    humidity_df = pd.DataFrame(data=list)
    humidity_df.rename(columns = {0:f'{city}'}, inplace = True)
    
    max_temp_df = CreateMax(temp_df, 'Temperature',f'{city}')
    max_pressure_df = CreateMax(pressure_df, 'Pressure',f'{city}')
    max_hours_df = CreateMax(hours_df, 'Hours',f'{city}')
    max_rainfall_df = CreateMax(rainfall_df, 'Rainfall',f'{city}')
    max_humidity_df = CreateMax(humidity_df, 'Humidity',f'{city}')


    df = pd.concat([virus_df_new,max_temp_df,max_pressure_df,max_hours_df,max_rainfall_df,max_humidity_df], axis=1)
    
    df = df.loc[:,~df.columns.duplicated()]
    
    df['VirusCRM'] = df['Virus_Count_Tokyo'].rolling(14, center = True).mean()

    for i in df.index:
        if i == 0:
            df.at[i,'Gradient'] = 1
        else:
            if df.iloc[i-1]['VirusCRM'] == 0:
                if df.at[i,'VirusCDM'] > 0:
                    df.at[i,'Gradient'] = 1
                else:
                    df.at[i,'Gradient'] = 0
            else:
                grd = df.iloc[i]['VirusCRM']/(df.iloc[i-1]['VirusCRM'])
                df.at[i,'Gradient'] = grd
    
    for i in df.index:
        if (df.iloc[i]['Gradient'] >= 1.1) and (df.iloc[i+1]['Gradient'] >= 1.1) and (df.iloc[i+2]['Gradient'] >= 1.1):
            df.at[i,'Spreading'] = 1
        else:
            df.at[i,'Spreading'] = 0
    df = df.astype({'Spreading':'int8'})

    df_virus_count = df[f'Virus_Count_{city}']
    df.drop(columns=['VirusCRM',f'Virus_Count_{city}','year','Gradient'], axis=1, inplace=True)
    df_labels = df[['Date']]
    FUTURE_PREDICTION = 4
    for i in range(FUTURE_PREDICTION):
        df_labels[f"T+{(i+1)*7}"] = df_labels["Date"] + pd.DateOffset(days = (i+1)*7)
    temp = df[["Date", "Spreading"]]
    for i in range(FUTURE_PREDICTION):
        target_column = f"T+{(i+1)*7}"
        df_labels = df_labels.merge(temp, 
                                how ="left",
                                left_on = (target_column),
                                right_on=("Date"),
                                suffixes = ("","_y")
        )
        df_labels.rename(columns={"Spreading":f"{target_column}_Spreading"},inplace=True)
    df_labels.drop(columns=["Date_y"],inplace=True)

    for i in range(FUTURE_PREDICTION):
        df_labels.drop(columns =[f"T+{(i+1)*7}"],inplace=True,axis=1 )

    df = df.merge(df_labels,
             how='left',
             on = ["Date"])
    df.dropna(inplace=True)

    X = df.drop(columns=['T+7_Spreading','T+14_Spreading','T+21_Spreading','T+28_Spreading'],axis=1)
    y1 = df['T+21_Spreading']
    y2 = df['T+7_Spreading']
    y3 = df['T+14_Spreading']
    y4 = df['T+28_Spreading']

    return X, y1, y2, y3, y4, df, df_virus_count

# %%
X, y1, y2, y3, y4, df, df_virus_count = DataPreprocess('Tokyo')
# Out:
# /Users/miyanishio/opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py:5039: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(
# /var/folders/k5/3yc13bs57f7637937yjlstth0000gn/T/ipykernel_10325/3620082658.py:166: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_labels[f"T+{(i+1)*7}"] = df_labels["Date"] + pd.DateOffset(days = (i+1)*7)

# %%
X = X.drop(columns=['Date'])

# %%
X = X[0:400] #until 2020 05-04
y1 = y1[0:400]
y2 = y2[0:400]
y3 = y2[0:400]
y4 = y2[0:400]

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

scaler = StandardScaler()
scaler1 = StandardScaler()
X_train, X_test = X[0:280], X[280:400]
y1_train, y1_test = y1[0:280], y1[280:400]

# %%
scaled_X_train = scaler1.fit_transform(X_train)
scaled_X_test = scaler1.transform(X_test)

# %%
model = Sequential()

model.add(Dense(12,activation="sigmoid"))
model.add(Dense(6,activation="sigmoid"))
model.add(Dense(3,activation="sigmoid"))

model.add(Dense(1, activation='sigmoid'))
model.compile(optimizer='rmsprop',loss='binary_crossentropy',metrics=['accuracy'])
# Out:
# 2022-12-14 12:24:33.329739: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
early_stop = EarlyStopping(monitor='val_loss',mode='min',verbose=1,patience=50)

# %%
model.fit(scaled_X_train,y1_train,epochs=400,validation_data=(scaled_X_test,y1_test),callbacks=[early_stop])
# Out:
# Epoch 1/400
# 9/9 [==============================] - 2s 47ms/step - loss: 0.7544 - accuracy: 0.1643 - val_loss: 0.7549 - val_accuracy: 0.1000
# Epoch 2/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.7400 - accuracy: 0.1643 - val_loss: 0.7416 - val_accuracy: 0.1000
# Epoch 3/400
# 9/9 [==============================] - 0s 7ms/step - loss: 0.7292 - accuracy: 0.1643 - val_loss: 0.7296 - val_accuracy: 0.1000
# Epoch 4/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.7195 - accuracy: 0.1643 - val_loss: 0.7186 - val_accuracy: 0.1000
# Epoch 5/400
# 9/9 [==============================] - 0s 7ms/step - loss: 0.7103 - accuracy: 0.1643 - val_loss: 0.7078 - val_accuracy: 0.1000
# Epoch 6/400
# 9/9 [==============================] - 0s 11ms/step - loss: 0.7015 - accuracy: 0.1643 - val_loss: 0.6979 - val_accuracy: 0.1083
# Epoch 7/400
# 9/9 [==============================] - 0s 8ms/step - loss: 0.6931 - accuracy: 0.5071 - val_loss: 0.6877 - val_accuracy: 0.9000
# Epoch 8/400
# 9/9 [==============================] - 0s 9ms/step - loss: 0.6849 - accuracy: 0.8357 - val_loss: 0.6782 - val_accuracy: 0.9000
# Epoch 9/400
# 9/9 [==============================] - 0s 8ms/step - loss: 0.6771 - accuracy: 0.8357 - val_loss: 0.6689 - val_accuracy: 0.9000
# Epoch 10/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.6695 - accuracy: 0.8357 - val_loss: 0.6601 - val_accuracy: 0.9000
# Epoch 11/400
# 9/9 [==============================] - 0s 8ms/step - loss: 0.6621 - accuracy: 0.8357 - val_loss: 0.6511 - val_accuracy: 0.9000
# Epoch 12/400
# 9/9 [==============================] - 0s 8ms/step - loss: 0.6549 - accuracy: 0.8357 - val_loss: 0.6427 - val_accuracy: 0.9000
# Epoch 13/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.6480 - accuracy: 0.8357 - val_loss: 0.6343 - val_accuracy: 0.9000
# Epoch 14/400
# 9/9 [==============================] - 0s 7ms/step - loss: 0.6411 - accuracy: 0.8357 - val_loss: 0.6258 - val_accuracy: 0.9000
# Epoch 15/400
# 9/9 [==============================] - 0s 7ms/step - loss: 0.6342 - accuracy: 0.8357 - val_loss: 0.6174 - val_accuracy: 0.9000
# Epoch 16/400
# 9/9 [==============================] - 0s 7ms/step - loss: 0.6274 - accuracy: 0.8357 - val_loss: 0.6090 - val_accuracy: 0.9000
# Epoch 17/400
# 9/9 [==============================] - 0s 7ms/step - loss: 0.6208 - accuracy: 0.8357 - val_loss: 0.6010 - val_accuracy: 0.9000
# Epoch 18/400
# 9/9 [==============================] - 0s 11ms/step - loss: 0.6142 - accuracy: 0.8357 - val_loss: 0.5930 - val_accuracy: 0.9000
# Epoch 19/400
# 9/9 [==============================] - 0s 9ms/step - loss: 0.6078 - accuracy: 0.8357 - val_loss: 0.5852 - val_accuracy: 0.9000
# Epoch 20/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.6014 - accuracy: 0.8357 - val_loss: 0.5770 - val_accuracy: 0.9000
# Epoch 21/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.5950 - accuracy: 0.8357 - val_loss: 0.5691 - val_accuracy: 0.9000
# Epoch 22/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.5887 - accuracy: 0.8357 - val_loss: 0.5612 - val_accuracy: 0.9000
# Epoch 23/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.5825 - accuracy: 0.8357 - val_loss: 0.5534 - val_accuracy: 0.9000
# Epoch 24/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.5765 - accuracy: 0.8357 - val_loss: 0.5461 - val_accuracy: 0.9000
# Epoch 25/400
# 9/9 [==============================] - 0s 7ms/step - loss: 0.5707 - accuracy: 0.8357 - val_loss: 0.5389 - val_accuracy: 0.9000
# Epoch 26/400
# 9/9 [==============================] - 0s 9ms/step - loss: 0.5650 - accuracy: 0.8357 - val_loss: 0.5316 - val_accuracy: 0.9000
# Epoch 27/400
# 9/9 [==============================] - 0s 9ms/step - loss: 0.5595 - accuracy: 0.8357 - val_loss: 0.5245 - val_accuracy: 0.9000
# Epoch 28/400
# 9/9 [==============================] - 0s 7ms/step - loss: 0.5540 - accuracy: 0.8357 - val_loss: 0.5176 - val_accuracy: 0.9000
# Epoch 29/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.5488 - accuracy: 0.8357 - val_loss: 0.5108 - val_accuracy: 0.9000
# Epoch 30/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.5436 - accuracy: 0.8357 - val_loss: 0.5040 - val_accuracy: 0.9000
# Epoch 31/400
# 9/9 [==============================] - 0s 10ms/step - loss: 0.5386 - accuracy: 0.8357 - val_loss: 0.4978 - val_accuracy: 0.9000
# Epoch 32/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.5338 - accuracy: 0.8357 - val_loss: 0.4913 - val_accuracy: 0.9000
# Epoch 33/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.5291 - accuracy: 0.8357 - val_loss: 0.4852 - val_accuracy: 0.9000
# Epoch 34/400
# 9/9 [==============================] - 0s 7ms/step - loss: 0.5246 - accuracy: 0.8357 - val_loss: 0.4795 - val_accuracy: 0.9000
# Epoch 35/400
# 9/9 [==============================] - 0s 7ms/step - loss: 0.5203 - accuracy: 0.8357 - val_loss: 0.4734 - val_accuracy: 0.9000
# Epoch 36/400
# 9/9 [==============================] - 0s 10ms/step - loss: 0.5160 - accuracy: 0.8357 - val_loss: 0.4677 - val_accuracy: 0.9000
# Epoch 37/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.5117 - accuracy: 0.8357 - val_loss: 0.4617 - val_accuracy: 0.9000
# Epoch 38/400
# 9/9 [==============================] - 0s 11ms/step - loss: 0.5075 - accuracy: 0.8357 - val_loss: 0.4559 - val_accuracy: 0.9000
# Epoch 39/400
# 9/9 [==============================] - 0s 10ms/step - loss: 0.5034 - accuracy: 0.8357 - val_loss: 0.4503 - val_accuracy: 0.9000
# Epoch 40/400
# 9/9 [==============================] - 0s 10ms/step - loss: 0.4995 - accuracy: 0.8357 - val_loss: 0.4448 - val_accuracy: 0.9000
# Epoch 41/400
# 9/9 [==============================] - 0s 9ms/step - loss: 0.4957 - accuracy: 0.8357 - val_loss: 0.4396 - val_accuracy: 0.9000
# Epoch 42/400
# 9/9 [==============================] - 0s 14ms/step - loss: 0.4921 - accuracy: 0.8357 - val_loss: 0.4342 - val_accuracy: 0.9000
# Epoch 43/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.4885 - accuracy: 0.8357 - val_loss: 0.4291 - val_accuracy: 0.9000
# Epoch 44/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.4851 - accuracy: 0.8357 - val_loss: 0.4242 - val_accuracy: 0.9000
# Epoch 45/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.4818 - accuracy: 0.8357 - val_loss: 0.4194 - val_accuracy: 0.9000
# Epoch 46/400
# 9/9 [==============================] - 0s 9ms/step - loss: 0.4787 - accuracy: 0.8357 - val_loss: 0.4148 - val_accuracy: 0.9000
# Epoch 47/400
# 9/9 [==============================] - 0s 18ms/step - loss: 0.4758 - accuracy: 0.8357 - val_loss: 0.4103 - val_accuracy: 0.9000
# Epoch 48/400
# 9/9 [==============================] - 0s 7ms/step - loss: 0.4729 - accuracy: 0.8357 - val_loss: 0.4057 - val_accuracy: 0.9000
# Epoch 49/400
# 9/9 [==============================] - 0s 18ms/step - loss: 0.4701 - accuracy: 0.8357 - val_loss: 0.4016 - val_accuracy: 0.9000
# Epoch 50/400
# 9/9 [==============================] - 0s 8ms/step - loss: 0.4675 - accuracy: 0.8357 - val_loss: 0.3978 - val_accuracy: 0.9000
# Epoch 51/400
# 9/9 [==============================] - 0s 9ms/step - loss: 0.4651 - accuracy: 0.8357 - val_loss: 0.3937 - val_accuracy: 0.9000
# Epoch 52/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.4626 - accuracy: 0.8357 - val_loss: 0.3895 - val_accuracy: 0.9000
# Epoch 53/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.4603 - accuracy: 0.8357 - val_loss: 0.3858 - val_accuracy: 0.9000
# Epoch 54/400
# 9/9 [==============================] - 0s 10ms/step - loss: 0.4581 - accuracy: 0.8357 - val_loss: 0.3823 - val_accuracy: 0.9000
# Epoch 55/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.4562 - accuracy: 0.8357 - val_loss: 0.3794 - val_accuracy: 0.9000
# Epoch 56/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.4545 - accuracy: 0.8357 - val_loss: 0.3765 - val_accuracy: 0.9000
# Epoch 57/400
# 9/9 [==============================] - 0s 9ms/step - loss: 0.4528 - accuracy: 0.8357 - val_loss: 0.3736 - val_accuracy: 0.9000
# Epoch 58/400
# 9/9 [==============================] - 0s 8ms/step - loss: 0.4513 - accuracy: 0.8357 - val_loss: 0.3709 - val_accuracy: 0.9000
# Epoch 59/400
# 9/9 [==============================] - 0s 7ms/step - loss: 0.4496 - accuracy: 0.8357 - val_loss: 0.3681 - val_accuracy: 0.9000
# Epoch 60/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.4482 - accuracy: 0.8357 - val_loss: 0.3658 - val_accuracy: 0.9000
# Epoch 61/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.4468 - accuracy: 0.8357 - val_loss: 0.3635 - val_accuracy: 0.9000
# Epoch 62/400
# 9/9 [==============================] - 0s 11ms/step - loss: 0.4454 - accuracy: 0.8357 - val_loss: 0.3610 - val_accuracy: 0.9000
# Epoch 63/400
# 9/9 [==============================] - 0s 9ms/step - loss: 0.4441 - accuracy: 0.8357 - val_loss: 0.3590 - val_accuracy: 0.9000
# Epoch 64/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.4429 - accuracy: 0.8357 - val_loss: 0.3570 - val_accuracy: 0.9000
# Epoch 65/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.4416 - accuracy: 0.8357 - val_loss: 0.3551 - val_accuracy: 0.9000
# Epoch 66/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.4405 - accuracy: 0.8357 - val_loss: 0.3530 - val_accuracy: 0.9000
# Epoch 67/400
# 9/9 [==============================] - 0s 7ms/step - loss: 0.4393 - accuracy: 0.8357 - val_loss: 0.3513 - val_accuracy: 0.9000
# Epoch 68/400
# 9/9 [==============================] - 0s 9ms/step - loss: 0.4382 - accuracy: 0.8357 - val_loss: 0.3497 - val_accuracy: 0.9000
# Epoch 69/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.4371 - accuracy: 0.8357 - val_loss: 0.3481 - val_accuracy: 0.9000
# Epoch 70/400
# 9/9 [==============================] - 0s 9ms/step - loss: 0.4360 - accuracy: 0.8357 - val_loss: 0.3468 - val_accuracy: 0.9000
# Epoch 71/400
# 9/9 [==============================] - 0s 9ms/step - loss: 0.4350 - accuracy: 0.8357 - val_loss: 0.3455 - val_accuracy: 0.9000
# Epoch 72/400
# 9/9 [==============================] - 0s 7ms/step - loss: 0.4339 - accuracy: 0.8357 - val_loss: 0.3442 - val_accuracy: 0.9000
# Epoch 73/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.4330 - accuracy: 0.8357 - val_loss: 0.3427 - val_accuracy: 0.9000
# Epoch 74/400
# 9/9 [==============================] - 0s 8ms/step - loss: 0.4319 - accuracy: 0.8357 - val_loss: 0.3416 - val_accuracy: 0.9000
# Epoch 75/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.4309 - accuracy: 0.8357 - val_loss: 0.3405 - val_accuracy: 0.9000
# Epoch 76/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.4299 - accuracy: 0.8357 - val_loss: 0.3393 - val_accuracy: 0.9000
# Epoch 77/400
# 9/9 [==============================] - 0s 8ms/step - loss: 0.4288 - accuracy: 0.8357 - val_loss: 0.3381 - val_accuracy: 0.9000
# Epoch 78/400
# 9/9 [==============================] - 0s 8ms/step - loss: 0.4277 - accuracy: 0.8357 - val_loss: 0.3367 - val_accuracy: 0.9000
# Epoch 79/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.4267 - accuracy: 0.8357 - val_loss: 0.3360 - val_accuracy: 0.9000
# Epoch 80/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.4256 - accuracy: 0.8357 - val_loss: 0.3352 - val_accuracy: 0.9000
# Epoch 81/400
# 9/9 [==============================] - 0s 7ms/step - loss: 0.4246 - accuracy: 0.8357 - val_loss: 0.3343 - val_accuracy: 0.9000
# Epoch 82/400
# 9/9 [==============================] - 0s 8ms/step - loss: 0.4234 - accuracy: 0.8357 - val_loss: 0.3333 - val_accuracy: 0.9000
# Epoch 83/400
# 9/9 [==============================] - 0s 9ms/step - loss: 0.4224 - accuracy: 0.8357 - val_loss: 0.3323 - val_accuracy: 0.9000
# Epoch 84/400
# 9/9 [==============================] - 0s 7ms/step - loss: 0.4211 - accuracy: 0.8357 - val_loss: 0.3315 - val_accuracy: 0.9000
# Epoch 85/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.4198 - accuracy: 0.8357 - val_loss: 0.3305 - val_accuracy: 0.9000
# Epoch 86/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.4185 - accuracy: 0.8357 - val_loss: 0.3295 - val_accuracy: 0.9000
# Epoch 87/400
# 9/9 [==============================] - 0s 12ms/step - loss: 0.4173 - accuracy: 0.8357 - val_loss: 0.3287 - val_accuracy: 0.9000
# Epoch 88/400
# 9/9 [==============================] - 0s 9ms/step - loss: 0.4160 - accuracy: 0.8357 - val_loss: 0.3278 - val_accuracy: 0.9000
# Epoch 89/400
# 9/9 [==============================] - 0s 7ms/step - loss: 0.4147 - accuracy: 0.8357 - val_loss: 0.3268 - val_accuracy: 0.9000
# Epoch 90/400
# 9/9 [==============================] - 0s 7ms/step - loss: 0.4133 - accuracy: 0.8357 - val_loss: 0.3257 - val_accuracy: 0.9000
# Epoch 91/400
# 9/9 [==============================] - 0s 7ms/step - loss: 0.4118 - accuracy: 0.8357 - val_loss: 0.3248 - val_accuracy: 0.9000
# Epoch 92/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.4104 - accuracy: 0.8357 - val_loss: 0.3237 - val_accuracy: 0.9000
# Epoch 93/400
# 9/9 [==============================] - 0s 10ms/step - loss: 0.4089 - accuracy: 0.8357 - val_loss: 0.3228 - val_accuracy: 0.9000
# Epoch 94/400
# 9/9 [==============================] - 0s 7ms/step - loss: 0.4075 - accuracy: 0.8357 - val_loss: 0.3217 - val_accuracy: 0.9000
# Epoch 95/400
# 9/9 [==============================] - 0s 7ms/step - loss: 0.4062 - accuracy: 0.8357 - val_loss: 0.3208 - val_accuracy: 0.9000
# Epoch 96/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.4047 - accuracy: 0.8357 - val_loss: 0.3199 - val_accuracy: 0.9000
# Epoch 97/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.4035 - accuracy: 0.8357 - val_loss: 0.3191 - val_accuracy: 0.9000
# Epoch 98/400
# 9/9 [==============================] - 0s 7ms/step - loss: 0.4020 - accuracy: 0.8357 - val_loss: 0.3184 - val_accuracy: 0.9000
# Epoch 99/400
# 9/9 [==============================] - 0s 8ms/step - loss: 0.4005 - accuracy: 0.8357 - val_loss: 0.3173 - val_accuracy: 0.9000
# Epoch 100/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.3991 - accuracy: 0.8357 - val_loss: 0.3163 - val_accuracy: 0.9000
# Epoch 101/400
# 9/9 [==============================] - 0s 7ms/step - loss: 0.3975 - accuracy: 0.8357 - val_loss: 0.3151 - val_accuracy: 0.9000
# Epoch 102/400
# 9/9 [==============================] - 0s 8ms/step - loss: 0.3961 - accuracy: 0.8357 - val_loss: 0.3141 - val_accuracy: 0.9000
# Epoch 103/400
# 9/9 [==============================] - 0s 10ms/step - loss: 0.3947 - accuracy: 0.8357 - val_loss: 0.3133 - val_accuracy: 0.9000
# Epoch 104/400
# 9/9 [==============================] - 0s 10ms/step - loss: 0.3933 - accuracy: 0.8357 - val_loss: 0.3125 - val_accuracy: 0.9000
# Epoch 105/400
# 9/9 [==============================] - 0s 7ms/step - loss: 0.3918 - accuracy: 0.8357 - val_loss: 0.3115 - val_accuracy: 0.9000
# Epoch 106/400
# 9/9 [==============================] - 0s 8ms/step - loss: 0.3903 - accuracy: 0.8357 - val_loss: 0.3106 - val_accuracy: 0.9000
# Epoch 107/400
# 9/9 [==============================] - 0s 9ms/step - loss: 0.3887 - accuracy: 0.8357 - val_loss: 0.3097 - val_accuracy: 0.9000
# Epoch 108/400
# 9/9 [==============================] - 0s 7ms/step - loss: 0.3870 - accuracy: 0.8357 - val_loss: 0.3087 - val_accuracy: 0.9000
# Epoch 109/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.3853 - accuracy: 0.8357 - val_loss: 0.3075 - val_accuracy: 0.9000
# Epoch 110/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.3835 - accuracy: 0.8357 - val_loss: 0.3065 - val_accuracy: 0.9000
# Epoch 111/400
# 9/9 [==============================] - 0s 7ms/step - loss: 0.3819 - accuracy: 0.8357 - val_loss: 0.3055 - val_accuracy: 0.9000
# Epoch 112/400
# 9/9 [==============================] - 0s 12ms/step - loss: 0.3804 - accuracy: 0.8357 - val_loss: 0.3045 - val_accuracy: 0.9000
# Epoch 113/400
# 9/9 [==============================] - 0s 7ms/step - loss: 0.3789 - accuracy: 0.8357 - val_loss: 0.3037 - val_accuracy: 0.9000
# Epoch 114/400
# 9/9 [==============================] - 0s 10ms/step - loss: 0.3774 - accuracy: 0.8357 - val_loss: 0.3028 - val_accuracy: 0.9000
# Epoch 115/400
# 9/9 [==============================] - 0s 10ms/step - loss: 0.3759 - accuracy: 0.8357 - val_loss: 0.3018 - val_accuracy: 0.9000
# Epoch 116/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.3745 - accuracy: 0.8357 - val_loss: 0.3008 - val_accuracy: 0.9000
# Epoch 117/400
# 9/9 [==============================] - 0s 8ms/step - loss: 0.3729 - accuracy: 0.8357 - val_loss: 0.3000 - val_accuracy: 0.9000
# Epoch 118/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.3715 - accuracy: 0.8357 - val_loss: 0.2992 - val_accuracy: 0.9000
# Epoch 119/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.3699 - accuracy: 0.8357 - val_loss: 0.2982 - val_accuracy: 0.9000
# Epoch 120/400
# 9/9 [==============================] - 0s 7ms/step - loss: 0.3682 - accuracy: 0.8357 - val_loss: 0.2973 - val_accuracy: 0.9000
# Epoch 121/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.3667 - accuracy: 0.8357 - val_loss: 0.2963 - val_accuracy: 0.9000
# Epoch 122/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.3651 - accuracy: 0.8357 - val_loss: 0.2953 - val_accuracy: 0.9000
# Epoch 123/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.3635 - accuracy: 0.8357 - val_loss: 0.2944 - val_accuracy: 0.9000
# Epoch 124/400
# 9/9 [==============================] - 0s 8ms/step - loss: 0.3619 - accuracy: 0.8357 - val_loss: 0.2933 - val_accuracy: 0.9000
# Epoch 125/400
# 9/9 [==============================] - 0s 10ms/step - loss: 0.3605 - accuracy: 0.8357 - val_loss: 0.2923 - val_accuracy: 0.9000
# Epoch 126/400
# 9/9 [==============================] - 0s 7ms/step - loss: 0.3589 - accuracy: 0.8357 - val_loss: 0.2912 - val_accuracy: 0.9000
# Epoch 127/400
# 9/9 [==============================] - 0s 7ms/step - loss: 0.3573 - accuracy: 0.8357 - val_loss: 0.2906 - val_accuracy: 0.9000
# Epoch 128/400
# 9/9 [==============================] - 0s 10ms/step - loss: 0.3559 - accuracy: 0.8357 - val_loss: 0.2897 - val_accuracy: 0.9000
# Epoch 129/400
# 9/9 [==============================] - 0s 8ms/step - loss: 0.3544 - accuracy: 0.8357 - val_loss: 0.2886 - val_accuracy: 0.9000
# Epoch 130/400
# 9/9 [==============================] - 0s 9ms/step - loss: 0.3530 - accuracy: 0.8357 - val_loss: 0.2877 - val_accuracy: 0.9000
# Epoch 131/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.3516 - accuracy: 0.8357 - val_loss: 0.2870 - val_accuracy: 0.9000
# Epoch 132/400
# 9/9 [==============================] - 0s 9ms/step - loss: 0.3501 - accuracy: 0.8357 - val_loss: 0.2861 - val_accuracy: 0.9000
# Epoch 133/400
# 9/9 [==============================] - 0s 7ms/step - loss: 0.3486 - accuracy: 0.8357 - val_loss: 0.2850 - val_accuracy: 0.9000
# Epoch 134/400
# 9/9 [==============================] - 0s 9ms/step - loss: 0.3472 - accuracy: 0.8357 - val_loss: 0.2841 - val_accuracy: 0.9000
# Epoch 135/400
# 9/9 [==============================] - 0s 9ms/step - loss: 0.3457 - accuracy: 0.8357 - val_loss: 0.2834 - val_accuracy: 0.9000
# Epoch 136/400
# 9/9 [==============================] - 0s 7ms/step - loss: 0.3442 - accuracy: 0.8357 - val_loss: 0.2823 - val_accuracy: 0.9000
# Epoch 137/400
# 9/9 [==============================] - 0s 10ms/step - loss: 0.3429 - accuracy: 0.8357 - val_loss: 0.2814 - val_accuracy: 0.9000
# Epoch 138/400
# 9/9 [==============================] - 0s 7ms/step - loss: 0.3415 - accuracy: 0.8357 - val_loss: 0.2806 - val_accuracy: 0.9000
# Epoch 139/400
# 9/9 [==============================] - 0s 8ms/step - loss: 0.3402 - accuracy: 0.8357 - val_loss: 0.2799 - val_accuracy: 0.9000
# Epoch 140/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.3388 - accuracy: 0.8357 - val_loss: 0.2790 - val_accuracy: 0.9000
# Epoch 141/400
# 9/9 [==============================] - 0s 8ms/step - loss: 0.3375 - accuracy: 0.8357 - val_loss: 0.2780 - val_accuracy: 0.9000
# Epoch 142/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.3361 - accuracy: 0.8357 - val_loss: 0.2773 - val_accuracy: 0.9000
# Epoch 143/400
# 9/9 [==============================] - 0s 7ms/step - loss: 0.3349 - accuracy: 0.8357 - val_loss: 0.2766 - val_accuracy: 0.9000
# Epoch 144/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.3335 - accuracy: 0.8357 - val_loss: 0.2759 - val_accuracy: 0.9000
# Epoch 145/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.3324 - accuracy: 0.8357 - val_loss: 0.2750 - val_accuracy: 0.9000
# Epoch 146/400
# 9/9 [==============================] - 0s 8ms/step - loss: 0.3312 - accuracy: 0.8357 - val_loss: 0.2742 - val_accuracy: 0.9000
# Epoch 147/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.3302 - accuracy: 0.8357 - val_loss: 0.2736 - val_accuracy: 0.9000
# Epoch 148/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.3291 - accuracy: 0.8357 - val_loss: 0.2728 - val_accuracy: 0.9000
# Epoch 149/400
# 9/9 [==============================] - 0s 8ms/step - loss: 0.3280 - accuracy: 0.8357 - val_loss: 0.2722 - val_accuracy: 0.9000
# Epoch 150/400
# 9/9 [==============================] - 0s 7ms/step - loss: 0.3267 - accuracy: 0.8357 - val_loss: 0.2716 - val_accuracy: 0.9000
# Epoch 151/400
# 9/9 [==============================] - 0s 7ms/step - loss: 0.3257 - accuracy: 0.8357 - val_loss: 0.2709 - val_accuracy: 0.9000
# Epoch 152/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.3245 - accuracy: 0.8357 - val_loss: 0.2703 - val_accuracy: 0.9000
# Epoch 153/400
# 9/9 [==============================] - 0s 7ms/step - loss: 0.3234 - accuracy: 0.8357 - val_loss: 0.2696 - val_accuracy: 0.9000
# Epoch 154/400
# 9/9 [==============================] - 0s 7ms/step - loss: 0.3223 - accuracy: 0.8357 - val_loss: 0.2689 - val_accuracy: 0.9000
# Epoch 155/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.3213 - accuracy: 0.8357 - val_loss: 0.2682 - val_accuracy: 0.9000
# Epoch 156/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.3202 - accuracy: 0.8357 - val_loss: 0.2675 - val_accuracy: 0.9000
# Epoch 157/400
# 9/9 [==============================] - 0s 7ms/step - loss: 0.3192 - accuracy: 0.8357 - val_loss: 0.2669 - val_accuracy: 0.9000
# Epoch 158/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.3184 - accuracy: 0.8357 - val_loss: 0.2664 - val_accuracy: 0.9000
# Epoch 159/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.3173 - accuracy: 0.8357 - val_loss: 0.2658 - val_accuracy: 0.9000
# Epoch 160/400
# 9/9 [==============================] - 0s 11ms/step - loss: 0.3165 - accuracy: 0.8357 - val_loss: 0.2652 - val_accuracy: 0.9000
# Epoch 161/400
# 9/9 [==============================] - 0s 11ms/step - loss: 0.3157 - accuracy: 0.8357 - val_loss: 0.2648 - val_accuracy: 0.9000
# Epoch 162/400
# 9/9 [==============================] - 0s 15ms/step - loss: 0.3146 - accuracy: 0.8357 - val_loss: 0.2641 - val_accuracy: 0.9000
# Epoch 163/400
# 9/9 [==============================] - 0s 9ms/step - loss: 0.3139 - accuracy: 0.8357 - val_loss: 0.2635 - val_accuracy: 0.9000
# Epoch 164/400
# 9/9 [==============================] - 0s 7ms/step - loss: 0.3130 - accuracy: 0.8357 - val_loss: 0.2631 - val_accuracy: 0.9000
# Epoch 165/400
# 9/9 [==============================] - 0s 7ms/step - loss: 0.3121 - accuracy: 0.8357 - val_loss: 0.2626 - val_accuracy: 0.9000
# Epoch 166/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.3114 - accuracy: 0.8357 - val_loss: 0.2621 - val_accuracy: 0.9000
# Epoch 167/400
# 9/9 [==============================] - 0s 9ms/step - loss: 0.3105 - accuracy: 0.8357 - val_loss: 0.2616 - val_accuracy: 0.9000
# Epoch 168/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.3097 - accuracy: 0.8357 - val_loss: 0.2612 - val_accuracy: 0.9000
# Epoch 169/400
# 9/9 [==============================] - 0s 7ms/step - loss: 0.3089 - accuracy: 0.8357 - val_loss: 0.2606 - val_accuracy: 0.9000
# Epoch 170/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.3081 - accuracy: 0.8357 - val_loss: 0.2600 - val_accuracy: 0.9000
# Epoch 171/400
# 9/9 [==============================] - 0s 9ms/step - loss: 0.3075 - accuracy: 0.8357 - val_loss: 0.2596 - val_accuracy: 0.9000
# Epoch 172/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.3066 - accuracy: 0.8357 - val_loss: 0.2591 - val_accuracy: 0.9000
# Epoch 173/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.3059 - accuracy: 0.8357 - val_loss: 0.2586 - val_accuracy: 0.9000
# Epoch 174/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.3051 - accuracy: 0.8357 - val_loss: 0.2580 - val_accuracy: 0.9000
# Epoch 175/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.3045 - accuracy: 0.8357 - val_loss: 0.2574 - val_accuracy: 0.9000
# Epoch 176/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.3038 - accuracy: 0.8357 - val_loss: 0.2571 - val_accuracy: 0.9000
# Epoch 177/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.3032 - accuracy: 0.8357 - val_loss: 0.2567 - val_accuracy: 0.9000
# Epoch 178/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.3024 - accuracy: 0.8357 - val_loss: 0.2561 - val_accuracy: 0.9000
# Epoch 179/400
# 9/9 [==============================] - 0s 12ms/step - loss: 0.3017 - accuracy: 0.8357 - val_loss: 0.2558 - val_accuracy: 0.9000
# Epoch 180/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.3010 - accuracy: 0.8357 - val_loss: 0.2554 - val_accuracy: 0.9000
# Epoch 181/400
# 9/9 [==============================] - 0s 10ms/step - loss: 0.3004 - accuracy: 0.8357 - val_loss: 0.2550 - val_accuracy: 0.9000
# Epoch 182/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.2998 - accuracy: 0.8357 - val_loss: 0.2546 - val_accuracy: 0.9000
# Epoch 183/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.2990 - accuracy: 0.8357 - val_loss: 0.2542 - val_accuracy: 0.9000
# Epoch 184/400
# 9/9 [==============================] - 0s 11ms/step - loss: 0.2983 - accuracy: 0.8357 - val_loss: 0.2539 - val_accuracy: 0.9000
# Epoch 185/400
# 9/9 [==============================] - 0s 8ms/step - loss: 0.2979 - accuracy: 0.8357 - val_loss: 0.2535 - val_accuracy: 0.9000
# Epoch 186/400
# 9/9 [==============================] - 0s 7ms/step - loss: 0.2971 - accuracy: 0.8357 - val_loss: 0.2531 - val_accuracy: 0.9000
# Epoch 187/400
# 9/9 [==============================] - 0s 8ms/step - loss: 0.2966 - accuracy: 0.8357 - val_loss: 0.2527 - val_accuracy: 0.9000
# Epoch 188/400
# 9/9 [==============================] - 0s 7ms/step - loss: 0.2960 - accuracy: 0.8357 - val_loss: 0.2524 - val_accuracy: 0.9000
# Epoch 189/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.2953 - accuracy: 0.8357 - val_loss: 0.2522 - val_accuracy: 0.9000
# Epoch 190/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.2949 - accuracy: 0.8357 - val_loss: 0.2517 - val_accuracy: 0.9000
# Epoch 191/400
# 9/9 [==============================] - 0s 9ms/step - loss: 0.2942 - accuracy: 0.8357 - val_loss: 0.2512 - val_accuracy: 0.9000
# Epoch 192/400
# 9/9 [==============================] - 0s 8ms/step - loss: 0.2939 - accuracy: 0.8357 - val_loss: 0.2507 - val_accuracy: 0.9000
# Epoch 193/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.2931 - accuracy: 0.8357 - val_loss: 0.2504 - val_accuracy: 0.9000
# Epoch 194/400
# 9/9 [==============================] - 0s 9ms/step - loss: 0.2926 - accuracy: 0.8357 - val_loss: 0.2502 - val_accuracy: 0.9000
# Epoch 195/400
# 9/9 [==============================] - 0s 8ms/step - loss: 0.2923 - accuracy: 0.8357 - val_loss: 0.2500 - val_accuracy: 0.9000
# Epoch 196/400
# 9/9 [==============================] - 0s 7ms/step - loss: 0.2915 - accuracy: 0.8357 - val_loss: 0.2497 - val_accuracy: 0.9000
# Epoch 197/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.2911 - accuracy: 0.8357 - val_loss: 0.2491 - val_accuracy: 0.9000
# Epoch 198/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.2906 - accuracy: 0.8357 - val_loss: 0.2488 - val_accuracy: 0.9000
# Epoch 199/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.2899 - accuracy: 0.8357 - val_loss: 0.2484 - val_accuracy: 0.9000
# Epoch 200/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.2896 - accuracy: 0.8357 - val_loss: 0.2480 - val_accuracy: 0.9000
# Epoch 201/400
# 9/9 [==============================] - 0s 7ms/step - loss: 0.2891 - accuracy: 0.8357 - val_loss: 0.2478 - val_accuracy: 0.9000
# Epoch 202/400
# 9/9 [==============================] - 0s 13ms/step - loss: 0.2884 - accuracy: 0.8357 - val_loss: 0.2476 - val_accuracy: 0.9000
# Epoch 203/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.2880 - accuracy: 0.8357 - val_loss: 0.2477 - val_accuracy: 0.9000
# Epoch 204/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.2876 - accuracy: 0.8357 - val_loss: 0.2474 - val_accuracy: 0.9000
# Epoch 205/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.2870 - accuracy: 0.8357 - val_loss: 0.2469 - val_accuracy: 0.9000
# Epoch 206/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.2866 - accuracy: 0.8357 - val_loss: 0.2466 - val_accuracy: 0.9000
# Epoch 207/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.2863 - accuracy: 0.8357 - val_loss: 0.2463 - val_accuracy: 0.9000
# Epoch 208/400
# 9/9 [==============================] - 0s 7ms/step - loss: 0.2856 - accuracy: 0.8357 - val_loss: 0.2461 - val_accuracy: 0.9000
# Epoch 209/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.2851 - accuracy: 0.8357 - val_loss: 0.2456 - val_accuracy: 0.9000
# Epoch 210/400
# 9/9 [==============================] - 0s 8ms/step - loss: 0.2850 - accuracy: 0.8357 - val_loss: 0.2452 - val_accuracy: 0.9000
# Epoch 211/400
# 9/9 [==============================] - 0s 7ms/step - loss: 0.2842 - accuracy: 0.8357 - val_loss: 0.2448 - val_accuracy: 0.9000
# Epoch 212/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.2837 - accuracy: 0.8357 - val_loss: 0.2446 - val_accuracy: 0.9000
# Epoch 213/400
# 9/9 [==============================] - 0s 13ms/step - loss: 0.2833 - accuracy: 0.8357 - val_loss: 0.2442 - val_accuracy: 0.9000
# Epoch 214/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.2829 - accuracy: 0.8357 - val_loss: 0.2439 - val_accuracy: 0.9000
# Epoch 215/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.2825 - accuracy: 0.8357 - val_loss: 0.2435 - val_accuracy: 0.9000
# Epoch 216/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.2822 - accuracy: 0.8357 - val_loss: 0.2434 - val_accuracy: 0.9000
# Epoch 217/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.2816 - accuracy: 0.8357 - val_loss: 0.2431 - val_accuracy: 0.9000
# Epoch 218/400
# 9/9 [==============================] - 0s 10ms/step - loss: 0.2813 - accuracy: 0.8357 - val_loss: 0.2428 - val_accuracy: 0.9000
# Epoch 219/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.2808 - accuracy: 0.8357 - val_loss: 0.2427 - val_accuracy: 0.9000
# Epoch 220/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.2804 - accuracy: 0.8357 - val_loss: 0.2423 - val_accuracy: 0.9000
# Epoch 221/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.2798 - accuracy: 0.8357 - val_loss: 0.2421 - val_accuracy: 0.9000
# Epoch 222/400
# 9/9 [==============================] - 0s 9ms/step - loss: 0.2797 - accuracy: 0.8357 - val_loss: 0.2419 - val_accuracy: 0.9000
# Epoch 223/400
# 9/9 [==============================] - 0s 10ms/step - loss: 0.2789 - accuracy: 0.8357 - val_loss: 0.2416 - val_accuracy: 0.9000
# Epoch 224/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.2786 - accuracy: 0.8357 - val_loss: 0.2413 - val_accuracy: 0.9000
# Epoch 225/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.2781 - accuracy: 0.8357 - val_loss: 0.2412 - val_accuracy: 0.9000
# Epoch 226/400
# 9/9 [==============================] - 0s 7ms/step - loss: 0.2779 - accuracy: 0.8357 - val_loss: 0.2410 - val_accuracy: 0.9000
# Epoch 227/400
# 9/9 [==============================] - 0s 10ms/step - loss: 0.2775 - accuracy: 0.8357 - val_loss: 0.2408 - val_accuracy: 0.9000
# Epoch 228/400
# 9/9 [==============================] - 0s 8ms/step - loss: 0.2769 - accuracy: 0.8357 - val_loss: 0.2406 - val_accuracy: 0.9000
# Epoch 229/400
# 9/9 [==============================] - 0s 7ms/step - loss: 0.2766 - accuracy: 0.8357 - val_loss: 0.2402 - val_accuracy: 0.9000
# Epoch 230/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.2763 - accuracy: 0.8357 - val_loss: 0.2401 - val_accuracy: 0.9000
# Epoch 231/400
# 9/9 [==============================] - 0s 9ms/step - loss: 0.2759 - accuracy: 0.8357 - val_loss: 0.2398 - val_accuracy: 0.9000
# Epoch 232/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.2755 - accuracy: 0.8357 - val_loss: 0.2395 - val_accuracy: 0.9000
# Epoch 233/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.2753 - accuracy: 0.8357 - val_loss: 0.2393 - val_accuracy: 0.9000
# Epoch 234/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.2747 - accuracy: 0.8357 - val_loss: 0.2391 - val_accuracy: 0.9000
# Epoch 235/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.2743 - accuracy: 0.8357 - val_loss: 0.2389 - val_accuracy: 0.9000
# Epoch 236/400
# 9/9 [==============================] - 0s 9ms/step - loss: 0.2739 - accuracy: 0.8357 - val_loss: 0.2388 - val_accuracy: 0.9000
# Epoch 237/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.2736 - accuracy: 0.8357 - val_loss: 0.2384 - val_accuracy: 0.9000
# Epoch 238/400
# 9/9 [==============================] - 0s 10ms/step - loss: 0.2734 - accuracy: 0.8357 - val_loss: 0.2381 - val_accuracy: 0.9000
# Epoch 239/400
# 9/9 [==============================] - 0s 10ms/step - loss: 0.2729 - accuracy: 0.8357 - val_loss: 0.2382 - val_accuracy: 0.9000
# Epoch 240/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.2726 - accuracy: 0.8357 - val_loss: 0.2378 - val_accuracy: 0.9000
# Epoch 241/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.2722 - accuracy: 0.8357 - val_loss: 0.2378 - val_accuracy: 0.9000
# Epoch 242/400
# 9/9 [==============================] - 0s 7ms/step - loss: 0.2718 - accuracy: 0.8357 - val_loss: 0.2375 - val_accuracy: 0.9000
# Epoch 243/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.2714 - accuracy: 0.8357 - val_loss: 0.2372 - val_accuracy: 0.9000
# Epoch 244/400
# 9/9 [==============================] - 0s 7ms/step - loss: 0.2711 - accuracy: 0.8357 - val_loss: 0.2368 - val_accuracy: 0.9000
# Epoch 245/400
# 9/9 [==============================] - 0s 9ms/step - loss: 0.2708 - accuracy: 0.8357 - val_loss: 0.2367 - val_accuracy: 0.9000
# Epoch 246/400
# 9/9 [==============================] - 0s 7ms/step - loss: 0.2702 - accuracy: 0.8357 - val_loss: 0.2365 - val_accuracy: 0.9000
# Epoch 247/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.2702 - accuracy: 0.8357 - val_loss: 0.2361 - val_accuracy: 0.9000
# Epoch 248/400
# 9/9 [==============================] - 0s 15ms/step - loss: 0.2696 - accuracy: 0.8357 - val_loss: 0.2357 - val_accuracy: 0.9000
# Epoch 249/400
# 9/9 [==============================] - 0s 9ms/step - loss: 0.2695 - accuracy: 0.8357 - val_loss: 0.2356 - val_accuracy: 0.9000
# Epoch 250/400
# 9/9 [==============================] - 0s 8ms/step - loss: 0.2692 - accuracy: 0.8357 - val_loss: 0.2354 - val_accuracy: 0.9000
# Epoch 251/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.2687 - accuracy: 0.8357 - val_loss: 0.2351 - val_accuracy: 0.9000
# Epoch 252/400
# 9/9 [==============================] - 0s 9ms/step - loss: 0.2684 - accuracy: 0.8357 - val_loss: 0.2352 - val_accuracy: 0.9000
# Epoch 253/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.2681 - accuracy: 0.8357 - val_loss: 0.2348 - val_accuracy: 0.9000
# Epoch 254/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2676 - accuracy: 0.8357 - val_loss: 0.2347 - val_accuracy: 0.9000
# Epoch 255/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.2674 - accuracy: 0.8357 - val_loss: 0.2344 - val_accuracy: 0.9000
# Epoch 256/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.2671 - accuracy: 0.8357 - val_loss: 0.2344 - val_accuracy: 0.9000
# Epoch 257/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2667 - accuracy: 0.8357 - val_loss: 0.2344 - val_accuracy: 0.9000
# Epoch 258/400
# 9/9 [==============================] - 0s 3ms/step - loss: 0.2666 - accuracy: 0.8357 - val_loss: 0.2337 - val_accuracy: 0.9000
# Epoch 259/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2662 - accuracy: 0.8357 - val_loss: 0.2335 - val_accuracy: 0.9000
# Epoch 260/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2656 - accuracy: 0.8357 - val_loss: 0.2335 - val_accuracy: 0.9000
# Epoch 261/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2654 - accuracy: 0.8357 - val_loss: 0.2332 - val_accuracy: 0.9000
# Epoch 262/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2650 - accuracy: 0.8357 - val_loss: 0.2329 - val_accuracy: 0.9000
# Epoch 263/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2650 - accuracy: 0.8357 - val_loss: 0.2326 - val_accuracy: 0.9000
# Epoch 264/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2644 - accuracy: 0.8357 - val_loss: 0.2327 - val_accuracy: 0.9000
# Epoch 265/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2642 - accuracy: 0.8357 - val_loss: 0.2324 - val_accuracy: 0.9000
# Epoch 266/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2638 - accuracy: 0.8357 - val_loss: 0.2322 - val_accuracy: 0.9000
# Epoch 267/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2634 - accuracy: 0.8357 - val_loss: 0.2322 - val_accuracy: 0.9000
# Epoch 268/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2637 - accuracy: 0.8357 - val_loss: 0.2313 - val_accuracy: 0.9000
# Epoch 269/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2628 - accuracy: 0.8357 - val_loss: 0.2310 - val_accuracy: 0.9000
# Epoch 270/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2628 - accuracy: 0.8357 - val_loss: 0.2308 - val_accuracy: 0.9000
# Epoch 271/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2623 - accuracy: 0.8357 - val_loss: 0.2311 - val_accuracy: 0.9000
# Epoch 272/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.2619 - accuracy: 0.8357 - val_loss: 0.2307 - val_accuracy: 0.9000
# Epoch 273/400
# 9/9 [==============================] - 0s 3ms/step - loss: 0.2617 - accuracy: 0.8357 - val_loss: 0.2306 - val_accuracy: 0.9000
# Epoch 274/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2615 - accuracy: 0.8357 - val_loss: 0.2303 - val_accuracy: 0.9000
# Epoch 275/400
# 9/9 [==============================] - 0s 7ms/step - loss: 0.2613 - accuracy: 0.8357 - val_loss: 0.2301 - val_accuracy: 0.9000
# Epoch 276/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2608 - accuracy: 0.8357 - val_loss: 0.2298 - val_accuracy: 0.9000
# Epoch 277/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2603 - accuracy: 0.8357 - val_loss: 0.2295 - val_accuracy: 0.9000
# Epoch 278/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2603 - accuracy: 0.8357 - val_loss: 0.2297 - val_accuracy: 0.9000
# Epoch 279/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.2601 - accuracy: 0.8357 - val_loss: 0.2294 - val_accuracy: 0.9000
# Epoch 280/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.2594 - accuracy: 0.8357 - val_loss: 0.2291 - val_accuracy: 0.9000
# Epoch 281/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.2594 - accuracy: 0.8357 - val_loss: 0.2289 - val_accuracy: 0.9000
# Epoch 282/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2589 - accuracy: 0.8357 - val_loss: 0.2288 - val_accuracy: 0.9000
# Epoch 283/400
# 9/9 [==============================] - 0s 7ms/step - loss: 0.2587 - accuracy: 0.8357 - val_loss: 0.2290 - val_accuracy: 0.9000
# Epoch 284/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2584 - accuracy: 0.8357 - val_loss: 0.2288 - val_accuracy: 0.9000
# Epoch 285/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.2582 - accuracy: 0.8357 - val_loss: 0.2285 - val_accuracy: 0.9000
# Epoch 286/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2578 - accuracy: 0.8357 - val_loss: 0.2284 - val_accuracy: 0.9000
# Epoch 287/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2577 - accuracy: 0.8357 - val_loss: 0.2279 - val_accuracy: 0.9000
# Epoch 288/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2573 - accuracy: 0.8357 - val_loss: 0.2274 - val_accuracy: 0.9000
# Epoch 289/400
# 9/9 [==============================] - 0s 3ms/step - loss: 0.2569 - accuracy: 0.8357 - val_loss: 0.2273 - val_accuracy: 0.9000
# Epoch 290/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2566 - accuracy: 0.8357 - val_loss: 0.2276 - val_accuracy: 0.9000
# Epoch 291/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2564 - accuracy: 0.8357 - val_loss: 0.2276 - val_accuracy: 0.9000
# Epoch 292/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2560 - accuracy: 0.8357 - val_loss: 0.2274 - val_accuracy: 0.9000
# Epoch 293/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2561 - accuracy: 0.8357 - val_loss: 0.2266 - val_accuracy: 0.9000
# Epoch 294/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2555 - accuracy: 0.8357 - val_loss: 0.2263 - val_accuracy: 0.9000
# Epoch 295/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2553 - accuracy: 0.8357 - val_loss: 0.2264 - val_accuracy: 0.9000
# Epoch 296/400
# 9/9 [==============================] - 0s 3ms/step - loss: 0.2550 - accuracy: 0.8357 - val_loss: 0.2263 - val_accuracy: 0.9000
# Epoch 297/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2549 - accuracy: 0.8357 - val_loss: 0.2260 - val_accuracy: 0.9000
# Epoch 298/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2544 - accuracy: 0.8357 - val_loss: 0.2254 - val_accuracy: 0.9000
# Epoch 299/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.2543 - accuracy: 0.8357 - val_loss: 0.2255 - val_accuracy: 0.8917
# Epoch 300/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2541 - accuracy: 0.8500 - val_loss: 0.2253 - val_accuracy: 0.8917
# Epoch 301/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.2535 - accuracy: 0.8857 - val_loss: 0.2249 - val_accuracy: 0.8917
# Epoch 302/400
# 9/9 [==============================] - 0s 3ms/step - loss: 0.2533 - accuracy: 0.8964 - val_loss: 0.2248 - val_accuracy: 0.9083
# Epoch 303/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2530 - accuracy: 0.8929 - val_loss: 0.2244 - val_accuracy: 0.9083
# Epoch 304/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2529 - accuracy: 0.8929 - val_loss: 0.2239 - val_accuracy: 0.9083
# Epoch 305/400
# 9/9 [==============================] - 0s 3ms/step - loss: 0.2526 - accuracy: 0.8964 - val_loss: 0.2238 - val_accuracy: 0.9083
# Epoch 306/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2521 - accuracy: 0.8964 - val_loss: 0.2235 - val_accuracy: 0.9083
# Epoch 307/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.2522 - accuracy: 0.8929 - val_loss: 0.2233 - val_accuracy: 0.9083
# Epoch 308/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2516 - accuracy: 0.8929 - val_loss: 0.2234 - val_accuracy: 0.9000
# Epoch 309/400
# 9/9 [==============================] - 0s 3ms/step - loss: 0.2514 - accuracy: 0.8929 - val_loss: 0.2231 - val_accuracy: 0.9000
# Epoch 310/400
# 9/9 [==============================] - 0s 3ms/step - loss: 0.2512 - accuracy: 0.8929 - val_loss: 0.2230 - val_accuracy: 0.9000
# Epoch 311/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2508 - accuracy: 0.8929 - val_loss: 0.2226 - val_accuracy: 0.9000
# Epoch 312/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2504 - accuracy: 0.8929 - val_loss: 0.2224 - val_accuracy: 0.9000
# Epoch 313/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2500 - accuracy: 0.8929 - val_loss: 0.2220 - val_accuracy: 0.9000
# Epoch 314/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2498 - accuracy: 0.8893 - val_loss: 0.2214 - val_accuracy: 0.9000
# Epoch 315/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.2500 - accuracy: 0.8893 - val_loss: 0.2209 - val_accuracy: 0.9000
# Epoch 316/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2493 - accuracy: 0.8893 - val_loss: 0.2209 - val_accuracy: 0.9000
# Epoch 317/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2490 - accuracy: 0.8893 - val_loss: 0.2206 - val_accuracy: 0.9000
# Epoch 318/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2489 - accuracy: 0.8893 - val_loss: 0.2202 - val_accuracy: 0.9000
# Epoch 319/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.2484 - accuracy: 0.8893 - val_loss: 0.2200 - val_accuracy: 0.9000
# Epoch 320/400
# 9/9 [==============================] - 0s 7ms/step - loss: 0.2482 - accuracy: 0.8857 - val_loss: 0.2202 - val_accuracy: 0.9000
# Epoch 321/400
# 9/9 [==============================] - 0s 7ms/step - loss: 0.2479 - accuracy: 0.8857 - val_loss: 0.2199 - val_accuracy: 0.9000
# Epoch 322/400
# 9/9 [==============================] - 0s 3ms/step - loss: 0.2477 - accuracy: 0.8857 - val_loss: 0.2196 - val_accuracy: 0.9000
# Epoch 323/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2479 - accuracy: 0.8857 - val_loss: 0.2194 - val_accuracy: 0.9000
# Epoch 324/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2470 - accuracy: 0.8857 - val_loss: 0.2196 - val_accuracy: 0.9000
# Epoch 325/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.2471 - accuracy: 0.8857 - val_loss: 0.2194 - val_accuracy: 0.9000
# Epoch 326/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.2466 - accuracy: 0.8857 - val_loss: 0.2192 - val_accuracy: 0.9000
# Epoch 327/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.2464 - accuracy: 0.8893 - val_loss: 0.2186 - val_accuracy: 0.9000
# Epoch 328/400
# 9/9 [==============================] - 0s 3ms/step - loss: 0.2461 - accuracy: 0.8857 - val_loss: 0.2179 - val_accuracy: 0.9000
# Epoch 329/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2460 - accuracy: 0.8857 - val_loss: 0.2176 - val_accuracy: 0.9000
# Epoch 330/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2459 - accuracy: 0.8893 - val_loss: 0.2174 - val_accuracy: 0.9000
# Epoch 331/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2455 - accuracy: 0.8893 - val_loss: 0.2174 - val_accuracy: 0.9000
# Epoch 332/400
# 9/9 [==============================] - 0s 3ms/step - loss: 0.2455 - accuracy: 0.8893 - val_loss: 0.2171 - val_accuracy: 0.9000
# Epoch 333/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2449 - accuracy: 0.8893 - val_loss: 0.2169 - val_accuracy: 0.9000
# Epoch 334/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2448 - accuracy: 0.8893 - val_loss: 0.2168 - val_accuracy: 0.9000
# Epoch 335/400
# 9/9 [==============================] - 0s 3ms/step - loss: 0.2447 - accuracy: 0.8893 - val_loss: 0.2165 - val_accuracy: 0.9000
# Epoch 336/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2443 - accuracy: 0.8893 - val_loss: 0.2168 - val_accuracy: 0.9000
# Epoch 337/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2440 - accuracy: 0.8893 - val_loss: 0.2161 - val_accuracy: 0.9000
# Epoch 338/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2438 - accuracy: 0.8893 - val_loss: 0.2158 - val_accuracy: 0.9000
# Epoch 339/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.2436 - accuracy: 0.8893 - val_loss: 0.2157 - val_accuracy: 0.9000
# Epoch 340/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2434 - accuracy: 0.8893 - val_loss: 0.2154 - val_accuracy: 0.9000
# Epoch 341/400
# 9/9 [==============================] - 0s 3ms/step - loss: 0.2432 - accuracy: 0.8893 - val_loss: 0.2151 - val_accuracy: 0.9000
# Epoch 342/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2434 - accuracy: 0.8893 - val_loss: 0.2145 - val_accuracy: 0.9000
# Epoch 343/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2427 - accuracy: 0.8893 - val_loss: 0.2143 - val_accuracy: 0.9000
# Epoch 344/400
# 9/9 [==============================] - 0s 3ms/step - loss: 0.2427 - accuracy: 0.8857 - val_loss: 0.2143 - val_accuracy: 0.9000
# Epoch 345/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2424 - accuracy: 0.8857 - val_loss: 0.2141 - val_accuracy: 0.9000
# Epoch 346/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2421 - accuracy: 0.8857 - val_loss: 0.2138 - val_accuracy: 0.9000
# Epoch 347/400
# 9/9 [==============================] - 0s 3ms/step - loss: 0.2420 - accuracy: 0.8857 - val_loss: 0.2137 - val_accuracy: 0.9000
# Epoch 348/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2417 - accuracy: 0.8857 - val_loss: 0.2134 - val_accuracy: 0.9000
# Epoch 349/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2418 - accuracy: 0.8857 - val_loss: 0.2129 - val_accuracy: 0.9000
# Epoch 350/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2414 - accuracy: 0.8857 - val_loss: 0.2127 - val_accuracy: 0.9000
# Epoch 351/400
# 9/9 [==============================] - 0s 7ms/step - loss: 0.2412 - accuracy: 0.8857 - val_loss: 0.2123 - val_accuracy: 0.9000
# Epoch 352/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2408 - accuracy: 0.8857 - val_loss: 0.2125 - val_accuracy: 0.9000
# Epoch 353/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.2407 - accuracy: 0.8857 - val_loss: 0.2125 - val_accuracy: 0.9000
# Epoch 354/400
# 9/9 [==============================] - 0s 20ms/step - loss: 0.2402 - accuracy: 0.8857 - val_loss: 0.2124 - val_accuracy: 0.9000
# Epoch 355/400
# 9/9 [==============================] - 0s 8ms/step - loss: 0.2403 - accuracy: 0.8857 - val_loss: 0.2121 - val_accuracy: 0.9000
# Epoch 356/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.2401 - accuracy: 0.8857 - val_loss: 0.2115 - val_accuracy: 0.9000
# Epoch 357/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.2397 - accuracy: 0.8857 - val_loss: 0.2111 - val_accuracy: 0.9000
# Epoch 358/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.2398 - accuracy: 0.8857 - val_loss: 0.2110 - val_accuracy: 0.9000
# Epoch 359/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2393 - accuracy: 0.8857 - val_loss: 0.2111 - val_accuracy: 0.9000
# Epoch 360/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2392 - accuracy: 0.8857 - val_loss: 0.2109 - val_accuracy: 0.9000
# Epoch 361/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2388 - accuracy: 0.8857 - val_loss: 0.2104 - val_accuracy: 0.9000
# Epoch 362/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2387 - accuracy: 0.8857 - val_loss: 0.2105 - val_accuracy: 0.9000
# Epoch 363/400
# 9/9 [==============================] - 0s 3ms/step - loss: 0.2384 - accuracy: 0.8857 - val_loss: 0.2101 - val_accuracy: 0.9000
# Epoch 364/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.2384 - accuracy: 0.8857 - val_loss: 0.2101 - val_accuracy: 0.9000
# Epoch 365/400
# 9/9 [==============================] - 0s 7ms/step - loss: 0.2380 - accuracy: 0.8857 - val_loss: 0.2104 - val_accuracy: 0.9000
# Epoch 366/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.2378 - accuracy: 0.8857 - val_loss: 0.2104 - val_accuracy: 0.9000
# Epoch 367/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.2375 - accuracy: 0.8857 - val_loss: 0.2099 - val_accuracy: 0.9000
# Epoch 368/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.2374 - accuracy: 0.8857 - val_loss: 0.2096 - val_accuracy: 0.9000
# Epoch 369/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.2372 - accuracy: 0.8857 - val_loss: 0.2095 - val_accuracy: 0.9000
# Epoch 370/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.2369 - accuracy: 0.8857 - val_loss: 0.2090 - val_accuracy: 0.9000
# Epoch 371/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.2367 - accuracy: 0.8857 - val_loss: 0.2086 - val_accuracy: 0.9000
# Epoch 372/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2365 - accuracy: 0.8857 - val_loss: 0.2086 - val_accuracy: 0.9000
# Epoch 373/400
# 9/9 [==============================] - 0s 19ms/step - loss: 0.2363 - accuracy: 0.8857 - val_loss: 0.2081 - val_accuracy: 0.9000
# Epoch 374/400
# 9/9 [==============================] - 0s 7ms/step - loss: 0.2360 - accuracy: 0.8857 - val_loss: 0.2080 - val_accuracy: 0.9000
# Epoch 375/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.2359 - accuracy: 0.8857 - val_loss: 0.2078 - val_accuracy: 0.9083
# Epoch 376/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.2361 - accuracy: 0.8857 - val_loss: 0.2076 - val_accuracy: 0.9083
# Epoch 377/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2353 - accuracy: 0.8857 - val_loss: 0.2076 - val_accuracy: 0.9083
# Epoch 378/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2352 - accuracy: 0.8857 - val_loss: 0.2075 - val_accuracy: 0.9083
# Epoch 379/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2354 - accuracy: 0.8857 - val_loss: 0.2074 - val_accuracy: 0.9083
# Epoch 380/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2350 - accuracy: 0.8857 - val_loss: 0.2072 - val_accuracy: 0.9083
# Epoch 381/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2347 - accuracy: 0.8857 - val_loss: 0.2070 - val_accuracy: 0.9083
# Epoch 382/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2344 - accuracy: 0.8857 - val_loss: 0.2064 - val_accuracy: 0.9083
# Epoch 383/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2343 - accuracy: 0.8857 - val_loss: 0.2059 - val_accuracy: 0.9083
# Epoch 384/400
# 9/9 [==============================] - 0s 7ms/step - loss: 0.2343 - accuracy: 0.8857 - val_loss: 0.2053 - val_accuracy: 0.9083
# Epoch 385/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.2341 - accuracy: 0.8857 - val_loss: 0.2053 - val_accuracy: 0.9083
# Epoch 386/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2340 - accuracy: 0.8857 - val_loss: 0.2053 - val_accuracy: 0.9000
# Epoch 387/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2336 - accuracy: 0.8857 - val_loss: 0.2054 - val_accuracy: 0.9000
# Epoch 388/400
# 9/9 [==============================] - 0s 3ms/step - loss: 0.2336 - accuracy: 0.8857 - val_loss: 0.2054 - val_accuracy: 0.9000
# Epoch 389/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2332 - accuracy: 0.8857 - val_loss: 0.2055 - val_accuracy: 0.9000
# Epoch 390/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.2329 - accuracy: 0.8857 - val_loss: 0.2050 - val_accuracy: 0.9000
# Epoch 391/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.2329 - accuracy: 0.8857 - val_loss: 0.2046 - val_accuracy: 0.9000
# Epoch 392/400
# 9/9 [==============================] - 0s 3ms/step - loss: 0.2329 - accuracy: 0.8857 - val_loss: 0.2041 - val_accuracy: 0.9000
# Epoch 393/400
# 9/9 [==============================] - 0s 9ms/step - loss: 0.2327 - accuracy: 0.8857 - val_loss: 0.2035 - val_accuracy: 0.9000
# Epoch 394/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2323 - accuracy: 0.8857 - val_loss: 0.2034 - val_accuracy: 0.9000
# Epoch 395/400
# 9/9 [==============================] - 0s 3ms/step - loss: 0.2324 - accuracy: 0.8857 - val_loss: 0.2034 - val_accuracy: 0.9000
# Epoch 396/400
# 9/9 [==============================] - 0s 3ms/step - loss: 0.2318 - accuracy: 0.8857 - val_loss: 0.2034 - val_accuracy: 0.9000
# Epoch 397/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2319 - accuracy: 0.8857 - val_loss: 0.2034 - val_accuracy: 0.9000
# Epoch 398/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2316 - accuracy: 0.8857 - val_loss: 0.2029 - val_accuracy: 0.9000
# Epoch 399/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2314 - accuracy: 0.8857 - val_loss: 0.2031 - val_accuracy: 0.9000
# Epoch 400/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2314 - accuracy: 0.8857 - val_loss: 0.2025 - val_accuracy: 0.9000

# %%
predictions = model.predict(scaled_X_test)

# %%
preds = []
for x in predictions:
    if x >= 0.5:
        preds.append(1)
    else:
        preds.append(0)

# %%
from sklearn.metrics import classification_report,confusion_matrix

# %%
print(classification_report(y1_test,preds))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.95      0.94      0.94       108
#          1.0       0.50      0.58      0.54        12
#
#     accuracy                           0.90       120
#    macro avg       0.73      0.76      0.74       120
# weighted avg       0.91      0.90      0.90       120
