# %% [markdown]
# ## DNN Mean + Max
# Took out data from 2020-2021, 2021-2022. (Used mean and maximum weather data)

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
# %matplotlib inline
from statistics import mean
from statistics import mean
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.callbacks import EarlyStopping

# %%
import seaborn as sns
import numpy as np
import pandas as pd
from statistics import mean
import math

FUTURE_PREDICTION = 4

def findmax(x):
    maximum = 0
    for number in x:
        maximum = max(x)
    return maximum

def findmean(x):
    m = 0
    m = mean(x)
    return m

def findmin(x):
    m = 0
    m = min(x)
    return m

def CreateMean(dataframe,title,city):

    dataframe = dataframe.iloc[522:3924:1]
    dataframe.rename(columns = {f'{city}' : f'{title}_Mean'}, inplace = True)
    dataframe = dataframe.reset_index(drop=True)
    for x in dataframe.index:
        if x % 7 == 6:
            list = []
            mean = 0
            for y in range(x-6,x+1,1):
                list.append(dataframe.iloc[y][f'{title}_Mean'])
            mean = findmean(list)
            dataframe.at[x,f'{title}_Mean'] = mean
    for x in dataframe.index:
        if x % 7 != 6:
            dataframe.drop(index= x, inplace=True)
    dataframe = dataframe.reset_index(drop=True)
    return dataframe

def CreateMax(dataframe,title,city):

    dataframe = dataframe.iloc[522:3924:1]
    dataframe.rename(columns = {f'{city}' : f'{title}_Max'}, inplace = True)
    dataframe = dataframe.reset_index(drop=True)
    for x in dataframe.index:
        if x % 7 == 6:
            list = []
            maximum = 0
            for y in range(x-6,x+1,1):
                list.append(dataframe.iloc[y][f'{title}_Max'])
            maximum = findmax(list)
            dataframe.at[x,f'{title}_Max'] = maximum
    for x in dataframe.index:
        if x % 7 != 6:
            dataframe.drop(index= x, inplace=True)
    dataframe = dataframe.reset_index(drop=True)
    return dataframe

def CreateMin(dataframe,title,city):

    dataframe = dataframe.iloc[522:3924:1]
    dataframe.rename(columns = {f'{city}' : f'{title}_Min'}, inplace = True)
    dataframe = dataframe.reset_index(drop=True)
    for x in dataframe.index:
        if x % 7 == 6:
            list = []
            minimum = 0
            for y in range(x-6,x+1,1):
                list.append(dataframe.iloc[y][f'{title}_Min'])
            minimum = findmin(list)
            dataframe.at[x,f'{title}_Min'] = minimum
    for x in dataframe.index:
        if x % 7 != 6:
            dataframe.drop(index= x, inplace=True)
    dataframe = dataframe.reset_index(drop=True)
    return dataframe
    
def DataPreprocess(city):
    virus_df = pd.read_csv('Data/virus.csv')
    virus_df['Date'] = pd.to_datetime(virus_df['Date'])
    virus_df['year'] = virus_df['Date'].apply(lambda date: date.year)
    virus_df['month'] = virus_df['Date'].apply(lambda date: date.month)
    virus_df_new = virus_df[['Date','month','year',f'{city}']]
    virus_df_new.rename(columns = {f'{city}' : f'Virus_Count_{city}'}, inplace = True)

    temp_df = pd.read_csv(f'Data/{city}_temp.csv')
    pressure_df = pd.read_csv(f'Data/{city}_pressure.csv')
    hours_df = pd.read_csv(f'Data/{city}_hours.csv')
    rainfall_df = pd.read_csv(f'Data/{city}_rainfall.csv')

    temp_df['Date'] = pd.to_datetime(temp_df['Date'])
    temp_df['year'] = temp_df['Date'].apply(lambda date: date.year)
    temp_df['month'] = temp_df['Date'].apply(lambda date: date.month)

    pressure_df['Date'] = pd.to_datetime(pressure_df['Date'])
    pressure_df['year'] = pressure_df['Date'].apply(lambda date: date.year)
    pressure_df['month'] = pressure_df['Date'].apply(lambda date: date.month)
    pressure_df = pressure_df.sort_values(by="Date")
    pressure_df = pressure_df.reset_index(drop=True)

    hours_df['Date'] = pd.to_datetime(hours_df['Date'])
    hours_df['year'] = hours_df['Date'].apply(lambda date: date.year)
    hours_df['month'] = hours_df['Date'].apply(lambda date: date.month)
    hours_df = hours_df.sort_values(by="Date")
    hours_df = hours_df.reset_index(drop=True)

    rainfall_df['Date'] = pd.to_datetime(rainfall_df['Date'])
    rainfall_df['year'] = rainfall_df['Date'].apply(lambda date: date.year)
    rainfall_df['month'] = rainfall_df['Date'].apply(lambda date: date.month)
    rainfall_df = rainfall_df.sort_values(by="Date")
    rainfall_df = rainfall_df.reset_index(drop=True)
    
    list = []
    for x in temp_df.index:
        t = temp_df.iloc[x][f'{city}']
        svp = 6.1078*10**(7.5*t/(t+237.3))
        e = pressure_df.iloc[x][f'{city}']
        h = e/svp*100
        list.append(h)
        
    humidity_df = pd.DataFrame(data=list)
    humidity_df.rename(columns = {0:f'{city}'}, inplace = True)

    mean_temp_df = CreateMean(temp_df, 'Temperature',f'{city}')
    mean_pressure_df = CreateMean(pressure_df, 'Pressure',f'{city}')
    mean_hours_df = CreateMean(hours_df, 'Hours',f'{city}')
    mean_rainfall_df = CreateMean(rainfall_df, 'Rainfall',f'{city}')
    mean_humidity_df = CreateMean(humidity_df, 'Humidity',f'{city}')
    
    max_temp_df = CreateMax(temp_df, 'Temperature',f'{city}')
    max_pressure_df = CreateMax(pressure_df, 'Pressure',f'{city}')
    max_hours_df = CreateMax(hours_df, 'Hours',f'{city}')
    max_rainfall_df = CreateMax(rainfall_df, 'Rainfall',f'{city}')
    max_humidity_df = CreateMax(humidity_df, 'Humidity',f'{city}')
    

    df = pd.concat([virus_df_new,mean_humidity_df,mean_temp_df,mean_pressure_df,mean_hours_df,mean_rainfall_df,max_temp_df,max_pressure_df,max_hours_df,max_rainfall_df,max_humidity_df], axis=1)
    df = df.loc[:,~df.columns.duplicated()]

    df['VirusCRM'] = df['Virus_Count_Tokyo'].rolling(14, center = True).mean()

    for i in df.index:
        if i == 0:
            df.at[i,'Gradient'] = 1
        else:
            if df.iloc[i-1]['VirusCRM'] == 0:
                if df.at[i,'VirusCDM'] > 0:
                    df.at[i,'Gradient'] = 1
                else:
                    df.at[i,'Gradient'] = 0
            else:
                grd = df.iloc[i]['VirusCRM']/(df.iloc[i-1]['VirusCRM'])
                df.at[i,'Gradient'] = grd
    
    for i in df.index:
        if (df.iloc[i]['Gradient'] >= 1.1) and (df.iloc[i+1]['Gradient'] >= 1.1) and (df.iloc[i+2]['Gradient'] >= 1.1):
            df.at[i,'Spreading'] = 1
        else:
            df.at[i,'Spreading'] = 0
    df = df.astype({'Spreading':'int8'})

    df_virus_count = df[f'Virus_Count_{city}']
    df.drop(columns=['year','Gradient','VirusCRM',f'Virus_Count_{city}'], axis=1, inplace=True)
    df_labels = df[['Date']]
    FUTURE_PREDICTION = 4
    for i in range(FUTURE_PREDICTION):
        df_labels[f"T+{(i+1)*7}"] = df_labels["Date"] + pd.DateOffset(days = (i+1)*7)
    temp = df[["Date", "Spreading"]]
    for i in range(FUTURE_PREDICTION):
        target_column = f"T+{(i+1)*7}"
        df_labels = df_labels.merge(temp, 
                                how ="left",
                                left_on = (target_column),
                                right_on=("Date"),
                                suffixes = ("","_y")
        )
        df_labels.rename(columns={"Spreading":f"{target_column}_Spreading"},inplace=True)
    df_labels.drop(columns=["Date_y"],inplace=True)

    for i in range(FUTURE_PREDICTION):
        df_labels.drop(columns =[f"T+{(i+1)*7}"],inplace=True,axis=1 )

    df = df.merge(df_labels,
             how='left',
             on = ["Date"])
    df.dropna(inplace=True)

    X = df.drop(columns=['T+7_Spreading','T+14_Spreading','T+21_Spreading','T+28_Spreading'],axis=1)
    y1 = df['T+21_Spreading']
    y2 = df['T+7_Spreading']
    y3 = df['T+14_Spreading']
    y4 = df['T+28_Spreading']

    return X, y1, y2, y3, y4, df, df_virus_count

# %%
X, y1, y2, y3, y4, df, df_virus_count = DataPreprocess('Tokyo')
# Out:
# /Users/miyanishio/opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py:5039: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(
# /var/folders/k5/3yc13bs57f7637937yjlstth0000gn/T/ipykernel_10297/684746323.py:171: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_labels[f"T+{(i+1)*7}"] = df_labels["Date"] + pd.DateOffset(days = (i+1)*7)

# %%
X[0:400]
# Out:
#           Date  month  Humidity_Mean  Temperature_Mean  Pressure_Mean  \
# 0   2012-09-10      9      71.007732         28.085714      26.942857
# 1   2012-09-17      9      67.730487         28.414286      26.200000
# 2   2012-09-24      9      78.780351         24.685714      24.600000
# 3   2012-10-01     10      69.795654         23.314286      20.128571
# 4   2012-10-08     10      74.175200         21.942857      19.657143
# ..         ...    ...            ...               ...            ...
# 395 2020-04-06      4      63.967539         12.271429       9.014286
# 396 2020-04-13      4      63.265454         11.557143       8.471429
# 397 2020-04-20      4      68.356621         12.300000       9.728571
# 398 2020-04-27      4      62.859690         13.657143       9.857143
# 399 2020-05-04      5      72.876093         17.985714      15.142857
#
#      Hours_Mean  Rainfall_Mean  Temperature_Max  Pressure_Max  Hours_Max  \
# 0      6.928571       0.928571             28.9          28.0       10.2
# 1      8.257143       1.714286             28.8          29.2       11.4
# 2      3.614286      19.285714             28.0          29.2        9.5
# 3      4.928571       2.928571             26.9          24.7       11.1
# 4      3.928571       9.214286             24.0          23.1        7.4
# ..          ...            ...              ...           ...        ...
# 395    6.542857       4.428571             15.7          13.1       11.9
# 396    6.914286      19.928571             14.3          10.5       11.7
# 397    6.228571      15.285714             14.7          14.3       11.8
# 398    6.671429       2.000000             18.3          13.2       12.5
# 399    8.800000       1.000000             20.7          19.4       12.2
#
#      Rainfall_Max  Humidity_Max  Spreading
# 0             4.5     77.172701          0
# 1             8.5     77.708924          0
# 2            45.5     89.425667          0
# 3            13.0     79.695709          0
# 4            30.0     82.331696          0
# ..            ...           ...        ...
# 395          31.0     97.184900          0
# 396         132.0     97.882723          0
# 397          89.5     96.108231          0
# 398          12.5     81.513563          0
# 399           5.0     86.658140          0
#
# [400 rows x 13 columns]

# %%
X = X.drop(columns=['Date'])

# %%
X = X[0:400] #until 2020 05-04
y1 = y1[0:400]
y2 = y2[0:400]
y3 = y2[0:400]
y4 = y2[0:400]

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

scaler = StandardScaler()
scaler1 = StandardScaler()
X_train, X_test = X[0:280], X[280:400]
y1_train, y1_test = y1[0:280], y1[280:400]

# %%
scaled_X_train = scaler1.fit_transform(X_train)
scaled_X_test = scaler1.transform(X_test)

# %%
model = Sequential()

model.add(Dense(12,activation="sigmoid"))
model.add(Dense(6,activation="sigmoid"))
model.add(Dense(3,activation="sigmoid"))

model.add(Dense(1, activation='sigmoid'))
model.compile(optimizer='rmsprop',loss='binary_crossentropy',metrics=['accuracy'])
# Out:
# 2022-12-14 12:22:17.186808: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
early_stop = EarlyStopping(monitor='val_loss',mode='min',verbose=1,patience=50)

# %%
model.fit(scaled_X_train,y1_train,epochs=400,validation_data=(scaled_X_test,y1_test),callbacks=[early_stop])
# Out:
# Epoch 1/400
# 9/9 [==============================] - 1s 33ms/step - loss: 0.5045 - accuracy: 0.8357 - val_loss: 0.4475 - val_accuracy: 0.9000
# Epoch 2/400
# 9/9 [==============================] - 0s 8ms/step - loss: 0.4958 - accuracy: 0.8357 - val_loss: 0.4378 - val_accuracy: 0.9000
# Epoch 3/400
# 9/9 [==============================] - 0s 9ms/step - loss: 0.4894 - accuracy: 0.8357 - val_loss: 0.4298 - val_accuracy: 0.9000
# Epoch 4/400
# 9/9 [==============================] - 0s 9ms/step - loss: 0.4839 - accuracy: 0.8357 - val_loss: 0.4223 - val_accuracy: 0.9000
# Epoch 5/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.4786 - accuracy: 0.8357 - val_loss: 0.4148 - val_accuracy: 0.9000
# Epoch 6/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.4737 - accuracy: 0.8357 - val_loss: 0.4079 - val_accuracy: 0.9000
# Epoch 7/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.4692 - accuracy: 0.8357 - val_loss: 0.4016 - val_accuracy: 0.9000
# Epoch 8/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.4651 - accuracy: 0.8357 - val_loss: 0.3957 - val_accuracy: 0.9000
# Epoch 9/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.4614 - accuracy: 0.8357 - val_loss: 0.3903 - val_accuracy: 0.9000
# Epoch 10/400
# 9/9 [==============================] - 0s 7ms/step - loss: 0.4578 - accuracy: 0.8357 - val_loss: 0.3846 - val_accuracy: 0.9000
# Epoch 11/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.4544 - accuracy: 0.8357 - val_loss: 0.3799 - val_accuracy: 0.9000
# Epoch 12/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.4513 - accuracy: 0.8357 - val_loss: 0.3749 - val_accuracy: 0.9000
# Epoch 13/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.4484 - accuracy: 0.8357 - val_loss: 0.3711 - val_accuracy: 0.9000
# Epoch 14/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.4458 - accuracy: 0.8357 - val_loss: 0.3673 - val_accuracy: 0.9000
# Epoch 15/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.4432 - accuracy: 0.8357 - val_loss: 0.3630 - val_accuracy: 0.9000
# Epoch 16/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.4408 - accuracy: 0.8357 - val_loss: 0.3599 - val_accuracy: 0.9000
# Epoch 17/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.4387 - accuracy: 0.8357 - val_loss: 0.3569 - val_accuracy: 0.9000
# Epoch 18/400
# 9/9 [==============================] - 0s 7ms/step - loss: 0.4366 - accuracy: 0.8357 - val_loss: 0.3542 - val_accuracy: 0.9000
# Epoch 19/400
# 9/9 [==============================] - 0s 7ms/step - loss: 0.4347 - accuracy: 0.8357 - val_loss: 0.3516 - val_accuracy: 0.9000
# Epoch 20/400
# 9/9 [==============================] - 0s 10ms/step - loss: 0.4329 - accuracy: 0.8357 - val_loss: 0.3493 - val_accuracy: 0.9000
# Epoch 21/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.4310 - accuracy: 0.8357 - val_loss: 0.3471 - val_accuracy: 0.9000
# Epoch 22/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.4293 - accuracy: 0.8357 - val_loss: 0.3450 - val_accuracy: 0.9000
# Epoch 23/400
# 9/9 [==============================] - 0s 7ms/step - loss: 0.4274 - accuracy: 0.8357 - val_loss: 0.3429 - val_accuracy: 0.9000
# Epoch 24/400
# 9/9 [==============================] - 0s 9ms/step - loss: 0.4255 - accuracy: 0.8357 - val_loss: 0.3409 - val_accuracy: 0.9000
# Epoch 25/400
# 9/9 [==============================] - 0s 8ms/step - loss: 0.4235 - accuracy: 0.8357 - val_loss: 0.3386 - val_accuracy: 0.9000
# Epoch 26/400
# 9/9 [==============================] - 0s 8ms/step - loss: 0.4214 - accuracy: 0.8357 - val_loss: 0.3367 - val_accuracy: 0.9000
# Epoch 27/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.4194 - accuracy: 0.8357 - val_loss: 0.3348 - val_accuracy: 0.9000
# Epoch 28/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.4174 - accuracy: 0.8357 - val_loss: 0.3332 - val_accuracy: 0.9000
# Epoch 29/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.4155 - accuracy: 0.8357 - val_loss: 0.3313 - val_accuracy: 0.9000
# Epoch 30/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.4136 - accuracy: 0.8357 - val_loss: 0.3299 - val_accuracy: 0.9000
# Epoch 31/400
# 9/9 [==============================] - 0s 7ms/step - loss: 0.4117 - accuracy: 0.8357 - val_loss: 0.3284 - val_accuracy: 0.9000
# Epoch 32/400
# 9/9 [==============================] - 0s 11ms/step - loss: 0.4098 - accuracy: 0.8357 - val_loss: 0.3269 - val_accuracy: 0.9000
# Epoch 33/400
# 9/9 [==============================] - 0s 8ms/step - loss: 0.4078 - accuracy: 0.8357 - val_loss: 0.3256 - val_accuracy: 0.9000
# Epoch 34/400
# 9/9 [==============================] - 0s 7ms/step - loss: 0.4057 - accuracy: 0.8357 - val_loss: 0.3241 - val_accuracy: 0.9000
# Epoch 35/400
# 9/9 [==============================] - 0s 11ms/step - loss: 0.4037 - accuracy: 0.8357 - val_loss: 0.3228 - val_accuracy: 0.9000
# Epoch 36/400
# 9/9 [==============================] - 0s 11ms/step - loss: 0.4016 - accuracy: 0.8357 - val_loss: 0.3215 - val_accuracy: 0.9000
# Epoch 37/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.3994 - accuracy: 0.8357 - val_loss: 0.3199 - val_accuracy: 0.9000
# Epoch 38/400
# 9/9 [==============================] - 0s 7ms/step - loss: 0.3974 - accuracy: 0.8357 - val_loss: 0.3183 - val_accuracy: 0.9000
# Epoch 39/400
# 9/9 [==============================] - 0s 9ms/step - loss: 0.3953 - accuracy: 0.8357 - val_loss: 0.3168 - val_accuracy: 0.9000
# Epoch 40/400
# 9/9 [==============================] - 0s 7ms/step - loss: 0.3935 - accuracy: 0.8357 - val_loss: 0.3155 - val_accuracy: 0.9000
# Epoch 41/400
# 9/9 [==============================] - 0s 10ms/step - loss: 0.3914 - accuracy: 0.8357 - val_loss: 0.3143 - val_accuracy: 0.9000
# Epoch 42/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.3895 - accuracy: 0.8357 - val_loss: 0.3131 - val_accuracy: 0.9000
# Epoch 43/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.3874 - accuracy: 0.8357 - val_loss: 0.3118 - val_accuracy: 0.9000
# Epoch 44/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.3853 - accuracy: 0.8357 - val_loss: 0.3103 - val_accuracy: 0.9000
# Epoch 45/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.3831 - accuracy: 0.8357 - val_loss: 0.3090 - val_accuracy: 0.9000
# Epoch 46/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.3809 - accuracy: 0.8357 - val_loss: 0.3075 - val_accuracy: 0.9000
# Epoch 47/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.3787 - accuracy: 0.8357 - val_loss: 0.3063 - val_accuracy: 0.9000
# Epoch 48/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.3765 - accuracy: 0.8357 - val_loss: 0.3049 - val_accuracy: 0.9000
# Epoch 49/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.3743 - accuracy: 0.8357 - val_loss: 0.3035 - val_accuracy: 0.9000
# Epoch 50/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.3720 - accuracy: 0.8357 - val_loss: 0.3023 - val_accuracy: 0.9000
# Epoch 51/400
# 9/9 [==============================] - 0s 3ms/step - loss: 0.3698 - accuracy: 0.8357 - val_loss: 0.3011 - val_accuracy: 0.9000
# Epoch 52/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.3676 - accuracy: 0.8357 - val_loss: 0.2999 - val_accuracy: 0.9000
# Epoch 53/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.3655 - accuracy: 0.8357 - val_loss: 0.2985 - val_accuracy: 0.9000
# Epoch 54/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.3635 - accuracy: 0.8357 - val_loss: 0.2972 - val_accuracy: 0.9000
# Epoch 55/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.3613 - accuracy: 0.8357 - val_loss: 0.2960 - val_accuracy: 0.9000
# Epoch 56/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.3592 - accuracy: 0.8357 - val_loss: 0.2946 - val_accuracy: 0.9000
# Epoch 57/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.3570 - accuracy: 0.8357 - val_loss: 0.2935 - val_accuracy: 0.9000
# Epoch 58/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.3549 - accuracy: 0.8357 - val_loss: 0.2924 - val_accuracy: 0.9000
# Epoch 59/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.3529 - accuracy: 0.8357 - val_loss: 0.2913 - val_accuracy: 0.9000
# Epoch 60/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.3510 - accuracy: 0.8357 - val_loss: 0.2904 - val_accuracy: 0.9000
# Epoch 61/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.3492 - accuracy: 0.8357 - val_loss: 0.2894 - val_accuracy: 0.9000
# Epoch 62/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.3473 - accuracy: 0.8357 - val_loss: 0.2882 - val_accuracy: 0.9000
# Epoch 63/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.3453 - accuracy: 0.8357 - val_loss: 0.2874 - val_accuracy: 0.9000
# Epoch 64/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.3435 - accuracy: 0.8357 - val_loss: 0.2862 - val_accuracy: 0.9000
# Epoch 65/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.3417 - accuracy: 0.8357 - val_loss: 0.2852 - val_accuracy: 0.9000
# Epoch 66/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.3399 - accuracy: 0.8357 - val_loss: 0.2842 - val_accuracy: 0.9000
# Epoch 67/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.3382 - accuracy: 0.8357 - val_loss: 0.2832 - val_accuracy: 0.9000
# Epoch 68/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.3363 - accuracy: 0.8357 - val_loss: 0.2822 - val_accuracy: 0.9000
# Epoch 69/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.3344 - accuracy: 0.8357 - val_loss: 0.2812 - val_accuracy: 0.9000
# Epoch 70/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.3326 - accuracy: 0.8357 - val_loss: 0.2802 - val_accuracy: 0.9000
# Epoch 71/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.3308 - accuracy: 0.8357 - val_loss: 0.2791 - val_accuracy: 0.9000
# Epoch 72/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.3291 - accuracy: 0.8357 - val_loss: 0.2782 - val_accuracy: 0.9000
# Epoch 73/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.3274 - accuracy: 0.8357 - val_loss: 0.2772 - val_accuracy: 0.9000
# Epoch 74/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.3258 - accuracy: 0.8357 - val_loss: 0.2763 - val_accuracy: 0.9000
# Epoch 75/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.3242 - accuracy: 0.8357 - val_loss: 0.2754 - val_accuracy: 0.9000
# Epoch 76/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.3227 - accuracy: 0.8357 - val_loss: 0.2745 - val_accuracy: 0.9000
# Epoch 77/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.3211 - accuracy: 0.8357 - val_loss: 0.2735 - val_accuracy: 0.9000
# Epoch 78/400
# 9/9 [==============================] - 0s 3ms/step - loss: 0.3196 - accuracy: 0.8357 - val_loss: 0.2726 - val_accuracy: 0.9000
# Epoch 79/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.3181 - accuracy: 0.8357 - val_loss: 0.2719 - val_accuracy: 0.9000
# Epoch 80/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.3167 - accuracy: 0.8357 - val_loss: 0.2711 - val_accuracy: 0.9000
# Epoch 81/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.3152 - accuracy: 0.8357 - val_loss: 0.2705 - val_accuracy: 0.9000
# Epoch 82/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.3137 - accuracy: 0.8357 - val_loss: 0.2695 - val_accuracy: 0.9000
# Epoch 83/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.3124 - accuracy: 0.8357 - val_loss: 0.2688 - val_accuracy: 0.9000
# Epoch 84/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.3110 - accuracy: 0.8357 - val_loss: 0.2680 - val_accuracy: 0.9000
# Epoch 85/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.3097 - accuracy: 0.8357 - val_loss: 0.2674 - val_accuracy: 0.9000
# Epoch 86/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.3086 - accuracy: 0.8357 - val_loss: 0.2668 - val_accuracy: 0.9000
# Epoch 87/400
# 9/9 [==============================] - 0s 9ms/step - loss: 0.3071 - accuracy: 0.8357 - val_loss: 0.2664 - val_accuracy: 0.9000
# Epoch 88/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.3059 - accuracy: 0.8357 - val_loss: 0.2656 - val_accuracy: 0.9000
# Epoch 89/400
# 9/9 [==============================] - 0s 7ms/step - loss: 0.3047 - accuracy: 0.8357 - val_loss: 0.2647 - val_accuracy: 0.9000
# Epoch 90/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.3034 - accuracy: 0.8357 - val_loss: 0.2639 - val_accuracy: 0.9000
# Epoch 91/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.3023 - accuracy: 0.8357 - val_loss: 0.2633 - val_accuracy: 0.9000
# Epoch 92/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.3011 - accuracy: 0.8357 - val_loss: 0.2627 - val_accuracy: 0.9000
# Epoch 93/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2997 - accuracy: 0.8357 - val_loss: 0.2619 - val_accuracy: 0.9000
# Epoch 94/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.2987 - accuracy: 0.8357 - val_loss: 0.2613 - val_accuracy: 0.9000
# Epoch 95/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2974 - accuracy: 0.8357 - val_loss: 0.2605 - val_accuracy: 0.9000
# Epoch 96/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2963 - accuracy: 0.8357 - val_loss: 0.2599 - val_accuracy: 0.9000
# Epoch 97/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2952 - accuracy: 0.8357 - val_loss: 0.2594 - val_accuracy: 0.9000
# Epoch 98/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2941 - accuracy: 0.8357 - val_loss: 0.2587 - val_accuracy: 0.9000
# Epoch 99/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2932 - accuracy: 0.8357 - val_loss: 0.2581 - val_accuracy: 0.9000
# Epoch 100/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.2919 - accuracy: 0.8357 - val_loss: 0.2574 - val_accuracy: 0.9000
# Epoch 101/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2909 - accuracy: 0.8357 - val_loss: 0.2569 - val_accuracy: 0.9000
# Epoch 102/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2898 - accuracy: 0.8357 - val_loss: 0.2562 - val_accuracy: 0.9000
# Epoch 103/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2886 - accuracy: 0.8357 - val_loss: 0.2557 - val_accuracy: 0.9000
# Epoch 104/400
# 9/9 [==============================] - 0s 3ms/step - loss: 0.2879 - accuracy: 0.8357 - val_loss: 0.2551 - val_accuracy: 0.9000
# Epoch 105/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2867 - accuracy: 0.8357 - val_loss: 0.2545 - val_accuracy: 0.9000
# Epoch 106/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2857 - accuracy: 0.8357 - val_loss: 0.2539 - val_accuracy: 0.9000
# Epoch 107/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2848 - accuracy: 0.8357 - val_loss: 0.2533 - val_accuracy: 0.9000
# Epoch 108/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2840 - accuracy: 0.8357 - val_loss: 0.2529 - val_accuracy: 0.9000
# Epoch 109/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2829 - accuracy: 0.8357 - val_loss: 0.2524 - val_accuracy: 0.9000
# Epoch 110/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2820 - accuracy: 0.8357 - val_loss: 0.2518 - val_accuracy: 0.9000
# Epoch 111/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2813 - accuracy: 0.8357 - val_loss: 0.2515 - val_accuracy: 0.9000
# Epoch 112/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2803 - accuracy: 0.8357 - val_loss: 0.2512 - val_accuracy: 0.9000
# Epoch 113/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2793 - accuracy: 0.8357 - val_loss: 0.2507 - val_accuracy: 0.9000
# Epoch 114/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2787 - accuracy: 0.8357 - val_loss: 0.2503 - val_accuracy: 0.9000
# Epoch 115/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2777 - accuracy: 0.8357 - val_loss: 0.2498 - val_accuracy: 0.9000
# Epoch 116/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.2770 - accuracy: 0.8357 - val_loss: 0.2496 - val_accuracy: 0.9000
# Epoch 117/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2760 - accuracy: 0.8357 - val_loss: 0.2491 - val_accuracy: 0.9000
# Epoch 118/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2752 - accuracy: 0.8357 - val_loss: 0.2486 - val_accuracy: 0.9000
# Epoch 119/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2743 - accuracy: 0.8357 - val_loss: 0.2481 - val_accuracy: 0.9000
# Epoch 120/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.2733 - accuracy: 0.8357 - val_loss: 0.2475 - val_accuracy: 0.9000
# Epoch 121/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2724 - accuracy: 0.8357 - val_loss: 0.2469 - val_accuracy: 0.9000
# Epoch 122/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2718 - accuracy: 0.8357 - val_loss: 0.2467 - val_accuracy: 0.9000
# Epoch 123/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2708 - accuracy: 0.8357 - val_loss: 0.2463 - val_accuracy: 0.9000
# Epoch 124/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2699 - accuracy: 0.8357 - val_loss: 0.2462 - val_accuracy: 0.9000
# Epoch 125/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2692 - accuracy: 0.8357 - val_loss: 0.2455 - val_accuracy: 0.9000
# Epoch 126/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2685 - accuracy: 0.8357 - val_loss: 0.2450 - val_accuracy: 0.9000
# Epoch 127/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.2676 - accuracy: 0.8357 - val_loss: 0.2443 - val_accuracy: 0.9000
# Epoch 128/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2668 - accuracy: 0.8357 - val_loss: 0.2438 - val_accuracy: 0.9000
# Epoch 129/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2661 - accuracy: 0.8357 - val_loss: 0.2436 - val_accuracy: 0.9000
# Epoch 130/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2654 - accuracy: 0.8357 - val_loss: 0.2430 - val_accuracy: 0.9000
# Epoch 131/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2647 - accuracy: 0.8357 - val_loss: 0.2424 - val_accuracy: 0.9000
# Epoch 132/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2638 - accuracy: 0.8357 - val_loss: 0.2422 - val_accuracy: 0.9000
# Epoch 133/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2634 - accuracy: 0.8357 - val_loss: 0.2418 - val_accuracy: 0.9000
# Epoch 134/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2625 - accuracy: 0.8357 - val_loss: 0.2413 - val_accuracy: 0.9000
# Epoch 135/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2617 - accuracy: 0.8357 - val_loss: 0.2408 - val_accuracy: 0.9000
# Epoch 136/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2611 - accuracy: 0.8357 - val_loss: 0.2405 - val_accuracy: 0.9000
# Epoch 137/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2603 - accuracy: 0.8357 - val_loss: 0.2404 - val_accuracy: 0.9000
# Epoch 138/400
# 9/9 [==============================] - 0s 8ms/step - loss: 0.2597 - accuracy: 0.8357 - val_loss: 0.2400 - val_accuracy: 0.9000
# Epoch 139/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2592 - accuracy: 0.8357 - val_loss: 0.2394 - val_accuracy: 0.9000
# Epoch 140/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2587 - accuracy: 0.8357 - val_loss: 0.2390 - val_accuracy: 0.9000
# Epoch 141/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2578 - accuracy: 0.8357 - val_loss: 0.2385 - val_accuracy: 0.9000
# Epoch 142/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.2572 - accuracy: 0.8357 - val_loss: 0.2385 - val_accuracy: 0.9000
# Epoch 143/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2565 - accuracy: 0.8357 - val_loss: 0.2376 - val_accuracy: 0.9000
# Epoch 144/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2560 - accuracy: 0.8357 - val_loss: 0.2369 - val_accuracy: 0.9000
# Epoch 145/400
# 9/9 [==============================] - 0s 3ms/step - loss: 0.2554 - accuracy: 0.8357 - val_loss: 0.2367 - val_accuracy: 0.9000
# Epoch 146/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.2546 - accuracy: 0.8357 - val_loss: 0.2363 - val_accuracy: 0.9000
# Epoch 147/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2541 - accuracy: 0.8357 - val_loss: 0.2357 - val_accuracy: 0.9000
# Epoch 148/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.2533 - accuracy: 0.8357 - val_loss: 0.2354 - val_accuracy: 0.9000
# Epoch 149/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2530 - accuracy: 0.8357 - val_loss: 0.2349 - val_accuracy: 0.9000
# Epoch 150/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2519 - accuracy: 0.8357 - val_loss: 0.2344 - val_accuracy: 0.9000
# Epoch 151/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.2515 - accuracy: 0.8357 - val_loss: 0.2342 - val_accuracy: 0.9000
# Epoch 152/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2509 - accuracy: 0.8357 - val_loss: 0.2334 - val_accuracy: 0.9000
# Epoch 153/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.2502 - accuracy: 0.8357 - val_loss: 0.2330 - val_accuracy: 0.9000
# Epoch 154/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2498 - accuracy: 0.8357 - val_loss: 0.2323 - val_accuracy: 0.9000
# Epoch 155/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2489 - accuracy: 0.8357 - val_loss: 0.2319 - val_accuracy: 0.9000
# Epoch 156/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2487 - accuracy: 0.8357 - val_loss: 0.2311 - val_accuracy: 0.9000
# Epoch 157/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2479 - accuracy: 0.8357 - val_loss: 0.2308 - val_accuracy: 0.9000
# Epoch 158/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2474 - accuracy: 0.8357 - val_loss: 0.2299 - val_accuracy: 0.9000
# Epoch 159/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.2467 - accuracy: 0.8357 - val_loss: 0.2294 - val_accuracy: 0.9000
# Epoch 160/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2462 - accuracy: 0.8357 - val_loss: 0.2287 - val_accuracy: 0.9000
# Epoch 161/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.2459 - accuracy: 0.8357 - val_loss: 0.2278 - val_accuracy: 0.9000
# Epoch 162/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2450 - accuracy: 0.8357 - val_loss: 0.2274 - val_accuracy: 0.9000
# Epoch 163/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.2445 - accuracy: 0.8357 - val_loss: 0.2268 - val_accuracy: 0.9000
# Epoch 164/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2440 - accuracy: 0.8357 - val_loss: 0.2261 - val_accuracy: 0.9000
# Epoch 165/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2436 - accuracy: 0.8357 - val_loss: 0.2259 - val_accuracy: 0.9000
# Epoch 166/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2428 - accuracy: 0.8357 - val_loss: 0.2259 - val_accuracy: 0.9000
# Epoch 167/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2424 - accuracy: 0.8357 - val_loss: 0.2257 - val_accuracy: 0.9000
# Epoch 168/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2420 - accuracy: 0.8357 - val_loss: 0.2252 - val_accuracy: 0.9000
# Epoch 169/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2411 - accuracy: 0.8357 - val_loss: 0.2245 - val_accuracy: 0.9000
# Epoch 170/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2407 - accuracy: 0.8357 - val_loss: 0.2244 - val_accuracy: 0.8917
# Epoch 171/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2401 - accuracy: 0.8607 - val_loss: 0.2234 - val_accuracy: 0.8917
# Epoch 172/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2397 - accuracy: 0.8536 - val_loss: 0.2228 - val_accuracy: 0.8833
# Epoch 173/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2396 - accuracy: 0.8536 - val_loss: 0.2223 - val_accuracy: 0.8833
# Epoch 174/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2388 - accuracy: 0.8786 - val_loss: 0.2219 - val_accuracy: 0.8833
# Epoch 175/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2383 - accuracy: 0.8929 - val_loss: 0.2219 - val_accuracy: 0.8833
# Epoch 176/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.2378 - accuracy: 0.8964 - val_loss: 0.2217 - val_accuracy: 0.9000
# Epoch 177/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2373 - accuracy: 0.8893 - val_loss: 0.2210 - val_accuracy: 0.9167
# Epoch 178/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2370 - accuracy: 0.8893 - val_loss: 0.2200 - val_accuracy: 0.9167
# Epoch 179/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2365 - accuracy: 0.8929 - val_loss: 0.2194 - val_accuracy: 0.9167
# Epoch 180/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2360 - accuracy: 0.8929 - val_loss: 0.2192 - val_accuracy: 0.9167
# Epoch 181/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2355 - accuracy: 0.8893 - val_loss: 0.2185 - val_accuracy: 0.9083
# Epoch 182/400
# 9/9 [==============================] - 0s 3ms/step - loss: 0.2351 - accuracy: 0.8929 - val_loss: 0.2179 - val_accuracy: 0.9083
# Epoch 183/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2349 - accuracy: 0.8929 - val_loss: 0.2170 - val_accuracy: 0.9083
# Epoch 184/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2340 - accuracy: 0.8929 - val_loss: 0.2170 - val_accuracy: 0.9083
# Epoch 185/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2336 - accuracy: 0.8929 - val_loss: 0.2167 - val_accuracy: 0.9083
# Epoch 186/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2334 - accuracy: 0.8929 - val_loss: 0.2161 - val_accuracy: 0.9083
# Epoch 187/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2328 - accuracy: 0.8929 - val_loss: 0.2158 - val_accuracy: 0.9083
# Epoch 188/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2322 - accuracy: 0.8929 - val_loss: 0.2162 - val_accuracy: 0.9000
# Epoch 189/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2317 - accuracy: 0.8929 - val_loss: 0.2159 - val_accuracy: 0.9000
# Epoch 190/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2315 - accuracy: 0.8929 - val_loss: 0.2155 - val_accuracy: 0.9000
# Epoch 191/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.2310 - accuracy: 0.8929 - val_loss: 0.2149 - val_accuracy: 0.9000
# Epoch 192/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2303 - accuracy: 0.8929 - val_loss: 0.2150 - val_accuracy: 0.9000
# Epoch 193/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2304 - accuracy: 0.8893 - val_loss: 0.2143 - val_accuracy: 0.9000
# Epoch 194/400
# 9/9 [==============================] - 0s 3ms/step - loss: 0.2298 - accuracy: 0.8893 - val_loss: 0.2134 - val_accuracy: 0.9000
# Epoch 195/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2293 - accuracy: 0.8893 - val_loss: 0.2125 - val_accuracy: 0.9000
# Epoch 196/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2288 - accuracy: 0.8893 - val_loss: 0.2116 - val_accuracy: 0.9000
# Epoch 197/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2286 - accuracy: 0.8893 - val_loss: 0.2116 - val_accuracy: 0.9000
# Epoch 198/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2281 - accuracy: 0.8893 - val_loss: 0.2110 - val_accuracy: 0.9000
# Epoch 199/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2277 - accuracy: 0.8893 - val_loss: 0.2112 - val_accuracy: 0.9000
# Epoch 200/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2272 - accuracy: 0.8893 - val_loss: 0.2112 - val_accuracy: 0.9000
# Epoch 201/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2269 - accuracy: 0.8893 - val_loss: 0.2100 - val_accuracy: 0.9000
# Epoch 202/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2264 - accuracy: 0.8893 - val_loss: 0.2093 - val_accuracy: 0.9000
# Epoch 203/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2262 - accuracy: 0.8893 - val_loss: 0.2086 - val_accuracy: 0.9000
# Epoch 204/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2261 - accuracy: 0.8893 - val_loss: 0.2077 - val_accuracy: 0.9000
# Epoch 205/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2254 - accuracy: 0.8893 - val_loss: 0.2077 - val_accuracy: 0.9000
# Epoch 206/400
# 9/9 [==============================] - 0s 3ms/step - loss: 0.2253 - accuracy: 0.8857 - val_loss: 0.2071 - val_accuracy: 0.9000
# Epoch 207/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.2247 - accuracy: 0.8857 - val_loss: 0.2072 - val_accuracy: 0.9000
# Epoch 208/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2243 - accuracy: 0.8857 - val_loss: 0.2067 - val_accuracy: 0.9000
# Epoch 209/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2238 - accuracy: 0.8857 - val_loss: 0.2068 - val_accuracy: 0.9000
# Epoch 210/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2235 - accuracy: 0.8857 - val_loss: 0.2066 - val_accuracy: 0.9000
# Epoch 211/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2232 - accuracy: 0.8857 - val_loss: 0.2060 - val_accuracy: 0.9000
# Epoch 212/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2232 - accuracy: 0.8857 - val_loss: 0.2051 - val_accuracy: 0.9000
# Epoch 213/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.2223 - accuracy: 0.8857 - val_loss: 0.2054 - val_accuracy: 0.9000
# Epoch 214/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2219 - accuracy: 0.8857 - val_loss: 0.2046 - val_accuracy: 0.9000
# Epoch 215/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2217 - accuracy: 0.8857 - val_loss: 0.2043 - val_accuracy: 0.9000
# Epoch 216/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.2216 - accuracy: 0.8857 - val_loss: 0.2036 - val_accuracy: 0.9000
# Epoch 217/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2215 - accuracy: 0.8857 - val_loss: 0.2034 - val_accuracy: 0.9000
# Epoch 218/400
# 9/9 [==============================] - 0s 7ms/step - loss: 0.2206 - accuracy: 0.8857 - val_loss: 0.2026 - val_accuracy: 0.9000
# Epoch 219/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2203 - accuracy: 0.8857 - val_loss: 0.2030 - val_accuracy: 0.9000
# Epoch 220/400
# 9/9 [==============================] - 0s 7ms/step - loss: 0.2202 - accuracy: 0.8857 - val_loss: 0.2029 - val_accuracy: 0.9000
# Epoch 221/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2197 - accuracy: 0.8821 - val_loss: 0.2026 - val_accuracy: 0.9000
# Epoch 222/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2193 - accuracy: 0.8821 - val_loss: 0.2020 - val_accuracy: 0.9000
# Epoch 223/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2189 - accuracy: 0.8821 - val_loss: 0.2016 - val_accuracy: 0.9000
# Epoch 224/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2190 - accuracy: 0.8821 - val_loss: 0.2021 - val_accuracy: 0.9000
# Epoch 225/400
# 9/9 [==============================] - 0s 3ms/step - loss: 0.2185 - accuracy: 0.8821 - val_loss: 0.2014 - val_accuracy: 0.9000
# Epoch 226/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2180 - accuracy: 0.8821 - val_loss: 0.2015 - val_accuracy: 0.9000
# Epoch 227/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2178 - accuracy: 0.8821 - val_loss: 0.2012 - val_accuracy: 0.9000
# Epoch 228/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2174 - accuracy: 0.8821 - val_loss: 0.2012 - val_accuracy: 0.9000
# Epoch 229/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.2170 - accuracy: 0.8857 - val_loss: 0.2005 - val_accuracy: 0.9000
# Epoch 230/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2165 - accuracy: 0.8857 - val_loss: 0.2002 - val_accuracy: 0.9000
# Epoch 231/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.2166 - accuracy: 0.8857 - val_loss: 0.1998 - val_accuracy: 0.9000
# Epoch 232/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2160 - accuracy: 0.8857 - val_loss: 0.1987 - val_accuracy: 0.9000
# Epoch 233/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2157 - accuracy: 0.8857 - val_loss: 0.1989 - val_accuracy: 0.9083
# Epoch 234/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.2155 - accuracy: 0.8857 - val_loss: 0.1981 - val_accuracy: 0.9083
# Epoch 235/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.2153 - accuracy: 0.8857 - val_loss: 0.1983 - val_accuracy: 0.9083
# Epoch 236/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2149 - accuracy: 0.8821 - val_loss: 0.1980 - val_accuracy: 0.9083
# Epoch 237/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2148 - accuracy: 0.8857 - val_loss: 0.1983 - val_accuracy: 0.9083
# Epoch 238/400
# 9/9 [==============================] - 0s 8ms/step - loss: 0.2143 - accuracy: 0.8857 - val_loss: 0.1984 - val_accuracy: 0.9083
# Epoch 239/400
# 9/9 [==============================] - 0s 7ms/step - loss: 0.2138 - accuracy: 0.8893 - val_loss: 0.1979 - val_accuracy: 0.9083
# Epoch 240/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2138 - accuracy: 0.8857 - val_loss: 0.1977 - val_accuracy: 0.9083
# Epoch 241/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.2136 - accuracy: 0.8893 - val_loss: 0.1971 - val_accuracy: 0.9083
# Epoch 242/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2133 - accuracy: 0.8893 - val_loss: 0.1965 - val_accuracy: 0.9083
# Epoch 243/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.2131 - accuracy: 0.8893 - val_loss: 0.1959 - val_accuracy: 0.9083
# Epoch 244/400
# 9/9 [==============================] - 0s 8ms/step - loss: 0.2126 - accuracy: 0.8893 - val_loss: 0.1956 - val_accuracy: 0.9083
# Epoch 245/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2123 - accuracy: 0.8893 - val_loss: 0.1957 - val_accuracy: 0.9083
# Epoch 246/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2120 - accuracy: 0.8893 - val_loss: 0.1953 - val_accuracy: 0.9083
# Epoch 247/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2121 - accuracy: 0.8893 - val_loss: 0.1957 - val_accuracy: 0.9083
# Epoch 248/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2115 - accuracy: 0.8893 - val_loss: 0.1959 - val_accuracy: 0.9083
# Epoch 249/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2113 - accuracy: 0.8893 - val_loss: 0.1957 - val_accuracy: 0.9083
# Epoch 250/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2110 - accuracy: 0.8893 - val_loss: 0.1955 - val_accuracy: 0.9083
# Epoch 251/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2106 - accuracy: 0.8893 - val_loss: 0.1950 - val_accuracy: 0.9083
# Epoch 252/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2103 - accuracy: 0.8893 - val_loss: 0.1954 - val_accuracy: 0.9167
# Epoch 253/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2100 - accuracy: 0.8893 - val_loss: 0.1957 - val_accuracy: 0.9167
# Epoch 254/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2097 - accuracy: 0.8893 - val_loss: 0.1961 - val_accuracy: 0.9167
# Epoch 255/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.2097 - accuracy: 0.8893 - val_loss: 0.1954 - val_accuracy: 0.9167
# Epoch 256/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.2093 - accuracy: 0.8893 - val_loss: 0.1950 - val_accuracy: 0.9167
# Epoch 257/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2090 - accuracy: 0.8893 - val_loss: 0.1944 - val_accuracy: 0.9167
# Epoch 258/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2086 - accuracy: 0.8893 - val_loss: 0.1943 - val_accuracy: 0.9167
# Epoch 259/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2086 - accuracy: 0.8893 - val_loss: 0.1946 - val_accuracy: 0.9167
# Epoch 260/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2084 - accuracy: 0.8893 - val_loss: 0.1948 - val_accuracy: 0.9167
# Epoch 261/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2078 - accuracy: 0.8893 - val_loss: 0.1940 - val_accuracy: 0.9167
# Epoch 262/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2080 - accuracy: 0.8893 - val_loss: 0.1939 - val_accuracy: 0.9167
# Epoch 263/400
# 9/9 [==============================] - 0s 8ms/step - loss: 0.2073 - accuracy: 0.8893 - val_loss: 0.1937 - val_accuracy: 0.9167
# Epoch 264/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.2072 - accuracy: 0.8893 - val_loss: 0.1933 - val_accuracy: 0.9167
# Epoch 265/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2074 - accuracy: 0.8893 - val_loss: 0.1929 - val_accuracy: 0.9167
# Epoch 266/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2071 - accuracy: 0.8893 - val_loss: 0.1931 - val_accuracy: 0.9167
# Epoch 267/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2065 - accuracy: 0.8893 - val_loss: 0.1930 - val_accuracy: 0.9167
# Epoch 268/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2064 - accuracy: 0.8893 - val_loss: 0.1929 - val_accuracy: 0.9167
# Epoch 269/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2059 - accuracy: 0.8893 - val_loss: 0.1932 - val_accuracy: 0.9167
# Epoch 270/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2060 - accuracy: 0.8929 - val_loss: 0.1929 - val_accuracy: 0.9167
# Epoch 271/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2054 - accuracy: 0.8893 - val_loss: 0.1924 - val_accuracy: 0.9167
# Epoch 272/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2053 - accuracy: 0.8929 - val_loss: 0.1920 - val_accuracy: 0.9167
# Epoch 273/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.2052 - accuracy: 0.8893 - val_loss: 0.1919 - val_accuracy: 0.9167
# Epoch 274/400
# 9/9 [==============================] - 0s 3ms/step - loss: 0.2047 - accuracy: 0.8893 - val_loss: 0.1926 - val_accuracy: 0.9167
# Epoch 275/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2047 - accuracy: 0.9000 - val_loss: 0.1923 - val_accuracy: 0.9167
# Epoch 276/400
# 9/9 [==============================] - 0s 7ms/step - loss: 0.2043 - accuracy: 0.9036 - val_loss: 0.1915 - val_accuracy: 0.9167
# Epoch 277/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.2041 - accuracy: 0.8929 - val_loss: 0.1916 - val_accuracy: 0.9167
# Epoch 278/400
# 9/9 [==============================] - 0s 7ms/step - loss: 0.2039 - accuracy: 0.9000 - val_loss: 0.1917 - val_accuracy: 0.9167
# Epoch 279/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2039 - accuracy: 0.9000 - val_loss: 0.1907 - val_accuracy: 0.9167
# Epoch 280/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.2036 - accuracy: 0.8964 - val_loss: 0.1908 - val_accuracy: 0.9167
# Epoch 281/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.2031 - accuracy: 0.9036 - val_loss: 0.1906 - val_accuracy: 0.9167
# Epoch 282/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2030 - accuracy: 0.9036 - val_loss: 0.1900 - val_accuracy: 0.9167
# Epoch 283/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2030 - accuracy: 0.9000 - val_loss: 0.1898 - val_accuracy: 0.9167
# Epoch 284/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2026 - accuracy: 0.9036 - val_loss: 0.1901 - val_accuracy: 0.9167
# Epoch 285/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.2021 - accuracy: 0.9036 - val_loss: 0.1904 - val_accuracy: 0.9167
# Epoch 286/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.2019 - accuracy: 0.9036 - val_loss: 0.1908 - val_accuracy: 0.9167
# Epoch 287/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2018 - accuracy: 0.9000 - val_loss: 0.1909 - val_accuracy: 0.9167
# Epoch 288/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.2017 - accuracy: 0.9036 - val_loss: 0.1904 - val_accuracy: 0.9167
# Epoch 289/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.2012 - accuracy: 0.9036 - val_loss: 0.1896 - val_accuracy: 0.9167
# Epoch 290/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.2014 - accuracy: 0.9000 - val_loss: 0.1885 - val_accuracy: 0.9167
# Epoch 291/400
# 9/9 [==============================] - 0s 7ms/step - loss: 0.2010 - accuracy: 0.9000 - val_loss: 0.1892 - val_accuracy: 0.9167
# Epoch 292/400
# 9/9 [==============================] - 0s 7ms/step - loss: 0.2010 - accuracy: 0.9036 - val_loss: 0.1888 - val_accuracy: 0.9167
# Epoch 293/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2003 - accuracy: 0.9036 - val_loss: 0.1894 - val_accuracy: 0.9167
# Epoch 294/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2003 - accuracy: 0.9036 - val_loss: 0.1895 - val_accuracy: 0.9167
# Epoch 295/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2001 - accuracy: 0.9036 - val_loss: 0.1894 - val_accuracy: 0.9167
# Epoch 296/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.1998 - accuracy: 0.9036 - val_loss: 0.1893 - val_accuracy: 0.9167
# Epoch 297/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.1997 - accuracy: 0.9036 - val_loss: 0.1893 - val_accuracy: 0.9167
# Epoch 298/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.1993 - accuracy: 0.9036 - val_loss: 0.1890 - val_accuracy: 0.9167
# Epoch 299/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.1990 - accuracy: 0.9036 - val_loss: 0.1887 - val_accuracy: 0.9167
# Epoch 300/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.1988 - accuracy: 0.9036 - val_loss: 0.1890 - val_accuracy: 0.9167
# Epoch 301/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.1988 - accuracy: 0.9036 - val_loss: 0.1893 - val_accuracy: 0.9167
# Epoch 302/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.1984 - accuracy: 0.9036 - val_loss: 0.1896 - val_accuracy: 0.9250
# Epoch 303/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.1981 - accuracy: 0.9036 - val_loss: 0.1896 - val_accuracy: 0.9250
# Epoch 304/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.1978 - accuracy: 0.9036 - val_loss: 0.1891 - val_accuracy: 0.9250
# Epoch 305/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.1978 - accuracy: 0.9036 - val_loss: 0.1892 - val_accuracy: 0.9250
# Epoch 306/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.1980 - accuracy: 0.9036 - val_loss: 0.1891 - val_accuracy: 0.9250
# Epoch 307/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.1974 - accuracy: 0.9036 - val_loss: 0.1897 - val_accuracy: 0.9250
# Epoch 308/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.1971 - accuracy: 0.9036 - val_loss: 0.1890 - val_accuracy: 0.9250
# Epoch 309/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.1967 - accuracy: 0.9036 - val_loss: 0.1890 - val_accuracy: 0.9250
# Epoch 310/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.1965 - accuracy: 0.9036 - val_loss: 0.1891 - val_accuracy: 0.9250
# Epoch 311/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.1964 - accuracy: 0.9036 - val_loss: 0.1885 - val_accuracy: 0.9250
# Epoch 312/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.1961 - accuracy: 0.9036 - val_loss: 0.1880 - val_accuracy: 0.9250
# Epoch 313/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.1964 - accuracy: 0.9036 - val_loss: 0.1881 - val_accuracy: 0.9250
# Epoch 314/400
# 9/9 [==============================] - 0s 7ms/step - loss: 0.1959 - accuracy: 0.9036 - val_loss: 0.1879 - val_accuracy: 0.9250
# Epoch 315/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.1955 - accuracy: 0.9036 - val_loss: 0.1884 - val_accuracy: 0.9250
# Epoch 316/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.1953 - accuracy: 0.9036 - val_loss: 0.1883 - val_accuracy: 0.9250
# Epoch 317/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.1957 - accuracy: 0.9036 - val_loss: 0.1878 - val_accuracy: 0.9250
# Epoch 318/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.1952 - accuracy: 0.9036 - val_loss: 0.1873 - val_accuracy: 0.9250
# Epoch 319/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.1947 - accuracy: 0.9036 - val_loss: 0.1871 - val_accuracy: 0.9250
# Epoch 320/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.1949 - accuracy: 0.9036 - val_loss: 0.1872 - val_accuracy: 0.9250
# Epoch 321/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.1947 - accuracy: 0.9036 - val_loss: 0.1872 - val_accuracy: 0.9250
# Epoch 322/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.1943 - accuracy: 0.9000 - val_loss: 0.1870 - val_accuracy: 0.9250
# Epoch 323/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.1939 - accuracy: 0.9036 - val_loss: 0.1866 - val_accuracy: 0.9250
# Epoch 324/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.1941 - accuracy: 0.9036 - val_loss: 0.1867 - val_accuracy: 0.9250
# Epoch 325/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.1937 - accuracy: 0.9000 - val_loss: 0.1868 - val_accuracy: 0.9250
# Epoch 326/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.1933 - accuracy: 0.9000 - val_loss: 0.1864 - val_accuracy: 0.9250
# Epoch 327/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.1933 - accuracy: 0.9000 - val_loss: 0.1863 - val_accuracy: 0.9250
# Epoch 328/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.1929 - accuracy: 0.9000 - val_loss: 0.1865 - val_accuracy: 0.9250
# Epoch 329/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.1930 - accuracy: 0.9000 - val_loss: 0.1868 - val_accuracy: 0.9250
# Epoch 330/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.1925 - accuracy: 0.9000 - val_loss: 0.1871 - val_accuracy: 0.9250
# Epoch 331/400
# 9/9 [==============================] - 0s 10ms/step - loss: 0.1921 - accuracy: 0.9000 - val_loss: 0.1868 - val_accuracy: 0.9250
# Epoch 332/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.1925 - accuracy: 0.9000 - val_loss: 0.1863 - val_accuracy: 0.9250
# Epoch 333/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.1918 - accuracy: 0.9000 - val_loss: 0.1866 - val_accuracy: 0.9250
# Epoch 334/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.1915 - accuracy: 0.9000 - val_loss: 0.1874 - val_accuracy: 0.9250
# Epoch 335/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.1916 - accuracy: 0.9000 - val_loss: 0.1873 - val_accuracy: 0.9250
# Epoch 336/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.1913 - accuracy: 0.9000 - val_loss: 0.1869 - val_accuracy: 0.9250
# Epoch 337/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.1912 - accuracy: 0.9000 - val_loss: 0.1869 - val_accuracy: 0.9250
# Epoch 338/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.1908 - accuracy: 0.9000 - val_loss: 0.1871 - val_accuracy: 0.9333
# Epoch 339/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.1904 - accuracy: 0.9000 - val_loss: 0.1865 - val_accuracy: 0.9250
# Epoch 340/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.1906 - accuracy: 0.9036 - val_loss: 0.1863 - val_accuracy: 0.9250
# Epoch 341/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.1902 - accuracy: 0.9000 - val_loss: 0.1861 - val_accuracy: 0.9333
# Epoch 342/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.1897 - accuracy: 0.9000 - val_loss: 0.1860 - val_accuracy: 0.9250
# Epoch 343/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.1898 - accuracy: 0.9000 - val_loss: 0.1854 - val_accuracy: 0.9250
# Epoch 344/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.1902 - accuracy: 0.9000 - val_loss: 0.1855 - val_accuracy: 0.9250
# Epoch 345/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.1892 - accuracy: 0.9000 - val_loss: 0.1863 - val_accuracy: 0.9333
# Epoch 346/400
# 9/9 [==============================] - 0s 3ms/step - loss: 0.1891 - accuracy: 0.9000 - val_loss: 0.1863 - val_accuracy: 0.9333
# Epoch 347/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.1891 - accuracy: 0.9000 - val_loss: 0.1867 - val_accuracy: 0.9333
# Epoch 348/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.1885 - accuracy: 0.9000 - val_loss: 0.1860 - val_accuracy: 0.9333
# Epoch 349/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.1886 - accuracy: 0.9000 - val_loss: 0.1858 - val_accuracy: 0.9333
# Epoch 350/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.1884 - accuracy: 0.9000 - val_loss: 0.1858 - val_accuracy: 0.9333
# Epoch 351/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.1883 - accuracy: 0.9000 - val_loss: 0.1861 - val_accuracy: 0.9333
# Epoch 352/400
# 9/9 [==============================] - 0s 7ms/step - loss: 0.1879 - accuracy: 0.9036 - val_loss: 0.1864 - val_accuracy: 0.9333
# Epoch 353/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.1878 - accuracy: 0.9036 - val_loss: 0.1867 - val_accuracy: 0.9333
# Epoch 354/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.1876 - accuracy: 0.9036 - val_loss: 0.1860 - val_accuracy: 0.9333
# Epoch 355/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.1875 - accuracy: 0.9036 - val_loss: 0.1857 - val_accuracy: 0.9333
# Epoch 356/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.1870 - accuracy: 0.9036 - val_loss: 0.1862 - val_accuracy: 0.9333
# Epoch 357/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.1869 - accuracy: 0.9071 - val_loss: 0.1861 - val_accuracy: 0.9333
# Epoch 358/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.1867 - accuracy: 0.9071 - val_loss: 0.1866 - val_accuracy: 0.9333
# Epoch 359/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.1864 - accuracy: 0.9071 - val_loss: 0.1865 - val_accuracy: 0.9333
# Epoch 360/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.1863 - accuracy: 0.9071 - val_loss: 0.1872 - val_accuracy: 0.9333
# Epoch 361/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.1859 - accuracy: 0.9071 - val_loss: 0.1866 - val_accuracy: 0.9333
# Epoch 362/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.1861 - accuracy: 0.9071 - val_loss: 0.1860 - val_accuracy: 0.9333
# Epoch 363/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.1858 - accuracy: 0.9036 - val_loss: 0.1867 - val_accuracy: 0.9333
# Epoch 364/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.1853 - accuracy: 0.9071 - val_loss: 0.1864 - val_accuracy: 0.9333
# Epoch 365/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.1855 - accuracy: 0.9071 - val_loss: 0.1864 - val_accuracy: 0.9333
# Epoch 366/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.1850 - accuracy: 0.9071 - val_loss: 0.1859 - val_accuracy: 0.9333
# Epoch 367/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.1850 - accuracy: 0.9071 - val_loss: 0.1860 - val_accuracy: 0.9333
# Epoch 368/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.1847 - accuracy: 0.9071 - val_loss: 0.1857 - val_accuracy: 0.9333
# Epoch 369/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.1844 - accuracy: 0.9071 - val_loss: 0.1860 - val_accuracy: 0.9333
# Epoch 370/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.1840 - accuracy: 0.9107 - val_loss: 0.1853 - val_accuracy: 0.9333
# Epoch 371/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.1841 - accuracy: 0.9071 - val_loss: 0.1851 - val_accuracy: 0.9333
# Epoch 372/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.1841 - accuracy: 0.9071 - val_loss: 0.1853 - val_accuracy: 0.9333
# Epoch 373/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.1834 - accuracy: 0.9071 - val_loss: 0.1857 - val_accuracy: 0.9333
# Epoch 374/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.1833 - accuracy: 0.9107 - val_loss: 0.1851 - val_accuracy: 0.9333
# Epoch 375/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.1833 - accuracy: 0.9107 - val_loss: 0.1849 - val_accuracy: 0.9333
# Epoch 376/400
# 9/9 [==============================] - 0s 3ms/step - loss: 0.1829 - accuracy: 0.9071 - val_loss: 0.1852 - val_accuracy: 0.9333
# Epoch 377/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.1831 - accuracy: 0.9071 - val_loss: 0.1853 - val_accuracy: 0.9333
# Epoch 378/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.1827 - accuracy: 0.9107 - val_loss: 0.1850 - val_accuracy: 0.9333
# Epoch 379/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.1828 - accuracy: 0.9071 - val_loss: 0.1853 - val_accuracy: 0.9333
# Epoch 380/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.1822 - accuracy: 0.9107 - val_loss: 0.1854 - val_accuracy: 0.9333
# Epoch 381/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.1818 - accuracy: 0.9107 - val_loss: 0.1846 - val_accuracy: 0.9333
# Epoch 382/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.1823 - accuracy: 0.9107 - val_loss: 0.1849 - val_accuracy: 0.9333
# Epoch 383/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.1819 - accuracy: 0.9107 - val_loss: 0.1851 - val_accuracy: 0.9333
# Epoch 384/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.1815 - accuracy: 0.9107 - val_loss: 0.1857 - val_accuracy: 0.9333
# Epoch 385/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.1813 - accuracy: 0.9107 - val_loss: 0.1859 - val_accuracy: 0.9333
# Epoch 386/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.1813 - accuracy: 0.9107 - val_loss: 0.1859 - val_accuracy: 0.9333
# Epoch 387/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.1813 - accuracy: 0.9107 - val_loss: 0.1854 - val_accuracy: 0.9333
# Epoch 388/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.1809 - accuracy: 0.9107 - val_loss: 0.1854 - val_accuracy: 0.9333
# Epoch 389/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.1807 - accuracy: 0.9107 - val_loss: 0.1858 - val_accuracy: 0.9333
# Epoch 390/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.1808 - accuracy: 0.9107 - val_loss: 0.1850 - val_accuracy: 0.9333
# Epoch 391/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.1805 - accuracy: 0.9071 - val_loss: 0.1848 - val_accuracy: 0.9333
# Epoch 392/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.1800 - accuracy: 0.9107 - val_loss: 0.1845 - val_accuracy: 0.9333
# Epoch 393/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.1799 - accuracy: 0.9143 - val_loss: 0.1843 - val_accuracy: 0.9333
# Epoch 394/400
# 9/9 [==============================] - 0s 7ms/step - loss: 0.1800 - accuracy: 0.9143 - val_loss: 0.1850 - val_accuracy: 0.9333
# Epoch 395/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.1796 - accuracy: 0.9143 - val_loss: 0.1850 - val_accuracy: 0.9250
# Epoch 396/400
# 9/9 [==============================] - 0s 7ms/step - loss: 0.1797 - accuracy: 0.9107 - val_loss: 0.1854 - val_accuracy: 0.9250
# Epoch 397/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.1792 - accuracy: 0.9143 - val_loss: 0.1860 - val_accuracy: 0.9250
# Epoch 398/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.1790 - accuracy: 0.9107 - val_loss: 0.1855 - val_accuracy: 0.9250
# Epoch 399/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.1789 - accuracy: 0.9143 - val_loss: 0.1856 - val_accuracy: 0.9250
# Epoch 400/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.1790 - accuracy: 0.9107 - val_loss: 0.1858 - val_accuracy: 0.9250

# %%
predictions = model.predict(scaled_X_test)

# %%
preds = []
for x in predictions:
    if x >= 0.5:
        preds.append(1)
    else:
        preds.append(0)

# %%
from sklearn.metrics import classification_report,confusion_matrix

# %%
print(classification_report(y1_test,preds))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.98      0.94      0.96       108
#          1.0       0.59      0.83      0.69        12
#
#     accuracy                           0.93       120
#    macro avg       0.78      0.88      0.82       120
# weighted avg       0.94      0.93      0.93       120
