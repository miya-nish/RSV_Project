# %% [markdown]
# ## DNN Retry Min
# Took out the data from 2020-2021, 2021-2022.

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
# %matplotlib inline
from statistics import mean
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.callbacks import EarlyStopping

# %%
import seaborn as sns
import numpy as np
import pandas as pd
from statistics import mean
import math

FUTURE_PREDICTION = 4

def findmax(x):
    maximum = 0
    for number in x:
        maximum = max(x)
    return maximum

def findmean(x):
    m = 0
    m = mean(x)
    return m

def findmin(x):
    m = 0
    m = min(x)
    return m

def CreateMean(dataframe,title,city):

    dataframe = dataframe.iloc[522:3924:1]
    dataframe.rename(columns = {f'{city}' : f'{title}_Mean'}, inplace = True)
    dataframe = dataframe.reset_index(drop=True)
    for x in dataframe.index:
        if x % 7 == 6:
            list = []
            mean = 0
            for y in range(x-6,x+1,1):
                list.append(dataframe.iloc[y][f'{title}_Mean'])
            mean = findmean(list)
            dataframe.at[x,f'{title}_Mean'] = mean
    for x in dataframe.index:
        if x % 7 != 6:
            dataframe.drop(index= x, inplace=True)
    dataframe = dataframe.reset_index(drop=True)
    return dataframe

def CreateMax(dataframe,title,city):

    dataframe = dataframe.iloc[522:3924:1]
    dataframe.rename(columns = {f'{city}' : f'{title}_Max'}, inplace = True)
    dataframe = dataframe.reset_index(drop=True)
    for x in dataframe.index:
        if x % 7 == 6:
            list = []
            maximum = 0
            for y in range(x-6,x+1,1):
                list.append(dataframe.iloc[y][f'{title}_Max'])
            maximum = findmax(list)
            dataframe.at[x,f'{title}_Max'] = maximum
    for x in dataframe.index:
        if x % 7 != 6:
            dataframe.drop(index= x, inplace=True)
    dataframe = dataframe.reset_index(drop=True)
    return dataframe

def CreateMin(dataframe,title,city):

    dataframe = dataframe.iloc[522:3924:1]
    dataframe.rename(columns = {f'{city}' : f'{title}_Min'}, inplace = True)
    dataframe = dataframe.reset_index(drop=True)
    for x in dataframe.index:
        if x % 7 == 6:
            list = []
            minimum = 0
            for y in range(x-6,x+1,1):
                list.append(dataframe.iloc[y][f'{title}_Min'])
            minimum = findmin(list)
            dataframe.at[x,f'{title}_Min'] = minimum
    for x in dataframe.index:
        if x % 7 != 6:
            dataframe.drop(index= x, inplace=True)
    dataframe = dataframe.reset_index(drop=True)
    return dataframe
    
def DataPreprocess(city):
    virus_df = pd.read_csv('Data/virus.csv')
    virus_df['Date'] = pd.to_datetime(virus_df['Date'])
    virus_df['year'] = virus_df['Date'].apply(lambda date: date.year)
    virus_df['month'] = virus_df['Date'].apply(lambda date: date.month)
    virus_df_new = virus_df[['Date','month','year',f'{city}']]
    virus_df_new.rename(columns = {f'{city}' : f'Virus_Count_{city}'}, inplace = True)

    temp_df = pd.read_csv(f'Data/{city}_temp.csv')
    pressure_df = pd.read_csv(f'Data/{city}_pressure.csv')
    hours_df = pd.read_csv(f'Data/{city}_hours.csv')
    rainfall_df = pd.read_csv(f'Data/{city}_rainfall.csv')

    temp_df['Date'] = pd.to_datetime(temp_df['Date'])
    temp_df['year'] = temp_df['Date'].apply(lambda date: date.year)
    temp_df['month'] = temp_df['Date'].apply(lambda date: date.month)

    pressure_df['Date'] = pd.to_datetime(pressure_df['Date'])
    pressure_df['year'] = pressure_df['Date'].apply(lambda date: date.year)
    pressure_df['month'] = pressure_df['Date'].apply(lambda date: date.month)
    pressure_df = pressure_df.sort_values(by="Date")
    pressure_df = pressure_df.reset_index(drop=True)

    hours_df['Date'] = pd.to_datetime(hours_df['Date'])
    hours_df['year'] = hours_df['Date'].apply(lambda date: date.year)
    hours_df['month'] = hours_df['Date'].apply(lambda date: date.month)
    hours_df = hours_df.sort_values(by="Date")
    hours_df = hours_df.reset_index(drop=True)

    rainfall_df['Date'] = pd.to_datetime(rainfall_df['Date'])
    rainfall_df['year'] = rainfall_df['Date'].apply(lambda date: date.year)
    rainfall_df['month'] = rainfall_df['Date'].apply(lambda date: date.month)
    rainfall_df = rainfall_df.sort_values(by="Date")
    rainfall_df = rainfall_df.reset_index(drop=True)

    list = []
    for x in temp_df.index:
        t = temp_df.iloc[x][f'{city}']
        svp = 6.1078*10**(7.5*t/(t+237.3))
        e = pressure_df.iloc[x][f'{city}']
        h = e/svp*100
        list.append(h)
        
    humidity_df = pd.DataFrame(data=list)
    humidity_df.rename(columns = {0:f'{city}'}, inplace = True)

    min_temp_df = CreateMin(temp_df, 'Temperature',f'{city}')
    min_pressure_df = CreateMin(pressure_df, 'Pressure',f'{city}')
    min_hours_df = CreateMin(hours_df, 'Hours',f'{city}')
    min_rainfall_df = CreateMin(rainfall_df, 'Rainfall',f'{city}')
    min_humidity_df = CreateMin(humidity_df, 'Humidity',f'{city}')

    df = pd.concat([virus_df_new, min_temp_df, min_pressure_df,min_hours_df,min_rainfall_df,min_humidity_df], axis=1)
    
    df = df.loc[:,~df.columns.duplicated()]
    
    df['VirusCRM'] = df['Virus_Count_Tokyo'].rolling(14, center = True).mean()

    for i in df.index:
        if i == 0:
            df.at[i,'Gradient'] = 1
        else:
            if df.iloc[i-1]['VirusCRM'] == 0:
                if df.at[i,'VirusCDM'] > 0:
                    df.at[i,'Gradient'] = 1
                else:
                    df.at[i,'Gradient'] = 0
            else:
                grd = df.iloc[i]['VirusCRM']/(df.iloc[i-1]['VirusCRM'])
                df.at[i,'Gradient'] = grd
    
    for i in df.index:
        if (df.iloc[i]['Gradient'] >= 1.1) and (df.iloc[i+1]['Gradient'] >= 1.1) and (df.iloc[i+2]['Gradient'] >= 1.1):
            df.at[i,'Spreading'] = 1
        else:
            df.at[i,'Spreading'] = 0
    df = df.astype({'Spreading':'int8'})

    df_virus_count = df[f'Virus_Count_{city}']
    df.drop(columns=['VirusCRM',f'Virus_Count_{city}','year','Gradient'], axis=1, inplace=True)
    df_labels = df[['Date']]
    FUTURE_PREDICTION = 4
    for i in range(FUTURE_PREDICTION):
        df_labels[f"T+{(i+1)*7}"] = df_labels["Date"] + pd.DateOffset(days = (i+1)*7)
    temp = df[["Date", "Spreading"]]
    for i in range(FUTURE_PREDICTION):
        target_column = f"T+{(i+1)*7}"
        df_labels = df_labels.merge(temp, 
                                how ="left",
                                left_on = (target_column),
                                right_on=("Date"),
                                suffixes = ("","_y")
        )
        df_labels.rename(columns={"Spreading":f"{target_column}_Spreading"},inplace=True)
    df_labels.drop(columns=["Date_y"],inplace=True)

    for i in range(FUTURE_PREDICTION):
        df_labels.drop(columns =[f"T+{(i+1)*7}"],inplace=True,axis=1 )

    df = df.merge(df_labels,
             how='left',
             on = ["Date"])
    df.dropna(inplace=True)

    X = df.drop(columns=['T+7_Spreading','T+14_Spreading','T+21_Spreading','T+28_Spreading'],axis=1)
    y1 = df['T+21_Spreading']
    y2 = df['T+7_Spreading']
    y3 = df['T+14_Spreading']
    y4 = df['T+28_Spreading']

    return X, y1, y2, y3, y4, df, df_virus_count

# %%
X, y1, y2, y3, y4, df, df_virus_count = DataPreprocess('Tokyo')
# Out:
# /Users/miyanishio/opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py:5039: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(
# /var/folders/k5/3yc13bs57f7637937yjlstth0000gn/T/ipykernel_10256/1453606338.py:165: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_labels[f"T+{(i+1)*7}"] = df_labels["Date"] + pd.DateOffset(days = (i+1)*7)

# %%
X = X.drop(columns=['Date'])

# %%
X = X[0:400] #until 2020 05-04
y1 = y1[0:400]
y2 = y2[0:400]
y3 = y2[0:400]
y4 = y2[0:400]

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

scaler = StandardScaler()
scaler1 = StandardScaler()
X_train, X_test = X[0:280], X[280:400]
y1_train, y1_test = y1[0:280], y1[280:400]

# %%
scaled_X_train = scaler1.fit_transform(X_train)
scaled_X_test = scaler1.transform(X_test)

# %%
model = Sequential()

model.add(Dense(12,activation="sigmoid"))
model.add(Dense(6,activation="sigmoid"))
model.add(Dense(3,activation="sigmoid"))

model.add(Dense(1, activation='sigmoid'))
model.compile(optimizer='rmsprop',loss='binary_crossentropy',metrics=['accuracy'])

# %%
early_stop = EarlyStopping(monitor='val_loss',mode='min',verbose=1,patience=50)

# %%
model.fit(scaled_X_train,y1_train,epochs=400,validation_data=(scaled_X_test,y1_test),callbacks=[early_stop])
# Out:
# Epoch 1/400
# 9/9 [==============================] - 1s 17ms/step - loss: 0.5233 - accuracy: 0.8357 - val_loss: 0.4718 - val_accuracy: 0.9000
# Epoch 2/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.5123 - accuracy: 0.8357 - val_loss: 0.4607 - val_accuracy: 0.9000
# Epoch 3/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.5048 - accuracy: 0.8357 - val_loss: 0.4517 - val_accuracy: 0.9000
# Epoch 4/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.4980 - accuracy: 0.8357 - val_loss: 0.4430 - val_accuracy: 0.9000
# Epoch 5/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.4918 - accuracy: 0.8357 - val_loss: 0.4350 - val_accuracy: 0.9000
# Epoch 6/400
# 9/9 [==============================] - 0s 7ms/step - loss: 0.4859 - accuracy: 0.8357 - val_loss: 0.4270 - val_accuracy: 0.9000
# Epoch 7/400
# 9/9 [==============================] - 0s 9ms/step - loss: 0.4803 - accuracy: 0.8357 - val_loss: 0.4195 - val_accuracy: 0.9000
# Epoch 8/400
# 9/9 [==============================] - 0s 19ms/step - loss: 0.4750 - accuracy: 0.8357 - val_loss: 0.4121 - val_accuracy: 0.9000
# Epoch 9/400
# 9/9 [==============================] - 0s 7ms/step - loss: 0.4702 - accuracy: 0.8357 - val_loss: 0.4057 - val_accuracy: 0.9000
# Epoch 10/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.4660 - accuracy: 0.8357 - val_loss: 0.4001 - val_accuracy: 0.9000
# Epoch 11/400
# 9/9 [==============================] - 0s 7ms/step - loss: 0.4621 - accuracy: 0.8357 - val_loss: 0.3945 - val_accuracy: 0.9000
# Epoch 12/400
# 9/9 [==============================] - 0s 9ms/step - loss: 0.4584 - accuracy: 0.8357 - val_loss: 0.3888 - val_accuracy: 0.9000
# Epoch 13/400
# 9/9 [==============================] - 0s 7ms/step - loss: 0.4549 - accuracy: 0.8357 - val_loss: 0.3840 - val_accuracy: 0.9000
# Epoch 14/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.4518 - accuracy: 0.8357 - val_loss: 0.3795 - val_accuracy: 0.9000
# Epoch 15/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.4489 - accuracy: 0.8357 - val_loss: 0.3748 - val_accuracy: 0.9000
# Epoch 16/400
# 9/9 [==============================] - 0s 8ms/step - loss: 0.4460 - accuracy: 0.8357 - val_loss: 0.3710 - val_accuracy: 0.9000
# Epoch 17/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.4436 - accuracy: 0.8357 - val_loss: 0.3674 - val_accuracy: 0.9000
# Epoch 18/400
# 9/9 [==============================] - 0s 7ms/step - loss: 0.4412 - accuracy: 0.8357 - val_loss: 0.3639 - val_accuracy: 0.9000
# Epoch 19/400
# 9/9 [==============================] - 0s 7ms/step - loss: 0.4389 - accuracy: 0.8357 - val_loss: 0.3605 - val_accuracy: 0.9000
# Epoch 20/400
# 9/9 [==============================] - 0s 7ms/step - loss: 0.4366 - accuracy: 0.8357 - val_loss: 0.3577 - val_accuracy: 0.9000
# Epoch 21/400
# 9/9 [==============================] - 0s 7ms/step - loss: 0.4346 - accuracy: 0.8357 - val_loss: 0.3549 - val_accuracy: 0.9000
# Epoch 22/400
# 9/9 [==============================] - 0s 8ms/step - loss: 0.4326 - accuracy: 0.8357 - val_loss: 0.3525 - val_accuracy: 0.9000
# Epoch 23/400
# 9/9 [==============================] - 0s 7ms/step - loss: 0.4309 - accuracy: 0.8357 - val_loss: 0.3504 - val_accuracy: 0.9000
# Epoch 24/400
# 9/9 [==============================] - 0s 7ms/step - loss: 0.4289 - accuracy: 0.8357 - val_loss: 0.3483 - val_accuracy: 0.9000
# Epoch 25/400
# 9/9 [==============================] - 0s 8ms/step - loss: 0.4270 - accuracy: 0.8357 - val_loss: 0.3457 - val_accuracy: 0.9000
# Epoch 26/400
# 9/9 [==============================] - 0s 7ms/step - loss: 0.4253 - accuracy: 0.8357 - val_loss: 0.3439 - val_accuracy: 0.9000
# Epoch 27/400
# 9/9 [==============================] - 0s 7ms/step - loss: 0.4234 - accuracy: 0.8357 - val_loss: 0.3421 - val_accuracy: 0.9000
# Epoch 28/400
# 9/9 [==============================] - 0s 9ms/step - loss: 0.4216 - accuracy: 0.8357 - val_loss: 0.3403 - val_accuracy: 0.9000
# Epoch 29/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.4198 - accuracy: 0.8357 - val_loss: 0.3384 - val_accuracy: 0.9000
# Epoch 30/400
# 9/9 [==============================] - 0s 7ms/step - loss: 0.4180 - accuracy: 0.8357 - val_loss: 0.3367 - val_accuracy: 0.9000
# Epoch 31/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.4162 - accuracy: 0.8357 - val_loss: 0.3353 - val_accuracy: 0.9000
# Epoch 32/400
# 9/9 [==============================] - 0s 8ms/step - loss: 0.4144 - accuracy: 0.8357 - val_loss: 0.3338 - val_accuracy: 0.9000
# Epoch 33/400
# 9/9 [==============================] - 0s 9ms/step - loss: 0.4126 - accuracy: 0.8357 - val_loss: 0.3325 - val_accuracy: 0.9000
# Epoch 34/400
# 9/9 [==============================] - 0s 7ms/step - loss: 0.4108 - accuracy: 0.8357 - val_loss: 0.3312 - val_accuracy: 0.9000
# Epoch 35/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.4088 - accuracy: 0.8357 - val_loss: 0.3298 - val_accuracy: 0.9000
# Epoch 36/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.4068 - accuracy: 0.8357 - val_loss: 0.3282 - val_accuracy: 0.9000
# Epoch 37/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.4049 - accuracy: 0.8357 - val_loss: 0.3269 - val_accuracy: 0.9000
# Epoch 38/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.4030 - accuracy: 0.8357 - val_loss: 0.3256 - val_accuracy: 0.9000
# Epoch 39/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.4009 - accuracy: 0.8357 - val_loss: 0.3244 - val_accuracy: 0.9000
# Epoch 40/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.3989 - accuracy: 0.8357 - val_loss: 0.3230 - val_accuracy: 0.9000
# Epoch 41/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.3968 - accuracy: 0.8357 - val_loss: 0.3217 - val_accuracy: 0.9000
# Epoch 42/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.3948 - accuracy: 0.8357 - val_loss: 0.3207 - val_accuracy: 0.9000
# Epoch 43/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.3928 - accuracy: 0.8357 - val_loss: 0.3197 - val_accuracy: 0.9000
# Epoch 44/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.3908 - accuracy: 0.8357 - val_loss: 0.3186 - val_accuracy: 0.9000
# Epoch 45/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.3888 - accuracy: 0.8357 - val_loss: 0.3177 - val_accuracy: 0.9000
# Epoch 46/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.3868 - accuracy: 0.8357 - val_loss: 0.3165 - val_accuracy: 0.9000
# Epoch 47/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.3849 - accuracy: 0.8357 - val_loss: 0.3156 - val_accuracy: 0.9000
# Epoch 48/400
# 9/9 [==============================] - 0s 7ms/step - loss: 0.3829 - accuracy: 0.8357 - val_loss: 0.3146 - val_accuracy: 0.9000
# Epoch 49/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.3810 - accuracy: 0.8357 - val_loss: 0.3137 - val_accuracy: 0.9000
# Epoch 50/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.3789 - accuracy: 0.8357 - val_loss: 0.3128 - val_accuracy: 0.9000
# Epoch 51/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.3770 - accuracy: 0.8357 - val_loss: 0.3119 - val_accuracy: 0.9000
# Epoch 52/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.3749 - accuracy: 0.8357 - val_loss: 0.3108 - val_accuracy: 0.9000
# Epoch 53/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.3731 - accuracy: 0.8357 - val_loss: 0.3100 - val_accuracy: 0.9000
# Epoch 54/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.3712 - accuracy: 0.8357 - val_loss: 0.3091 - val_accuracy: 0.9000
# Epoch 55/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.3693 - accuracy: 0.8357 - val_loss: 0.3082 - val_accuracy: 0.9000
# Epoch 56/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.3675 - accuracy: 0.8357 - val_loss: 0.3072 - val_accuracy: 0.9000
# Epoch 57/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.3654 - accuracy: 0.8357 - val_loss: 0.3064 - val_accuracy: 0.9000
# Epoch 58/400
# 9/9 [==============================] - 0s 7ms/step - loss: 0.3635 - accuracy: 0.8357 - val_loss: 0.3055 - val_accuracy: 0.9000
# Epoch 59/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.3615 - accuracy: 0.8357 - val_loss: 0.3046 - val_accuracy: 0.9000
# Epoch 60/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.3595 - accuracy: 0.8357 - val_loss: 0.3036 - val_accuracy: 0.9000
# Epoch 61/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.3576 - accuracy: 0.8357 - val_loss: 0.3028 - val_accuracy: 0.9000
# Epoch 62/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.3557 - accuracy: 0.8357 - val_loss: 0.3021 - val_accuracy: 0.9000
# Epoch 63/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.3539 - accuracy: 0.8357 - val_loss: 0.3012 - val_accuracy: 0.9000
# Epoch 64/400
# 9/9 [==============================] - 0s 7ms/step - loss: 0.3520 - accuracy: 0.8357 - val_loss: 0.3004 - val_accuracy: 0.9000
# Epoch 65/400
# 9/9 [==============================] - 0s 8ms/step - loss: 0.3501 - accuracy: 0.8357 - val_loss: 0.2995 - val_accuracy: 0.9000
# Epoch 66/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.3481 - accuracy: 0.8357 - val_loss: 0.2985 - val_accuracy: 0.9000
# Epoch 67/400
# 9/9 [==============================] - 0s 8ms/step - loss: 0.3461 - accuracy: 0.8357 - val_loss: 0.2978 - val_accuracy: 0.9000
# Epoch 68/400
# 9/9 [==============================] - 0s 7ms/step - loss: 0.3441 - accuracy: 0.8357 - val_loss: 0.2972 - val_accuracy: 0.9000
# Epoch 69/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.3424 - accuracy: 0.8357 - val_loss: 0.2965 - val_accuracy: 0.9000
# Epoch 70/400
# 9/9 [==============================] - 0s 7ms/step - loss: 0.3406 - accuracy: 0.8357 - val_loss: 0.2957 - val_accuracy: 0.9000
# Epoch 71/400
# 9/9 [==============================] - 0s 8ms/step - loss: 0.3389 - accuracy: 0.8357 - val_loss: 0.2948 - val_accuracy: 0.9000
# Epoch 72/400
# 9/9 [==============================] - 0s 8ms/step - loss: 0.3373 - accuracy: 0.8357 - val_loss: 0.2942 - val_accuracy: 0.9000
# Epoch 73/400
# 9/9 [==============================] - 0s 16ms/step - loss: 0.3356 - accuracy: 0.8357 - val_loss: 0.2935 - val_accuracy: 0.9000
# Epoch 74/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.3343 - accuracy: 0.8357 - val_loss: 0.2929 - val_accuracy: 0.9000
# Epoch 75/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.3326 - accuracy: 0.8357 - val_loss: 0.2923 - val_accuracy: 0.9000
# Epoch 76/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.3311 - accuracy: 0.8357 - val_loss: 0.2917 - val_accuracy: 0.9000
# Epoch 77/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.3296 - accuracy: 0.8357 - val_loss: 0.2911 - val_accuracy: 0.9000
# Epoch 78/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.3279 - accuracy: 0.8357 - val_loss: 0.2903 - val_accuracy: 0.9000
# Epoch 79/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.3262 - accuracy: 0.8357 - val_loss: 0.2897 - val_accuracy: 0.9000
# Epoch 80/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.3246 - accuracy: 0.8357 - val_loss: 0.2888 - val_accuracy: 0.9000
# Epoch 81/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.3230 - accuracy: 0.8357 - val_loss: 0.2882 - val_accuracy: 0.9000
# Epoch 82/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.3214 - accuracy: 0.8357 - val_loss: 0.2876 - val_accuracy: 0.9000
# Epoch 83/400
# 9/9 [==============================] - 0s 7ms/step - loss: 0.3202 - accuracy: 0.8357 - val_loss: 0.2870 - val_accuracy: 0.9000
# Epoch 84/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.3186 - accuracy: 0.8357 - val_loss: 0.2863 - val_accuracy: 0.9000
# Epoch 85/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.3174 - accuracy: 0.8357 - val_loss: 0.2856 - val_accuracy: 0.9000
# Epoch 86/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.3161 - accuracy: 0.8357 - val_loss: 0.2850 - val_accuracy: 0.9000
# Epoch 87/400
# 9/9 [==============================] - 0s 12ms/step - loss: 0.3147 - accuracy: 0.8357 - val_loss: 0.2845 - val_accuracy: 0.9000
# Epoch 88/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.3136 - accuracy: 0.8357 - val_loss: 0.2840 - val_accuracy: 0.9000
# Epoch 89/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.3124 - accuracy: 0.8357 - val_loss: 0.2834 - val_accuracy: 0.9000
# Epoch 90/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.3112 - accuracy: 0.8357 - val_loss: 0.2829 - val_accuracy: 0.9000
# Epoch 91/400
# 9/9 [==============================] - 0s 7ms/step - loss: 0.3102 - accuracy: 0.8357 - val_loss: 0.2823 - val_accuracy: 0.9000
# Epoch 92/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.3090 - accuracy: 0.8357 - val_loss: 0.2819 - val_accuracy: 0.9000
# Epoch 93/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.3078 - accuracy: 0.8357 - val_loss: 0.2814 - val_accuracy: 0.9000
# Epoch 94/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.3066 - accuracy: 0.8357 - val_loss: 0.2807 - val_accuracy: 0.9000
# Epoch 95/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.3057 - accuracy: 0.8357 - val_loss: 0.2802 - val_accuracy: 0.9000
# Epoch 96/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.3046 - accuracy: 0.8357 - val_loss: 0.2796 - val_accuracy: 0.9000
# Epoch 97/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.3034 - accuracy: 0.8357 - val_loss: 0.2791 - val_accuracy: 0.9000
# Epoch 98/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.3025 - accuracy: 0.8357 - val_loss: 0.2785 - val_accuracy: 0.9000
# Epoch 99/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.3016 - accuracy: 0.8357 - val_loss: 0.2782 - val_accuracy: 0.9000
# Epoch 100/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.3006 - accuracy: 0.8357 - val_loss: 0.2778 - val_accuracy: 0.9000
# Epoch 101/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2996 - accuracy: 0.8357 - val_loss: 0.2774 - val_accuracy: 0.9000
# Epoch 102/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2987 - accuracy: 0.8357 - val_loss: 0.2768 - val_accuracy: 0.9000
# Epoch 103/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2978 - accuracy: 0.8357 - val_loss: 0.2764 - val_accuracy: 0.9000
# Epoch 104/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2968 - accuracy: 0.8357 - val_loss: 0.2759 - val_accuracy: 0.9000
# Epoch 105/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2959 - accuracy: 0.8357 - val_loss: 0.2754 - val_accuracy: 0.9000
# Epoch 106/400
# 9/9 [==============================] - 0s 9ms/step - loss: 0.2948 - accuracy: 0.8357 - val_loss: 0.2750 - val_accuracy: 0.9000
# Epoch 107/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2939 - accuracy: 0.8357 - val_loss: 0.2744 - val_accuracy: 0.9000
# Epoch 108/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2931 - accuracy: 0.8357 - val_loss: 0.2738 - val_accuracy: 0.9000
# Epoch 109/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.2921 - accuracy: 0.8357 - val_loss: 0.2733 - val_accuracy: 0.9000
# Epoch 110/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2914 - accuracy: 0.8357 - val_loss: 0.2727 - val_accuracy: 0.9000
# Epoch 111/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2904 - accuracy: 0.8357 - val_loss: 0.2722 - val_accuracy: 0.9000
# Epoch 112/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2897 - accuracy: 0.8357 - val_loss: 0.2717 - val_accuracy: 0.9000
# Epoch 113/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2888 - accuracy: 0.8357 - val_loss: 0.2712 - val_accuracy: 0.9000
# Epoch 114/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.2879 - accuracy: 0.8357 - val_loss: 0.2706 - val_accuracy: 0.9000
# Epoch 115/400
# 9/9 [==============================] - 0s 7ms/step - loss: 0.2871 - accuracy: 0.8357 - val_loss: 0.2702 - val_accuracy: 0.9000
# Epoch 116/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.2864 - accuracy: 0.8357 - val_loss: 0.2696 - val_accuracy: 0.9000
# Epoch 117/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.2856 - accuracy: 0.8357 - val_loss: 0.2691 - val_accuracy: 0.9000
# Epoch 118/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2849 - accuracy: 0.8357 - val_loss: 0.2688 - val_accuracy: 0.9000
# Epoch 119/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2844 - accuracy: 0.8357 - val_loss: 0.2684 - val_accuracy: 0.9000
# Epoch 120/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2835 - accuracy: 0.8357 - val_loss: 0.2679 - val_accuracy: 0.9000
# Epoch 121/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2828 - accuracy: 0.8357 - val_loss: 0.2674 - val_accuracy: 0.9000
# Epoch 122/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2822 - accuracy: 0.8357 - val_loss: 0.2667 - val_accuracy: 0.9000
# Epoch 123/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2814 - accuracy: 0.8357 - val_loss: 0.2662 - val_accuracy: 0.9000
# Epoch 124/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2808 - accuracy: 0.8357 - val_loss: 0.2659 - val_accuracy: 0.9000
# Epoch 125/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2800 - accuracy: 0.8357 - val_loss: 0.2652 - val_accuracy: 0.9000
# Epoch 126/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2794 - accuracy: 0.8357 - val_loss: 0.2646 - val_accuracy: 0.9000
# Epoch 127/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2787 - accuracy: 0.8357 - val_loss: 0.2640 - val_accuracy: 0.9000
# Epoch 128/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2781 - accuracy: 0.8357 - val_loss: 0.2635 - val_accuracy: 0.9000
# Epoch 129/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2775 - accuracy: 0.8393 - val_loss: 0.2630 - val_accuracy: 0.9000
# Epoch 130/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2770 - accuracy: 0.8429 - val_loss: 0.2624 - val_accuracy: 0.9000
# Epoch 131/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2763 - accuracy: 0.8571 - val_loss: 0.2619 - val_accuracy: 0.8917
# Epoch 132/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2756 - accuracy: 0.8607 - val_loss: 0.2616 - val_accuracy: 0.8750
# Epoch 133/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2749 - accuracy: 0.8893 - val_loss: 0.2610 - val_accuracy: 0.8750
# Epoch 134/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2744 - accuracy: 0.8857 - val_loss: 0.2604 - val_accuracy: 0.8917
# Epoch 135/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2739 - accuracy: 0.8857 - val_loss: 0.2600 - val_accuracy: 0.8917
# Epoch 136/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2731 - accuracy: 0.8893 - val_loss: 0.2595 - val_accuracy: 0.8917
# Epoch 137/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2730 - accuracy: 0.8857 - val_loss: 0.2588 - val_accuracy: 0.8917
# Epoch 138/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2722 - accuracy: 0.8893 - val_loss: 0.2583 - val_accuracy: 0.8917
# Epoch 139/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2716 - accuracy: 0.8857 - val_loss: 0.2577 - val_accuracy: 0.9000
# Epoch 140/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2714 - accuracy: 0.8857 - val_loss: 0.2572 - val_accuracy: 0.9000
# Epoch 141/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2706 - accuracy: 0.8857 - val_loss: 0.2567 - val_accuracy: 0.9000
# Epoch 142/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2701 - accuracy: 0.8821 - val_loss: 0.2563 - val_accuracy: 0.9000
# Epoch 143/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2695 - accuracy: 0.8821 - val_loss: 0.2557 - val_accuracy: 0.9000
# Epoch 144/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.2690 - accuracy: 0.8821 - val_loss: 0.2552 - val_accuracy: 0.9000
# Epoch 145/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.2685 - accuracy: 0.8821 - val_loss: 0.2547 - val_accuracy: 0.9000
# Epoch 146/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2679 - accuracy: 0.8821 - val_loss: 0.2544 - val_accuracy: 0.9000
# Epoch 147/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.2674 - accuracy: 0.8821 - val_loss: 0.2537 - val_accuracy: 0.9000
# Epoch 148/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2669 - accuracy: 0.8821 - val_loss: 0.2535 - val_accuracy: 0.9000
# Epoch 149/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2665 - accuracy: 0.8857 - val_loss: 0.2530 - val_accuracy: 0.9000
# Epoch 150/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2661 - accuracy: 0.8857 - val_loss: 0.2526 - val_accuracy: 0.9000
# Epoch 151/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2655 - accuracy: 0.8857 - val_loss: 0.2523 - val_accuracy: 0.9000
# Epoch 152/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2651 - accuracy: 0.8857 - val_loss: 0.2518 - val_accuracy: 0.9000
# Epoch 153/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.2647 - accuracy: 0.8857 - val_loss: 0.2513 - val_accuracy: 0.9000
# Epoch 154/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2642 - accuracy: 0.8857 - val_loss: 0.2509 - val_accuracy: 0.9000
# Epoch 155/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.2637 - accuracy: 0.8857 - val_loss: 0.2504 - val_accuracy: 0.9000
# Epoch 156/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.2634 - accuracy: 0.8857 - val_loss: 0.2502 - val_accuracy: 0.9000
# Epoch 157/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2630 - accuracy: 0.8857 - val_loss: 0.2497 - val_accuracy: 0.9000
# Epoch 158/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.2627 - accuracy: 0.8857 - val_loss: 0.2491 - val_accuracy: 0.9000
# Epoch 159/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.2621 - accuracy: 0.8857 - val_loss: 0.2484 - val_accuracy: 0.9000
# Epoch 160/400
# 9/9 [==============================] - 0s 7ms/step - loss: 0.2621 - accuracy: 0.8857 - val_loss: 0.2482 - val_accuracy: 0.9000
# Epoch 161/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2615 - accuracy: 0.8857 - val_loss: 0.2478 - val_accuracy: 0.9000
# Epoch 162/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2611 - accuracy: 0.8857 - val_loss: 0.2474 - val_accuracy: 0.9000
# Epoch 163/400
# 9/9 [==============================] - 0s 3ms/step - loss: 0.2610 - accuracy: 0.8857 - val_loss: 0.2470 - val_accuracy: 0.9000
# Epoch 164/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.2606 - accuracy: 0.8857 - val_loss: 0.2465 - val_accuracy: 0.9000
# Epoch 165/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2602 - accuracy: 0.8857 - val_loss: 0.2461 - val_accuracy: 0.9000
# Epoch 166/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.2598 - accuracy: 0.8857 - val_loss: 0.2455 - val_accuracy: 0.9000
# Epoch 167/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.2594 - accuracy: 0.8857 - val_loss: 0.2451 - val_accuracy: 0.9000
# Epoch 168/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.2595 - accuracy: 0.8857 - val_loss: 0.2446 - val_accuracy: 0.9000
# Epoch 169/400
# 9/9 [==============================] - 0s 9ms/step - loss: 0.2590 - accuracy: 0.8857 - val_loss: 0.2444 - val_accuracy: 0.9000
# Epoch 170/400
# 9/9 [==============================] - 0s 9ms/step - loss: 0.2584 - accuracy: 0.8857 - val_loss: 0.2441 - val_accuracy: 0.9000
# Epoch 171/400
# 9/9 [==============================] - 0s 12ms/step - loss: 0.2584 - accuracy: 0.8857 - val_loss: 0.2437 - val_accuracy: 0.9000
# Epoch 172/400
# 9/9 [==============================] - 0s 8ms/step - loss: 0.2579 - accuracy: 0.8857 - val_loss: 0.2433 - val_accuracy: 0.9000
# Epoch 173/400
# 9/9 [==============================] - 0s 9ms/step - loss: 0.2575 - accuracy: 0.8857 - val_loss: 0.2431 - val_accuracy: 0.9000
# Epoch 174/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.2574 - accuracy: 0.8857 - val_loss: 0.2429 - val_accuracy: 0.9000
# Epoch 175/400
# 9/9 [==============================] - 0s 7ms/step - loss: 0.2572 - accuracy: 0.8857 - val_loss: 0.2427 - val_accuracy: 0.9000
# Epoch 176/400
# 9/9 [==============================] - 0s 7ms/step - loss: 0.2568 - accuracy: 0.8857 - val_loss: 0.2424 - val_accuracy: 0.9000
# Epoch 177/400
# 9/9 [==============================] - 0s 7ms/step - loss: 0.2565 - accuracy: 0.8857 - val_loss: 0.2420 - val_accuracy: 0.9000
# Epoch 178/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.2561 - accuracy: 0.8857 - val_loss: 0.2416 - val_accuracy: 0.9000
# Epoch 179/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2557 - accuracy: 0.8857 - val_loss: 0.2412 - val_accuracy: 0.9000
# Epoch 180/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.2557 - accuracy: 0.8857 - val_loss: 0.2410 - val_accuracy: 0.9000
# Epoch 181/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.2554 - accuracy: 0.8857 - val_loss: 0.2406 - val_accuracy: 0.9000
# Epoch 182/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2549 - accuracy: 0.8857 - val_loss: 0.2401 - val_accuracy: 0.9000
# Epoch 183/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2547 - accuracy: 0.8857 - val_loss: 0.2398 - val_accuracy: 0.9000
# Epoch 184/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.2545 - accuracy: 0.8857 - val_loss: 0.2396 - val_accuracy: 0.9000
# Epoch 185/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2543 - accuracy: 0.8857 - val_loss: 0.2395 - val_accuracy: 0.9000
# Epoch 186/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2540 - accuracy: 0.8857 - val_loss: 0.2390 - val_accuracy: 0.9000
# Epoch 187/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2541 - accuracy: 0.8857 - val_loss: 0.2384 - val_accuracy: 0.9000
# Epoch 188/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2535 - accuracy: 0.8857 - val_loss: 0.2382 - val_accuracy: 0.9000
# Epoch 189/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2531 - accuracy: 0.8857 - val_loss: 0.2378 - val_accuracy: 0.9000
# Epoch 190/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2532 - accuracy: 0.8821 - val_loss: 0.2375 - val_accuracy: 0.9000
# Epoch 191/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2528 - accuracy: 0.8857 - val_loss: 0.2374 - val_accuracy: 0.9000
# Epoch 192/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.2526 - accuracy: 0.8857 - val_loss: 0.2370 - val_accuracy: 0.9000
# Epoch 193/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2525 - accuracy: 0.8821 - val_loss: 0.2367 - val_accuracy: 0.9000
# Epoch 194/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.2522 - accuracy: 0.8857 - val_loss: 0.2363 - val_accuracy: 0.9000
# Epoch 195/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2520 - accuracy: 0.8821 - val_loss: 0.2359 - val_accuracy: 0.9000
# Epoch 196/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2519 - accuracy: 0.8821 - val_loss: 0.2357 - val_accuracy: 0.9000
# Epoch 197/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.2515 - accuracy: 0.8821 - val_loss: 0.2354 - val_accuracy: 0.9000
# Epoch 198/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2512 - accuracy: 0.8821 - val_loss: 0.2352 - val_accuracy: 0.9000
# Epoch 199/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2512 - accuracy: 0.8821 - val_loss: 0.2351 - val_accuracy: 0.9000
# Epoch 200/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2512 - accuracy: 0.8821 - val_loss: 0.2350 - val_accuracy: 0.9000
# Epoch 201/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2508 - accuracy: 0.8821 - val_loss: 0.2348 - val_accuracy: 0.9000
# Epoch 202/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.2505 - accuracy: 0.8821 - val_loss: 0.2344 - val_accuracy: 0.9000
# Epoch 203/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2504 - accuracy: 0.8821 - val_loss: 0.2340 - val_accuracy: 0.9000
# Epoch 204/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.2500 - accuracy: 0.8857 - val_loss: 0.2335 - val_accuracy: 0.9000
# Epoch 205/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.2500 - accuracy: 0.8821 - val_loss: 0.2331 - val_accuracy: 0.9000
# Epoch 206/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2499 - accuracy: 0.8857 - val_loss: 0.2328 - val_accuracy: 0.9000
# Epoch 207/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2495 - accuracy: 0.8821 - val_loss: 0.2327 - val_accuracy: 0.9000
# Epoch 208/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2495 - accuracy: 0.8821 - val_loss: 0.2324 - val_accuracy: 0.9000
# Epoch 209/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.2491 - accuracy: 0.8857 - val_loss: 0.2318 - val_accuracy: 0.9000
# Epoch 210/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2491 - accuracy: 0.8821 - val_loss: 0.2317 - val_accuracy: 0.9000
# Epoch 211/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.2489 - accuracy: 0.8821 - val_loss: 0.2316 - val_accuracy: 0.9000
# Epoch 212/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.2488 - accuracy: 0.8857 - val_loss: 0.2313 - val_accuracy: 0.9000
# Epoch 213/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.2484 - accuracy: 0.8857 - val_loss: 0.2309 - val_accuracy: 0.9000
# Epoch 214/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.2481 - accuracy: 0.8857 - val_loss: 0.2307 - val_accuracy: 0.9000
# Epoch 215/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2482 - accuracy: 0.8857 - val_loss: 0.2302 - val_accuracy: 0.9000
# Epoch 216/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.2481 - accuracy: 0.8857 - val_loss: 0.2299 - val_accuracy: 0.9000
# Epoch 217/400
# 9/9 [==============================] - 0s 10ms/step - loss: 0.2479 - accuracy: 0.8857 - val_loss: 0.2298 - val_accuracy: 0.9000
# Epoch 218/400
# 9/9 [==============================] - 0s 8ms/step - loss: 0.2475 - accuracy: 0.8857 - val_loss: 0.2295 - val_accuracy: 0.9000
# Epoch 219/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2478 - accuracy: 0.8857 - val_loss: 0.2290 - val_accuracy: 0.9000
# Epoch 220/400
# 9/9 [==============================] - 0s 7ms/step - loss: 0.2474 - accuracy: 0.8857 - val_loss: 0.2287 - val_accuracy: 0.9000
# Epoch 221/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.2473 - accuracy: 0.8857 - val_loss: 0.2285 - val_accuracy: 0.9000
# Epoch 222/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.2469 - accuracy: 0.8821 - val_loss: 0.2285 - val_accuracy: 0.9000
# Epoch 223/400
# 9/9 [==============================] - 0s 7ms/step - loss: 0.2467 - accuracy: 0.8857 - val_loss: 0.2281 - val_accuracy: 0.9000
# Epoch 224/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.2466 - accuracy: 0.8857 - val_loss: 0.2275 - val_accuracy: 0.9000
# Epoch 225/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.2465 - accuracy: 0.8857 - val_loss: 0.2272 - val_accuracy: 0.9000
# Epoch 226/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.2462 - accuracy: 0.8857 - val_loss: 0.2269 - val_accuracy: 0.9000
# Epoch 227/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.2465 - accuracy: 0.8857 - val_loss: 0.2265 - val_accuracy: 0.9000
# Epoch 228/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.2459 - accuracy: 0.8857 - val_loss: 0.2261 - val_accuracy: 0.9000
# Epoch 229/400
# 9/9 [==============================] - 0s 7ms/step - loss: 0.2456 - accuracy: 0.8857 - val_loss: 0.2260 - val_accuracy: 0.9000
# Epoch 230/400
# 9/9 [==============================] - 0s 14ms/step - loss: 0.2456 - accuracy: 0.8857 - val_loss: 0.2256 - val_accuracy: 0.9000
# Epoch 231/400
# 9/9 [==============================] - 0s 14ms/step - loss: 0.2454 - accuracy: 0.8857 - val_loss: 0.2255 - val_accuracy: 0.9000
# Epoch 232/400
# 9/9 [==============================] - 0s 17ms/step - loss: 0.2452 - accuracy: 0.8857 - val_loss: 0.2254 - val_accuracy: 0.9000
# Epoch 233/400
# 9/9 [==============================] - 0s 7ms/step - loss: 0.2452 - accuracy: 0.8857 - val_loss: 0.2253 - val_accuracy: 0.9000
# Epoch 234/400
# 9/9 [==============================] - 0s 9ms/step - loss: 0.2448 - accuracy: 0.8857 - val_loss: 0.2252 - val_accuracy: 0.9000
# Epoch 235/400
# 9/9 [==============================] - 0s 13ms/step - loss: 0.2452 - accuracy: 0.8857 - val_loss: 0.2249 - val_accuracy: 0.9000
# Epoch 236/400
# 9/9 [==============================] - 0s 7ms/step - loss: 0.2446 - accuracy: 0.8857 - val_loss: 0.2244 - val_accuracy: 0.9000
# Epoch 237/400
# 9/9 [==============================] - 0s 7ms/step - loss: 0.2444 - accuracy: 0.8857 - val_loss: 0.2241 - val_accuracy: 0.9000
# Epoch 238/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.2443 - accuracy: 0.8857 - val_loss: 0.2237 - val_accuracy: 0.9000
# Epoch 239/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2443 - accuracy: 0.8857 - val_loss: 0.2233 - val_accuracy: 0.9000
# Epoch 240/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2440 - accuracy: 0.8857 - val_loss: 0.2228 - val_accuracy: 0.9000
# Epoch 241/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.2437 - accuracy: 0.8857 - val_loss: 0.2225 - val_accuracy: 0.9000
# Epoch 242/400
# 9/9 [==============================] - 0s 8ms/step - loss: 0.2437 - accuracy: 0.8857 - val_loss: 0.2221 - val_accuracy: 0.9000
# Epoch 243/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.2435 - accuracy: 0.8857 - val_loss: 0.2222 - val_accuracy: 0.9000
# Epoch 244/400
# 9/9 [==============================] - 0s 7ms/step - loss: 0.2434 - accuracy: 0.8857 - val_loss: 0.2222 - val_accuracy: 0.9000
# Epoch 245/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.2433 - accuracy: 0.8857 - val_loss: 0.2218 - val_accuracy: 0.9000
# Epoch 246/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.2434 - accuracy: 0.8857 - val_loss: 0.2214 - val_accuracy: 0.9000
# Epoch 247/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.2428 - accuracy: 0.8857 - val_loss: 0.2212 - val_accuracy: 0.9000
# Epoch 248/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2428 - accuracy: 0.8857 - val_loss: 0.2207 - val_accuracy: 0.9000
# Epoch 249/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2427 - accuracy: 0.8857 - val_loss: 0.2202 - val_accuracy: 0.9000
# Epoch 250/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2424 - accuracy: 0.8857 - val_loss: 0.2202 - val_accuracy: 0.9000
# Epoch 251/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2427 - accuracy: 0.8857 - val_loss: 0.2201 - val_accuracy: 0.9000
# Epoch 252/400
# 9/9 [==============================] - 0s 10ms/step - loss: 0.2423 - accuracy: 0.8857 - val_loss: 0.2199 - val_accuracy: 0.9000
# Epoch 253/400
# 9/9 [==============================] - 0s 7ms/step - loss: 0.2421 - accuracy: 0.8893 - val_loss: 0.2195 - val_accuracy: 0.9000
# Epoch 254/400
# 9/9 [==============================] - 0s 11ms/step - loss: 0.2420 - accuracy: 0.8857 - val_loss: 0.2191 - val_accuracy: 0.9000
# Epoch 255/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2417 - accuracy: 0.8857 - val_loss: 0.2191 - val_accuracy: 0.9000
# Epoch 256/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2416 - accuracy: 0.8857 - val_loss: 0.2187 - val_accuracy: 0.9000
# Epoch 257/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.2415 - accuracy: 0.8857 - val_loss: 0.2182 - val_accuracy: 0.9000
# Epoch 258/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.2415 - accuracy: 0.8857 - val_loss: 0.2178 - val_accuracy: 0.9000
# Epoch 259/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.2413 - accuracy: 0.8857 - val_loss: 0.2175 - val_accuracy: 0.9000
# Epoch 260/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.2411 - accuracy: 0.8893 - val_loss: 0.2172 - val_accuracy: 0.9000
# Epoch 261/400
# 9/9 [==============================] - 0s 8ms/step - loss: 0.2409 - accuracy: 0.8857 - val_loss: 0.2173 - val_accuracy: 0.9000
# Epoch 262/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.2409 - accuracy: 0.8857 - val_loss: 0.2169 - val_accuracy: 0.9000
# Epoch 263/400
# 9/9 [==============================] - 0s 8ms/step - loss: 0.2407 - accuracy: 0.8857 - val_loss: 0.2165 - val_accuracy: 0.9000
# Epoch 264/400
# 9/9 [==============================] - 0s 10ms/step - loss: 0.2408 - accuracy: 0.8857 - val_loss: 0.2164 - val_accuracy: 0.9000
# Epoch 265/400
# 9/9 [==============================] - 0s 9ms/step - loss: 0.2403 - accuracy: 0.8857 - val_loss: 0.2163 - val_accuracy: 0.9000
# Epoch 266/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.2404 - accuracy: 0.8857 - val_loss: 0.2159 - val_accuracy: 0.9000
# Epoch 267/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2404 - accuracy: 0.8857 - val_loss: 0.2157 - val_accuracy: 0.9000
# Epoch 268/400
# 9/9 [==============================] - 0s 7ms/step - loss: 0.2401 - accuracy: 0.8857 - val_loss: 0.2156 - val_accuracy: 0.9000
# Epoch 269/400
# 9/9 [==============================] - 0s 8ms/step - loss: 0.2398 - accuracy: 0.8857 - val_loss: 0.2151 - val_accuracy: 0.9000
# Epoch 270/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.2404 - accuracy: 0.8893 - val_loss: 0.2148 - val_accuracy: 0.9000
# Epoch 271/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.2398 - accuracy: 0.8857 - val_loss: 0.2149 - val_accuracy: 0.9000
# Epoch 272/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.2396 - accuracy: 0.8893 - val_loss: 0.2147 - val_accuracy: 0.9000
# Epoch 273/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2394 - accuracy: 0.8893 - val_loss: 0.2142 - val_accuracy: 0.9000
# Epoch 274/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2392 - accuracy: 0.8857 - val_loss: 0.2140 - val_accuracy: 0.9000
# Epoch 275/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2392 - accuracy: 0.8857 - val_loss: 0.2138 - val_accuracy: 0.9000
# Epoch 276/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2390 - accuracy: 0.8857 - val_loss: 0.2136 - val_accuracy: 0.9000
# Epoch 277/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.2394 - accuracy: 0.8857 - val_loss: 0.2131 - val_accuracy: 0.9000
# Epoch 278/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2387 - accuracy: 0.8893 - val_loss: 0.2127 - val_accuracy: 0.9000
# Epoch 279/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.2387 - accuracy: 0.8893 - val_loss: 0.2125 - val_accuracy: 0.9000
# Epoch 280/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.2388 - accuracy: 0.8893 - val_loss: 0.2121 - val_accuracy: 0.9000
# Epoch 281/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.2383 - accuracy: 0.8893 - val_loss: 0.2119 - val_accuracy: 0.9000
# Epoch 282/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2385 - accuracy: 0.8857 - val_loss: 0.2118 - val_accuracy: 0.9000
# Epoch 283/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.2383 - accuracy: 0.8893 - val_loss: 0.2112 - val_accuracy: 0.9000
# Epoch 284/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.2381 - accuracy: 0.8857 - val_loss: 0.2109 - val_accuracy: 0.9000
# Epoch 285/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.2379 - accuracy: 0.8857 - val_loss: 0.2108 - val_accuracy: 0.9000
# Epoch 286/400
# 9/9 [==============================] - 0s 7ms/step - loss: 0.2379 - accuracy: 0.8857 - val_loss: 0.2106 - val_accuracy: 0.9000
# Epoch 287/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2378 - accuracy: 0.8857 - val_loss: 0.2103 - val_accuracy: 0.9000
# Epoch 288/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2374 - accuracy: 0.8857 - val_loss: 0.2103 - val_accuracy: 0.9000
# Epoch 289/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.2376 - accuracy: 0.8893 - val_loss: 0.2098 - val_accuracy: 0.9000
# Epoch 290/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.2372 - accuracy: 0.8857 - val_loss: 0.2093 - val_accuracy: 0.9000
# Epoch 291/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2372 - accuracy: 0.8893 - val_loss: 0.2088 - val_accuracy: 0.9000
# Epoch 292/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.2372 - accuracy: 0.8857 - val_loss: 0.2087 - val_accuracy: 0.9000
# Epoch 293/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2372 - accuracy: 0.8893 - val_loss: 0.2084 - val_accuracy: 0.9000
# Epoch 294/400
# 9/9 [==============================] - 0s 17ms/step - loss: 0.2367 - accuracy: 0.8893 - val_loss: 0.2081 - val_accuracy: 0.9000
# Epoch 295/400
# 9/9 [==============================] - 0s 7ms/step - loss: 0.2366 - accuracy: 0.8857 - val_loss: 0.2083 - val_accuracy: 0.9000
# Epoch 296/400
# 9/9 [==============================] - 0s 11ms/step - loss: 0.2366 - accuracy: 0.8893 - val_loss: 0.2080 - val_accuracy: 0.9000
# Epoch 297/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.2364 - accuracy: 0.8857 - val_loss: 0.2079 - val_accuracy: 0.9000
# Epoch 298/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.2363 - accuracy: 0.8857 - val_loss: 0.2079 - val_accuracy: 0.9000
# Epoch 299/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.2360 - accuracy: 0.8893 - val_loss: 0.2074 - val_accuracy: 0.9000
# Epoch 300/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.2361 - accuracy: 0.8893 - val_loss: 0.2073 - val_accuracy: 0.9000
# Epoch 301/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.2364 - accuracy: 0.8857 - val_loss: 0.2070 - val_accuracy: 0.9000
# Epoch 302/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.2357 - accuracy: 0.8893 - val_loss: 0.2064 - val_accuracy: 0.9000
# Epoch 303/400
# 9/9 [==============================] - 0s 8ms/step - loss: 0.2356 - accuracy: 0.8893 - val_loss: 0.2065 - val_accuracy: 0.9000
# Epoch 304/400
# 9/9 [==============================] - 0s 7ms/step - loss: 0.2358 - accuracy: 0.8857 - val_loss: 0.2065 - val_accuracy: 0.9000
# Epoch 305/400
# 9/9 [==============================] - 0s 7ms/step - loss: 0.2353 - accuracy: 0.8893 - val_loss: 0.2063 - val_accuracy: 0.9000
# Epoch 306/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.2352 - accuracy: 0.8857 - val_loss: 0.2063 - val_accuracy: 0.9000
# Epoch 307/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.2352 - accuracy: 0.8893 - val_loss: 0.2057 - val_accuracy: 0.9000
# Epoch 308/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.2348 - accuracy: 0.8893 - val_loss: 0.2054 - val_accuracy: 0.9000
# Epoch 309/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.2352 - accuracy: 0.8857 - val_loss: 0.2053 - val_accuracy: 0.9000
# Epoch 310/400
# 9/9 [==============================] - 0s 7ms/step - loss: 0.2346 - accuracy: 0.8893 - val_loss: 0.2050 - val_accuracy: 0.9000
# Epoch 311/400
# 9/9 [==============================] - 0s 9ms/step - loss: 0.2348 - accuracy: 0.8857 - val_loss: 0.2049 - val_accuracy: 0.9000
# Epoch 312/400
# 9/9 [==============================] - 0s 8ms/step - loss: 0.2347 - accuracy: 0.8893 - val_loss: 0.2048 - val_accuracy: 0.9000
# Epoch 313/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.2343 - accuracy: 0.8893 - val_loss: 0.2041 - val_accuracy: 0.9000
# Epoch 314/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.2341 - accuracy: 0.8893 - val_loss: 0.2038 - val_accuracy: 0.9000
# Epoch 315/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.2341 - accuracy: 0.8893 - val_loss: 0.2033 - val_accuracy: 0.9000
# Epoch 316/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.2339 - accuracy: 0.8893 - val_loss: 0.2028 - val_accuracy: 0.9000
# Epoch 317/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.2342 - accuracy: 0.8857 - val_loss: 0.2027 - val_accuracy: 0.9000
# Epoch 318/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.2338 - accuracy: 0.8893 - val_loss: 0.2024 - val_accuracy: 0.9000
# Epoch 319/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.2337 - accuracy: 0.8893 - val_loss: 0.2022 - val_accuracy: 0.9000
# Epoch 320/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2335 - accuracy: 0.8893 - val_loss: 0.2017 - val_accuracy: 0.9000
# Epoch 321/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2333 - accuracy: 0.8857 - val_loss: 0.2015 - val_accuracy: 0.9000
# Epoch 322/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.2334 - accuracy: 0.8857 - val_loss: 0.2014 - val_accuracy: 0.9000
# Epoch 323/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.2331 - accuracy: 0.8857 - val_loss: 0.2014 - val_accuracy: 0.9000
# Epoch 324/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.2330 - accuracy: 0.8857 - val_loss: 0.2013 - val_accuracy: 0.9000
# Epoch 325/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.2328 - accuracy: 0.8893 - val_loss: 0.2010 - val_accuracy: 0.9000
# Epoch 326/400
# 9/9 [==============================] - 0s 8ms/step - loss: 0.2327 - accuracy: 0.8893 - val_loss: 0.2005 - val_accuracy: 0.9000
# Epoch 327/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.2328 - accuracy: 0.8857 - val_loss: 0.2001 - val_accuracy: 0.9000
# Epoch 328/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2325 - accuracy: 0.8893 - val_loss: 0.1999 - val_accuracy: 0.9000
# Epoch 329/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2321 - accuracy: 0.8893 - val_loss: 0.1999 - val_accuracy: 0.9000
# Epoch 330/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.2321 - accuracy: 0.8893 - val_loss: 0.1996 - val_accuracy: 0.9000
# Epoch 331/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.2323 - accuracy: 0.8893 - val_loss: 0.1992 - val_accuracy: 0.9000
# Epoch 332/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.2318 - accuracy: 0.8893 - val_loss: 0.1987 - val_accuracy: 0.9000
# Epoch 333/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.2319 - accuracy: 0.8929 - val_loss: 0.1988 - val_accuracy: 0.9000
# Epoch 334/400
# 9/9 [==============================] - 0s 7ms/step - loss: 0.2318 - accuracy: 0.8893 - val_loss: 0.1985 - val_accuracy: 0.9000
# Epoch 335/400
# 9/9 [==============================] - 0s 20ms/step - loss: 0.2314 - accuracy: 0.8893 - val_loss: 0.1982 - val_accuracy: 0.9000
# Epoch 336/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2313 - accuracy: 0.8893 - val_loss: 0.1975 - val_accuracy: 0.9000
# Epoch 337/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2312 - accuracy: 0.8857 - val_loss: 0.1971 - val_accuracy: 0.9000
# Epoch 338/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.2310 - accuracy: 0.8893 - val_loss: 0.1974 - val_accuracy: 0.9000
# Epoch 339/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.2312 - accuracy: 0.8893 - val_loss: 0.1970 - val_accuracy: 0.9000
# Epoch 340/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2310 - accuracy: 0.8893 - val_loss: 0.1969 - val_accuracy: 0.9000
# Epoch 341/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.2304 - accuracy: 0.8893 - val_loss: 0.1964 - val_accuracy: 0.9000
# Epoch 342/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.2305 - accuracy: 0.8893 - val_loss: 0.1963 - val_accuracy: 0.9000
# Epoch 343/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.2304 - accuracy: 0.8893 - val_loss: 0.1954 - val_accuracy: 0.9000
# Epoch 344/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.2302 - accuracy: 0.8893 - val_loss: 0.1956 - val_accuracy: 0.9000
# Epoch 345/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2301 - accuracy: 0.8857 - val_loss: 0.1954 - val_accuracy: 0.9000
# Epoch 346/400
# 9/9 [==============================] - 0s 3ms/step - loss: 0.2299 - accuracy: 0.8893 - val_loss: 0.1950 - val_accuracy: 0.9000
# Epoch 347/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.2297 - accuracy: 0.8893 - val_loss: 0.1950 - val_accuracy: 0.9000
# Epoch 348/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2300 - accuracy: 0.8893 - val_loss: 0.1944 - val_accuracy: 0.9000
# Epoch 349/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.2294 - accuracy: 0.8929 - val_loss: 0.1943 - val_accuracy: 0.9000
# Epoch 350/400
# 9/9 [==============================] - 0s 8ms/step - loss: 0.2293 - accuracy: 0.8893 - val_loss: 0.1943 - val_accuracy: 0.9000
# Epoch 351/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.2293 - accuracy: 0.8893 - val_loss: 0.1936 - val_accuracy: 0.9000
# Epoch 352/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2292 - accuracy: 0.8929 - val_loss: 0.1935 - val_accuracy: 0.9000
# Epoch 353/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2290 - accuracy: 0.8893 - val_loss: 0.1936 - val_accuracy: 0.9000
# Epoch 354/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2290 - accuracy: 0.8893 - val_loss: 0.1929 - val_accuracy: 0.9000
# Epoch 355/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2286 - accuracy: 0.8929 - val_loss: 0.1925 - val_accuracy: 0.9000
# Epoch 356/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.2287 - accuracy: 0.8929 - val_loss: 0.1924 - val_accuracy: 0.9000
# Epoch 357/400
# 9/9 [==============================] - 0s 7ms/step - loss: 0.2288 - accuracy: 0.8893 - val_loss: 0.1920 - val_accuracy: 0.9000
# Epoch 358/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2282 - accuracy: 0.8929 - val_loss: 0.1916 - val_accuracy: 0.9000
# Epoch 359/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.2286 - accuracy: 0.8857 - val_loss: 0.1913 - val_accuracy: 0.9000
# Epoch 360/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.2280 - accuracy: 0.8929 - val_loss: 0.1908 - val_accuracy: 0.9000
# Epoch 361/400
# 9/9 [==============================] - 0s 8ms/step - loss: 0.2279 - accuracy: 0.8893 - val_loss: 0.1905 - val_accuracy: 0.9000
# Epoch 362/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.2276 - accuracy: 0.8893 - val_loss: 0.1909 - val_accuracy: 0.9000
# Epoch 363/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2276 - accuracy: 0.8893 - val_loss: 0.1909 - val_accuracy: 0.9000
# Epoch 364/400
# 9/9 [==============================] - 0s 7ms/step - loss: 0.2280 - accuracy: 0.8929 - val_loss: 0.1906 - val_accuracy: 0.9000
# Epoch 365/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.2275 - accuracy: 0.8893 - val_loss: 0.1903 - val_accuracy: 0.9000
# Epoch 366/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.2271 - accuracy: 0.8893 - val_loss: 0.1899 - val_accuracy: 0.9000
# Epoch 367/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2270 - accuracy: 0.8964 - val_loss: 0.1896 - val_accuracy: 0.9000
# Epoch 368/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.2268 - accuracy: 0.8929 - val_loss: 0.1894 - val_accuracy: 0.8917
# Epoch 369/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.2268 - accuracy: 0.8964 - val_loss: 0.1893 - val_accuracy: 0.8917
# Epoch 370/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2266 - accuracy: 0.8964 - val_loss: 0.1893 - val_accuracy: 0.8917
# Epoch 371/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.2266 - accuracy: 0.8964 - val_loss: 0.1888 - val_accuracy: 0.8917
# Epoch 372/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.2264 - accuracy: 0.8929 - val_loss: 0.1888 - val_accuracy: 0.8917
# Epoch 373/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.2260 - accuracy: 0.8964 - val_loss: 0.1882 - val_accuracy: 0.8917
# Epoch 374/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.2260 - accuracy: 0.8964 - val_loss: 0.1876 - val_accuracy: 0.8917
# Epoch 375/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.2257 - accuracy: 0.8964 - val_loss: 0.1873 - val_accuracy: 0.8917
# Epoch 376/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.2261 - accuracy: 0.8964 - val_loss: 0.1868 - val_accuracy: 0.8917
# Epoch 377/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.2257 - accuracy: 0.8929 - val_loss: 0.1868 - val_accuracy: 0.8917
# Epoch 378/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.2254 - accuracy: 0.8929 - val_loss: 0.1865 - val_accuracy: 0.8917
# Epoch 379/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.2254 - accuracy: 0.8929 - val_loss: 0.1860 - val_accuracy: 0.8917
# Epoch 380/400
# 9/9 [==============================] - 0s 31ms/step - loss: 0.2249 - accuracy: 0.8964 - val_loss: 0.1854 - val_accuracy: 0.8917
# Epoch 381/400
# 9/9 [==============================] - 0s 8ms/step - loss: 0.2251 - accuracy: 0.8929 - val_loss: 0.1854 - val_accuracy: 0.8917
# Epoch 382/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.2247 - accuracy: 0.8964 - val_loss: 0.1850 - val_accuracy: 0.8917
# Epoch 383/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.2245 - accuracy: 0.8929 - val_loss: 0.1848 - val_accuracy: 0.8917
# Epoch 384/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.2243 - accuracy: 0.8964 - val_loss: 0.1846 - val_accuracy: 0.8917
# Epoch 385/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.2243 - accuracy: 0.8964 - val_loss: 0.1842 - val_accuracy: 0.8917
# Epoch 386/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.2239 - accuracy: 0.8964 - val_loss: 0.1836 - val_accuracy: 0.8917
# Epoch 387/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.2238 - accuracy: 0.8964 - val_loss: 0.1833 - val_accuracy: 0.8917
# Epoch 388/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.2239 - accuracy: 0.8964 - val_loss: 0.1828 - val_accuracy: 0.8917
# Epoch 389/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.2236 - accuracy: 0.8964 - val_loss: 0.1826 - val_accuracy: 0.8917
# Epoch 390/400
# 9/9 [==============================] - 0s 8ms/step - loss: 0.2237 - accuracy: 0.8929 - val_loss: 0.1826 - val_accuracy: 0.8917
# Epoch 391/400
# 9/9 [==============================] - 0s 8ms/step - loss: 0.2233 - accuracy: 0.8964 - val_loss: 0.1821 - val_accuracy: 0.8917
# Epoch 392/400
# 9/9 [==============================] - 0s 7ms/step - loss: 0.2231 - accuracy: 0.8964 - val_loss: 0.1819 - val_accuracy: 0.8917
# Epoch 393/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.2230 - accuracy: 0.8964 - val_loss: 0.1815 - val_accuracy: 0.8917
# Epoch 394/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2230 - accuracy: 0.8929 - val_loss: 0.1814 - val_accuracy: 0.8917
# Epoch 395/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2225 - accuracy: 0.8964 - val_loss: 0.1805 - val_accuracy: 0.8917
# Epoch 396/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.2223 - accuracy: 0.8964 - val_loss: 0.1801 - val_accuracy: 0.8917
# Epoch 397/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.2223 - accuracy: 0.8929 - val_loss: 0.1798 - val_accuracy: 0.8917
# Epoch 398/400
# 9/9 [==============================] - 0s 7ms/step - loss: 0.2225 - accuracy: 0.8929 - val_loss: 0.1796 - val_accuracy: 0.8917
# Epoch 399/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.2218 - accuracy: 0.8929 - val_loss: 0.1794 - val_accuracy: 0.8917
# Epoch 400/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.2225 - accuracy: 0.8929 - val_loss: 0.1789 - val_accuracy: 0.8917

# %%
predictions = model.predict(scaled_X_test)

# %%
preds = []
for x in predictions:
    if x >= 0.5:
        preds.append(1)
    else:
        preds.append(0)

# %%
from sklearn.metrics import classification_report,confusion_matrix

# %%
print(classification_report(y1_test,preds))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.94      0.94      0.94       108
#          1.0       0.46      0.50      0.48        12
#
#     accuracy                           0.89       120
#    macro avg       0.70      0.72      0.71       120
# weighted avg       0.90      0.89      0.89       120
