# %% [markdown]
# ## DNN Retry Max & Mean
# Kept original data for reference.

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
# %matplotlib inline
from statistics import mean
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.callbacks import EarlyStopping

# %%
import seaborn as sns
import numpy as np
import pandas as pd
from statistics import mean
import math

FUTURE_PREDICTION = 4

def findmax(x):
    maximum = 0
    for number in x:
        maximum = max(x)
    return maximum

def findmean(x):
    m = 0
    m = mean(x)
    return m


def CreateMean(dataframe,title,city):

    dataframe = dataframe.iloc[522:3924:1]
    dataframe.rename(columns = {f'{city}' : f'{title}_Mean'}, inplace = True)
    dataframe = dataframe.reset_index(drop=True)
    for x in dataframe.index:
        if x % 7 == 6:
            list = []
            mean = 0
            for y in range(x-6,x+1,1):
                list.append(dataframe.iloc[y][f'{title}_Mean'])
            mean = findmean(list)
            dataframe.at[x,f'{title}_Mean'] = mean
    for x in dataframe.index:
        if x % 7 != 6:
            dataframe.drop(index= x, inplace=True)
    dataframe = dataframe.reset_index(drop=True)
    return dataframe

def CreateMax(dataframe,title,city):

    dataframe = dataframe.iloc[522:3924:1]
    dataframe.rename(columns = {f'{city}' : f'{title}_Max'}, inplace = True)
    dataframe = dataframe.reset_index(drop=True)
    for x in dataframe.index:
        if x % 7 == 6:
            list = []
            maximum = 0
            for y in range(x-6,x+1,1):
                list.append(dataframe.iloc[y][f'{title}_Max'])
            maximum = findmax(list)
            dataframe.at[x,f'{title}_Max'] = maximum
    for x in dataframe.index:
        if x % 7 != 6:
            dataframe.drop(index= x, inplace=True)
    dataframe = dataframe.reset_index(drop=True)
    return dataframe

def CreateMin(dataframe,title,city):

    dataframe = dataframe.iloc[522:3924:1]
    dataframe.rename(columns = {f'{city}' : f'{title}_Min'}, inplace = True)
    dataframe = dataframe.reset_index(drop=True)
    for x in dataframe.index:
        if x % 7 == 6:
            list = []
            minimum = 0
            for y in range(x-6,x+1,1):
                list.append(dataframe.iloc[y][f'{title}_Min'])
            minimum = findmin(list)
            dataframe.at[x,f'{title}_Min'] = minimum
    for x in dataframe.index:
        if x % 7 != 6:
            dataframe.drop(index= x, inplace=True)
    dataframe = dataframe.reset_index(drop=True)
    return dataframe
    
def DataPreprocess(city):
    virus_df = pd.read_csv('Data/virus.csv')
    virus_df['Date'] = pd.to_datetime(virus_df['Date'])
    virus_df['year'] = virus_df['Date'].apply(lambda date: date.year)
    virus_df['month'] = virus_df['Date'].apply(lambda date: date.month)
    virus_df_new = virus_df[['Date','month','year',f'{city}']]
    virus_df_new.rename(columns = {f'{city}' : f'Virus_Count_{city}'}, inplace = True)

    temp_df = pd.read_csv(f'Data/{city}_temp.csv')
    pressure_df = pd.read_csv(f'Data/{city}_pressure.csv')
    hours_df = pd.read_csv(f'Data/{city}_hours.csv')
    rainfall_df = pd.read_csv(f'Data/{city}_rainfall.csv')

    temp_df['Date'] = pd.to_datetime(temp_df['Date'])
    temp_df['year'] = temp_df['Date'].apply(lambda date: date.year)
    temp_df['month'] = temp_df['Date'].apply(lambda date: date.month)

    pressure_df['Date'] = pd.to_datetime(pressure_df['Date'])
    pressure_df['year'] = pressure_df['Date'].apply(lambda date: date.year)
    pressure_df['month'] = pressure_df['Date'].apply(lambda date: date.month)
    pressure_df = pressure_df.sort_values(by="Date")
    pressure_df = pressure_df.reset_index(drop=True)

    hours_df['Date'] = pd.to_datetime(hours_df['Date'])
    hours_df['year'] = hours_df['Date'].apply(lambda date: date.year)
    hours_df['month'] = hours_df['Date'].apply(lambda date: date.month)
    hours_df = hours_df.sort_values(by="Date")
    hours_df = hours_df.reset_index(drop=True)

    rainfall_df['Date'] = pd.to_datetime(rainfall_df['Date'])
    rainfall_df['year'] = rainfall_df['Date'].apply(lambda date: date.year)
    rainfall_df['month'] = rainfall_df['Date'].apply(lambda date: date.month)
    rainfall_df = rainfall_df.sort_values(by="Date")
    rainfall_df = rainfall_df.reset_index(drop=True)
    
    list = []
    for x in temp_df.index:
        t = temp_df.iloc[x][f'{city}']
        svp = 6.1078*10**(7.5*t/(t+237.3))
        e = pressure_df.iloc[x][f'{city}']
        h = e/svp*100
        list.append(h)
        
    humidity_df = pd.DataFrame(data=list)
    humidity_df.rename(columns = {0:f'{city}'}, inplace = True)

    mean_temp_df = CreateMean(temp_df, 'Temperature',f'{city}')
    mean_pressure_df = CreateMean(pressure_df, 'Pressure',f'{city}')
    mean_hours_df = CreateMean(hours_df, 'Hours',f'{city}')
    mean_rainfall_df = CreateMean(rainfall_df, 'Rainfall',f'{city}')
    mean_humidity_df = CreateMean(humidity_df, 'Humidity',f'{city}')
    
    max_temp_df = CreateMax(temp_df, 'Temperature',f'{city}')
    max_pressure_df = CreateMax(pressure_df, 'Pressure',f'{city}')
    max_hours_df = CreateMax(hours_df, 'Hours',f'{city}')
    max_rainfall_df = CreateMax(rainfall_df, 'Rainfall',f'{city}')
    max_humidity_df = CreateMax(humidity_df, 'Humidity',f'{city}')
    

    df = pd.concat([virus_df_new,mean_humidity_df,mean_temp_df,mean_pressure_df,mean_hours_df,mean_rainfall_df,max_temp_df,max_pressure_df,max_hours_df,max_rainfall_df,max_humidity_df], axis=1)
    df = df.loc[:,~df.columns.duplicated()]

    df['VirusCRM'] = df['Virus_Count_Tokyo'].rolling(14, center = True).mean()

    for i in df.index:
        if i == 0:
            df.at[i,'Gradient'] = 1
        else:
            if df.iloc[i-1]['VirusCRM'] == 0:
                if df.at[i,'VirusCDM'] > 0:
                    df.at[i,'Gradient'] = 1
                else:
                    df.at[i,'Gradient'] = 0
            else:
                grd = df.iloc[i]['VirusCRM']/(df.iloc[i-1]['VirusCRM'])
                df.at[i,'Gradient'] = grd
    
    for i in df.index:
        if (df.iloc[i]['Gradient'] >= 1.1) and (df.iloc[i+1]['Gradient'] >= 1.1) and (df.iloc[i+2]['Gradient'] >= 1.1):
            df.at[i,'Spreading'] = 1
        else:
            df.at[i,'Spreading'] = 0
    df = df.astype({'Spreading':'int8'})

    df_virus_count = df[f'Virus_Count_{city}']
    df.drop(columns=['year','Gradient','VirusCRM',f'Virus_Count_{city}'], axis=1, inplace=True)
    df_labels = df[['Date']]
    
    FUTURE_PREDICTION = 4
    for i in range(FUTURE_PREDICTION):
        df_labels[f"T+{(i+1)*7}"] = df_labels["Date"] + pd.DateOffset(days = (i+1)*7)
    temp = df[["Date", "Spreading"]]
    for i in range(FUTURE_PREDICTION):
        target_column = f"T+{(i+1)*7}"
        df_labels = df_labels.merge(temp, 
                                how ="left",
                                left_on = (target_column),
                                right_on=("Date"),
                                suffixes = ("","_y")
        )
        df_labels.rename(columns={"Spreading":f"{target_column}_Spreading"},inplace=True)
    df_labels.drop(columns=["Date_y"],inplace=True)

    for i in range(FUTURE_PREDICTION):
        df_labels.drop(columns =[f"T+{(i+1)*7}"],inplace=True,axis=1 )

    df = df.merge(df_labels,
             how='left',
             on = ["Date"])
    df.dropna(inplace=True)

    X = df.drop(columns=['T+7_Spreading','T+14_Spreading','T+21_Spreading','T+28_Spreading'],axis=1)
    y1 = df['T+21_Spreading']
    y2 = df['T+7_Spreading']
    y3 = df['T+14_Spreading']
    y4 = df['T+28_Spreading']

    return X, y1, y2, y3, y4, df, df_virus_count

# %%
X, y1, y2, y3, y4, df, df_virus_count = DataPreprocess('Tokyo')
# Out:
# /Users/miyanishio/opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py:5039: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(
# /var/folders/k5/3yc13bs57f7637937yjlstth0000gn/T/ipykernel_11039/2635125380.py:168: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_labels[f"T+{(i+1)*7}"] = df_labels["Date"] + pd.DateOffset(days = (i+1)*7)

# %%
X = X.drop(columns=['Date'])

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

scaler = StandardScaler()
scaler1 = StandardScaler()
X_train, X_test = X[0:336], X[336:482] #70-30 Split
y1_train, y1_test = y1[0:336], y1[336:482]

# %%
scaled_X_train = scaler1.fit_transform(X_train)
scaled_X_test = scaler1.transform(X_test)

# %%
model = Sequential()

model.add(Dense(12,activation="sigmoid"))
model.add(Dense(6,activation="sigmoid"))
model.add(Dense(3,activation="sigmoid"))

model.add(Dense(1, activation='sigmoid'))
model.compile(optimizer='rmsprop',loss='binary_crossentropy',metrics=['accuracy'])
# Out:
# 2022-12-14 13:09:36.074844: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
early_stop = EarlyStopping(monitor='val_loss',mode='min',verbose=1,patience=50)

# %%
model.fit(scaled_X_train,y1_train,epochs=400,validation_data=(scaled_X_test,y1_test),callbacks=[early_stop])
# Out:
# Epoch 1/400
# 11/11 [==============================] - 1s 27ms/step - loss: 0.9266 - accuracy: 0.1548 - val_loss: 0.9050 - val_accuracy: 0.1575
# Epoch 2/400
# 11/11 [==============================] - 0s 4ms/step - loss: 0.8975 - accuracy: 0.1548 - val_loss: 0.8812 - val_accuracy: 0.1575
# Epoch 3/400
# 11/11 [==============================] - 0s 4ms/step - loss: 0.8743 - accuracy: 0.1548 - val_loss: 0.8596 - val_accuracy: 0.1575
# Epoch 4/400
# 11/11 [==============================] - 0s 4ms/step - loss: 0.8529 - accuracy: 0.1548 - val_loss: 0.8394 - val_accuracy: 0.1575
# Epoch 5/400
# 11/11 [==============================] - 0s 5ms/step - loss: 0.8328 - accuracy: 0.1548 - val_loss: 0.8200 - val_accuracy: 0.1575
# Epoch 6/400
# 11/11 [==============================] - 0s 5ms/step - loss: 0.8132 - accuracy: 0.1548 - val_loss: 0.8009 - val_accuracy: 0.1575
# Epoch 7/400
# 11/11 [==============================] - 0s 5ms/step - loss: 0.7938 - accuracy: 0.1548 - val_loss: 0.7821 - val_accuracy: 0.1575
# Epoch 8/400
# 11/11 [==============================] - 0s 5ms/step - loss: 0.7752 - accuracy: 0.1548 - val_loss: 0.7647 - val_accuracy: 0.1575
# Epoch 9/400
# 11/11 [==============================] - 0s 9ms/step - loss: 0.7573 - accuracy: 0.1548 - val_loss: 0.7469 - val_accuracy: 0.1575
# Epoch 10/400
# 11/11 [==============================] - 0s 17ms/step - loss: 0.7397 - accuracy: 0.1548 - val_loss: 0.7306 - val_accuracy: 0.1575
# Epoch 11/400
# 11/11 [==============================] - 0s 12ms/step - loss: 0.7230 - accuracy: 0.1548 - val_loss: 0.7144 - val_accuracy: 0.1575
# Epoch 12/400
# 11/11 [==============================] - 0s 6ms/step - loss: 0.7070 - accuracy: 0.1548 - val_loss: 0.6996 - val_accuracy: 0.1575
# Epoch 13/400
# 11/11 [==============================] - 0s 7ms/step - loss: 0.6918 - accuracy: 0.5595 - val_loss: 0.6845 - val_accuracy: 0.8425
# Epoch 14/400
# 11/11 [==============================] - 0s 22ms/step - loss: 0.6769 - accuracy: 0.8452 - val_loss: 0.6707 - val_accuracy: 0.8425
# Epoch 15/400
# 11/11 [==============================] - 0s 5ms/step - loss: 0.6629 - accuracy: 0.8452 - val_loss: 0.6573 - val_accuracy: 0.8425
# Epoch 16/400
# 11/11 [==============================] - 0s 8ms/step - loss: 0.6492 - accuracy: 0.8452 - val_loss: 0.6443 - val_accuracy: 0.8425
# Epoch 17/400
# 11/11 [==============================] - 0s 6ms/step - loss: 0.6364 - accuracy: 0.8452 - val_loss: 0.6321 - val_accuracy: 0.8425
# Epoch 18/400
# 11/11 [==============================] - 0s 5ms/step - loss: 0.6241 - accuracy: 0.8452 - val_loss: 0.6207 - val_accuracy: 0.8425
# Epoch 19/400
# 11/11 [==============================] - 0s 5ms/step - loss: 0.6125 - accuracy: 0.8452 - val_loss: 0.6098 - val_accuracy: 0.8425
# Epoch 20/400
# 11/11 [==============================] - 0s 4ms/step - loss: 0.6015 - accuracy: 0.8452 - val_loss: 0.5992 - val_accuracy: 0.8425
# Epoch 21/400
# 11/11 [==============================] - 0s 6ms/step - loss: 0.5909 - accuracy: 0.8452 - val_loss: 0.5889 - val_accuracy: 0.8425
# Epoch 22/400
# 11/11 [==============================] - 0s 6ms/step - loss: 0.5807 - accuracy: 0.8452 - val_loss: 0.5793 - val_accuracy: 0.8425
# Epoch 23/400
# 11/11 [==============================] - 0s 5ms/step - loss: 0.5713 - accuracy: 0.8452 - val_loss: 0.5710 - val_accuracy: 0.8425
# Epoch 24/400
# 11/11 [==============================] - 0s 5ms/step - loss: 0.5627 - accuracy: 0.8452 - val_loss: 0.5623 - val_accuracy: 0.8425
# Epoch 25/400
# 11/11 [==============================] - 0s 5ms/step - loss: 0.5541 - accuracy: 0.8452 - val_loss: 0.5545 - val_accuracy: 0.8425
# Epoch 26/400
# 11/11 [==============================] - 0s 6ms/step - loss: 0.5462 - accuracy: 0.8452 - val_loss: 0.5466 - val_accuracy: 0.8425
# Epoch 27/400
# 11/11 [==============================] - 0s 7ms/step - loss: 0.5385 - accuracy: 0.8452 - val_loss: 0.5397 - val_accuracy: 0.8425
# Epoch 28/400
# 11/11 [==============================] - 0s 9ms/step - loss: 0.5315 - accuracy: 0.8452 - val_loss: 0.5329 - val_accuracy: 0.8425
# Epoch 29/400
# 11/11 [==============================] - 0s 5ms/step - loss: 0.5248 - accuracy: 0.8452 - val_loss: 0.5265 - val_accuracy: 0.8425
# Epoch 30/400
# 11/11 [==============================] - 0s 5ms/step - loss: 0.5184 - accuracy: 0.8452 - val_loss: 0.5207 - val_accuracy: 0.8425
# Epoch 31/400
# 11/11 [==============================] - 0s 6ms/step - loss: 0.5125 - accuracy: 0.8452 - val_loss: 0.5150 - val_accuracy: 0.8425
# Epoch 32/400
# 11/11 [==============================] - 0s 9ms/step - loss: 0.5068 - accuracy: 0.8452 - val_loss: 0.5095 - val_accuracy: 0.8425
# Epoch 33/400
# 11/11 [==============================] - 0s 6ms/step - loss: 0.5014 - accuracy: 0.8452 - val_loss: 0.5046 - val_accuracy: 0.8425
# Epoch 34/400
# 11/11 [==============================] - 0s 5ms/step - loss: 0.4964 - accuracy: 0.8452 - val_loss: 0.4997 - val_accuracy: 0.8425
# Epoch 35/400
# 11/11 [==============================] - 0s 6ms/step - loss: 0.4917 - accuracy: 0.8452 - val_loss: 0.4957 - val_accuracy: 0.8425
# Epoch 36/400
# 11/11 [==============================] - 0s 8ms/step - loss: 0.4874 - accuracy: 0.8452 - val_loss: 0.4914 - val_accuracy: 0.8425
# Epoch 37/400
# 11/11 [==============================] - 0s 12ms/step - loss: 0.4832 - accuracy: 0.8452 - val_loss: 0.4878 - val_accuracy: 0.8425
# Epoch 38/400
# 11/11 [==============================] - 0s 6ms/step - loss: 0.4795 - accuracy: 0.8452 - val_loss: 0.4843 - val_accuracy: 0.8425
# Epoch 39/400
# 11/11 [==============================] - 0s 7ms/step - loss: 0.4758 - accuracy: 0.8452 - val_loss: 0.4810 - val_accuracy: 0.8425
# Epoch 40/400
# 11/11 [==============================] - 0s 7ms/step - loss: 0.4723 - accuracy: 0.8452 - val_loss: 0.4775 - val_accuracy: 0.8425
# Epoch 41/400
# 11/11 [==============================] - 0s 5ms/step - loss: 0.4688 - accuracy: 0.8452 - val_loss: 0.4744 - val_accuracy: 0.8425
# Epoch 42/400
# 11/11 [==============================] - 0s 6ms/step - loss: 0.4656 - accuracy: 0.8452 - val_loss: 0.4715 - val_accuracy: 0.8425
# Epoch 43/400
# 11/11 [==============================] - 0s 7ms/step - loss: 0.4626 - accuracy: 0.8452 - val_loss: 0.4689 - val_accuracy: 0.8425
# Epoch 44/400
# 11/11 [==============================] - 0s 5ms/step - loss: 0.4599 - accuracy: 0.8452 - val_loss: 0.4664 - val_accuracy: 0.8425
# Epoch 45/400
# 11/11 [==============================] - 0s 14ms/step - loss: 0.4572 - accuracy: 0.8452 - val_loss: 0.4642 - val_accuracy: 0.8425
# Epoch 46/400
# 11/11 [==============================] - 0s 10ms/step - loss: 0.4546 - accuracy: 0.8452 - val_loss: 0.4616 - val_accuracy: 0.8425
# Epoch 47/400
# 11/11 [==============================] - 0s 7ms/step - loss: 0.4521 - accuracy: 0.8452 - val_loss: 0.4601 - val_accuracy: 0.8425
# Epoch 48/400
# 11/11 [==============================] - 0s 7ms/step - loss: 0.4503 - accuracy: 0.8452 - val_loss: 0.4584 - val_accuracy: 0.8425
# Epoch 49/400
# 11/11 [==============================] - 0s 6ms/step - loss: 0.4484 - accuracy: 0.8452 - val_loss: 0.4568 - val_accuracy: 0.8425
# Epoch 50/400
# 11/11 [==============================] - 0s 28ms/step - loss: 0.4464 - accuracy: 0.8452 - val_loss: 0.4551 - val_accuracy: 0.8425
# Epoch 51/400
# 11/11 [==============================] - 0s 10ms/step - loss: 0.4443 - accuracy: 0.8452 - val_loss: 0.4535 - val_accuracy: 0.8425
# Epoch 52/400
# 11/11 [==============================] - 0s 6ms/step - loss: 0.4423 - accuracy: 0.8452 - val_loss: 0.4519 - val_accuracy: 0.8425
# Epoch 53/400
# 11/11 [==============================] - 0s 6ms/step - loss: 0.4404 - accuracy: 0.8452 - val_loss: 0.4507 - val_accuracy: 0.8425
# Epoch 54/400
# 11/11 [==============================] - 0s 5ms/step - loss: 0.4387 - accuracy: 0.8452 - val_loss: 0.4494 - val_accuracy: 0.8425
# Epoch 55/400
# 11/11 [==============================] - 0s 4ms/step - loss: 0.4369 - accuracy: 0.8452 - val_loss: 0.4481 - val_accuracy: 0.8425
# Epoch 56/400
# 11/11 [==============================] - 0s 5ms/step - loss: 0.4352 - accuracy: 0.8452 - val_loss: 0.4470 - val_accuracy: 0.8425
# Epoch 57/400
# 11/11 [==============================] - 0s 5ms/step - loss: 0.4336 - accuracy: 0.8452 - val_loss: 0.4460 - val_accuracy: 0.8425
# Epoch 58/400
# 11/11 [==============================] - 0s 4ms/step - loss: 0.4319 - accuracy: 0.8452 - val_loss: 0.4450 - val_accuracy: 0.8425
# Epoch 59/400
# 11/11 [==============================] - 0s 5ms/step - loss: 0.4304 - accuracy: 0.8452 - val_loss: 0.4443 - val_accuracy: 0.8425
# Epoch 60/400
# 11/11 [==============================] - 0s 5ms/step - loss: 0.4289 - accuracy: 0.8452 - val_loss: 0.4433 - val_accuracy: 0.8425
# Epoch 61/400
# 11/11 [==============================] - 0s 5ms/step - loss: 0.4273 - accuracy: 0.8452 - val_loss: 0.4426 - val_accuracy: 0.8425
# Epoch 62/400
# 11/11 [==============================] - 0s 5ms/step - loss: 0.4258 - accuracy: 0.8452 - val_loss: 0.4419 - val_accuracy: 0.8425
# Epoch 63/400
# 11/11 [==============================] - 0s 5ms/step - loss: 0.4244 - accuracy: 0.8452 - val_loss: 0.4414 - val_accuracy: 0.8425
# Epoch 64/400
# 11/11 [==============================] - 0s 5ms/step - loss: 0.4232 - accuracy: 0.8452 - val_loss: 0.4412 - val_accuracy: 0.8425
# Epoch 65/400
# 11/11 [==============================] - 0s 7ms/step - loss: 0.4220 - accuracy: 0.8452 - val_loss: 0.4407 - val_accuracy: 0.8425
# Epoch 66/400
# 11/11 [==============================] - 0s 6ms/step - loss: 0.4207 - accuracy: 0.8452 - val_loss: 0.4402 - val_accuracy: 0.8425
# Epoch 67/400
# 11/11 [==============================] - 0s 23ms/step - loss: 0.4194 - accuracy: 0.8452 - val_loss: 0.4398 - val_accuracy: 0.8425
# Epoch 68/400
# 11/11 [==============================] - 0s 19ms/step - loss: 0.4182 - accuracy: 0.8452 - val_loss: 0.4397 - val_accuracy: 0.8425
# Epoch 69/400
# 11/11 [==============================] - 0s 17ms/step - loss: 0.4171 - accuracy: 0.8452 - val_loss: 0.4394 - val_accuracy: 0.8425
# Epoch 70/400
# 11/11 [==============================] - 0s 11ms/step - loss: 0.4160 - accuracy: 0.8452 - val_loss: 0.4393 - val_accuracy: 0.8425
# Epoch 71/400
# 11/11 [==============================] - 0s 6ms/step - loss: 0.4149 - accuracy: 0.8452 - val_loss: 0.4392 - val_accuracy: 0.8425
# Epoch 72/400
# 11/11 [==============================] - 0s 5ms/step - loss: 0.4139 - accuracy: 0.8452 - val_loss: 0.4390 - val_accuracy: 0.8425
# Epoch 73/400
# 11/11 [==============================] - 0s 5ms/step - loss: 0.4128 - accuracy: 0.8452 - val_loss: 0.4389 - val_accuracy: 0.8425
# Epoch 74/400
# 11/11 [==============================] - 0s 11ms/step - loss: 0.4116 - accuracy: 0.8452 - val_loss: 0.4387 - val_accuracy: 0.8425
# Epoch 75/400
# 11/11 [==============================] - 0s 9ms/step - loss: 0.4105 - accuracy: 0.8452 - val_loss: 0.4388 - val_accuracy: 0.8425
# Epoch 76/400
# 11/11 [==============================] - 0s 10ms/step - loss: 0.4094 - accuracy: 0.8452 - val_loss: 0.4388 - val_accuracy: 0.8425
# Epoch 77/400
# 11/11 [==============================] - 0s 8ms/step - loss: 0.4085 - accuracy: 0.8452 - val_loss: 0.4387 - val_accuracy: 0.8425
# Epoch 78/400
# 11/11 [==============================] - 0s 10ms/step - loss: 0.4073 - accuracy: 0.8452 - val_loss: 0.4388 - val_accuracy: 0.8425
# Epoch 79/400
# 11/11 [==============================] - 0s 8ms/step - loss: 0.4062 - accuracy: 0.8452 - val_loss: 0.4388 - val_accuracy: 0.8425
# Epoch 80/400
# 11/11 [==============================] - 0s 5ms/step - loss: 0.4051 - accuracy: 0.8452 - val_loss: 0.4389 - val_accuracy: 0.8425
# Epoch 81/400
# 11/11 [==============================] - 0s 7ms/step - loss: 0.4041 - accuracy: 0.8452 - val_loss: 0.4390 - val_accuracy: 0.8425
# Epoch 82/400
# 11/11 [==============================] - 0s 6ms/step - loss: 0.4029 - accuracy: 0.8452 - val_loss: 0.4391 - val_accuracy: 0.8425
# Epoch 83/400
# 11/11 [==============================] - 0s 8ms/step - loss: 0.4018 - accuracy: 0.8452 - val_loss: 0.4392 - val_accuracy: 0.8425
# Epoch 84/400
# 11/11 [==============================] - 0s 5ms/step - loss: 0.4006 - accuracy: 0.8452 - val_loss: 0.4394 - val_accuracy: 0.8425
# Epoch 85/400
# 11/11 [==============================] - 0s 5ms/step - loss: 0.3997 - accuracy: 0.8452 - val_loss: 0.4394 - val_accuracy: 0.8425
# Epoch 86/400
# 11/11 [==============================] - 0s 8ms/step - loss: 0.3986 - accuracy: 0.8452 - val_loss: 0.4395 - val_accuracy: 0.8425
# Epoch 87/400
# 11/11 [==============================] - 0s 5ms/step - loss: 0.3977 - accuracy: 0.8452 - val_loss: 0.4397 - val_accuracy: 0.8425
# Epoch 88/400
# 11/11 [==============================] - 0s 5ms/step - loss: 0.3967 - accuracy: 0.8452 - val_loss: 0.4397 - val_accuracy: 0.8425
# Epoch 89/400
# 11/11 [==============================] - 0s 5ms/step - loss: 0.3957 - accuracy: 0.8452 - val_loss: 0.4398 - val_accuracy: 0.8425
# Epoch 90/400
# 11/11 [==============================] - 0s 5ms/step - loss: 0.3946 - accuracy: 0.8452 - val_loss: 0.4400 - val_accuracy: 0.8425
# Epoch 91/400
# 11/11 [==============================] - 0s 6ms/step - loss: 0.3936 - accuracy: 0.8452 - val_loss: 0.4401 - val_accuracy: 0.8425
# Epoch 92/400
# 11/11 [==============================] - 0s 5ms/step - loss: 0.3924 - accuracy: 0.8452 - val_loss: 0.4403 - val_accuracy: 0.8425
# Epoch 93/400
# 11/11 [==============================] - 0s 5ms/step - loss: 0.3914 - accuracy: 0.8452 - val_loss: 0.4404 - val_accuracy: 0.8425
# Epoch 94/400
# 11/11 [==============================] - 0s 6ms/step - loss: 0.3903 - accuracy: 0.8452 - val_loss: 0.4407 - val_accuracy: 0.8425
# Epoch 95/400
# 11/11 [==============================] - 0s 5ms/step - loss: 0.3891 - accuracy: 0.8452 - val_loss: 0.4408 - val_accuracy: 0.8425
# Epoch 96/400
# 11/11 [==============================] - 0s 6ms/step - loss: 0.3880 - accuracy: 0.8452 - val_loss: 0.4410 - val_accuracy: 0.8425
# Epoch 97/400
# 11/11 [==============================] - 0s 8ms/step - loss: 0.3870 - accuracy: 0.8452 - val_loss: 0.4412 - val_accuracy: 0.8425
# Epoch 98/400
# 11/11 [==============================] - 0s 5ms/step - loss: 0.3859 - accuracy: 0.8452 - val_loss: 0.4414 - val_accuracy: 0.8425
# Epoch 99/400
# 11/11 [==============================] - 0s 5ms/step - loss: 0.3848 - accuracy: 0.8452 - val_loss: 0.4416 - val_accuracy: 0.8425
# Epoch 100/400
# 11/11 [==============================] - 0s 6ms/step - loss: 0.3837 - accuracy: 0.8452 - val_loss: 0.4417 - val_accuracy: 0.8425
# Epoch 101/400
# 11/11 [==============================] - 0s 9ms/step - loss: 0.3825 - accuracy: 0.8452 - val_loss: 0.4420 - val_accuracy: 0.8425
# Epoch 102/400
# 11/11 [==============================] - 0s 6ms/step - loss: 0.3815 - accuracy: 0.8452 - val_loss: 0.4422 - val_accuracy: 0.8425
# Epoch 103/400
# 11/11 [==============================] - 0s 12ms/step - loss: 0.3804 - accuracy: 0.8452 - val_loss: 0.4424 - val_accuracy: 0.8425
# Epoch 104/400
# 11/11 [==============================] - 0s 6ms/step - loss: 0.3793 - accuracy: 0.8452 - val_loss: 0.4425 - val_accuracy: 0.8425
# Epoch 105/400
# 11/11 [==============================] - 0s 7ms/step - loss: 0.3783 - accuracy: 0.8452 - val_loss: 0.4427 - val_accuracy: 0.8425
# Epoch 106/400
# 11/11 [==============================] - 0s 9ms/step - loss: 0.3773 - accuracy: 0.8452 - val_loss: 0.4429 - val_accuracy: 0.8425
# Epoch 107/400
# 11/11 [==============================] - 0s 6ms/step - loss: 0.3764 - accuracy: 0.8452 - val_loss: 0.4430 - val_accuracy: 0.8425
# Epoch 108/400
# 11/11 [==============================] - 0s 9ms/step - loss: 0.3753 - accuracy: 0.8452 - val_loss: 0.4432 - val_accuracy: 0.8425
# Epoch 109/400
# 11/11 [==============================] - 0s 22ms/step - loss: 0.3741 - accuracy: 0.8452 - val_loss: 0.4435 - val_accuracy: 0.8425
# Epoch 110/400
# 11/11 [==============================] - 0s 6ms/step - loss: 0.3731 - accuracy: 0.8452 - val_loss: 0.4437 - val_accuracy: 0.8425
# Epoch 111/400
# 11/11 [==============================] - 0s 7ms/step - loss: 0.3719 - accuracy: 0.8452 - val_loss: 0.4439 - val_accuracy: 0.8425
# Epoch 112/400
# 11/11 [==============================] - 0s 17ms/step - loss: 0.3708 - accuracy: 0.8452 - val_loss: 0.4441 - val_accuracy: 0.8425
# Epoch 113/400
# 11/11 [==============================] - 0s 8ms/step - loss: 0.3697 - accuracy: 0.8452 - val_loss: 0.4443 - val_accuracy: 0.8425
# Epoch 114/400
# 11/11 [==============================] - 0s 6ms/step - loss: 0.3686 - accuracy: 0.8452 - val_loss: 0.4446 - val_accuracy: 0.8425
# Epoch 115/400
# 11/11 [==============================] - 0s 6ms/step - loss: 0.3674 - accuracy: 0.8452 - val_loss: 0.4449 - val_accuracy: 0.8425
# Epoch 116/400
# 11/11 [==============================] - 0s 7ms/step - loss: 0.3662 - accuracy: 0.8452 - val_loss: 0.4450 - val_accuracy: 0.8425
# Epoch 117/400
# 11/11 [==============================] - 0s 15ms/step - loss: 0.3650 - accuracy: 0.8452 - val_loss: 0.4452 - val_accuracy: 0.8425
# Epoch 118/400
# 11/11 [==============================] - 0s 8ms/step - loss: 0.3638 - accuracy: 0.8452 - val_loss: 0.4454 - val_accuracy: 0.8425
# Epoch 119/400
# 11/11 [==============================] - 0s 9ms/step - loss: 0.3627 - accuracy: 0.8452 - val_loss: 0.4456 - val_accuracy: 0.8425
# Epoch 120/400
# 11/11 [==============================] - 0s 8ms/step - loss: 0.3615 - accuracy: 0.8452 - val_loss: 0.4458 - val_accuracy: 0.8425
# Epoch 121/400
# 11/11 [==============================] - 0s 5ms/step - loss: 0.3603 - accuracy: 0.8452 - val_loss: 0.4460 - val_accuracy: 0.8425
# Epoch 122/400
# 11/11 [==============================] - 0s 5ms/step - loss: 0.3592 - accuracy: 0.8452 - val_loss: 0.4461 - val_accuracy: 0.8425
# Epoch 123/400
# 11/11 [==============================] - 0s 8ms/step - loss: 0.3581 - accuracy: 0.8452 - val_loss: 0.4461 - val_accuracy: 0.8425
# Epoch 124/400
# 11/11 [==============================] - 0s 6ms/step - loss: 0.3570 - accuracy: 0.8452 - val_loss: 0.4462 - val_accuracy: 0.8425
# Epoch 124: early stopping

# %%
predictions = model.predict(scaled_X_test)

# %%
preds = []
for x in predictions:
    if x >= 0.5:
        preds.append(1)
    else:
        preds.append(0)

# %%
from sklearn.metrics import classification_report,confusion_matrix

# %%
print(classification_report(y1_test,preds))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.84      1.00      0.91       123
#          1.0       0.00      0.00      0.00        23
#
#     accuracy                           0.84       146
#    macro avg       0.42      0.50      0.46       146
# weighted avg       0.71      0.84      0.77       146
# /Users/miyanishio/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/miyanishio/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/miyanishio/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
