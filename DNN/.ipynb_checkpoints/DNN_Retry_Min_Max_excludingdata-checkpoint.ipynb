# %% [markdown]
# ## DNN Retry Min + Max
# Included the minimum and maximum, as well as took out the data from 2020-2021, 2021-2022.

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
# %matplotlib inline
from statistics import mean
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.callbacks import EarlyStopping

# %%
import seaborn as sns
import numpy as np
import pandas as pd
from statistics import mean
import math

FUTURE_PREDICTION = 4

def findmax(x):
    maximum = 0
    for number in x:
        maximum = max(x)
    return maximum

def findmean(x):
    m = 0
    m = mean(x)
    return m

def findmin(x):
    m = 0
    m = min(x)
    return m

def CreateMean(dataframe,title,city):

    dataframe = dataframe.iloc[522:3924:1]
    dataframe.rename(columns = {f'{city}' : f'{title}_Mean'}, inplace = True)
    dataframe = dataframe.reset_index(drop=True)
    for x in dataframe.index:
        if x % 7 == 6:
            list = []
            mean = 0
            for y in range(x-6,x+1,1):
                list.append(dataframe.iloc[y][f'{title}_Mean'])
            mean = findmean(list)
            dataframe.at[x,f'{title}_Mean'] = mean
    for x in dataframe.index:
        if x % 7 != 6:
            dataframe.drop(index= x, inplace=True)
    dataframe = dataframe.reset_index(drop=True)
    return dataframe

def CreateMax(dataframe,title,city):

    dataframe = dataframe.iloc[522:3924:1]
    dataframe.rename(columns = {f'{city}' : f'{title}_Max'}, inplace = True)
    dataframe = dataframe.reset_index(drop=True)
    for x in dataframe.index:
        if x % 7 == 6:
            list = []
            maximum = 0
            for y in range(x-6,x+1,1):
                list.append(dataframe.iloc[y][f'{title}_Max'])
            maximum = findmax(list)
            dataframe.at[x,f'{title}_Max'] = maximum
    for x in dataframe.index:
        if x % 7 != 6:
            dataframe.drop(index= x, inplace=True)
    dataframe = dataframe.reset_index(drop=True)
    return dataframe

def CreateMin(dataframe,title,city):

    dataframe = dataframe.iloc[522:3924:1]
    dataframe.rename(columns = {f'{city}' : f'{title}_Min'}, inplace = True)
    dataframe = dataframe.reset_index(drop=True)
    for x in dataframe.index:
        if x % 7 == 6:
            list = []
            minimum = 0
            for y in range(x-6,x+1,1):
                list.append(dataframe.iloc[y][f'{title}_Min'])
            minimum = findmin(list)
            dataframe.at[x,f'{title}_Min'] = minimum
    for x in dataframe.index:
        if x % 7 != 6:
            dataframe.drop(index= x, inplace=True)
    dataframe = dataframe.reset_index(drop=True)
    return dataframe
    
def DataPreprocess(city):
    virus_df = pd.read_csv('Data/virus.csv')
    virus_df['Date'] = pd.to_datetime(virus_df['Date'])
    virus_df['year'] = virus_df['Date'].apply(lambda date: date.year)
    virus_df['month'] = virus_df['Date'].apply(lambda date: date.month)
    virus_df_new = virus_df[['Date','month','year',f'{city}']]
    virus_df_new.rename(columns = {f'{city}' : f'Virus_Count_{city}'}, inplace = True)

    temp_df = pd.read_csv(f'Data/{city}_temp.csv')
    pressure_df = pd.read_csv(f'Data/{city}_pressure.csv')
    hours_df = pd.read_csv(f'Data/{city}_hours.csv')
    rainfall_df = pd.read_csv(f'Data/{city}_rainfall.csv')

    temp_df['Date'] = pd.to_datetime(temp_df['Date'])
    temp_df['year'] = temp_df['Date'].apply(lambda date: date.year)
    temp_df['month'] = temp_df['Date'].apply(lambda date: date.month)

    pressure_df['Date'] = pd.to_datetime(pressure_df['Date'])
    pressure_df['year'] = pressure_df['Date'].apply(lambda date: date.year)
    pressure_df['month'] = pressure_df['Date'].apply(lambda date: date.month)
    pressure_df = pressure_df.sort_values(by="Date")
    pressure_df = pressure_df.reset_index(drop=True)

    hours_df['Date'] = pd.to_datetime(hours_df['Date'])
    hours_df['year'] = hours_df['Date'].apply(lambda date: date.year)
    hours_df['month'] = hours_df['Date'].apply(lambda date: date.month)
    hours_df = hours_df.sort_values(by="Date")
    hours_df = hours_df.reset_index(drop=True)

    rainfall_df['Date'] = pd.to_datetime(rainfall_df['Date'])
    rainfall_df['year'] = rainfall_df['Date'].apply(lambda date: date.year)
    rainfall_df['month'] = rainfall_df['Date'].apply(lambda date: date.month)
    rainfall_df = rainfall_df.sort_values(by="Date")
    rainfall_df = rainfall_df.reset_index(drop=True)

    list = []
    for x in temp_df.index:
        t = temp_df.iloc[x][f'{city}']
        svp = 6.1078*10**(7.5*t/(t+237.3))
        e = pressure_df.iloc[x][f'{city}']
        h = e/svp*100
        list.append(h)
        
    humidity_df = pd.DataFrame(data=list)
    humidity_df.rename(columns = {0:f'{city}'}, inplace = True)
    
    max_temp_df = CreateMax(temp_df, 'Temperature',f'{city}')
    max_pressure_df = CreateMax(pressure_df, 'Pressure',f'{city}')
    max_hours_df = CreateMax(hours_df, 'Hours',f'{city}')
    max_rainfall_df = CreateMax(rainfall_df, 'Rainfall',f'{city}')
    max_humidity_df = CreateMax(humidity_df, 'Humidity',f'{city}')
    
    min_temp_df = CreateMin(temp_df, 'Temperature',f'{city}')
    min_pressure_df = CreateMin(pressure_df, 'Pressure',f'{city}')
    min_hours_df = CreateMin(hours_df, 'Hours',f'{city}')
    min_rainfall_df = CreateMin(rainfall_df, 'Rainfall',f'{city}')
    min_humidity_df = CreateMin(humidity_df, 'Humidity',f'{city}')

    df = pd.concat([virus_df_new,max_temp_df,max_pressure_df,max_hours_df,max_rainfall_df,max_humidity_df,min_temp_df,min_pressure_df,min_hours_df,min_rainfall_df,min_humidity_df], axis=1)
    df = df.loc[:,~df.columns.duplicated()]

    df['VirusCRM'] = df['Virus_Count_Tokyo'].rolling(14, center = True).mean()

    for i in df.index:
        if i == 0:
            df.at[i,'Gradient'] = 1
        else:
            if df.iloc[i-1]['VirusCRM'] == 0:
                if df.at[i,'VirusCDM'] > 0:
                    df.at[i,'Gradient'] = 1
                else:
                    df.at[i,'Gradient'] = 0
            else:
                grd = df.iloc[i]['VirusCRM']/(df.iloc[i-1]['VirusCRM'])
                df.at[i,'Gradient'] = grd
    
    for i in df.index:
        if (df.iloc[i]['Gradient'] >= 1.1) and (df.iloc[i+1]['Gradient'] >= 1.1) and (df.iloc[i+2]['Gradient'] >= 1.1):
            df.at[i,'Spreading'] = 1
        else:
            df.at[i,'Spreading'] = 0
    df = df.astype({'Spreading':'int8'})

    df_virus_count = df[f'Virus_Count_{city}']
    df.drop(columns=['VirusCRM',f'Virus_Count_{city}','year','Gradient'], axis=1, inplace=True)
    df_labels = df[['Date']]
    FUTURE_PREDICTION = 4
    for i in range(FUTURE_PREDICTION):
        df_labels[f"T+{(i+1)*7}"] = df_labels["Date"] + pd.DateOffset(days = (i+1)*7)
    temp = df[["Date", "Spreading"]]
    for i in range(FUTURE_PREDICTION):
        target_column = f"T+{(i+1)*7}"
        df_labels = df_labels.merge(temp, 
                                how ="left",
                                left_on = (target_column),
                                right_on=("Date"),
                                suffixes = ("","_y")
        )
        df_labels.rename(columns={"Spreading":f"{target_column}_Spreading"},inplace=True)
    df_labels.drop(columns=["Date_y"],inplace=True)

    for i in range(FUTURE_PREDICTION):
        df_labels.drop(columns =[f"T+{(i+1)*7}"],inplace=True,axis=1 )

    df = df.merge(df_labels,
             how='left',
             on = ["Date"])
    df.dropna(inplace=True)

    X = df.drop(columns=['T+7_Spreading','T+14_Spreading','T+21_Spreading','T+28_Spreading'],axis=1)
    y1 = df['T+21_Spreading']
    y2 = df['T+7_Spreading']
    y3 = df['T+14_Spreading']
    y4 = df['T+28_Spreading']

    return X, y1, y2, y3, y4, df, df_virus_count

# %%
X, y1, y2, y3, y4, df, df_virus_count = DataPreprocess('Tokyo')
# Out:
# /Users/miyanishio/opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py:5039: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(
# /var/folders/k5/3yc13bs57f7637937yjlstth0000gn/T/ipykernel_86591/3585207071.py:170: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_labels[f"T+{(i+1)*7}"] = df_labels["Date"] + pd.DateOffset(days = (i+1)*7)

# %%
X = X.drop(columns=['Date'])

# %%
X = X[0:400] #until 2020 05-04
y1 = y1[0:400]
y2 = y2[0:400]
y3 = y2[0:400]
y4 = y2[0:400]

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

scaler = StandardScaler()
scaler1 = StandardScaler()
X_train, X_test = X[0:280], X[280:400]
y1_train, y1_test = y1[0:280], y1[280:400]

# %%
scaled_X_train = scaler1.fit_transform(X_train)
scaled_X_test = scaler1.transform(X_test)

# %%
model = Sequential()

model.add(Dense(12,activation="sigmoid"))
model.add(Dense(6,activation="sigmoid"))
model.add(Dense(3,activation="sigmoid"))

model.add(Dense(1, activation='sigmoid'))
model.compile(optimizer='rmsprop',loss='binary_crossentropy',metrics=['accuracy'])
# Out:
# 2022-11-14 16:57:27.178537: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
early_stop = EarlyStopping(monitor='val_loss',mode='min',verbose=1,patience=50)

# %%
model.fit(scaled_X_train,y1_train,epochs=400,validation_data=(scaled_X_test,y1_test),callbacks=[early_stop])
# Out:
# Epoch 1/400
# 9/9 [==============================] - 1s 36ms/step - loss: 0.6522 - accuracy: 0.8357 - val_loss: 0.6347 - val_accuracy: 0.9000
# Epoch 2/400
# 9/9 [==============================] - 0s 10ms/step - loss: 0.6404 - accuracy: 0.8357 - val_loss: 0.6233 - val_accuracy: 0.9000
# Epoch 3/400
# 9/9 [==============================] - 0s 10ms/step - loss: 0.6314 - accuracy: 0.8357 - val_loss: 0.6128 - val_accuracy: 0.9000
# Epoch 4/400
# 9/9 [==============================] - 0s 13ms/step - loss: 0.6231 - accuracy: 0.8357 - val_loss: 0.6026 - val_accuracy: 0.9000
# Epoch 5/400
# 9/9 [==============================] - 0s 24ms/step - loss: 0.6149 - accuracy: 0.8357 - val_loss: 0.5927 - val_accuracy: 0.9000
# Epoch 6/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.6071 - accuracy: 0.8357 - val_loss: 0.5833 - val_accuracy: 0.9000
# Epoch 7/400
# 9/9 [==============================] - 0s 9ms/step - loss: 0.5997 - accuracy: 0.8357 - val_loss: 0.5743 - val_accuracy: 0.9000
# Epoch 8/400
# 9/9 [==============================] - 0s 8ms/step - loss: 0.5925 - accuracy: 0.8357 - val_loss: 0.5654 - val_accuracy: 0.9000
# Epoch 9/400
# 9/9 [==============================] - 0s 12ms/step - loss: 0.5854 - accuracy: 0.8357 - val_loss: 0.5564 - val_accuracy: 0.9000
# Epoch 10/400
# 9/9 [==============================] - 0s 18ms/step - loss: 0.5785 - accuracy: 0.8357 - val_loss: 0.5477 - val_accuracy: 0.9000
# Epoch 11/400
# 9/9 [==============================] - 0s 12ms/step - loss: 0.5718 - accuracy: 0.8357 - val_loss: 0.5395 - val_accuracy: 0.9000
# Epoch 12/400
# 9/9 [==============================] - 0s 14ms/step - loss: 0.5653 - accuracy: 0.8357 - val_loss: 0.5312 - val_accuracy: 0.9000
# Epoch 13/400
# 9/9 [==============================] - 0s 15ms/step - loss: 0.5590 - accuracy: 0.8357 - val_loss: 0.5230 - val_accuracy: 0.9000
# Epoch 14/400
# 9/9 [==============================] - 0s 11ms/step - loss: 0.5529 - accuracy: 0.8357 - val_loss: 0.5152 - val_accuracy: 0.9000
# Epoch 15/400
# 9/9 [==============================] - 0s 10ms/step - loss: 0.5468 - accuracy: 0.8357 - val_loss: 0.5073 - val_accuracy: 0.9000
# Epoch 16/400
# 9/9 [==============================] - 0s 9ms/step - loss: 0.5411 - accuracy: 0.8357 - val_loss: 0.5001 - val_accuracy: 0.9000
# Epoch 17/400
# 9/9 [==============================] - 0s 9ms/step - loss: 0.5356 - accuracy: 0.8357 - val_loss: 0.4927 - val_accuracy: 0.9000
# Epoch 18/400
# 9/9 [==============================] - 0s 11ms/step - loss: 0.5303 - accuracy: 0.8357 - val_loss: 0.4857 - val_accuracy: 0.9000
# Epoch 19/400
# 9/9 [==============================] - 0s 13ms/step - loss: 0.5252 - accuracy: 0.8357 - val_loss: 0.4790 - val_accuracy: 0.9000
# Epoch 20/400
# 9/9 [==============================] - 0s 27ms/step - loss: 0.5203 - accuracy: 0.8357 - val_loss: 0.4725 - val_accuracy: 0.9000
# Epoch 21/400
# 9/9 [==============================] - 0s 7ms/step - loss: 0.5156 - accuracy: 0.8357 - val_loss: 0.4658 - val_accuracy: 0.9000
# Epoch 22/400
# 9/9 [==============================] - 0s 9ms/step - loss: 0.5109 - accuracy: 0.8357 - val_loss: 0.4596 - val_accuracy: 0.9000
# Epoch 23/400
# 9/9 [==============================] - 0s 8ms/step - loss: 0.5066 - accuracy: 0.8357 - val_loss: 0.4537 - val_accuracy: 0.9000
# Epoch 24/400
# 9/9 [==============================] - 0s 10ms/step - loss: 0.5025 - accuracy: 0.8357 - val_loss: 0.4479 - val_accuracy: 0.9000
# Epoch 25/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.4986 - accuracy: 0.8357 - val_loss: 0.4421 - val_accuracy: 0.9000
# Epoch 26/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.4948 - accuracy: 0.8357 - val_loss: 0.4368 - val_accuracy: 0.9000
# Epoch 27/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.4911 - accuracy: 0.8357 - val_loss: 0.4314 - val_accuracy: 0.9000
# Epoch 28/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.4877 - accuracy: 0.8357 - val_loss: 0.4262 - val_accuracy: 0.9000
# Epoch 29/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.4843 - accuracy: 0.8357 - val_loss: 0.4212 - val_accuracy: 0.9000
# Epoch 30/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.4812 - accuracy: 0.8357 - val_loss: 0.4165 - val_accuracy: 0.9000
# Epoch 31/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.4783 - accuracy: 0.8357 - val_loss: 0.4123 - val_accuracy: 0.9000
# Epoch 32/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.4756 - accuracy: 0.8357 - val_loss: 0.4075 - val_accuracy: 0.9000
# Epoch 33/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.4730 - accuracy: 0.8357 - val_loss: 0.4039 - val_accuracy: 0.9000
# Epoch 34/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.4710 - accuracy: 0.8357 - val_loss: 0.4003 - val_accuracy: 0.9000
# Epoch 35/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.4689 - accuracy: 0.8357 - val_loss: 0.3971 - val_accuracy: 0.9000
# Epoch 36/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.4670 - accuracy: 0.8357 - val_loss: 0.3938 - val_accuracy: 0.9000
# Epoch 37/400
# 9/9 [==============================] - 0s 7ms/step - loss: 0.4651 - accuracy: 0.8357 - val_loss: 0.3905 - val_accuracy: 0.9000
# Epoch 38/400
# 9/9 [==============================] - 0s 8ms/step - loss: 0.4633 - accuracy: 0.8357 - val_loss: 0.3871 - val_accuracy: 0.9000
# Epoch 39/400
# 9/9 [==============================] - 0s 9ms/step - loss: 0.4615 - accuracy: 0.8357 - val_loss: 0.3837 - val_accuracy: 0.9000
# Epoch 40/400
# 9/9 [==============================] - 0s 14ms/step - loss: 0.4598 - accuracy: 0.8357 - val_loss: 0.3803 - val_accuracy: 0.9000
# Epoch 41/400
# 9/9 [==============================] - 0s 10ms/step - loss: 0.4582 - accuracy: 0.8357 - val_loss: 0.3776 - val_accuracy: 0.9000
# Epoch 42/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.4568 - accuracy: 0.8357 - val_loss: 0.3747 - val_accuracy: 0.9000
# Epoch 43/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.4555 - accuracy: 0.8357 - val_loss: 0.3722 - val_accuracy: 0.9000
# Epoch 44/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.4545 - accuracy: 0.8357 - val_loss: 0.3698 - val_accuracy: 0.9000
# Epoch 45/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.4535 - accuracy: 0.8357 - val_loss: 0.3677 - val_accuracy: 0.9000
# Epoch 46/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.4526 - accuracy: 0.8357 - val_loss: 0.3656 - val_accuracy: 0.9000
# Epoch 47/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.4517 - accuracy: 0.8357 - val_loss: 0.3638 - val_accuracy: 0.9000
# Epoch 48/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.4511 - accuracy: 0.8357 - val_loss: 0.3619 - val_accuracy: 0.9000
# Epoch 49/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.4504 - accuracy: 0.8357 - val_loss: 0.3603 - val_accuracy: 0.9000
# Epoch 50/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.4498 - accuracy: 0.8357 - val_loss: 0.3587 - val_accuracy: 0.9000
# Epoch 51/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.4492 - accuracy: 0.8357 - val_loss: 0.3571 - val_accuracy: 0.9000
# Epoch 52/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.4488 - accuracy: 0.8357 - val_loss: 0.3559 - val_accuracy: 0.9000
# Epoch 53/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.4484 - accuracy: 0.8357 - val_loss: 0.3544 - val_accuracy: 0.9000
# Epoch 54/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.4480 - accuracy: 0.8357 - val_loss: 0.3532 - val_accuracy: 0.9000
# Epoch 55/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.4476 - accuracy: 0.8357 - val_loss: 0.3522 - val_accuracy: 0.9000
# Epoch 56/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.4473 - accuracy: 0.8357 - val_loss: 0.3510 - val_accuracy: 0.9000
# Epoch 57/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.4472 - accuracy: 0.8357 - val_loss: 0.3503 - val_accuracy: 0.9000
# Epoch 58/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.4469 - accuracy: 0.8357 - val_loss: 0.3496 - val_accuracy: 0.9000
# Epoch 59/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.4467 - accuracy: 0.8357 - val_loss: 0.3489 - val_accuracy: 0.9000
# Epoch 60/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.4466 - accuracy: 0.8357 - val_loss: 0.3482 - val_accuracy: 0.9000
# Epoch 61/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.4464 - accuracy: 0.8357 - val_loss: 0.3477 - val_accuracy: 0.9000
# Epoch 62/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.4463 - accuracy: 0.8357 - val_loss: 0.3469 - val_accuracy: 0.9000
# Epoch 63/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.4462 - accuracy: 0.8357 - val_loss: 0.3463 - val_accuracy: 0.9000
# Epoch 64/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.4460 - accuracy: 0.8357 - val_loss: 0.3459 - val_accuracy: 0.9000
# Epoch 65/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.4459 - accuracy: 0.8357 - val_loss: 0.3454 - val_accuracy: 0.9000
# Epoch 66/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.4459 - accuracy: 0.8357 - val_loss: 0.3450 - val_accuracy: 0.9000
# Epoch 67/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.4458 - accuracy: 0.8357 - val_loss: 0.3447 - val_accuracy: 0.9000
# Epoch 68/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.4457 - accuracy: 0.8357 - val_loss: 0.3443 - val_accuracy: 0.9000
# Epoch 69/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.4456 - accuracy: 0.8357 - val_loss: 0.3439 - val_accuracy: 0.9000
# Epoch 70/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.4458 - accuracy: 0.8357 - val_loss: 0.3435 - val_accuracy: 0.9000
# Epoch 71/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.4454 - accuracy: 0.8357 - val_loss: 0.3433 - val_accuracy: 0.9000
# Epoch 72/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.4455 - accuracy: 0.8357 - val_loss: 0.3431 - val_accuracy: 0.9000
# Epoch 73/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.4453 - accuracy: 0.8357 - val_loss: 0.3428 - val_accuracy: 0.9000
# Epoch 74/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.4453 - accuracy: 0.8357 - val_loss: 0.3425 - val_accuracy: 0.9000
# Epoch 75/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.4452 - accuracy: 0.8357 - val_loss: 0.3425 - val_accuracy: 0.9000
# Epoch 76/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.4451 - accuracy: 0.8357 - val_loss: 0.3422 - val_accuracy: 0.9000
# Epoch 77/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.4451 - accuracy: 0.8357 - val_loss: 0.3421 - val_accuracy: 0.9000
# Epoch 78/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.4450 - accuracy: 0.8357 - val_loss: 0.3420 - val_accuracy: 0.9000
# Epoch 79/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.4450 - accuracy: 0.8357 - val_loss: 0.3419 - val_accuracy: 0.9000
# Epoch 80/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.4448 - accuracy: 0.8357 - val_loss: 0.3419 - val_accuracy: 0.9000
# Epoch 81/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.4447 - accuracy: 0.8357 - val_loss: 0.3418 - val_accuracy: 0.9000
# Epoch 82/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.4447 - accuracy: 0.8357 - val_loss: 0.3416 - val_accuracy: 0.9000
# Epoch 83/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.4447 - accuracy: 0.8357 - val_loss: 0.3414 - val_accuracy: 0.9000
# Epoch 84/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.4446 - accuracy: 0.8357 - val_loss: 0.3411 - val_accuracy: 0.9000
# Epoch 85/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.4445 - accuracy: 0.8357 - val_loss: 0.3412 - val_accuracy: 0.9000
# Epoch 86/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.4444 - accuracy: 0.8357 - val_loss: 0.3410 - val_accuracy: 0.9000
# Epoch 87/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.4443 - accuracy: 0.8357 - val_loss: 0.3410 - val_accuracy: 0.9000
# Epoch 88/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.4443 - accuracy: 0.8357 - val_loss: 0.3409 - val_accuracy: 0.9000
# Epoch 89/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.4442 - accuracy: 0.8357 - val_loss: 0.3409 - val_accuracy: 0.9000
# Epoch 90/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.4441 - accuracy: 0.8357 - val_loss: 0.3406 - val_accuracy: 0.9000
# Epoch 91/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.4440 - accuracy: 0.8357 - val_loss: 0.3404 - val_accuracy: 0.9000
# Epoch 92/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.4439 - accuracy: 0.8357 - val_loss: 0.3404 - val_accuracy: 0.9000
# Epoch 93/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.4438 - accuracy: 0.8357 - val_loss: 0.3404 - val_accuracy: 0.9000
# Epoch 94/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.4437 - accuracy: 0.8357 - val_loss: 0.3403 - val_accuracy: 0.9000
# Epoch 95/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.4437 - accuracy: 0.8357 - val_loss: 0.3399 - val_accuracy: 0.9000
# Epoch 96/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.4436 - accuracy: 0.8357 - val_loss: 0.3398 - val_accuracy: 0.9000
# Epoch 97/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.4435 - accuracy: 0.8357 - val_loss: 0.3396 - val_accuracy: 0.9000
# Epoch 98/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.4434 - accuracy: 0.8357 - val_loss: 0.3397 - val_accuracy: 0.9000
# Epoch 99/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.4433 - accuracy: 0.8357 - val_loss: 0.3396 - val_accuracy: 0.9000
# Epoch 100/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.4432 - accuracy: 0.8357 - val_loss: 0.3394 - val_accuracy: 0.9000
# Epoch 101/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.4430 - accuracy: 0.8357 - val_loss: 0.3393 - val_accuracy: 0.9000
# Epoch 102/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.4430 - accuracy: 0.8357 - val_loss: 0.3392 - val_accuracy: 0.9000
# Epoch 103/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.4429 - accuracy: 0.8357 - val_loss: 0.3392 - val_accuracy: 0.9000
# Epoch 104/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.4427 - accuracy: 0.8357 - val_loss: 0.3391 - val_accuracy: 0.9000
# Epoch 105/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.4427 - accuracy: 0.8357 - val_loss: 0.3390 - val_accuracy: 0.9000
# Epoch 106/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.4425 - accuracy: 0.8357 - val_loss: 0.3389 - val_accuracy: 0.9000
# Epoch 107/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.4424 - accuracy: 0.8357 - val_loss: 0.3388 - val_accuracy: 0.9000
# Epoch 108/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.4423 - accuracy: 0.8357 - val_loss: 0.3386 - val_accuracy: 0.9000
# Epoch 109/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.4422 - accuracy: 0.8357 - val_loss: 0.3387 - val_accuracy: 0.9000
# Epoch 110/400
# 9/9 [==============================] - 0s 7ms/step - loss: 0.4421 - accuracy: 0.8357 - val_loss: 0.3387 - val_accuracy: 0.9000
# Epoch 111/400
# 9/9 [==============================] - 0s 15ms/step - loss: 0.4419 - accuracy: 0.8357 - val_loss: 0.3385 - val_accuracy: 0.9000
# Epoch 112/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.4419 - accuracy: 0.8357 - val_loss: 0.3385 - val_accuracy: 0.9000
# Epoch 113/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.4417 - accuracy: 0.8357 - val_loss: 0.3384 - val_accuracy: 0.9000
# Epoch 114/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.4416 - accuracy: 0.8357 - val_loss: 0.3382 - val_accuracy: 0.9000
# Epoch 115/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.4414 - accuracy: 0.8357 - val_loss: 0.3382 - val_accuracy: 0.9000
# Epoch 116/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.4413 - accuracy: 0.8357 - val_loss: 0.3381 - val_accuracy: 0.9000
# Epoch 117/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.4413 - accuracy: 0.8357 - val_loss: 0.3379 - val_accuracy: 0.9000
# Epoch 118/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.4412 - accuracy: 0.8357 - val_loss: 0.3377 - val_accuracy: 0.9000
# Epoch 119/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.4410 - accuracy: 0.8357 - val_loss: 0.3376 - val_accuracy: 0.9000
# Epoch 120/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.4408 - accuracy: 0.8357 - val_loss: 0.3375 - val_accuracy: 0.9000
# Epoch 121/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.4407 - accuracy: 0.8357 - val_loss: 0.3375 - val_accuracy: 0.9000
# Epoch 122/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.4406 - accuracy: 0.8357 - val_loss: 0.3372 - val_accuracy: 0.9000
# Epoch 123/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.4406 - accuracy: 0.8357 - val_loss: 0.3368 - val_accuracy: 0.9000
# Epoch 124/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.4403 - accuracy: 0.8357 - val_loss: 0.3367 - val_accuracy: 0.9000
# Epoch 125/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.4402 - accuracy: 0.8357 - val_loss: 0.3365 - val_accuracy: 0.9000
# Epoch 126/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.4401 - accuracy: 0.8357 - val_loss: 0.3364 - val_accuracy: 0.9000
# Epoch 127/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.4398 - accuracy: 0.8357 - val_loss: 0.3362 - val_accuracy: 0.9000
# Epoch 128/400
# 9/9 [==============================] - 0s 7ms/step - loss: 0.4397 - accuracy: 0.8357 - val_loss: 0.3362 - val_accuracy: 0.9000
# Epoch 129/400
# 9/9 [==============================] - 0s 7ms/step - loss: 0.4395 - accuracy: 0.8357 - val_loss: 0.3361 - val_accuracy: 0.9000
# Epoch 130/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.4394 - accuracy: 0.8357 - val_loss: 0.3360 - val_accuracy: 0.9000
# Epoch 131/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.4392 - accuracy: 0.8357 - val_loss: 0.3358 - val_accuracy: 0.9000
# Epoch 132/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.4390 - accuracy: 0.8357 - val_loss: 0.3357 - val_accuracy: 0.9000
# Epoch 133/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.4389 - accuracy: 0.8357 - val_loss: 0.3357 - val_accuracy: 0.9000
# Epoch 134/400
# 9/9 [==============================] - 0s 7ms/step - loss: 0.4387 - accuracy: 0.8357 - val_loss: 0.3355 - val_accuracy: 0.9000
# Epoch 135/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.4385 - accuracy: 0.8357 - val_loss: 0.3352 - val_accuracy: 0.9000
# Epoch 136/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.4384 - accuracy: 0.8357 - val_loss: 0.3351 - val_accuracy: 0.9000
# Epoch 137/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.4382 - accuracy: 0.8357 - val_loss: 0.3351 - val_accuracy: 0.9000
# Epoch 138/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.4380 - accuracy: 0.8357 - val_loss: 0.3350 - val_accuracy: 0.9000
# Epoch 139/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.4378 - accuracy: 0.8357 - val_loss: 0.3348 - val_accuracy: 0.9000
# Epoch 140/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.4376 - accuracy: 0.8357 - val_loss: 0.3346 - val_accuracy: 0.9000
# Epoch 141/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.4375 - accuracy: 0.8357 - val_loss: 0.3344 - val_accuracy: 0.9000
# Epoch 142/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.4372 - accuracy: 0.8357 - val_loss: 0.3342 - val_accuracy: 0.9000
# Epoch 143/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.4370 - accuracy: 0.8357 - val_loss: 0.3340 - val_accuracy: 0.9000
# Epoch 144/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.4368 - accuracy: 0.8357 - val_loss: 0.3338 - val_accuracy: 0.9000
# Epoch 145/400
# 9/9 [==============================] - 0s 7ms/step - loss: 0.4366 - accuracy: 0.8357 - val_loss: 0.3336 - val_accuracy: 0.9000
# Epoch 146/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.4363 - accuracy: 0.8357 - val_loss: 0.3336 - val_accuracy: 0.9000
# Epoch 147/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.4363 - accuracy: 0.8357 - val_loss: 0.3333 - val_accuracy: 0.9000
# Epoch 148/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.4359 - accuracy: 0.8357 - val_loss: 0.3332 - val_accuracy: 0.9000
# Epoch 149/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.4358 - accuracy: 0.8357 - val_loss: 0.3331 - val_accuracy: 0.9000
# Epoch 150/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.4355 - accuracy: 0.8357 - val_loss: 0.3329 - val_accuracy: 0.9000
# Epoch 151/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.4353 - accuracy: 0.8357 - val_loss: 0.3326 - val_accuracy: 0.9000
# Epoch 152/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.4351 - accuracy: 0.8357 - val_loss: 0.3325 - val_accuracy: 0.9000
# Epoch 153/400
# 9/9 [==============================] - 0s 7ms/step - loss: 0.4349 - accuracy: 0.8357 - val_loss: 0.3324 - val_accuracy: 0.9000
# Epoch 154/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.4346 - accuracy: 0.8357 - val_loss: 0.3321 - val_accuracy: 0.9000
# Epoch 155/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.4344 - accuracy: 0.8357 - val_loss: 0.3319 - val_accuracy: 0.9000
# Epoch 156/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.4341 - accuracy: 0.8357 - val_loss: 0.3316 - val_accuracy: 0.9000
# Epoch 157/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.4339 - accuracy: 0.8357 - val_loss: 0.3315 - val_accuracy: 0.9000
# Epoch 158/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.4338 - accuracy: 0.8357 - val_loss: 0.3312 - val_accuracy: 0.9000
# Epoch 159/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.4335 - accuracy: 0.8357 - val_loss: 0.3311 - val_accuracy: 0.9000
# Epoch 160/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.4332 - accuracy: 0.8357 - val_loss: 0.3311 - val_accuracy: 0.9000
# Epoch 161/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.4330 - accuracy: 0.8357 - val_loss: 0.3309 - val_accuracy: 0.9000
# Epoch 162/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.4327 - accuracy: 0.8357 - val_loss: 0.3308 - val_accuracy: 0.9000
# Epoch 163/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.4325 - accuracy: 0.8357 - val_loss: 0.3304 - val_accuracy: 0.9000
# Epoch 164/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.4323 - accuracy: 0.8357 - val_loss: 0.3300 - val_accuracy: 0.9000
# Epoch 165/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.4319 - accuracy: 0.8357 - val_loss: 0.3299 - val_accuracy: 0.9000
# Epoch 166/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.4317 - accuracy: 0.8357 - val_loss: 0.3297 - val_accuracy: 0.9000
# Epoch 167/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.4314 - accuracy: 0.8357 - val_loss: 0.3295 - val_accuracy: 0.9000
# Epoch 168/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.4312 - accuracy: 0.8357 - val_loss: 0.3294 - val_accuracy: 0.9000
# Epoch 169/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.4309 - accuracy: 0.8357 - val_loss: 0.3292 - val_accuracy: 0.9000
# Epoch 170/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.4306 - accuracy: 0.8357 - val_loss: 0.3289 - val_accuracy: 0.9000
# Epoch 171/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.4303 - accuracy: 0.8357 - val_loss: 0.3286 - val_accuracy: 0.9000
# Epoch 172/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.4300 - accuracy: 0.8357 - val_loss: 0.3284 - val_accuracy: 0.9000
# Epoch 173/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.4298 - accuracy: 0.8357 - val_loss: 0.3282 - val_accuracy: 0.9000
# Epoch 174/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.4295 - accuracy: 0.8357 - val_loss: 0.3279 - val_accuracy: 0.9000
# Epoch 175/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.4292 - accuracy: 0.8357 - val_loss: 0.3279 - val_accuracy: 0.9000
# Epoch 176/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.4291 - accuracy: 0.8357 - val_loss: 0.3275 - val_accuracy: 0.9000
# Epoch 177/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.4286 - accuracy: 0.8357 - val_loss: 0.3274 - val_accuracy: 0.9000
# Epoch 178/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.4284 - accuracy: 0.8357 - val_loss: 0.3272 - val_accuracy: 0.9000
# Epoch 179/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.4280 - accuracy: 0.8357 - val_loss: 0.3269 - val_accuracy: 0.9000
# Epoch 180/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.4278 - accuracy: 0.8357 - val_loss: 0.3267 - val_accuracy: 0.9000
# Epoch 181/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.4275 - accuracy: 0.8357 - val_loss: 0.3264 - val_accuracy: 0.9000
# Epoch 182/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.4271 - accuracy: 0.8357 - val_loss: 0.3263 - val_accuracy: 0.9000
# Epoch 183/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.4267 - accuracy: 0.8357 - val_loss: 0.3259 - val_accuracy: 0.9000
# Epoch 184/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.4266 - accuracy: 0.8357 - val_loss: 0.3257 - val_accuracy: 0.9000
# Epoch 185/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.4261 - accuracy: 0.8357 - val_loss: 0.3255 - val_accuracy: 0.9000
# Epoch 186/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.4259 - accuracy: 0.8357 - val_loss: 0.3251 - val_accuracy: 0.9000
# Epoch 187/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.4255 - accuracy: 0.8357 - val_loss: 0.3249 - val_accuracy: 0.9000
# Epoch 188/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.4252 - accuracy: 0.8357 - val_loss: 0.3247 - val_accuracy: 0.9000
# Epoch 189/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.4248 - accuracy: 0.8357 - val_loss: 0.3245 - val_accuracy: 0.9000
# Epoch 190/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.4245 - accuracy: 0.8357 - val_loss: 0.3242 - val_accuracy: 0.9000
# Epoch 191/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.4242 - accuracy: 0.8357 - val_loss: 0.3239 - val_accuracy: 0.9000
# Epoch 192/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.4238 - accuracy: 0.8357 - val_loss: 0.3237 - val_accuracy: 0.9000
# Epoch 193/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.4235 - accuracy: 0.8357 - val_loss: 0.3236 - val_accuracy: 0.9000
# Epoch 194/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.4231 - accuracy: 0.8357 - val_loss: 0.3232 - val_accuracy: 0.9000
# Epoch 195/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.4227 - accuracy: 0.8357 - val_loss: 0.3230 - val_accuracy: 0.9000
# Epoch 196/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.4224 - accuracy: 0.8357 - val_loss: 0.3227 - val_accuracy: 0.9000
# Epoch 197/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.4220 - accuracy: 0.8357 - val_loss: 0.3225 - val_accuracy: 0.9000
# Epoch 198/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.4218 - accuracy: 0.8357 - val_loss: 0.3222 - val_accuracy: 0.9000
# Epoch 199/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.4213 - accuracy: 0.8357 - val_loss: 0.3220 - val_accuracy: 0.9000
# Epoch 200/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.4211 - accuracy: 0.8357 - val_loss: 0.3218 - val_accuracy: 0.9000
# Epoch 201/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.4206 - accuracy: 0.8357 - val_loss: 0.3215 - val_accuracy: 0.9000
# Epoch 202/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.4203 - accuracy: 0.8357 - val_loss: 0.3212 - val_accuracy: 0.9000
# Epoch 203/400
# 9/9 [==============================] - 0s 7ms/step - loss: 0.4199 - accuracy: 0.8357 - val_loss: 0.3210 - val_accuracy: 0.9000
# Epoch 204/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.4196 - accuracy: 0.8357 - val_loss: 0.3208 - val_accuracy: 0.9000
# Epoch 205/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.4192 - accuracy: 0.8357 - val_loss: 0.3205 - val_accuracy: 0.9000
# Epoch 206/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.4189 - accuracy: 0.8357 - val_loss: 0.3201 - val_accuracy: 0.9000
# Epoch 207/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.4185 - accuracy: 0.8357 - val_loss: 0.3197 - val_accuracy: 0.9000
# Epoch 208/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.4182 - accuracy: 0.8357 - val_loss: 0.3194 - val_accuracy: 0.9000
# Epoch 209/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.4177 - accuracy: 0.8357 - val_loss: 0.3191 - val_accuracy: 0.9000
# Epoch 210/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.4173 - accuracy: 0.8357 - val_loss: 0.3187 - val_accuracy: 0.9000
# Epoch 211/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.4168 - accuracy: 0.8357 - val_loss: 0.3183 - val_accuracy: 0.9000
# Epoch 212/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.4164 - accuracy: 0.8357 - val_loss: 0.3178 - val_accuracy: 0.9000
# Epoch 213/400
# 9/9 [==============================] - 0s 7ms/step - loss: 0.4158 - accuracy: 0.8357 - val_loss: 0.3174 - val_accuracy: 0.9000
# Epoch 214/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.4155 - accuracy: 0.8357 - val_loss: 0.3170 - val_accuracy: 0.9000
# Epoch 215/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.4150 - accuracy: 0.8357 - val_loss: 0.3167 - val_accuracy: 0.9000
# Epoch 216/400
# 9/9 [==============================] - 0s 7ms/step - loss: 0.4145 - accuracy: 0.8357 - val_loss: 0.3163 - val_accuracy: 0.9000
# Epoch 217/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.4141 - accuracy: 0.8357 - val_loss: 0.3160 - val_accuracy: 0.9000
# Epoch 218/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.4137 - accuracy: 0.8357 - val_loss: 0.3156 - val_accuracy: 0.9000
# Epoch 219/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.4132 - accuracy: 0.8357 - val_loss: 0.3153 - val_accuracy: 0.9000
# Epoch 220/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.4128 - accuracy: 0.8357 - val_loss: 0.3149 - val_accuracy: 0.9000
# Epoch 221/400
# 9/9 [==============================] - 0s 7ms/step - loss: 0.4124 - accuracy: 0.8357 - val_loss: 0.3147 - val_accuracy: 0.9000
# Epoch 222/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.4120 - accuracy: 0.8357 - val_loss: 0.3144 - val_accuracy: 0.9000
# Epoch 223/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.4116 - accuracy: 0.8357 - val_loss: 0.3140 - val_accuracy: 0.9000
# Epoch 224/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.4111 - accuracy: 0.8357 - val_loss: 0.3138 - val_accuracy: 0.9000
# Epoch 225/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.4107 - accuracy: 0.8357 - val_loss: 0.3135 - val_accuracy: 0.9000
# Epoch 226/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.4103 - accuracy: 0.8357 - val_loss: 0.3133 - val_accuracy: 0.9000
# Epoch 227/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.4098 - accuracy: 0.8357 - val_loss: 0.3129 - val_accuracy: 0.9000
# Epoch 228/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.4093 - accuracy: 0.8357 - val_loss: 0.3126 - val_accuracy: 0.9000
# Epoch 229/400
# 9/9 [==============================] - 0s 8ms/step - loss: 0.4089 - accuracy: 0.8357 - val_loss: 0.3123 - val_accuracy: 0.9000
# Epoch 230/400
# 9/9 [==============================] - 0s 10ms/step - loss: 0.4084 - accuracy: 0.8357 - val_loss: 0.3119 - val_accuracy: 0.9000
# Epoch 231/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.4080 - accuracy: 0.8357 - val_loss: 0.3115 - val_accuracy: 0.9000
# Epoch 232/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.4076 - accuracy: 0.8357 - val_loss: 0.3111 - val_accuracy: 0.9000
# Epoch 233/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.4071 - accuracy: 0.8357 - val_loss: 0.3107 - val_accuracy: 0.9000
# Epoch 234/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.4067 - accuracy: 0.8357 - val_loss: 0.3105 - val_accuracy: 0.9000
# Epoch 235/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.4062 - accuracy: 0.8357 - val_loss: 0.3101 - val_accuracy: 0.9000
# Epoch 236/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.4058 - accuracy: 0.8357 - val_loss: 0.3100 - val_accuracy: 0.9000
# Epoch 237/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.4053 - accuracy: 0.8357 - val_loss: 0.3098 - val_accuracy: 0.9000
# Epoch 238/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.4048 - accuracy: 0.8357 - val_loss: 0.3094 - val_accuracy: 0.9000
# Epoch 239/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.4044 - accuracy: 0.8357 - val_loss: 0.3091 - val_accuracy: 0.9000
# Epoch 240/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.4039 - accuracy: 0.8357 - val_loss: 0.3088 - val_accuracy: 0.9000
# Epoch 241/400
# 9/9 [==============================] - 0s 8ms/step - loss: 0.4034 - accuracy: 0.8357 - val_loss: 0.3083 - val_accuracy: 0.9000
# Epoch 242/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.4029 - accuracy: 0.8357 - val_loss: 0.3081 - val_accuracy: 0.9000
# Epoch 243/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.4024 - accuracy: 0.8357 - val_loss: 0.3077 - val_accuracy: 0.9000
# Epoch 244/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.4020 - accuracy: 0.8357 - val_loss: 0.3074 - val_accuracy: 0.9000
# Epoch 245/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.4015 - accuracy: 0.8357 - val_loss: 0.3070 - val_accuracy: 0.9000
# Epoch 246/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.4010 - accuracy: 0.8357 - val_loss: 0.3066 - val_accuracy: 0.9000
# Epoch 247/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.4006 - accuracy: 0.8357 - val_loss: 0.3063 - val_accuracy: 0.9000
# Epoch 248/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.4001 - accuracy: 0.8357 - val_loss: 0.3059 - val_accuracy: 0.9000
# Epoch 249/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.3995 - accuracy: 0.8357 - val_loss: 0.3057 - val_accuracy: 0.9000
# Epoch 250/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.3991 - accuracy: 0.8357 - val_loss: 0.3053 - val_accuracy: 0.9000
# Epoch 251/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.3985 - accuracy: 0.8357 - val_loss: 0.3051 - val_accuracy: 0.9000
# Epoch 252/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.3980 - accuracy: 0.8357 - val_loss: 0.3047 - val_accuracy: 0.9000
# Epoch 253/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.3974 - accuracy: 0.8357 - val_loss: 0.3044 - val_accuracy: 0.9000
# Epoch 254/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.3969 - accuracy: 0.8357 - val_loss: 0.3040 - val_accuracy: 0.9000
# Epoch 255/400
# 9/9 [==============================] - 0s 7ms/step - loss: 0.3964 - accuracy: 0.8357 - val_loss: 0.3037 - val_accuracy: 0.9000
# Epoch 256/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.3960 - accuracy: 0.8357 - val_loss: 0.3033 - val_accuracy: 0.9000
# Epoch 257/400
# 9/9 [==============================] - 0s 7ms/step - loss: 0.3954 - accuracy: 0.8357 - val_loss: 0.3031 - val_accuracy: 0.9000
# Epoch 258/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.3949 - accuracy: 0.8357 - val_loss: 0.3028 - val_accuracy: 0.9000
# Epoch 259/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.3944 - accuracy: 0.8357 - val_loss: 0.3026 - val_accuracy: 0.9000
# Epoch 260/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.3938 - accuracy: 0.8357 - val_loss: 0.3020 - val_accuracy: 0.9000
# Epoch 261/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.3933 - accuracy: 0.8357 - val_loss: 0.3015 - val_accuracy: 0.9000
# Epoch 262/400
# 9/9 [==============================] - 0s 7ms/step - loss: 0.3928 - accuracy: 0.8357 - val_loss: 0.3010 - val_accuracy: 0.9000
# Epoch 263/400
# 9/9 [==============================] - 0s 8ms/step - loss: 0.3921 - accuracy: 0.8357 - val_loss: 0.3007 - val_accuracy: 0.9000
# Epoch 264/400
# 9/9 [==============================] - 0s 9ms/step - loss: 0.3916 - accuracy: 0.8357 - val_loss: 0.3003 - val_accuracy: 0.9000
# Epoch 265/400
# 9/9 [==============================] - 1s 83ms/step - loss: 0.3910 - accuracy: 0.8357 - val_loss: 0.3001 - val_accuracy: 0.9000
# Epoch 266/400
# 9/9 [==============================] - 0s 8ms/step - loss: 0.3904 - accuracy: 0.8357 - val_loss: 0.2997 - val_accuracy: 0.9000
# Epoch 267/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.3900 - accuracy: 0.8357 - val_loss: 0.2994 - val_accuracy: 0.9000
# Epoch 268/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.3894 - accuracy: 0.8357 - val_loss: 0.2992 - val_accuracy: 0.9000
# Epoch 269/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.3889 - accuracy: 0.8357 - val_loss: 0.2989 - val_accuracy: 0.9000
# Epoch 270/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.3884 - accuracy: 0.8357 - val_loss: 0.2985 - val_accuracy: 0.9000
# Epoch 271/400
# 9/9 [==============================] - 0s 8ms/step - loss: 0.3877 - accuracy: 0.8357 - val_loss: 0.2979 - val_accuracy: 0.9000
# Epoch 272/400
# 9/9 [==============================] - 0s 11ms/step - loss: 0.3872 - accuracy: 0.8357 - val_loss: 0.2974 - val_accuracy: 0.9000
# Epoch 273/400
# 9/9 [==============================] - 0s 8ms/step - loss: 0.3866 - accuracy: 0.8357 - val_loss: 0.2971 - val_accuracy: 0.9000
# Epoch 274/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.3862 - accuracy: 0.8357 - val_loss: 0.2967 - val_accuracy: 0.9000
# Epoch 275/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.3855 - accuracy: 0.8357 - val_loss: 0.2964 - val_accuracy: 0.9000
# Epoch 276/400
# 9/9 [==============================] - 0s 11ms/step - loss: 0.3850 - accuracy: 0.8357 - val_loss: 0.2961 - val_accuracy: 0.9000
# Epoch 277/400
# 9/9 [==============================] - 0s 7ms/step - loss: 0.3845 - accuracy: 0.8357 - val_loss: 0.2956 - val_accuracy: 0.9000
# Epoch 278/400
# 9/9 [==============================] - 0s 11ms/step - loss: 0.3838 - accuracy: 0.8357 - val_loss: 0.2953 - val_accuracy: 0.9000
# Epoch 279/400
# 9/9 [==============================] - 0s 11ms/step - loss: 0.3832 - accuracy: 0.8357 - val_loss: 0.2948 - val_accuracy: 0.9000
# Epoch 280/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.3825 - accuracy: 0.8357 - val_loss: 0.2944 - val_accuracy: 0.9000
# Epoch 281/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.3818 - accuracy: 0.8357 - val_loss: 0.2939 - val_accuracy: 0.9000
# Epoch 282/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.3811 - accuracy: 0.8357 - val_loss: 0.2934 - val_accuracy: 0.9000
# Epoch 283/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.3805 - accuracy: 0.8357 - val_loss: 0.2929 - val_accuracy: 0.9000
# Epoch 284/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.3798 - accuracy: 0.8357 - val_loss: 0.2925 - val_accuracy: 0.9000
# Epoch 285/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.3792 - accuracy: 0.8357 - val_loss: 0.2919 - val_accuracy: 0.9000
# Epoch 286/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.3786 - accuracy: 0.8357 - val_loss: 0.2915 - val_accuracy: 0.9000
# Epoch 287/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.3779 - accuracy: 0.8357 - val_loss: 0.2912 - val_accuracy: 0.9000
# Epoch 288/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.3773 - accuracy: 0.8357 - val_loss: 0.2907 - val_accuracy: 0.9000
# Epoch 289/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.3766 - accuracy: 0.8357 - val_loss: 0.2902 - val_accuracy: 0.9000
# Epoch 290/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.3761 - accuracy: 0.8357 - val_loss: 0.2898 - val_accuracy: 0.9000
# Epoch 291/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.3753 - accuracy: 0.8357 - val_loss: 0.2895 - val_accuracy: 0.9000
# Epoch 292/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.3747 - accuracy: 0.8357 - val_loss: 0.2892 - val_accuracy: 0.9000
# Epoch 293/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.3740 - accuracy: 0.8357 - val_loss: 0.2888 - val_accuracy: 0.9000
# Epoch 294/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.3733 - accuracy: 0.8357 - val_loss: 0.2882 - val_accuracy: 0.9000
# Epoch 295/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.3726 - accuracy: 0.8357 - val_loss: 0.2877 - val_accuracy: 0.9000
# Epoch 296/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.3720 - accuracy: 0.8357 - val_loss: 0.2872 - val_accuracy: 0.9000
# Epoch 297/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.3713 - accuracy: 0.8357 - val_loss: 0.2868 - val_accuracy: 0.9000
# Epoch 298/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.3705 - accuracy: 0.8357 - val_loss: 0.2864 - val_accuracy: 0.9000
# Epoch 299/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.3698 - accuracy: 0.8357 - val_loss: 0.2859 - val_accuracy: 0.9000
# Epoch 300/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.3691 - accuracy: 0.8357 - val_loss: 0.2854 - val_accuracy: 0.9000
# Epoch 301/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.3683 - accuracy: 0.8357 - val_loss: 0.2850 - val_accuracy: 0.9000
# Epoch 302/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.3675 - accuracy: 0.8357 - val_loss: 0.2846 - val_accuracy: 0.9000
# Epoch 303/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.3667 - accuracy: 0.8357 - val_loss: 0.2841 - val_accuracy: 0.9000
# Epoch 304/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.3660 - accuracy: 0.8357 - val_loss: 0.2837 - val_accuracy: 0.9000
# Epoch 305/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.3653 - accuracy: 0.8357 - val_loss: 0.2832 - val_accuracy: 0.9000
# Epoch 306/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.3645 - accuracy: 0.8357 - val_loss: 0.2828 - val_accuracy: 0.9000
# Epoch 307/400
# 9/9 [==============================] - 0s 10ms/step - loss: 0.3636 - accuracy: 0.8357 - val_loss: 0.2822 - val_accuracy: 0.9000
# Epoch 308/400
# 9/9 [==============================] - 0s 10ms/step - loss: 0.3628 - accuracy: 0.8357 - val_loss: 0.2815 - val_accuracy: 0.9000
# Epoch 309/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.3621 - accuracy: 0.8357 - val_loss: 0.2811 - val_accuracy: 0.9000
# Epoch 310/400
# 9/9 [==============================] - 0s 8ms/step - loss: 0.3614 - accuracy: 0.8357 - val_loss: 0.2807 - val_accuracy: 0.9000
# Epoch 311/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.3606 - accuracy: 0.8357 - val_loss: 0.2802 - val_accuracy: 0.9000
# Epoch 312/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.3598 - accuracy: 0.8357 - val_loss: 0.2798 - val_accuracy: 0.9000
# Epoch 313/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.3591 - accuracy: 0.8357 - val_loss: 0.2793 - val_accuracy: 0.9000
# Epoch 314/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.3584 - accuracy: 0.8357 - val_loss: 0.2788 - val_accuracy: 0.9000
# Epoch 315/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.3576 - accuracy: 0.8357 - val_loss: 0.2785 - val_accuracy: 0.9000
# Epoch 316/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.3568 - accuracy: 0.8357 - val_loss: 0.2781 - val_accuracy: 0.9000
# Epoch 317/400
# 9/9 [==============================] - 0s 7ms/step - loss: 0.3561 - accuracy: 0.8357 - val_loss: 0.2776 - val_accuracy: 0.9000
# Epoch 318/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.3552 - accuracy: 0.8357 - val_loss: 0.2769 - val_accuracy: 0.9000
# Epoch 319/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.3546 - accuracy: 0.8357 - val_loss: 0.2764 - val_accuracy: 0.9000
# Epoch 320/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.3536 - accuracy: 0.8357 - val_loss: 0.2760 - val_accuracy: 0.9000
# Epoch 321/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.3529 - accuracy: 0.8357 - val_loss: 0.2754 - val_accuracy: 0.9000
# Epoch 322/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.3520 - accuracy: 0.8357 - val_loss: 0.2751 - val_accuracy: 0.9000
# Epoch 323/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.3512 - accuracy: 0.8357 - val_loss: 0.2745 - val_accuracy: 0.9000
# Epoch 324/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.3504 - accuracy: 0.8357 - val_loss: 0.2739 - val_accuracy: 0.9000
# Epoch 325/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.3496 - accuracy: 0.8357 - val_loss: 0.2734 - val_accuracy: 0.9000
# Epoch 326/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.3489 - accuracy: 0.8357 - val_loss: 0.2731 - val_accuracy: 0.9000
# Epoch 327/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.3481 - accuracy: 0.8357 - val_loss: 0.2726 - val_accuracy: 0.9000
# Epoch 328/400
# 9/9 [==============================] - 0s 7ms/step - loss: 0.3473 - accuracy: 0.8357 - val_loss: 0.2720 - val_accuracy: 0.9000
# Epoch 329/400
# 9/9 [==============================] - 0s 7ms/step - loss: 0.3465 - accuracy: 0.8357 - val_loss: 0.2715 - val_accuracy: 0.9000
# Epoch 330/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.3455 - accuracy: 0.8357 - val_loss: 0.2711 - val_accuracy: 0.9000
# Epoch 331/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.3447 - accuracy: 0.8357 - val_loss: 0.2706 - val_accuracy: 0.9000
# Epoch 332/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.3439 - accuracy: 0.8357 - val_loss: 0.2701 - val_accuracy: 0.9000
# Epoch 333/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.3430 - accuracy: 0.8357 - val_loss: 0.2698 - val_accuracy: 0.9000
# Epoch 334/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.3422 - accuracy: 0.8357 - val_loss: 0.2691 - val_accuracy: 0.9000
# Epoch 335/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.3414 - accuracy: 0.8357 - val_loss: 0.2687 - val_accuracy: 0.9000
# Epoch 336/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.3407 - accuracy: 0.8357 - val_loss: 0.2682 - val_accuracy: 0.9000
# Epoch 337/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.3398 - accuracy: 0.8357 - val_loss: 0.2677 - val_accuracy: 0.9000
# Epoch 338/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.3389 - accuracy: 0.8357 - val_loss: 0.2672 - val_accuracy: 0.9000
# Epoch 339/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.3381 - accuracy: 0.8357 - val_loss: 0.2666 - val_accuracy: 0.9000
# Epoch 340/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.3372 - accuracy: 0.8357 - val_loss: 0.2661 - val_accuracy: 0.9000
# Epoch 341/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.3363 - accuracy: 0.8357 - val_loss: 0.2655 - val_accuracy: 0.9000
# Epoch 342/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.3354 - accuracy: 0.8357 - val_loss: 0.2650 - val_accuracy: 0.9000
# Epoch 343/400
# 9/9 [==============================] - 0s 10ms/step - loss: 0.3344 - accuracy: 0.8357 - val_loss: 0.2644 - val_accuracy: 0.9000
# Epoch 344/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.3336 - accuracy: 0.8357 - val_loss: 0.2636 - val_accuracy: 0.9000
# Epoch 345/400
# 9/9 [==============================] - 0s 9ms/step - loss: 0.3327 - accuracy: 0.8357 - val_loss: 0.2634 - val_accuracy: 0.9000
# Epoch 346/400
# 9/9 [==============================] - 0s 17ms/step - loss: 0.3319 - accuracy: 0.8357 - val_loss: 0.2629 - val_accuracy: 0.9000
# Epoch 347/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.3311 - accuracy: 0.8357 - val_loss: 0.2621 - val_accuracy: 0.9000
# Epoch 348/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.3302 - accuracy: 0.8357 - val_loss: 0.2619 - val_accuracy: 0.9000
# Epoch 349/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.3294 - accuracy: 0.8357 - val_loss: 0.2614 - val_accuracy: 0.9000
# Epoch 350/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.3286 - accuracy: 0.8357 - val_loss: 0.2610 - val_accuracy: 0.9000
# Epoch 351/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.3277 - accuracy: 0.8357 - val_loss: 0.2605 - val_accuracy: 0.9000
# Epoch 352/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.3269 - accuracy: 0.8357 - val_loss: 0.2600 - val_accuracy: 0.9000
# Epoch 353/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.3260 - accuracy: 0.8357 - val_loss: 0.2595 - val_accuracy: 0.9000
# Epoch 354/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.3251 - accuracy: 0.8357 - val_loss: 0.2590 - val_accuracy: 0.9000
# Epoch 355/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.3244 - accuracy: 0.8357 - val_loss: 0.2585 - val_accuracy: 0.9000
# Epoch 356/400
# 9/9 [==============================] - 0s 7ms/step - loss: 0.3236 - accuracy: 0.8357 - val_loss: 0.2580 - val_accuracy: 0.9000
# Epoch 357/400
# 9/9 [==============================] - 0s 7ms/step - loss: 0.3229 - accuracy: 0.8357 - val_loss: 0.2573 - val_accuracy: 0.9000
# Epoch 358/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.3220 - accuracy: 0.8357 - val_loss: 0.2567 - val_accuracy: 0.9000
# Epoch 359/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.3212 - accuracy: 0.8357 - val_loss: 0.2559 - val_accuracy: 0.9000
# Epoch 360/400
# 9/9 [==============================] - 0s 7ms/step - loss: 0.3204 - accuracy: 0.8357 - val_loss: 0.2552 - val_accuracy: 0.9000
# Epoch 361/400
# 9/9 [==============================] - 0s 7ms/step - loss: 0.3196 - accuracy: 0.8357 - val_loss: 0.2549 - val_accuracy: 0.9000
# Epoch 362/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.3187 - accuracy: 0.8357 - val_loss: 0.2544 - val_accuracy: 0.9000
# Epoch 363/400
# 9/9 [==============================] - 0s 7ms/step - loss: 0.3180 - accuracy: 0.8357 - val_loss: 0.2539 - val_accuracy: 0.9000
# Epoch 364/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.3172 - accuracy: 0.8357 - val_loss: 0.2533 - val_accuracy: 0.9000
# Epoch 365/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.3163 - accuracy: 0.8357 - val_loss: 0.2528 - val_accuracy: 0.9000
# Epoch 366/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.3155 - accuracy: 0.8357 - val_loss: 0.2522 - val_accuracy: 0.9000
# Epoch 367/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.3147 - accuracy: 0.8357 - val_loss: 0.2517 - val_accuracy: 0.9000
# Epoch 368/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.3138 - accuracy: 0.8357 - val_loss: 0.2508 - val_accuracy: 0.9000
# Epoch 369/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.3130 - accuracy: 0.8357 - val_loss: 0.2501 - val_accuracy: 0.9000
# Epoch 370/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.3121 - accuracy: 0.8357 - val_loss: 0.2495 - val_accuracy: 0.9000
# Epoch 371/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.3113 - accuracy: 0.8357 - val_loss: 0.2489 - val_accuracy: 0.9000
# Epoch 372/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.3104 - accuracy: 0.8357 - val_loss: 0.2484 - val_accuracy: 0.9000
# Epoch 373/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.3095 - accuracy: 0.8357 - val_loss: 0.2477 - val_accuracy: 0.9000
# Epoch 374/400
# 9/9 [==============================] - 0s 8ms/step - loss: 0.3087 - accuracy: 0.8357 - val_loss: 0.2470 - val_accuracy: 0.9000
# Epoch 375/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.3079 - accuracy: 0.8357 - val_loss: 0.2466 - val_accuracy: 0.9000
# Epoch 376/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.3071 - accuracy: 0.8357 - val_loss: 0.2462 - val_accuracy: 0.9000
# Epoch 377/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.3063 - accuracy: 0.8357 - val_loss: 0.2458 - val_accuracy: 0.9000
# Epoch 378/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.3055 - accuracy: 0.8357 - val_loss: 0.2452 - val_accuracy: 0.9000
# Epoch 379/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.3048 - accuracy: 0.8357 - val_loss: 0.2451 - val_accuracy: 0.9000
# Epoch 380/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.3040 - accuracy: 0.8357 - val_loss: 0.2447 - val_accuracy: 0.9000
# Epoch 381/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.3033 - accuracy: 0.8357 - val_loss: 0.2442 - val_accuracy: 0.9000
# Epoch 382/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.3025 - accuracy: 0.8357 - val_loss: 0.2438 - val_accuracy: 0.9000
# Epoch 383/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.3016 - accuracy: 0.8357 - val_loss: 0.2430 - val_accuracy: 0.9000
# Epoch 384/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.3007 - accuracy: 0.8357 - val_loss: 0.2423 - val_accuracy: 0.9000
# Epoch 385/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.2999 - accuracy: 0.8357 - val_loss: 0.2418 - val_accuracy: 0.9000
# Epoch 386/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.2988 - accuracy: 0.8357 - val_loss: 0.2410 - val_accuracy: 0.9000
# Epoch 387/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.2980 - accuracy: 0.8357 - val_loss: 0.2408 - val_accuracy: 0.9000
# Epoch 388/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.2971 - accuracy: 0.8357 - val_loss: 0.2402 - val_accuracy: 0.9000
# Epoch 389/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2961 - accuracy: 0.8357 - val_loss: 0.2397 - val_accuracy: 0.9000
# Epoch 390/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2953 - accuracy: 0.8357 - val_loss: 0.2389 - val_accuracy: 0.9000
# Epoch 391/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.2944 - accuracy: 0.8357 - val_loss: 0.2382 - val_accuracy: 0.9000
# Epoch 392/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.2936 - accuracy: 0.8357 - val_loss: 0.2378 - val_accuracy: 0.9000
# Epoch 393/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.2926 - accuracy: 0.8357 - val_loss: 0.2372 - val_accuracy: 0.9000
# Epoch 394/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.2919 - accuracy: 0.8357 - val_loss: 0.2366 - val_accuracy: 0.9000
# Epoch 395/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.2912 - accuracy: 0.8357 - val_loss: 0.2364 - val_accuracy: 0.9000
# Epoch 396/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.2904 - accuracy: 0.8357 - val_loss: 0.2359 - val_accuracy: 0.9000
# Epoch 397/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.2896 - accuracy: 0.8357 - val_loss: 0.2353 - val_accuracy: 0.9000
# Epoch 398/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.2889 - accuracy: 0.8357 - val_loss: 0.2347 - val_accuracy: 0.9000
# Epoch 399/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.2881 - accuracy: 0.8357 - val_loss: 0.2343 - val_accuracy: 0.9000
# Epoch 400/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.2873 - accuracy: 0.8357 - val_loss: 0.2338 - val_accuracy: 0.9000

# %%
predictions = model.predict(scaled_X_test)

# %%
preds = []
for x in predictions:
    if x >= 0.5:
        preds.append(1)
    else:
        preds.append(0)

# %%
from sklearn.metrics import classification_report,confusion_matrix

# %%
print(classification_report(y1_test,preds))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.90      1.00      0.95       108
#          1.0       0.00      0.00      0.00        12
#
#     accuracy                           0.90       120
#    macro avg       0.45      0.50      0.47       120
# weighted avg       0.81      0.90      0.85       120
# /Users/miyanishio/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/miyanishio/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/miyanishio/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
