# %% [markdown]
# ## DNN Retry Min + Max + Mean
# Included the minimum, as well as took out the data from 2020-2021, 2021-2022.

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
# %matplotlib inline
from statistics import mean
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.callbacks import EarlyStopping

# %%
import seaborn as sns
import numpy as np
import pandas as pd
from statistics import mean
import math

FUTURE_PREDICTION = 4

def findmax(x):
    maximum = 0
    for number in x:
        maximum = max(x)
    return maximum

def findmean(x):
    m = 0
    m = mean(x)
    return m

def findmin(x):
    m = 0
    m = min(x)
    return m

def CreateMean(dataframe,title,city):

    dataframe = dataframe.iloc[522:3924:1]
    dataframe.rename(columns = {f'{city}' : f'{title}_Mean'}, inplace = True)
    dataframe = dataframe.reset_index(drop=True)
    for x in dataframe.index:
        if x % 7 == 6:
            list = []
            mean = 0
            for y in range(x-6,x+1,1):
                list.append(dataframe.iloc[y][f'{title}_Mean'])
            mean = findmean(list)
            dataframe.at[x,f'{title}_Mean'] = mean
    for x in dataframe.index:
        if x % 7 != 6:
            dataframe.drop(index= x, inplace=True)
    dataframe = dataframe.reset_index(drop=True)
    return dataframe

def CreateMax(dataframe,title,city):

    dataframe = dataframe.iloc[522:3924:1]
    dataframe.rename(columns = {f'{city}' : f'{title}_Max'}, inplace = True)
    dataframe = dataframe.reset_index(drop=True)
    for x in dataframe.index:
        if x % 7 == 6:
            list = []
            maximum = 0
            for y in range(x-6,x+1,1):
                list.append(dataframe.iloc[y][f'{title}_Max'])
            maximum = findmax(list)
            dataframe.at[x,f'{title}_Max'] = maximum
    for x in dataframe.index:
        if x % 7 != 6:
            dataframe.drop(index= x, inplace=True)
    dataframe = dataframe.reset_index(drop=True)
    return dataframe

def CreateMin(dataframe,title,city):

    dataframe = dataframe.iloc[522:3924:1]
    dataframe.rename(columns = {f'{city}' : f'{title}_Min'}, inplace = True)
    dataframe = dataframe.reset_index(drop=True)
    for x in dataframe.index:
        if x % 7 == 6:
            list = []
            minimum = 0
            for y in range(x-6,x+1,1):
                list.append(dataframe.iloc[y][f'{title}_Min'])
            minimum = findmin(list)
            dataframe.at[x,f'{title}_Min'] = minimum
    for x in dataframe.index:
        if x % 7 != 6:
            dataframe.drop(index= x, inplace=True)
    dataframe = dataframe.reset_index(drop=True)
    return dataframe
    
def DataPreprocess(city):
    virus_df = pd.read_csv('Data/virus.csv')
    virus_df['Date'] = pd.to_datetime(virus_df['Date'])
    virus_df['year'] = virus_df['Date'].apply(lambda date: date.year)
    virus_df['month'] = virus_df['Date'].apply(lambda date: date.month)
    virus_df_new = virus_df[['Date','month','year',f'{city}']]
    virus_df_new.rename(columns = {f'{city}' : f'Virus_Count_{city}'}, inplace = True)

    temp_df = pd.read_csv(f'Data/{city}_temp.csv')
    pressure_df = pd.read_csv(f'Data/{city}_pressure.csv')
    hours_df = pd.read_csv(f'Data/{city}_hours.csv')
    rainfall_df = pd.read_csv(f'Data/{city}_rainfall.csv')

    temp_df['Date'] = pd.to_datetime(temp_df['Date'])
    temp_df['year'] = temp_df['Date'].apply(lambda date: date.year)
    temp_df['month'] = temp_df['Date'].apply(lambda date: date.month)

    pressure_df['Date'] = pd.to_datetime(pressure_df['Date'])
    pressure_df['year'] = pressure_df['Date'].apply(lambda date: date.year)
    pressure_df['month'] = pressure_df['Date'].apply(lambda date: date.month)
    pressure_df = pressure_df.sort_values(by="Date")
    pressure_df = pressure_df.reset_index(drop=True)

    hours_df['Date'] = pd.to_datetime(hours_df['Date'])
    hours_df['year'] = hours_df['Date'].apply(lambda date: date.year)
    hours_df['month'] = hours_df['Date'].apply(lambda date: date.month)
    hours_df = hours_df.sort_values(by="Date")
    hours_df = hours_df.reset_index(drop=True)

    rainfall_df['Date'] = pd.to_datetime(rainfall_df['Date'])
    rainfall_df['year'] = rainfall_df['Date'].apply(lambda date: date.year)
    rainfall_df['month'] = rainfall_df['Date'].apply(lambda date: date.month)
    rainfall_df = rainfall_df.sort_values(by="Date")
    rainfall_df = rainfall_df.reset_index(drop=True)

    list = []
    for x in temp_df.index:
        t = temp_df.iloc[x][f'{city}']
        svp = 6.1078*10**(7.5*t/(t+237.3))
        e = pressure_df.iloc[x][f'{city}']
        h = e/svp*100
        list.append(h)
        
    humidity_df = pd.DataFrame(data=list)
    humidity_df.rename(columns = {0:f'{city}'}, inplace = True)

    mean_temp_df = CreateMean(temp_df, 'Temperature',f'{city}')
    mean_pressure_df = CreateMean(pressure_df, 'Pressure',f'{city}')
    mean_hours_df = CreateMean(hours_df, 'Hours',f'{city}')
    mean_rainfall_df = CreateMean(rainfall_df, 'Rainfall',f'{city}')
    mean_humidity_df = CreateMean(humidity_df, 'Humidity',f'{city}')
    
    max_temp_df = CreateMax(temp_df, 'Temperature',f'{city}')
    max_pressure_df = CreateMax(pressure_df, 'Pressure',f'{city}')
    max_hours_df = CreateMax(hours_df, 'Hours',f'{city}')
    max_rainfall_df = CreateMax(rainfall_df, 'Rainfall',f'{city}')
    max_humidity_df = CreateMax(humidity_df, 'Humidity',f'{city}')
    
    min_temp_df = CreateMin(temp_df, 'Temperature',f'{city}')
    min_pressure_df = CreateMin(pressure_df, 'Pressure',f'{city}')
    min_hours_df = CreateMin(hours_df, 'Hours',f'{city}')
    min_rainfall_df = CreateMin(rainfall_df, 'Rainfall',f'{city}')
    min_humidity_df = CreateMin(humidity_df, 'Humidity',f'{city}')

    df = pd.concat([virus_df_new,mean_temp_df,mean_pressure_df,mean_hours_df,mean_rainfall_df,mean_humidity_df,max_temp_df,max_pressure_df,max_hours_df,max_rainfall_df,max_humidity_df,
                   min_temp_df, min_pressure_df,min_hours_df,min_rainfall_df,min_humidity_df], axis=1)
    
    df = df.loc[:,~df.columns.duplicated()]
    
    df['VirusCRM'] = df['Virus_Count_Tokyo'].rolling(14, center = True).mean()

    for i in df.index:
        if i == 0:
            df.at[i,'Gradient'] = 1
        else:
            if df.iloc[i-1]['VirusCRM'] == 0:
                if df.at[i,'VirusCDM'] > 0:
                    df.at[i,'Gradient'] = 1
                else:
                    df.at[i,'Gradient'] = 0
            else:
                grd = df.iloc[i]['VirusCRM']/(df.iloc[i-1]['VirusCRM'])
                df.at[i,'Gradient'] = grd
    
    for i in df.index:
        if (df.iloc[i]['Gradient'] >= 1.1) and (df.iloc[i+1]['Gradient'] >= 1.1) and (df.iloc[i+2]['Gradient'] >= 1.1):
            df.at[i,'Spreading'] = 1
        else:
            df.at[i,'Spreading'] = 0
    df = df.astype({'Spreading':'int8'})

    df_virus_count = df[f'Virus_Count_{city}']
    df.drop(columns=['VirusCRM',f'Virus_Count_{city}','year','Gradient'], axis=1, inplace=True)
    df_labels = df[['Date']]
    FUTURE_PREDICTION = 4
    for i in range(FUTURE_PREDICTION):
        df_labels[f"T+{(i+1)*7}"] = df_labels["Date"] + pd.DateOffset(days = (i+1)*7)
    temp = df[["Date", "Spreading"]]
    for i in range(FUTURE_PREDICTION):
        target_column = f"T+{(i+1)*7}"
        df_labels = df_labels.merge(temp, 
                                how ="left",
                                left_on = (target_column),
                                right_on=("Date"),
                                suffixes = ("","_y")
        )
        df_labels.rename(columns={"Spreading":f"{target_column}_Spreading"},inplace=True)
    df_labels.drop(columns=["Date_y"],inplace=True)

    for i in range(FUTURE_PREDICTION):
        df_labels.drop(columns =[f"T+{(i+1)*7}"],inplace=True,axis=1 )

    df = df.merge(df_labels,
             how='left',
             on = ["Date"])
    df.dropna(inplace=True)

    X = df.drop(columns=['T+7_Spreading','T+14_Spreading','T+21_Spreading','T+28_Spreading'],axis=1)
    y1 = df['T+21_Spreading']
    y2 = df['T+7_Spreading']
    y3 = df['T+14_Spreading']
    y4 = df['T+28_Spreading']

    return X, y1, y2, y3, y4, df, df_virus_count

# %%
X, y1, y2, y3, y4, df, df_virus_count = DataPreprocess('Tokyo')
# Out:
# /Users/miyanishio/opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py:5039: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(
# /var/folders/k5/3yc13bs57f7637937yjlstth0000gn/T/ipykernel_86662/999066033.py:178: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_labels[f"T+{(i+1)*7}"] = df_labels["Date"] + pd.DateOffset(days = (i+1)*7)

# %%
X = X.drop(columns=['Date'])

# %%
X = X[0:400] #until 2020 05-04
y1 = y1[0:400]
y2 = y2[0:400]
y3 = y2[0:400]
y4 = y2[0:400]

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

scaler = StandardScaler()
scaler1 = StandardScaler()
X_train, X_test = X[0:280], X[280:400]
y1_train, y1_test = y1[0:280], y1[280:400]

# %%
scaled_X_train = scaler1.fit_transform(X_train)
scaled_X_test = scaler1.transform(X_test)

# %%
model = Sequential()

model.add(Dense(12,activation="sigmoid"))
model.add(Dense(6,activation="sigmoid"))
model.add(Dense(3,activation="sigmoid"))

model.add(Dense(1, activation='sigmoid'))
model.compile(optimizer='rmsprop',loss='binary_crossentropy',metrics=['accuracy'])
# Out:
# 2022-11-14 17:03:37.276040: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
early_stop = EarlyStopping(monitor='val_loss',mode='min',verbose=1,patience=50)

# %%
model.fit(scaled_X_train,y1_train,epochs=400,validation_data=(scaled_X_test,y1_test),callbacks=[early_stop])
# Out:
# Epoch 1/400
# 9/9 [==============================] - 1s 46ms/step - loss: 0.5155 - accuracy: 0.8357 - val_loss: 0.4608 - val_accuracy: 0.9000
# Epoch 2/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.5068 - accuracy: 0.8357 - val_loss: 0.4516 - val_accuracy: 0.9000
# Epoch 3/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.5005 - accuracy: 0.8357 - val_loss: 0.4436 - val_accuracy: 0.9000
# Epoch 4/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.4951 - accuracy: 0.8357 - val_loss: 0.4368 - val_accuracy: 0.9000
# Epoch 5/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.4899 - accuracy: 0.8357 - val_loss: 0.4291 - val_accuracy: 0.9000
# Epoch 6/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.4848 - accuracy: 0.8357 - val_loss: 0.4221 - val_accuracy: 0.9000
# Epoch 7/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.4800 - accuracy: 0.8357 - val_loss: 0.4153 - val_accuracy: 0.9000
# Epoch 8/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.4756 - accuracy: 0.8357 - val_loss: 0.4089 - val_accuracy: 0.9000
# Epoch 9/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.4716 - accuracy: 0.8357 - val_loss: 0.4038 - val_accuracy: 0.9000
# Epoch 10/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.4680 - accuracy: 0.8357 - val_loss: 0.3983 - val_accuracy: 0.9000
# Epoch 11/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.4646 - accuracy: 0.8357 - val_loss: 0.3933 - val_accuracy: 0.9000
# Epoch 12/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.4615 - accuracy: 0.8357 - val_loss: 0.3885 - val_accuracy: 0.9000
# Epoch 13/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.4585 - accuracy: 0.8357 - val_loss: 0.3841 - val_accuracy: 0.9000
# Epoch 14/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.4558 - accuracy: 0.8357 - val_loss: 0.3799 - val_accuracy: 0.9000
# Epoch 15/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.4533 - accuracy: 0.8357 - val_loss: 0.3764 - val_accuracy: 0.9000
# Epoch 16/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.4510 - accuracy: 0.8357 - val_loss: 0.3728 - val_accuracy: 0.9000
# Epoch 17/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.4490 - accuracy: 0.8357 - val_loss: 0.3698 - val_accuracy: 0.9000
# Epoch 18/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.4470 - accuracy: 0.8357 - val_loss: 0.3673 - val_accuracy: 0.9000
# Epoch 19/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.4454 - accuracy: 0.8357 - val_loss: 0.3646 - val_accuracy: 0.9000
# Epoch 20/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.4435 - accuracy: 0.8357 - val_loss: 0.3619 - val_accuracy: 0.9000
# Epoch 21/400
# 9/9 [==============================] - 0s 7ms/step - loss: 0.4418 - accuracy: 0.8357 - val_loss: 0.3592 - val_accuracy: 0.9000
# Epoch 22/400
# 9/9 [==============================] - 0s 7ms/step - loss: 0.4399 - accuracy: 0.8357 - val_loss: 0.3566 - val_accuracy: 0.9000
# Epoch 23/400
# 9/9 [==============================] - 0s 15ms/step - loss: 0.4383 - accuracy: 0.8357 - val_loss: 0.3544 - val_accuracy: 0.9000
# Epoch 24/400
# 9/9 [==============================] - 0s 8ms/step - loss: 0.4366 - accuracy: 0.8357 - val_loss: 0.3519 - val_accuracy: 0.9000
# Epoch 25/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.4350 - accuracy: 0.8357 - val_loss: 0.3499 - val_accuracy: 0.9000
# Epoch 26/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.4335 - accuracy: 0.8357 - val_loss: 0.3481 - val_accuracy: 0.9000
# Epoch 27/400
# 9/9 [==============================] - 0s 7ms/step - loss: 0.4320 - accuracy: 0.8357 - val_loss: 0.3462 - val_accuracy: 0.9000
# Epoch 28/400
# 9/9 [==============================] - 0s 34ms/step - loss: 0.4304 - accuracy: 0.8357 - val_loss: 0.3444 - val_accuracy: 0.9000
# Epoch 29/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.4290 - accuracy: 0.8357 - val_loss: 0.3427 - val_accuracy: 0.9000
# Epoch 30/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.4274 - accuracy: 0.8357 - val_loss: 0.3412 - val_accuracy: 0.9000
# Epoch 31/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.4259 - accuracy: 0.8357 - val_loss: 0.3396 - val_accuracy: 0.9000
# Epoch 32/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.4243 - accuracy: 0.8357 - val_loss: 0.3381 - val_accuracy: 0.9000
# Epoch 33/400
# 9/9 [==============================] - 0s 8ms/step - loss: 0.4229 - accuracy: 0.8357 - val_loss: 0.3368 - val_accuracy: 0.9000
# Epoch 34/400
# 9/9 [==============================] - 0s 14ms/step - loss: 0.4213 - accuracy: 0.8357 - val_loss: 0.3356 - val_accuracy: 0.9000
# Epoch 35/400
# 9/9 [==============================] - 0s 35ms/step - loss: 0.4197 - accuracy: 0.8357 - val_loss: 0.3341 - val_accuracy: 0.9000
# Epoch 36/400
# 9/9 [==============================] - 0s 33ms/step - loss: 0.4182 - accuracy: 0.8357 - val_loss: 0.3327 - val_accuracy: 0.9000
# Epoch 37/400
# 9/9 [==============================] - 0s 14ms/step - loss: 0.4167 - accuracy: 0.8357 - val_loss: 0.3312 - val_accuracy: 0.9000
# Epoch 38/400
# 9/9 [==============================] - 0s 15ms/step - loss: 0.4150 - accuracy: 0.8357 - val_loss: 0.3300 - val_accuracy: 0.9000
# Epoch 39/400
# 9/9 [==============================] - 0s 21ms/step - loss: 0.4134 - accuracy: 0.8357 - val_loss: 0.3287 - val_accuracy: 0.9000
# Epoch 40/400
# 9/9 [==============================] - 0s 10ms/step - loss: 0.4117 - accuracy: 0.8357 - val_loss: 0.3276 - val_accuracy: 0.9000
# Epoch 41/400
# 9/9 [==============================] - 0s 15ms/step - loss: 0.4100 - accuracy: 0.8357 - val_loss: 0.3266 - val_accuracy: 0.9000
# Epoch 42/400
# 9/9 [==============================] - 0s 22ms/step - loss: 0.4084 - accuracy: 0.8357 - val_loss: 0.3253 - val_accuracy: 0.9000
# Epoch 43/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.4067 - accuracy: 0.8357 - val_loss: 0.3243 - val_accuracy: 0.9000
# Epoch 44/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.4050 - accuracy: 0.8357 - val_loss: 0.3231 - val_accuracy: 0.9000
# Epoch 45/400
# 9/9 [==============================] - 0s 8ms/step - loss: 0.4033 - accuracy: 0.8357 - val_loss: 0.3218 - val_accuracy: 0.9000
# Epoch 46/400
# 9/9 [==============================] - 0s 7ms/step - loss: 0.4015 - accuracy: 0.8357 - val_loss: 0.3206 - val_accuracy: 0.9000
# Epoch 47/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.3996 - accuracy: 0.8357 - val_loss: 0.3196 - val_accuracy: 0.9000
# Epoch 48/400
# 9/9 [==============================] - 0s 8ms/step - loss: 0.3979 - accuracy: 0.8357 - val_loss: 0.3185 - val_accuracy: 0.9000
# Epoch 49/400
# 9/9 [==============================] - 0s 7ms/step - loss: 0.3961 - accuracy: 0.8357 - val_loss: 0.3176 - val_accuracy: 0.9000
# Epoch 50/400
# 9/9 [==============================] - 0s 7ms/step - loss: 0.3942 - accuracy: 0.8357 - val_loss: 0.3162 - val_accuracy: 0.9000
# Epoch 51/400
# 9/9 [==============================] - 0s 7ms/step - loss: 0.3923 - accuracy: 0.8357 - val_loss: 0.3151 - val_accuracy: 0.9000
# Epoch 52/400
# 9/9 [==============================] - 0s 7ms/step - loss: 0.3903 - accuracy: 0.8357 - val_loss: 0.3139 - val_accuracy: 0.9000
# Epoch 53/400
# 9/9 [==============================] - 0s 7ms/step - loss: 0.3884 - accuracy: 0.8357 - val_loss: 0.3127 - val_accuracy: 0.9000
# Epoch 54/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.3865 - accuracy: 0.8357 - val_loss: 0.3116 - val_accuracy: 0.9000
# Epoch 55/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.3847 - accuracy: 0.8357 - val_loss: 0.3106 - val_accuracy: 0.9000
# Epoch 56/400
# 9/9 [==============================] - 0s 8ms/step - loss: 0.3829 - accuracy: 0.8357 - val_loss: 0.3096 - val_accuracy: 0.9000
# Epoch 57/400
# 9/9 [==============================] - 0s 7ms/step - loss: 0.3811 - accuracy: 0.8357 - val_loss: 0.3087 - val_accuracy: 0.9000
# Epoch 58/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.3796 - accuracy: 0.8357 - val_loss: 0.3076 - val_accuracy: 0.9000
# Epoch 59/400
# 9/9 [==============================] - 0s 11ms/step - loss: 0.3777 - accuracy: 0.8357 - val_loss: 0.3066 - val_accuracy: 0.9000
# Epoch 60/400
# 9/9 [==============================] - 0s 14ms/step - loss: 0.3760 - accuracy: 0.8357 - val_loss: 0.3054 - val_accuracy: 0.9000
# Epoch 61/400
# 9/9 [==============================] - 0s 7ms/step - loss: 0.3743 - accuracy: 0.8357 - val_loss: 0.3045 - val_accuracy: 0.9000
# Epoch 62/400
# 9/9 [==============================] - 0s 8ms/step - loss: 0.3725 - accuracy: 0.8357 - val_loss: 0.3035 - val_accuracy: 0.9000
# Epoch 63/400
# 9/9 [==============================] - 0s 7ms/step - loss: 0.3708 - accuracy: 0.8357 - val_loss: 0.3026 - val_accuracy: 0.9000
# Epoch 64/400
# 9/9 [==============================] - 0s 7ms/step - loss: 0.3689 - accuracy: 0.8357 - val_loss: 0.3016 - val_accuracy: 0.9000
# Epoch 65/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.3670 - accuracy: 0.8357 - val_loss: 0.3005 - val_accuracy: 0.9000
# Epoch 66/400
# 9/9 [==============================] - 0s 7ms/step - loss: 0.3653 - accuracy: 0.8357 - val_loss: 0.2995 - val_accuracy: 0.9000
# Epoch 67/400
# 9/9 [==============================] - 0s 11ms/step - loss: 0.3635 - accuracy: 0.8357 - val_loss: 0.2984 - val_accuracy: 0.9000
# Epoch 68/400
# 9/9 [==============================] - 0s 13ms/step - loss: 0.3617 - accuracy: 0.8357 - val_loss: 0.2974 - val_accuracy: 0.9000
# Epoch 69/400
# 9/9 [==============================] - 0s 9ms/step - loss: 0.3600 - accuracy: 0.8357 - val_loss: 0.2968 - val_accuracy: 0.9000
# Epoch 70/400
# 9/9 [==============================] - 0s 9ms/step - loss: 0.3582 - accuracy: 0.8357 - val_loss: 0.2957 - val_accuracy: 0.9000
# Epoch 71/400
# 9/9 [==============================] - 0s 8ms/step - loss: 0.3566 - accuracy: 0.8357 - val_loss: 0.2948 - val_accuracy: 0.9000
# Epoch 72/400
# 9/9 [==============================] - 0s 15ms/step - loss: 0.3549 - accuracy: 0.8357 - val_loss: 0.2940 - val_accuracy: 0.9000
# Epoch 73/400
# 9/9 [==============================] - 0s 9ms/step - loss: 0.3531 - accuracy: 0.8357 - val_loss: 0.2930 - val_accuracy: 0.9000
# Epoch 74/400
# 9/9 [==============================] - 0s 11ms/step - loss: 0.3513 - accuracy: 0.8357 - val_loss: 0.2921 - val_accuracy: 0.9000
# Epoch 75/400
# 9/9 [==============================] - 0s 13ms/step - loss: 0.3494 - accuracy: 0.8357 - val_loss: 0.2913 - val_accuracy: 0.9000
# Epoch 76/400
# 9/9 [==============================] - 0s 8ms/step - loss: 0.3477 - accuracy: 0.8357 - val_loss: 0.2904 - val_accuracy: 0.9000
# Epoch 77/400
# 9/9 [==============================] - 0s 7ms/step - loss: 0.3459 - accuracy: 0.8357 - val_loss: 0.2896 - val_accuracy: 0.9000
# Epoch 78/400
# 9/9 [==============================] - 0s 7ms/step - loss: 0.3441 - accuracy: 0.8357 - val_loss: 0.2888 - val_accuracy: 0.9000
# Epoch 79/400
# 9/9 [==============================] - 0s 10ms/step - loss: 0.3424 - accuracy: 0.8357 - val_loss: 0.2878 - val_accuracy: 0.9000
# Epoch 80/400
# 9/9 [==============================] - 0s 11ms/step - loss: 0.3408 - accuracy: 0.8357 - val_loss: 0.2871 - val_accuracy: 0.9000
# Epoch 81/400
# 9/9 [==============================] - 0s 21ms/step - loss: 0.3391 - accuracy: 0.8357 - val_loss: 0.2863 - val_accuracy: 0.9000
# Epoch 82/400
# 9/9 [==============================] - 0s 7ms/step - loss: 0.3375 - accuracy: 0.8357 - val_loss: 0.2854 - val_accuracy: 0.9000
# Epoch 83/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.3358 - accuracy: 0.8357 - val_loss: 0.2845 - val_accuracy: 0.9000
# Epoch 84/400
# 9/9 [==============================] - 0s 20ms/step - loss: 0.3343 - accuracy: 0.8357 - val_loss: 0.2839 - val_accuracy: 0.9000
# Epoch 85/400
# 9/9 [==============================] - 0s 12ms/step - loss: 0.3327 - accuracy: 0.8357 - val_loss: 0.2834 - val_accuracy: 0.9000
# Epoch 86/400
# 9/9 [==============================] - 0s 10ms/step - loss: 0.3310 - accuracy: 0.8357 - val_loss: 0.2824 - val_accuracy: 0.9000
# Epoch 87/400
# 9/9 [==============================] - 0s 8ms/step - loss: 0.3295 - accuracy: 0.8357 - val_loss: 0.2816 - val_accuracy: 0.9000
# Epoch 88/400
# 9/9 [==============================] - 0s 11ms/step - loss: 0.3279 - accuracy: 0.8357 - val_loss: 0.2810 - val_accuracy: 0.9000
# Epoch 89/400
# 9/9 [==============================] - 0s 7ms/step - loss: 0.3263 - accuracy: 0.8357 - val_loss: 0.2802 - val_accuracy: 0.9000
# Epoch 90/400
# 9/9 [==============================] - 0s 17ms/step - loss: 0.3247 - accuracy: 0.8357 - val_loss: 0.2794 - val_accuracy: 0.9000
# Epoch 91/400
# 9/9 [==============================] - 0s 9ms/step - loss: 0.3232 - accuracy: 0.8357 - val_loss: 0.2786 - val_accuracy: 0.9000
# Epoch 92/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.3216 - accuracy: 0.8357 - val_loss: 0.2779 - val_accuracy: 0.9000
# Epoch 93/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.3202 - accuracy: 0.8357 - val_loss: 0.2771 - val_accuracy: 0.9000
# Epoch 94/400
# 9/9 [==============================] - 0s 19ms/step - loss: 0.3187 - accuracy: 0.8357 - val_loss: 0.2763 - val_accuracy: 0.9000
# Epoch 95/400
# 9/9 [==============================] - 0s 8ms/step - loss: 0.3174 - accuracy: 0.8357 - val_loss: 0.2757 - val_accuracy: 0.9000
# Epoch 96/400
# 9/9 [==============================] - 0s 11ms/step - loss: 0.3160 - accuracy: 0.8357 - val_loss: 0.2750 - val_accuracy: 0.9000
# Epoch 97/400
# 9/9 [==============================] - 0s 14ms/step - loss: 0.3148 - accuracy: 0.8357 - val_loss: 0.2744 - val_accuracy: 0.9000
# Epoch 98/400
# 9/9 [==============================] - 0s 8ms/step - loss: 0.3135 - accuracy: 0.8357 - val_loss: 0.2739 - val_accuracy: 0.9000
# Epoch 99/400
# 9/9 [==============================] - 0s 7ms/step - loss: 0.3121 - accuracy: 0.8357 - val_loss: 0.2734 - val_accuracy: 0.9000
# Epoch 100/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.3108 - accuracy: 0.8357 - val_loss: 0.2728 - val_accuracy: 0.9000
# Epoch 101/400
# 9/9 [==============================] - 0s 7ms/step - loss: 0.3095 - accuracy: 0.8357 - val_loss: 0.2723 - val_accuracy: 0.9000
# Epoch 102/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.3083 - accuracy: 0.8357 - val_loss: 0.2717 - val_accuracy: 0.9000
# Epoch 103/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.3069 - accuracy: 0.8357 - val_loss: 0.2709 - val_accuracy: 0.9000
# Epoch 104/400
# 9/9 [==============================] - 0s 8ms/step - loss: 0.3060 - accuracy: 0.8357 - val_loss: 0.2701 - val_accuracy: 0.9000
# Epoch 105/400
# 9/9 [==============================] - 0s 9ms/step - loss: 0.3046 - accuracy: 0.8357 - val_loss: 0.2696 - val_accuracy: 0.9000
# Epoch 106/400
# 9/9 [==============================] - 0s 8ms/step - loss: 0.3035 - accuracy: 0.8357 - val_loss: 0.2691 - val_accuracy: 0.9000
# Epoch 107/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.3022 - accuracy: 0.8357 - val_loss: 0.2687 - val_accuracy: 0.9000
# Epoch 108/400
# 9/9 [==============================] - 0s 15ms/step - loss: 0.3009 - accuracy: 0.8357 - val_loss: 0.2683 - val_accuracy: 0.9000
# Epoch 109/400
# 9/9 [==============================] - 0s 9ms/step - loss: 0.2997 - accuracy: 0.8357 - val_loss: 0.2677 - val_accuracy: 0.9000
# Epoch 110/400
# 9/9 [==============================] - 0s 9ms/step - loss: 0.2984 - accuracy: 0.8357 - val_loss: 0.2671 - val_accuracy: 0.9000
# Epoch 111/400
# 9/9 [==============================] - 0s 7ms/step - loss: 0.2971 - accuracy: 0.8357 - val_loss: 0.2663 - val_accuracy: 0.9000
# Epoch 112/400
# 9/9 [==============================] - 0s 7ms/step - loss: 0.2959 - accuracy: 0.8357 - val_loss: 0.2660 - val_accuracy: 0.9000
# Epoch 113/400
# 9/9 [==============================] - 0s 7ms/step - loss: 0.2946 - accuracy: 0.8357 - val_loss: 0.2655 - val_accuracy: 0.9000
# Epoch 114/400
# 9/9 [==============================] - 0s 7ms/step - loss: 0.2938 - accuracy: 0.8357 - val_loss: 0.2650 - val_accuracy: 0.9000
# Epoch 115/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.2926 - accuracy: 0.8357 - val_loss: 0.2644 - val_accuracy: 0.9000
# Epoch 116/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.2916 - accuracy: 0.8357 - val_loss: 0.2640 - val_accuracy: 0.9000
# Epoch 117/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.2906 - accuracy: 0.8357 - val_loss: 0.2638 - val_accuracy: 0.9000
# Epoch 118/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.2895 - accuracy: 0.8357 - val_loss: 0.2630 - val_accuracy: 0.9000
# Epoch 119/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.2886 - accuracy: 0.8357 - val_loss: 0.2623 - val_accuracy: 0.9000
# Epoch 120/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.2875 - accuracy: 0.8357 - val_loss: 0.2619 - val_accuracy: 0.9000
# Epoch 121/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.2863 - accuracy: 0.8357 - val_loss: 0.2616 - val_accuracy: 0.9000
# Epoch 122/400
# 9/9 [==============================] - 0s 8ms/step - loss: 0.2853 - accuracy: 0.8357 - val_loss: 0.2611 - val_accuracy: 0.9000
# Epoch 123/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.2842 - accuracy: 0.8357 - val_loss: 0.2605 - val_accuracy: 0.9000
# Epoch 124/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.2831 - accuracy: 0.8357 - val_loss: 0.2599 - val_accuracy: 0.9000
# Epoch 125/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.2821 - accuracy: 0.8357 - val_loss: 0.2595 - val_accuracy: 0.9000
# Epoch 126/400
# 9/9 [==============================] - 0s 11ms/step - loss: 0.2809 - accuracy: 0.8357 - val_loss: 0.2591 - val_accuracy: 0.9000
# Epoch 127/400
# 9/9 [==============================] - 0s 9ms/step - loss: 0.2801 - accuracy: 0.8357 - val_loss: 0.2584 - val_accuracy: 0.9000
# Epoch 128/400
# 9/9 [==============================] - 0s 8ms/step - loss: 0.2791 - accuracy: 0.8357 - val_loss: 0.2576 - val_accuracy: 0.9000
# Epoch 129/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.2781 - accuracy: 0.8357 - val_loss: 0.2571 - val_accuracy: 0.9000
# Epoch 130/400
# 9/9 [==============================] - 0s 7ms/step - loss: 0.2771 - accuracy: 0.8357 - val_loss: 0.2567 - val_accuracy: 0.9000
# Epoch 131/400
# 9/9 [==============================] - 0s 9ms/step - loss: 0.2761 - accuracy: 0.8357 - val_loss: 0.2559 - val_accuracy: 0.9000
# Epoch 132/400
# 9/9 [==============================] - 0s 10ms/step - loss: 0.2750 - accuracy: 0.8357 - val_loss: 0.2556 - val_accuracy: 0.9000
# Epoch 133/400
# 9/9 [==============================] - 0s 8ms/step - loss: 0.2740 - accuracy: 0.8357 - val_loss: 0.2550 - val_accuracy: 0.9000
# Epoch 134/400
# 9/9 [==============================] - 0s 8ms/step - loss: 0.2731 - accuracy: 0.8357 - val_loss: 0.2544 - val_accuracy: 0.9000
# Epoch 135/400
# 9/9 [==============================] - 0s 7ms/step - loss: 0.2720 - accuracy: 0.8357 - val_loss: 0.2538 - val_accuracy: 0.9000
# Epoch 136/400
# 9/9 [==============================] - 0s 7ms/step - loss: 0.2709 - accuracy: 0.8357 - val_loss: 0.2530 - val_accuracy: 0.9000
# Epoch 137/400
# 9/9 [==============================] - 0s 14ms/step - loss: 0.2700 - accuracy: 0.8357 - val_loss: 0.2524 - val_accuracy: 0.9000
# Epoch 138/400
# 9/9 [==============================] - 0s 12ms/step - loss: 0.2691 - accuracy: 0.8357 - val_loss: 0.2515 - val_accuracy: 0.9000
# Epoch 139/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.2681 - accuracy: 0.8357 - val_loss: 0.2505 - val_accuracy: 0.9000
# Epoch 140/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.2673 - accuracy: 0.8357 - val_loss: 0.2501 - val_accuracy: 0.9000
# Epoch 141/400
# 9/9 [==============================] - 0s 8ms/step - loss: 0.2662 - accuracy: 0.8357 - val_loss: 0.2495 - val_accuracy: 0.9000
# Epoch 142/400
# 9/9 [==============================] - 0s 14ms/step - loss: 0.2656 - accuracy: 0.8357 - val_loss: 0.2492 - val_accuracy: 0.9000
# Epoch 143/400
# 9/9 [==============================] - 0s 10ms/step - loss: 0.2647 - accuracy: 0.8357 - val_loss: 0.2484 - val_accuracy: 0.9000
# Epoch 144/400
# 9/9 [==============================] - 0s 16ms/step - loss: 0.2640 - accuracy: 0.8357 - val_loss: 0.2478 - val_accuracy: 0.9000
# Epoch 145/400
# 9/9 [==============================] - 0s 9ms/step - loss: 0.2633 - accuracy: 0.8357 - val_loss: 0.2476 - val_accuracy: 0.9000
# Epoch 146/400
# 9/9 [==============================] - 0s 9ms/step - loss: 0.2622 - accuracy: 0.8357 - val_loss: 0.2471 - val_accuracy: 0.9000
# Epoch 147/400
# 9/9 [==============================] - 0s 10ms/step - loss: 0.2616 - accuracy: 0.8357 - val_loss: 0.2460 - val_accuracy: 0.9000
# Epoch 148/400
# 9/9 [==============================] - 0s 8ms/step - loss: 0.2607 - accuracy: 0.8357 - val_loss: 0.2450 - val_accuracy: 0.9000
# Epoch 149/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.2600 - accuracy: 0.8357 - val_loss: 0.2442 - val_accuracy: 0.9000
# Epoch 150/400
# 9/9 [==============================] - 0s 7ms/step - loss: 0.2589 - accuracy: 0.8357 - val_loss: 0.2433 - val_accuracy: 0.9000
# Epoch 151/400
# 9/9 [==============================] - 0s 14ms/step - loss: 0.2582 - accuracy: 0.8357 - val_loss: 0.2429 - val_accuracy: 0.9000
# Epoch 152/400
# 9/9 [==============================] - 0s 8ms/step - loss: 0.2572 - accuracy: 0.8393 - val_loss: 0.2418 - val_accuracy: 0.8917
# Epoch 153/400
# 9/9 [==============================] - 0s 8ms/step - loss: 0.2566 - accuracy: 0.8393 - val_loss: 0.2413 - val_accuracy: 0.8833
# Epoch 154/400
# 9/9 [==============================] - 0s 7ms/step - loss: 0.2556 - accuracy: 0.8750 - val_loss: 0.2406 - val_accuracy: 0.8917
# Epoch 155/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.2547 - accuracy: 0.8714 - val_loss: 0.2396 - val_accuracy: 0.8833
# Epoch 156/400
# 9/9 [==============================] - 0s 10ms/step - loss: 0.2539 - accuracy: 0.8750 - val_loss: 0.2389 - val_accuracy: 0.8833
# Epoch 157/400
# 9/9 [==============================] - 0s 7ms/step - loss: 0.2532 - accuracy: 0.8857 - val_loss: 0.2377 - val_accuracy: 0.8833
# Epoch 158/400
# 9/9 [==============================] - 0s 9ms/step - loss: 0.2523 - accuracy: 0.8929 - val_loss: 0.2375 - val_accuracy: 0.8833
# Epoch 159/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.2517 - accuracy: 0.8929 - val_loss: 0.2365 - val_accuracy: 0.8833
# Epoch 160/400
# 9/9 [==============================] - 0s 7ms/step - loss: 0.2508 - accuracy: 0.8929 - val_loss: 0.2363 - val_accuracy: 0.8833
# Epoch 161/400
# 9/9 [==============================] - 0s 7ms/step - loss: 0.2505 - accuracy: 0.8929 - val_loss: 0.2356 - val_accuracy: 0.8833
# Epoch 162/400
# 9/9 [==============================] - 0s 8ms/step - loss: 0.2493 - accuracy: 0.8929 - val_loss: 0.2346 - val_accuracy: 0.8833
# Epoch 163/400
# 9/9 [==============================] - 0s 12ms/step - loss: 0.2485 - accuracy: 0.8929 - val_loss: 0.2338 - val_accuracy: 0.8917
# Epoch 164/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.2480 - accuracy: 0.8929 - val_loss: 0.2327 - val_accuracy: 0.8917
# Epoch 165/400
# 9/9 [==============================] - 0s 8ms/step - loss: 0.2472 - accuracy: 0.8929 - val_loss: 0.2319 - val_accuracy: 0.9000
# Epoch 166/400
# 9/9 [==============================] - 0s 7ms/step - loss: 0.2466 - accuracy: 0.8964 - val_loss: 0.2310 - val_accuracy: 0.9000
# Epoch 167/400
# 9/9 [==============================] - 0s 7ms/step - loss: 0.2458 - accuracy: 0.8964 - val_loss: 0.2303 - val_accuracy: 0.9083
# Epoch 168/400
# 9/9 [==============================] - 0s 7ms/step - loss: 0.2452 - accuracy: 0.8964 - val_loss: 0.2296 - val_accuracy: 0.9083
# Epoch 169/400
# 9/9 [==============================] - 0s 7ms/step - loss: 0.2444 - accuracy: 0.8964 - val_loss: 0.2290 - val_accuracy: 0.9083
# Epoch 170/400
# 9/9 [==============================] - 0s 9ms/step - loss: 0.2436 - accuracy: 0.8964 - val_loss: 0.2285 - val_accuracy: 0.9167
# Epoch 171/400
# 9/9 [==============================] - 0s 7ms/step - loss: 0.2430 - accuracy: 0.8964 - val_loss: 0.2281 - val_accuracy: 0.9167
# Epoch 172/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.2422 - accuracy: 0.8929 - val_loss: 0.2268 - val_accuracy: 0.9167
# Epoch 173/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.2415 - accuracy: 0.8929 - val_loss: 0.2261 - val_accuracy: 0.9167
# Epoch 174/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.2410 - accuracy: 0.8929 - val_loss: 0.2255 - val_accuracy: 0.9167
# Epoch 175/400
# 9/9 [==============================] - 0s 7ms/step - loss: 0.2401 - accuracy: 0.8929 - val_loss: 0.2243 - val_accuracy: 0.9167
# Epoch 176/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.2394 - accuracy: 0.8929 - val_loss: 0.2230 - val_accuracy: 0.9167
# Epoch 177/400
# 9/9 [==============================] - 0s 8ms/step - loss: 0.2390 - accuracy: 0.8929 - val_loss: 0.2228 - val_accuracy: 0.9167
# Epoch 178/400
# 9/9 [==============================] - 0s 7ms/step - loss: 0.2381 - accuracy: 0.8929 - val_loss: 0.2223 - val_accuracy: 0.9167
# Epoch 179/400
# 9/9 [==============================] - 0s 9ms/step - loss: 0.2375 - accuracy: 0.8929 - val_loss: 0.2216 - val_accuracy: 0.9167
# Epoch 180/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.2368 - accuracy: 0.8929 - val_loss: 0.2204 - val_accuracy: 0.9167
# Epoch 181/400
# 9/9 [==============================] - 0s 7ms/step - loss: 0.2365 - accuracy: 0.8929 - val_loss: 0.2190 - val_accuracy: 0.9167
# Epoch 182/400
# 9/9 [==============================] - 0s 7ms/step - loss: 0.2357 - accuracy: 0.8964 - val_loss: 0.2191 - val_accuracy: 0.9083
# Epoch 183/400
# 9/9 [==============================] - 0s 7ms/step - loss: 0.2352 - accuracy: 0.8929 - val_loss: 0.2193 - val_accuracy: 0.9083
# Epoch 184/400
# 9/9 [==============================] - 0s 7ms/step - loss: 0.2346 - accuracy: 0.8929 - val_loss: 0.2191 - val_accuracy: 0.9083
# Epoch 185/400
# 9/9 [==============================] - 0s 9ms/step - loss: 0.2338 - accuracy: 0.8929 - val_loss: 0.2185 - val_accuracy: 0.9083
# Epoch 186/400
# 9/9 [==============================] - 0s 12ms/step - loss: 0.2337 - accuracy: 0.8929 - val_loss: 0.2170 - val_accuracy: 0.9083
# Epoch 187/400
# 9/9 [==============================] - 0s 8ms/step - loss: 0.2327 - accuracy: 0.8929 - val_loss: 0.2165 - val_accuracy: 0.9083
# Epoch 188/400
# 9/9 [==============================] - 0s 8ms/step - loss: 0.2321 - accuracy: 0.8929 - val_loss: 0.2153 - val_accuracy: 0.9083
# Epoch 189/400
# 9/9 [==============================] - 0s 7ms/step - loss: 0.2316 - accuracy: 0.8929 - val_loss: 0.2147 - val_accuracy: 0.9083
# Epoch 190/400
# 9/9 [==============================] - 0s 8ms/step - loss: 0.2309 - accuracy: 0.8929 - val_loss: 0.2142 - val_accuracy: 0.9083
# Epoch 191/400
# 9/9 [==============================] - 0s 10ms/step - loss: 0.2303 - accuracy: 0.8929 - val_loss: 0.2143 - val_accuracy: 0.9167
# Epoch 192/400
# 9/9 [==============================] - 0s 9ms/step - loss: 0.2297 - accuracy: 0.8929 - val_loss: 0.2137 - val_accuracy: 0.9250
# Epoch 193/400
# 9/9 [==============================] - 0s 15ms/step - loss: 0.2294 - accuracy: 0.8929 - val_loss: 0.2126 - val_accuracy: 0.9250
# Epoch 194/400
# 9/9 [==============================] - 0s 8ms/step - loss: 0.2286 - accuracy: 0.8929 - val_loss: 0.2119 - val_accuracy: 0.9250
# Epoch 195/400
# 9/9 [==============================] - 0s 7ms/step - loss: 0.2281 - accuracy: 0.8929 - val_loss: 0.2118 - val_accuracy: 0.9250
# Epoch 196/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.2275 - accuracy: 0.8893 - val_loss: 0.2107 - val_accuracy: 0.9250
# Epoch 197/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.2270 - accuracy: 0.8929 - val_loss: 0.2103 - val_accuracy: 0.9250
# Epoch 198/400
# 9/9 [==============================] - 0s 7ms/step - loss: 0.2268 - accuracy: 0.8893 - val_loss: 0.2098 - val_accuracy: 0.9250
# Epoch 199/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.2262 - accuracy: 0.8929 - val_loss: 0.2092 - val_accuracy: 0.9250
# Epoch 200/400
# 9/9 [==============================] - 0s 9ms/step - loss: 0.2255 - accuracy: 0.8929 - val_loss: 0.2095 - val_accuracy: 0.9250
# Epoch 201/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.2250 - accuracy: 0.8929 - val_loss: 0.2082 - val_accuracy: 0.9250
# Epoch 202/400
# 9/9 [==============================] - 0s 8ms/step - loss: 0.2245 - accuracy: 0.8929 - val_loss: 0.2075 - val_accuracy: 0.9250
# Epoch 203/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.2242 - accuracy: 0.8929 - val_loss: 0.2058 - val_accuracy: 0.9250
# Epoch 204/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.2235 - accuracy: 0.9000 - val_loss: 0.2052 - val_accuracy: 0.9250
# Epoch 205/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.2238 - accuracy: 0.8964 - val_loss: 0.2045 - val_accuracy: 0.9250
# Epoch 206/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.2225 - accuracy: 0.8964 - val_loss: 0.2045 - val_accuracy: 0.9250
# Epoch 207/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.2222 - accuracy: 0.8929 - val_loss: 0.2039 - val_accuracy: 0.9250
# Epoch 208/400
# 9/9 [==============================] - 0s 9ms/step - loss: 0.2219 - accuracy: 0.8929 - val_loss: 0.2036 - val_accuracy: 0.9250
# Epoch 209/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.2213 - accuracy: 0.8964 - val_loss: 0.2041 - val_accuracy: 0.9250
# Epoch 210/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.2211 - accuracy: 0.8964 - val_loss: 0.2037 - val_accuracy: 0.9250
# Epoch 211/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.2203 - accuracy: 0.9000 - val_loss: 0.2023 - val_accuracy: 0.9250
# Epoch 212/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.2198 - accuracy: 0.9000 - val_loss: 0.2009 - val_accuracy: 0.9250
# Epoch 213/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.2194 - accuracy: 0.8929 - val_loss: 0.2005 - val_accuracy: 0.9250
# Epoch 214/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.2190 - accuracy: 0.9036 - val_loss: 0.1999 - val_accuracy: 0.9250
# Epoch 215/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.2185 - accuracy: 0.8964 - val_loss: 0.2003 - val_accuracy: 0.9250
# Epoch 216/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.2182 - accuracy: 0.9000 - val_loss: 0.1998 - val_accuracy: 0.9250
# Epoch 217/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.2175 - accuracy: 0.9036 - val_loss: 0.1989 - val_accuracy: 0.9250
# Epoch 218/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.2172 - accuracy: 0.9036 - val_loss: 0.1990 - val_accuracy: 0.9250
# Epoch 219/400
# 9/9 [==============================] - 0s 7ms/step - loss: 0.2168 - accuracy: 0.9036 - val_loss: 0.1991 - val_accuracy: 0.9250
# Epoch 220/400
# 9/9 [==============================] - 0s 7ms/step - loss: 0.2162 - accuracy: 0.9000 - val_loss: 0.1979 - val_accuracy: 0.9250
# Epoch 221/400
# 9/9 [==============================] - 0s 8ms/step - loss: 0.2158 - accuracy: 0.9036 - val_loss: 0.1981 - val_accuracy: 0.9250
# Epoch 222/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.2155 - accuracy: 0.9036 - val_loss: 0.1981 - val_accuracy: 0.9250
# Epoch 223/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.2151 - accuracy: 0.9036 - val_loss: 0.1980 - val_accuracy: 0.9250
# Epoch 224/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.2147 - accuracy: 0.9036 - val_loss: 0.1973 - val_accuracy: 0.9250
# Epoch 225/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.2145 - accuracy: 0.9000 - val_loss: 0.1961 - val_accuracy: 0.9250
# Epoch 226/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.2138 - accuracy: 0.9036 - val_loss: 0.1964 - val_accuracy: 0.9250
# Epoch 227/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.2136 - accuracy: 0.9036 - val_loss: 0.1955 - val_accuracy: 0.9250
# Epoch 228/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2129 - accuracy: 0.9000 - val_loss: 0.1954 - val_accuracy: 0.9250
# Epoch 229/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.2127 - accuracy: 0.9000 - val_loss: 0.1938 - val_accuracy: 0.9250
# Epoch 230/400
# 9/9 [==============================] - 0s 7ms/step - loss: 0.2127 - accuracy: 0.9036 - val_loss: 0.1934 - val_accuracy: 0.9250
# Epoch 231/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.2117 - accuracy: 0.9000 - val_loss: 0.1934 - val_accuracy: 0.9250
# Epoch 232/400
# 9/9 [==============================] - 0s 8ms/step - loss: 0.2117 - accuracy: 0.9036 - val_loss: 0.1935 - val_accuracy: 0.9250
# Epoch 233/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.2115 - accuracy: 0.9036 - val_loss: 0.1926 - val_accuracy: 0.9250
# Epoch 234/400
# 9/9 [==============================] - 0s 9ms/step - loss: 0.2108 - accuracy: 0.9071 - val_loss: 0.1930 - val_accuracy: 0.9250
# Epoch 235/400
# 9/9 [==============================] - 0s 7ms/step - loss: 0.2105 - accuracy: 0.9036 - val_loss: 0.1916 - val_accuracy: 0.9250
# Epoch 236/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.2101 - accuracy: 0.9036 - val_loss: 0.1905 - val_accuracy: 0.9250
# Epoch 237/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.2098 - accuracy: 0.9071 - val_loss: 0.1910 - val_accuracy: 0.9250
# Epoch 238/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.2095 - accuracy: 0.9071 - val_loss: 0.1901 - val_accuracy: 0.9250
# Epoch 239/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.2089 - accuracy: 0.9071 - val_loss: 0.1898 - val_accuracy: 0.9250
# Epoch 240/400
# 9/9 [==============================] - 0s 11ms/step - loss: 0.2085 - accuracy: 0.9071 - val_loss: 0.1898 - val_accuracy: 0.9250
# Epoch 241/400
# 9/9 [==============================] - 0s 7ms/step - loss: 0.2083 - accuracy: 0.9036 - val_loss: 0.1895 - val_accuracy: 0.9250
# Epoch 242/400
# 9/9 [==============================] - 0s 8ms/step - loss: 0.2080 - accuracy: 0.9071 - val_loss: 0.1886 - val_accuracy: 0.9250
# Epoch 243/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.2077 - accuracy: 0.9107 - val_loss: 0.1886 - val_accuracy: 0.9250
# Epoch 244/400
# 9/9 [==============================] - 0s 7ms/step - loss: 0.2072 - accuracy: 0.9071 - val_loss: 0.1894 - val_accuracy: 0.9167
# Epoch 245/400
# 9/9 [==============================] - 0s 7ms/step - loss: 0.2069 - accuracy: 0.9107 - val_loss: 0.1892 - val_accuracy: 0.9167
# Epoch 246/400
# 9/9 [==============================] - 0s 8ms/step - loss: 0.2064 - accuracy: 0.9143 - val_loss: 0.1883 - val_accuracy: 0.9250
# Epoch 247/400
# 9/9 [==============================] - 0s 10ms/step - loss: 0.2061 - accuracy: 0.9143 - val_loss: 0.1888 - val_accuracy: 0.9167
# Epoch 248/400
# 9/9 [==============================] - 0s 9ms/step - loss: 0.2058 - accuracy: 0.9107 - val_loss: 0.1881 - val_accuracy: 0.9333
# Epoch 249/400
# 9/9 [==============================] - 0s 8ms/step - loss: 0.2053 - accuracy: 0.9143 - val_loss: 0.1868 - val_accuracy: 0.9250
# Epoch 250/400
# 9/9 [==============================] - 0s 9ms/step - loss: 0.2052 - accuracy: 0.9179 - val_loss: 0.1860 - val_accuracy: 0.9250
# Epoch 251/400
# 9/9 [==============================] - 0s 7ms/step - loss: 0.2047 - accuracy: 0.9179 - val_loss: 0.1853 - val_accuracy: 0.9250
# Epoch 252/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.2047 - accuracy: 0.9143 - val_loss: 0.1861 - val_accuracy: 0.9333
# Epoch 253/400
# 9/9 [==============================] - 0s 8ms/step - loss: 0.2043 - accuracy: 0.9179 - val_loss: 0.1863 - val_accuracy: 0.9333
# Epoch 254/400
# 9/9 [==============================] - 0s 7ms/step - loss: 0.2035 - accuracy: 0.9179 - val_loss: 0.1857 - val_accuracy: 0.9333
# Epoch 255/400
# 9/9 [==============================] - 0s 7ms/step - loss: 0.2034 - accuracy: 0.9179 - val_loss: 0.1854 - val_accuracy: 0.9333
# Epoch 256/400
# 9/9 [==============================] - 0s 8ms/step - loss: 0.2032 - accuracy: 0.9179 - val_loss: 0.1848 - val_accuracy: 0.9333
# Epoch 257/400
# 9/9 [==============================] - 0s 7ms/step - loss: 0.2031 - accuracy: 0.9179 - val_loss: 0.1849 - val_accuracy: 0.9417
# Epoch 258/400
# 9/9 [==============================] - 0s 11ms/step - loss: 0.2025 - accuracy: 0.9179 - val_loss: 0.1849 - val_accuracy: 0.9417
# Epoch 259/400
# 9/9 [==============================] - 0s 7ms/step - loss: 0.2021 - accuracy: 0.9179 - val_loss: 0.1849 - val_accuracy: 0.9333
# Epoch 260/400
# 9/9 [==============================] - 0s 9ms/step - loss: 0.2018 - accuracy: 0.9179 - val_loss: 0.1848 - val_accuracy: 0.9333
# Epoch 261/400
# 9/9 [==============================] - 0s 10ms/step - loss: 0.2016 - accuracy: 0.9179 - val_loss: 0.1838 - val_accuracy: 0.9417
# Epoch 262/400
# 9/9 [==============================] - 0s 8ms/step - loss: 0.2013 - accuracy: 0.9179 - val_loss: 0.1838 - val_accuracy: 0.9417
# Epoch 263/400
# 9/9 [==============================] - 0s 9ms/step - loss: 0.2011 - accuracy: 0.9179 - val_loss: 0.1825 - val_accuracy: 0.9417
# Epoch 264/400
# 9/9 [==============================] - 0s 9ms/step - loss: 0.2006 - accuracy: 0.9179 - val_loss: 0.1824 - val_accuracy: 0.9417
# Epoch 265/400
# 9/9 [==============================] - 0s 9ms/step - loss: 0.2003 - accuracy: 0.9179 - val_loss: 0.1821 - val_accuracy: 0.9417
# Epoch 266/400
# 9/9 [==============================] - 0s 9ms/step - loss: 0.2000 - accuracy: 0.9179 - val_loss: 0.1826 - val_accuracy: 0.9417
# Epoch 267/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.1998 - accuracy: 0.9179 - val_loss: 0.1815 - val_accuracy: 0.9417
# Epoch 268/400
# 9/9 [==============================] - 0s 9ms/step - loss: 0.1992 - accuracy: 0.9179 - val_loss: 0.1807 - val_accuracy: 0.9417
# Epoch 269/400
# 9/9 [==============================] - 0s 7ms/step - loss: 0.1990 - accuracy: 0.9179 - val_loss: 0.1807 - val_accuracy: 0.9417
# Epoch 270/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.1987 - accuracy: 0.9179 - val_loss: 0.1816 - val_accuracy: 0.9333
# Epoch 271/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.1983 - accuracy: 0.9179 - val_loss: 0.1809 - val_accuracy: 0.9417
# Epoch 272/400
# 9/9 [==============================] - 0s 7ms/step - loss: 0.1979 - accuracy: 0.9179 - val_loss: 0.1804 - val_accuracy: 0.9417
# Epoch 273/400
# 9/9 [==============================] - 0s 8ms/step - loss: 0.1977 - accuracy: 0.9179 - val_loss: 0.1805 - val_accuracy: 0.9417
# Epoch 274/400
# 9/9 [==============================] - 0s 7ms/step - loss: 0.1974 - accuracy: 0.9179 - val_loss: 0.1804 - val_accuracy: 0.9417
# Epoch 275/400
# 9/9 [==============================] - 0s 7ms/step - loss: 0.1973 - accuracy: 0.9179 - val_loss: 0.1800 - val_accuracy: 0.9333
# Epoch 276/400
# 9/9 [==============================] - 0s 7ms/step - loss: 0.1969 - accuracy: 0.9179 - val_loss: 0.1801 - val_accuracy: 0.9333
# Epoch 277/400
# 9/9 [==============================] - 0s 8ms/step - loss: 0.1968 - accuracy: 0.9179 - val_loss: 0.1805 - val_accuracy: 0.9333
# Epoch 278/400
# 9/9 [==============================] - 0s 7ms/step - loss: 0.1963 - accuracy: 0.9179 - val_loss: 0.1795 - val_accuracy: 0.9417
# Epoch 279/400
# 9/9 [==============================] - 0s 7ms/step - loss: 0.1959 - accuracy: 0.9214 - val_loss: 0.1800 - val_accuracy: 0.9333
# Epoch 280/400
# 9/9 [==============================] - 0s 7ms/step - loss: 0.1956 - accuracy: 0.9179 - val_loss: 0.1787 - val_accuracy: 0.9417
# Epoch 281/400
# 9/9 [==============================] - 0s 7ms/step - loss: 0.1957 - accuracy: 0.9179 - val_loss: 0.1784 - val_accuracy: 0.9417
# Epoch 282/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.1949 - accuracy: 0.9214 - val_loss: 0.1786 - val_accuracy: 0.9417
# Epoch 283/400
# 9/9 [==============================] - 0s 8ms/step - loss: 0.1950 - accuracy: 0.9214 - val_loss: 0.1792 - val_accuracy: 0.9417
# Epoch 284/400
# 9/9 [==============================] - 0s 11ms/step - loss: 0.1945 - accuracy: 0.9179 - val_loss: 0.1791 - val_accuracy: 0.9417
# Epoch 285/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.1944 - accuracy: 0.9214 - val_loss: 0.1793 - val_accuracy: 0.9333
# Epoch 286/400
# 9/9 [==============================] - 0s 7ms/step - loss: 0.1942 - accuracy: 0.9214 - val_loss: 0.1788 - val_accuracy: 0.9417
# Epoch 287/400
# 9/9 [==============================] - 0s 7ms/step - loss: 0.1935 - accuracy: 0.9214 - val_loss: 0.1774 - val_accuracy: 0.9417
# Epoch 288/400
# 9/9 [==============================] - 0s 8ms/step - loss: 0.1935 - accuracy: 0.9214 - val_loss: 0.1768 - val_accuracy: 0.9417
# Epoch 289/400
# 9/9 [==============================] - 0s 9ms/step - loss: 0.1934 - accuracy: 0.9214 - val_loss: 0.1765 - val_accuracy: 0.9417
# Epoch 290/400
# 9/9 [==============================] - 0s 12ms/step - loss: 0.1927 - accuracy: 0.9214 - val_loss: 0.1758 - val_accuracy: 0.9417
# Epoch 291/400
# 9/9 [==============================] - 0s 7ms/step - loss: 0.1927 - accuracy: 0.9214 - val_loss: 0.1762 - val_accuracy: 0.9417
# Epoch 292/400
# 9/9 [==============================] - 0s 9ms/step - loss: 0.1922 - accuracy: 0.9214 - val_loss: 0.1765 - val_accuracy: 0.9417
# Epoch 293/400
# 9/9 [==============================] - 0s 8ms/step - loss: 0.1920 - accuracy: 0.9214 - val_loss: 0.1771 - val_accuracy: 0.9417
# Epoch 294/400
# 9/9 [==============================] - 0s 8ms/step - loss: 0.1915 - accuracy: 0.9214 - val_loss: 0.1774 - val_accuracy: 0.9417
# Epoch 295/400
# 9/9 [==============================] - 0s 9ms/step - loss: 0.1914 - accuracy: 0.9214 - val_loss: 0.1759 - val_accuracy: 0.9417
# Epoch 296/400
# 9/9 [==============================] - 0s 22ms/step - loss: 0.1915 - accuracy: 0.9214 - val_loss: 0.1761 - val_accuracy: 0.9417
# Epoch 297/400
# 9/9 [==============================] - 0s 7ms/step - loss: 0.1910 - accuracy: 0.9214 - val_loss: 0.1758 - val_accuracy: 0.9417
# Epoch 298/400
# 9/9 [==============================] - 0s 13ms/step - loss: 0.1908 - accuracy: 0.9214 - val_loss: 0.1761 - val_accuracy: 0.9417
# Epoch 299/400
# 9/9 [==============================] - 0s 11ms/step - loss: 0.1905 - accuracy: 0.9214 - val_loss: 0.1755 - val_accuracy: 0.9417
# Epoch 300/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.1901 - accuracy: 0.9214 - val_loss: 0.1757 - val_accuracy: 0.9417
# Epoch 301/400
# 9/9 [==============================] - 0s 8ms/step - loss: 0.1901 - accuracy: 0.9214 - val_loss: 0.1760 - val_accuracy: 0.9417
# Epoch 302/400
# 9/9 [==============================] - 0s 13ms/step - loss: 0.1900 - accuracy: 0.9214 - val_loss: 0.1758 - val_accuracy: 0.9417
# Epoch 303/400
# 9/9 [==============================] - 0s 8ms/step - loss: 0.1896 - accuracy: 0.9214 - val_loss: 0.1762 - val_accuracy: 0.9417
# Epoch 304/400
# 9/9 [==============================] - 0s 9ms/step - loss: 0.1893 - accuracy: 0.9214 - val_loss: 0.1767 - val_accuracy: 0.9417
# Epoch 305/400
# 9/9 [==============================] - 0s 8ms/step - loss: 0.1891 - accuracy: 0.9214 - val_loss: 0.1756 - val_accuracy: 0.9417
# Epoch 306/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.1887 - accuracy: 0.9214 - val_loss: 0.1752 - val_accuracy: 0.9417
# Epoch 307/400
# 9/9 [==============================] - 0s 7ms/step - loss: 0.1888 - accuracy: 0.9214 - val_loss: 0.1754 - val_accuracy: 0.9417
# Epoch 308/400
# 9/9 [==============================] - 0s 8ms/step - loss: 0.1882 - accuracy: 0.9214 - val_loss: 0.1756 - val_accuracy: 0.9417
# Epoch 309/400
# 9/9 [==============================] - 0s 7ms/step - loss: 0.1880 - accuracy: 0.9214 - val_loss: 0.1755 - val_accuracy: 0.9417
# Epoch 310/400
# 9/9 [==============================] - 0s 8ms/step - loss: 0.1878 - accuracy: 0.9214 - val_loss: 0.1752 - val_accuracy: 0.9417
# Epoch 311/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.1875 - accuracy: 0.9214 - val_loss: 0.1753 - val_accuracy: 0.9417
# Epoch 312/400
# 9/9 [==============================] - 0s 7ms/step - loss: 0.1872 - accuracy: 0.9250 - val_loss: 0.1747 - val_accuracy: 0.9417
# Epoch 313/400
# 9/9 [==============================] - 0s 10ms/step - loss: 0.1873 - accuracy: 0.9214 - val_loss: 0.1744 - val_accuracy: 0.9417
# Epoch 314/400
# 9/9 [==============================] - 0s 10ms/step - loss: 0.1866 - accuracy: 0.9214 - val_loss: 0.1738 - val_accuracy: 0.9417
# Epoch 315/400
# 9/9 [==============================] - 0s 7ms/step - loss: 0.1866 - accuracy: 0.9214 - val_loss: 0.1746 - val_accuracy: 0.9417
# Epoch 316/400
# 9/9 [==============================] - 0s 8ms/step - loss: 0.1858 - accuracy: 0.9250 - val_loss: 0.1735 - val_accuracy: 0.9417
# Epoch 317/400
# 9/9 [==============================] - 0s 7ms/step - loss: 0.1860 - accuracy: 0.9250 - val_loss: 0.1737 - val_accuracy: 0.9417
# Epoch 318/400
# 9/9 [==============================] - 0s 9ms/step - loss: 0.1860 - accuracy: 0.9214 - val_loss: 0.1728 - val_accuracy: 0.9417
# Epoch 319/400
# 9/9 [==============================] - 0s 13ms/step - loss: 0.1857 - accuracy: 0.9214 - val_loss: 0.1732 - val_accuracy: 0.9417
# Epoch 320/400
# 9/9 [==============================] - 0s 9ms/step - loss: 0.1850 - accuracy: 0.9250 - val_loss: 0.1728 - val_accuracy: 0.9417
# Epoch 321/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.1851 - accuracy: 0.9214 - val_loss: 0.1722 - val_accuracy: 0.9417
# Epoch 322/400
# 9/9 [==============================] - 0s 9ms/step - loss: 0.1847 - accuracy: 0.9250 - val_loss: 0.1721 - val_accuracy: 0.9417
# Epoch 323/400
# 9/9 [==============================] - 0s 7ms/step - loss: 0.1847 - accuracy: 0.9250 - val_loss: 0.1722 - val_accuracy: 0.9417
# Epoch 324/400
# 9/9 [==============================] - 0s 9ms/step - loss: 0.1841 - accuracy: 0.9250 - val_loss: 0.1726 - val_accuracy: 0.9417
# Epoch 325/400
# 9/9 [==============================] - 0s 8ms/step - loss: 0.1842 - accuracy: 0.9250 - val_loss: 0.1732 - val_accuracy: 0.9417
# Epoch 326/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.1841 - accuracy: 0.9179 - val_loss: 0.1724 - val_accuracy: 0.9417
# Epoch 327/400
# 9/9 [==============================] - 0s 7ms/step - loss: 0.1837 - accuracy: 0.9214 - val_loss: 0.1728 - val_accuracy: 0.9417
# Epoch 328/400
# 9/9 [==============================] - 0s 8ms/step - loss: 0.1838 - accuracy: 0.9250 - val_loss: 0.1719 - val_accuracy: 0.9417
# Epoch 329/400
# 9/9 [==============================] - 0s 7ms/step - loss: 0.1833 - accuracy: 0.9250 - val_loss: 0.1724 - val_accuracy: 0.9417
# Epoch 330/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.1835 - accuracy: 0.9214 - val_loss: 0.1721 - val_accuracy: 0.9417
# Epoch 331/400
# 9/9 [==============================] - 0s 9ms/step - loss: 0.1825 - accuracy: 0.9214 - val_loss: 0.1724 - val_accuracy: 0.9417
# Epoch 332/400
# 9/9 [==============================] - 0s 7ms/step - loss: 0.1828 - accuracy: 0.9214 - val_loss: 0.1725 - val_accuracy: 0.9417
# Epoch 333/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.1821 - accuracy: 0.9214 - val_loss: 0.1718 - val_accuracy: 0.9417
# Epoch 334/400
# 9/9 [==============================] - 0s 7ms/step - loss: 0.1827 - accuracy: 0.9214 - val_loss: 0.1720 - val_accuracy: 0.9417
# Epoch 335/400
# 9/9 [==============================] - 0s 7ms/step - loss: 0.1820 - accuracy: 0.9214 - val_loss: 0.1714 - val_accuracy: 0.9417
# Epoch 336/400
# 9/9 [==============================] - 0s 7ms/step - loss: 0.1821 - accuracy: 0.9214 - val_loss: 0.1714 - val_accuracy: 0.9417
# Epoch 337/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.1813 - accuracy: 0.9214 - val_loss: 0.1714 - val_accuracy: 0.9417
# Epoch 338/400
# 9/9 [==============================] - 0s 8ms/step - loss: 0.1814 - accuracy: 0.9214 - val_loss: 0.1713 - val_accuracy: 0.9417
# Epoch 339/400
# 9/9 [==============================] - 0s 7ms/step - loss: 0.1812 - accuracy: 0.9214 - val_loss: 0.1706 - val_accuracy: 0.9417
# Epoch 340/400
# 9/9 [==============================] - 0s 9ms/step - loss: 0.1807 - accuracy: 0.9214 - val_loss: 0.1698 - val_accuracy: 0.9417
# Epoch 341/400
# 9/9 [==============================] - 1s 64ms/step - loss: 0.1811 - accuracy: 0.9214 - val_loss: 0.1693 - val_accuracy: 0.9417
# Epoch 342/400
# 9/9 [==============================] - 0s 16ms/step - loss: 0.1803 - accuracy: 0.9214 - val_loss: 0.1699 - val_accuracy: 0.9417
# Epoch 343/400
# 9/9 [==============================] - 0s 10ms/step - loss: 0.1802 - accuracy: 0.9179 - val_loss: 0.1684 - val_accuracy: 0.9417
# Epoch 344/400
# 9/9 [==============================] - 0s 14ms/step - loss: 0.1802 - accuracy: 0.9214 - val_loss: 0.1689 - val_accuracy: 0.9417
# Epoch 345/400
# 9/9 [==============================] - 0s 7ms/step - loss: 0.1803 - accuracy: 0.9214 - val_loss: 0.1689 - val_accuracy: 0.9417
# Epoch 346/400
# 9/9 [==============================] - 0s 8ms/step - loss: 0.1801 - accuracy: 0.9214 - val_loss: 0.1689 - val_accuracy: 0.9417
# Epoch 347/400
# 9/9 [==============================] - 0s 7ms/step - loss: 0.1794 - accuracy: 0.9214 - val_loss: 0.1701 - val_accuracy: 0.9417
# Epoch 348/400
# 9/9 [==============================] - 0s 8ms/step - loss: 0.1795 - accuracy: 0.9179 - val_loss: 0.1698 - val_accuracy: 0.9417
# Epoch 349/400
# 9/9 [==============================] - 0s 7ms/step - loss: 0.1790 - accuracy: 0.9214 - val_loss: 0.1702 - val_accuracy: 0.9417
# Epoch 350/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.1786 - accuracy: 0.9214 - val_loss: 0.1700 - val_accuracy: 0.9417
# Epoch 351/400
# 9/9 [==============================] - 0s 7ms/step - loss: 0.1789 - accuracy: 0.9214 - val_loss: 0.1690 - val_accuracy: 0.9417
# Epoch 352/400
# 9/9 [==============================] - 0s 7ms/step - loss: 0.1789 - accuracy: 0.9214 - val_loss: 0.1689 - val_accuracy: 0.9417
# Epoch 353/400
# 9/9 [==============================] - 0s 7ms/step - loss: 0.1786 - accuracy: 0.9214 - val_loss: 0.1700 - val_accuracy: 0.9417
# Epoch 354/400
# 9/9 [==============================] - 0s 9ms/step - loss: 0.1779 - accuracy: 0.9214 - val_loss: 0.1690 - val_accuracy: 0.9417
# Epoch 355/400
# 9/9 [==============================] - 0s 9ms/step - loss: 0.1779 - accuracy: 0.9214 - val_loss: 0.1690 - val_accuracy: 0.9417
# Epoch 356/400
# 9/9 [==============================] - 0s 9ms/step - loss: 0.1779 - accuracy: 0.9179 - val_loss: 0.1687 - val_accuracy: 0.9417
# Epoch 357/400
# 9/9 [==============================] - 0s 9ms/step - loss: 0.1774 - accuracy: 0.9214 - val_loss: 0.1697 - val_accuracy: 0.9417
# Epoch 358/400
# 9/9 [==============================] - 0s 12ms/step - loss: 0.1775 - accuracy: 0.9214 - val_loss: 0.1690 - val_accuracy: 0.9417
# Epoch 359/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.1770 - accuracy: 0.9214 - val_loss: 0.1681 - val_accuracy: 0.9417
# Epoch 360/400
# 9/9 [==============================] - 0s 9ms/step - loss: 0.1769 - accuracy: 0.9214 - val_loss: 0.1672 - val_accuracy: 0.9417
# Epoch 361/400
# 9/9 [==============================] - 0s 9ms/step - loss: 0.1770 - accuracy: 0.9214 - val_loss: 0.1672 - val_accuracy: 0.9417
# Epoch 362/400
# 9/9 [==============================] - 0s 10ms/step - loss: 0.1766 - accuracy: 0.9179 - val_loss: 0.1662 - val_accuracy: 0.9417
# Epoch 363/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.1766 - accuracy: 0.9250 - val_loss: 0.1677 - val_accuracy: 0.9417
# Epoch 364/400
# 9/9 [==============================] - 0s 8ms/step - loss: 0.1764 - accuracy: 0.9250 - val_loss: 0.1680 - val_accuracy: 0.9417
# Epoch 365/400
# 9/9 [==============================] - 0s 8ms/step - loss: 0.1764 - accuracy: 0.9250 - val_loss: 0.1687 - val_accuracy: 0.9417
# Epoch 366/400
# 9/9 [==============================] - 0s 9ms/step - loss: 0.1760 - accuracy: 0.9214 - val_loss: 0.1681 - val_accuracy: 0.9417
# Epoch 367/400
# 9/9 [==============================] - 0s 11ms/step - loss: 0.1761 - accuracy: 0.9214 - val_loss: 0.1686 - val_accuracy: 0.9417
# Epoch 368/400
# 9/9 [==============================] - 0s 10ms/step - loss: 0.1757 - accuracy: 0.9214 - val_loss: 0.1684 - val_accuracy: 0.9417
# Epoch 369/400
# 9/9 [==============================] - 0s 7ms/step - loss: 0.1755 - accuracy: 0.9214 - val_loss: 0.1688 - val_accuracy: 0.9417
# Epoch 370/400
# 9/9 [==============================] - 0s 9ms/step - loss: 0.1750 - accuracy: 0.9214 - val_loss: 0.1684 - val_accuracy: 0.9417
# Epoch 371/400
# 9/9 [==============================] - 0s 8ms/step - loss: 0.1749 - accuracy: 0.9214 - val_loss: 0.1686 - val_accuracy: 0.9417
# Epoch 372/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.1752 - accuracy: 0.9214 - val_loss: 0.1672 - val_accuracy: 0.9417
# Epoch 373/400
# 9/9 [==============================] - 0s 12ms/step - loss: 0.1748 - accuracy: 0.9179 - val_loss: 0.1672 - val_accuracy: 0.9417
# Epoch 374/400
# 9/9 [==============================] - 0s 12ms/step - loss: 0.1743 - accuracy: 0.9179 - val_loss: 0.1671 - val_accuracy: 0.9417
# Epoch 375/400
# 9/9 [==============================] - 0s 8ms/step - loss: 0.1746 - accuracy: 0.9214 - val_loss: 0.1666 - val_accuracy: 0.9417
# Epoch 376/400
# 9/9 [==============================] - 0s 7ms/step - loss: 0.1746 - accuracy: 0.9250 - val_loss: 0.1663 - val_accuracy: 0.9417
# Epoch 377/400
# 9/9 [==============================] - 0s 9ms/step - loss: 0.1738 - accuracy: 0.9214 - val_loss: 0.1659 - val_accuracy: 0.9417
# Epoch 378/400
# 9/9 [==============================] - 0s 8ms/step - loss: 0.1742 - accuracy: 0.9214 - val_loss: 0.1661 - val_accuracy: 0.9417
# Epoch 379/400
# 9/9 [==============================] - 0s 8ms/step - loss: 0.1736 - accuracy: 0.9214 - val_loss: 0.1650 - val_accuracy: 0.9417
# Epoch 380/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.1734 - accuracy: 0.9179 - val_loss: 0.1656 - val_accuracy: 0.9417
# Epoch 381/400
# 9/9 [==============================] - 0s 12ms/step - loss: 0.1733 - accuracy: 0.9214 - val_loss: 0.1665 - val_accuracy: 0.9417
# Epoch 382/400
# 9/9 [==============================] - 0s 12ms/step - loss: 0.1733 - accuracy: 0.9250 - val_loss: 0.1662 - val_accuracy: 0.9417
# Epoch 383/400
# 9/9 [==============================] - 0s 9ms/step - loss: 0.1730 - accuracy: 0.9179 - val_loss: 0.1674 - val_accuracy: 0.9417
# Epoch 384/400
# 9/9 [==============================] - 0s 7ms/step - loss: 0.1726 - accuracy: 0.9214 - val_loss: 0.1675 - val_accuracy: 0.9417
# Epoch 385/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.1731 - accuracy: 0.9214 - val_loss: 0.1674 - val_accuracy: 0.9417
# Epoch 386/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.1729 - accuracy: 0.9214 - val_loss: 0.1675 - val_accuracy: 0.9417
# Epoch 387/400
# 9/9 [==============================] - 0s 8ms/step - loss: 0.1720 - accuracy: 0.9214 - val_loss: 0.1667 - val_accuracy: 0.9417
# Epoch 388/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.1721 - accuracy: 0.9214 - val_loss: 0.1656 - val_accuracy: 0.9417
# Epoch 389/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.1719 - accuracy: 0.9214 - val_loss: 0.1657 - val_accuracy: 0.9417
# Epoch 390/400
# 9/9 [==============================] - 0s 7ms/step - loss: 0.1720 - accuracy: 0.9214 - val_loss: 0.1655 - val_accuracy: 0.9417
# Epoch 391/400
# 9/9 [==============================] - 0s 9ms/step - loss: 0.1715 - accuracy: 0.9214 - val_loss: 0.1646 - val_accuracy: 0.9417
# Epoch 392/400
# 9/9 [==============================] - 0s 7ms/step - loss: 0.1716 - accuracy: 0.9214 - val_loss: 0.1647 - val_accuracy: 0.9417
# Epoch 393/400
# 9/9 [==============================] - 0s 7ms/step - loss: 0.1715 - accuracy: 0.9250 - val_loss: 0.1655 - val_accuracy: 0.9417
# Epoch 394/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.1716 - accuracy: 0.9250 - val_loss: 0.1656 - val_accuracy: 0.9417
# Epoch 395/400
# 9/9 [==============================] - 0s 9ms/step - loss: 0.1708 - accuracy: 0.9214 - val_loss: 0.1657 - val_accuracy: 0.9417
# Epoch 396/400
# 9/9 [==============================] - 0s 7ms/step - loss: 0.1710 - accuracy: 0.9250 - val_loss: 0.1650 - val_accuracy: 0.9417
# Epoch 397/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.1705 - accuracy: 0.9214 - val_loss: 0.1649 - val_accuracy: 0.9417
# Epoch 398/400
# 9/9 [==============================] - 0s 9ms/step - loss: 0.1703 - accuracy: 0.9214 - val_loss: 0.1650 - val_accuracy: 0.9417
# Epoch 399/400
# 9/9 [==============================] - 0s 7ms/step - loss: 0.1709 - accuracy: 0.9214 - val_loss: 0.1660 - val_accuracy: 0.9417
# Epoch 400/400
# 9/9 [==============================] - 0s 8ms/step - loss: 0.1703 - accuracy: 0.9214 - val_loss: 0.1659 - val_accuracy: 0.9417

# %%
predictions = model.predict(scaled_X_test)

# %%
preds = []
for x in predictions:
    if x >= 0.5:
        preds.append(1)
    else:
        preds.append(0)

# %%
from sklearn.metrics import classification_report,confusion_matrix

# %%
print(classification_report(y1_test,preds))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.98      0.95      0.97       108
#          1.0       0.67      0.83      0.74        12
#
#     accuracy                           0.94       120
#    macro avg       0.82      0.89      0.85       120
# weighted avg       0.95      0.94      0.94       120
