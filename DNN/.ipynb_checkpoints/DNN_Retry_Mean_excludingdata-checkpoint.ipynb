# %% [markdown]
# ## DNN Retry Mean
# Took out the data from 2020-2021, 2021-2022.

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
# %matplotlib inline
from statistics import mean
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.callbacks import EarlyStopping

# %%
import seaborn as sns
import numpy as np
import pandas as pd
from statistics import mean
import math

FUTURE_PREDICTION = 4

def findmax(x):
    maximum = 0
    for number in x:
        maximum = max(x)
    return maximum

def findmean(x):
    m = 0
    m = mean(x)
    return m

def findmin(x):
    m = 0
    m = min(x)
    return m

def CreateMean(dataframe,title,city):

    dataframe = dataframe.iloc[522:3924:1]
    dataframe.rename(columns = {f'{city}' : f'{title}_Mean'}, inplace = True)
    dataframe = dataframe.reset_index(drop=True)
    for x in dataframe.index:
        if x % 7 == 6:
            list = []
            mean = 0
            for y in range(x-6,x+1,1):
                list.append(dataframe.iloc[y][f'{title}_Mean'])
            mean = findmean(list)
            dataframe.at[x,f'{title}_Mean'] = mean
    for x in dataframe.index:
        if x % 7 != 6:
            dataframe.drop(index= x, inplace=True)
    dataframe = dataframe.reset_index(drop=True)
    return dataframe

def CreateMax(dataframe,title,city):

    dataframe = dataframe.iloc[522:3924:1]
    dataframe.rename(columns = {f'{city}' : f'{title}_Max'}, inplace = True)
    dataframe = dataframe.reset_index(drop=True)
    for x in dataframe.index:
        if x % 7 == 6:
            list = []
            maximum = 0
            for y in range(x-6,x+1,1):
                list.append(dataframe.iloc[y][f'{title}_Max'])
            maximum = findmax(list)
            dataframe.at[x,f'{title}_Max'] = maximum
    for x in dataframe.index:
        if x % 7 != 6:
            dataframe.drop(index= x, inplace=True)
    dataframe = dataframe.reset_index(drop=True)
    return dataframe

def CreateMin(dataframe,title,city):

    dataframe = dataframe.iloc[522:3924:1]
    dataframe.rename(columns = {f'{city}' : f'{title}_Min'}, inplace = True)
    dataframe = dataframe.reset_index(drop=True)
    for x in dataframe.index:
        if x % 7 == 6:
            list = []
            minimum = 0
            for y in range(x-6,x+1,1):
                list.append(dataframe.iloc[y][f'{title}_Min'])
            minimum = findmin(list)
            dataframe.at[x,f'{title}_Min'] = minimum
    for x in dataframe.index:
        if x % 7 != 6:
            dataframe.drop(index= x, inplace=True)
    dataframe = dataframe.reset_index(drop=True)
    return dataframe
    
def DataPreprocess(city):
    virus_df = pd.read_csv('Data/virus.csv')
    virus_df['Date'] = pd.to_datetime(virus_df['Date'])
    virus_df['year'] = virus_df['Date'].apply(lambda date: date.year)
    virus_df['month'] = virus_df['Date'].apply(lambda date: date.month)
    virus_df_new = virus_df[['Date','month','year',f'{city}']]
    virus_df_new.rename(columns = {f'{city}' : f'Virus_Count_{city}'}, inplace = True)

    temp_df = pd.read_csv(f'Data/{city}_temp.csv')
    pressure_df = pd.read_csv(f'Data/{city}_pressure.csv')
    hours_df = pd.read_csv(f'Data/{city}_hours.csv')
    rainfall_df = pd.read_csv(f'Data/{city}_rainfall.csv')

    temp_df['Date'] = pd.to_datetime(temp_df['Date'])
    temp_df['year'] = temp_df['Date'].apply(lambda date: date.year)
    temp_df['month'] = temp_df['Date'].apply(lambda date: date.month)

    pressure_df['Date'] = pd.to_datetime(pressure_df['Date'])
    pressure_df['year'] = pressure_df['Date'].apply(lambda date: date.year)
    pressure_df['month'] = pressure_df['Date'].apply(lambda date: date.month)
    pressure_df = pressure_df.sort_values(by="Date")
    pressure_df = pressure_df.reset_index(drop=True)

    hours_df['Date'] = pd.to_datetime(hours_df['Date'])
    hours_df['year'] = hours_df['Date'].apply(lambda date: date.year)
    hours_df['month'] = hours_df['Date'].apply(lambda date: date.month)
    hours_df = hours_df.sort_values(by="Date")
    hours_df = hours_df.reset_index(drop=True)

    rainfall_df['Date'] = pd.to_datetime(rainfall_df['Date'])
    rainfall_df['year'] = rainfall_df['Date'].apply(lambda date: date.year)
    rainfall_df['month'] = rainfall_df['Date'].apply(lambda date: date.month)
    rainfall_df = rainfall_df.sort_values(by="Date")
    rainfall_df = rainfall_df.reset_index(drop=True)

    list = []
    for x in temp_df.index:
        t = temp_df.iloc[x][f'{city}']
        svp = 6.1078*10**(7.5*t/(t+237.3))
        e = pressure_df.iloc[x][f'{city}']
        h = e/svp*100
        list.append(h)
        
    humidity_df = pd.DataFrame(data=list)
    humidity_df.rename(columns = {0:f'{city}'}, inplace = True)

    mean_temp_df = CreateMean(temp_df, 'Temperature',f'{city}')
    mean_pressure_df = CreateMean(pressure_df, 'Pressure',f'{city}')
    mean_hours_df = CreateMean(hours_df, 'Hours',f'{city}')
    mean_rainfall_df = CreateMean(rainfall_df, 'Rainfall',f'{city}')
    mean_humidity_df = CreateMean(humidity_df, 'Humidity',f'{city}')


    df = pd.concat([virus_df_new,mean_temp_df,mean_pressure_df,mean_hours_df,mean_rainfall_df,mean_humidity_df], axis=1)
    
    df = df.loc[:,~df.columns.duplicated()]
    
    df['VirusCRM'] = df['Virus_Count_Tokyo'].rolling(14, center = True).mean()

    for i in df.index:
        if i == 0:
            df.at[i,'Gradient'] = 1
        else:
            if df.iloc[i-1]['VirusCRM'] == 0:
                if df.at[i,'VirusCDM'] > 0:
                    df.at[i,'Gradient'] = 1
                else:
                    df.at[i,'Gradient'] = 0
            else:
                grd = df.iloc[i]['VirusCRM']/(df.iloc[i-1]['VirusCRM'])
                df.at[i,'Gradient'] = grd
    
    for i in df.index:
        if (df.iloc[i]['Gradient'] >= 1.1) and (df.iloc[i+1]['Gradient'] >= 1.1) and (df.iloc[i+2]['Gradient'] >= 1.1):
            df.at[i,'Spreading'] = 1
        else:
            df.at[i,'Spreading'] = 0
    df = df.astype({'Spreading':'int8'})

    df_virus_count = df[f'Virus_Count_{city}']
    df.drop(columns=['VirusCRM',f'Virus_Count_{city}','year','Gradient'], axis=1, inplace=True)
    df_labels = df[['Date']]
    FUTURE_PREDICTION = 4
    for i in range(FUTURE_PREDICTION):
        df_labels[f"T+{(i+1)*7}"] = df_labels["Date"] + pd.DateOffset(days = (i+1)*7)
    temp = df[["Date", "Spreading"]]
    for i in range(FUTURE_PREDICTION):
        target_column = f"T+{(i+1)*7}"
        df_labels = df_labels.merge(temp, 
                                how ="left",
                                left_on = (target_column),
                                right_on=("Date"),
                                suffixes = ("","_y")
        )
        df_labels.rename(columns={"Spreading":f"{target_column}_Spreading"},inplace=True)
    df_labels.drop(columns=["Date_y"],inplace=True)

    for i in range(FUTURE_PREDICTION):
        df_labels.drop(columns =[f"T+{(i+1)*7}"],inplace=True,axis=1 )

    df = df.merge(df_labels,
             how='left',
             on = ["Date"])
    df.dropna(inplace=True)

    X = df.drop(columns=['T+7_Spreading','T+14_Spreading','T+21_Spreading','T+28_Spreading'],axis=1)
    y1 = df['T+21_Spreading']
    y2 = df['T+7_Spreading']
    y3 = df['T+14_Spreading']
    y4 = df['T+28_Spreading']

    return X, y1, y2, y3, y4, df, df_virus_count

# %%
X, y1, y2, y3, y4, df, df_virus_count = DataPreprocess('Tokyo')
# Out:
# /Users/miyanishio/opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py:5039: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(
# /var/folders/k5/3yc13bs57f7637937yjlstth0000gn/T/ipykernel_10320/3508209727.py:166: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_labels[f"T+{(i+1)*7}"] = df_labels["Date"] + pd.DateOffset(days = (i+1)*7)

# %%
X = X.drop(columns=['Date'])

# %%
X = X[0:400] #until 2020 05-04
y1 = y1[0:400]
y2 = y2[0:400]
y3 = y2[0:400]
y4 = y2[0:400]

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

scaler = StandardScaler()
scaler1 = StandardScaler()
X_train, X_test = X[0:280], X[280:400]
y1_train, y1_test = y1[0:280], y1[280:400]

# %%
scaled_X_train = scaler1.fit_transform(X_train)
scaled_X_test = scaler1.transform(X_test)

# %%
model = Sequential()

model.add(Dense(12,activation="sigmoid"))
model.add(Dense(6,activation="sigmoid"))
model.add(Dense(3,activation="sigmoid"))

model.add(Dense(1, activation='sigmoid'))
model.compile(optimizer='rmsprop',loss='binary_crossentropy',metrics=['accuracy'])
# Out:
# 2022-12-14 12:24:24.871614: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
early_stop = EarlyStopping(monitor='val_loss',mode='min',verbose=1,patience=50)

# %%
model.fit(scaled_X_train,y1_train,epochs=400,validation_data=(scaled_X_test,y1_test),callbacks=[early_stop])
# Out:
# Epoch 1/400
# 9/9 [==============================] - 1s 21ms/step - loss: 0.7352 - accuracy: 0.1643 - val_loss: 0.7202 - val_accuracy: 0.1000
# Epoch 2/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.7085 - accuracy: 0.2500 - val_loss: 0.6943 - val_accuracy: 0.4667
# Epoch 3/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.6881 - accuracy: 0.6321 - val_loss: 0.6723 - val_accuracy: 0.9000
# Epoch 4/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.6698 - accuracy: 0.8357 - val_loss: 0.6513 - val_accuracy: 0.9000
# Epoch 5/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.6526 - accuracy: 0.8357 - val_loss: 0.6315 - val_accuracy: 0.9000
# Epoch 6/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.6363 - accuracy: 0.8357 - val_loss: 0.6124 - val_accuracy: 0.9000
# Epoch 7/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.6208 - accuracy: 0.8357 - val_loss: 0.5943 - val_accuracy: 0.9000
# Epoch 8/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.6061 - accuracy: 0.8357 - val_loss: 0.5772 - val_accuracy: 0.9000
# Epoch 9/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.5923 - accuracy: 0.8357 - val_loss: 0.5606 - val_accuracy: 0.9000
# Epoch 10/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.5792 - accuracy: 0.8357 - val_loss: 0.5449 - val_accuracy: 0.9000
# Epoch 11/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.5669 - accuracy: 0.8357 - val_loss: 0.5299 - val_accuracy: 0.9000
# Epoch 12/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.5553 - accuracy: 0.8357 - val_loss: 0.5158 - val_accuracy: 0.9000
# Epoch 13/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.5446 - accuracy: 0.8357 - val_loss: 0.5027 - val_accuracy: 0.9000
# Epoch 14/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.5347 - accuracy: 0.8357 - val_loss: 0.4905 - val_accuracy: 0.9000
# Epoch 15/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.5254 - accuracy: 0.8357 - val_loss: 0.4785 - val_accuracy: 0.9000
# Epoch 16/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.5167 - accuracy: 0.8357 - val_loss: 0.4675 - val_accuracy: 0.9000
# Epoch 17/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.5087 - accuracy: 0.8357 - val_loss: 0.4573 - val_accuracy: 0.9000
# Epoch 18/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.5018 - accuracy: 0.8357 - val_loss: 0.4486 - val_accuracy: 0.9000
# Epoch 19/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.4953 - accuracy: 0.8357 - val_loss: 0.4400 - val_accuracy: 0.9000
# Epoch 20/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.4893 - accuracy: 0.8357 - val_loss: 0.4316 - val_accuracy: 0.9000
# Epoch 21/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.4837 - accuracy: 0.8357 - val_loss: 0.4241 - val_accuracy: 0.9000
# Epoch 22/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.4788 - accuracy: 0.8357 - val_loss: 0.4173 - val_accuracy: 0.9000
# Epoch 23/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.4742 - accuracy: 0.8357 - val_loss: 0.4108 - val_accuracy: 0.9000
# Epoch 24/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.4699 - accuracy: 0.8357 - val_loss: 0.4046 - val_accuracy: 0.9000
# Epoch 25/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.4660 - accuracy: 0.8357 - val_loss: 0.3990 - val_accuracy: 0.9000
# Epoch 26/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.4625 - accuracy: 0.8357 - val_loss: 0.3942 - val_accuracy: 0.9000
# Epoch 27/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.4593 - accuracy: 0.8357 - val_loss: 0.3892 - val_accuracy: 0.9000
# Epoch 28/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.4564 - accuracy: 0.8357 - val_loss: 0.3851 - val_accuracy: 0.9000
# Epoch 29/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.4538 - accuracy: 0.8357 - val_loss: 0.3816 - val_accuracy: 0.9000
# Epoch 30/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.4514 - accuracy: 0.8357 - val_loss: 0.3776 - val_accuracy: 0.9000
# Epoch 31/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.4492 - accuracy: 0.8357 - val_loss: 0.3743 - val_accuracy: 0.9000
# Epoch 32/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.4469 - accuracy: 0.8357 - val_loss: 0.3713 - val_accuracy: 0.9000
# Epoch 33/400
# 9/9 [==============================] - 0s 19ms/step - loss: 0.4449 - accuracy: 0.8357 - val_loss: 0.3682 - val_accuracy: 0.9000
# Epoch 34/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.4429 - accuracy: 0.8357 - val_loss: 0.3654 - val_accuracy: 0.9000
# Epoch 35/400
# 9/9 [==============================] - 0s 9ms/step - loss: 0.4410 - accuracy: 0.8357 - val_loss: 0.3631 - val_accuracy: 0.9000
# Epoch 36/400
# 9/9 [==============================] - 0s 9ms/step - loss: 0.4392 - accuracy: 0.8357 - val_loss: 0.3605 - val_accuracy: 0.9000
# Epoch 37/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.4374 - accuracy: 0.8357 - val_loss: 0.3584 - val_accuracy: 0.9000
# Epoch 38/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.4357 - accuracy: 0.8357 - val_loss: 0.3560 - val_accuracy: 0.9000
# Epoch 39/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.4339 - accuracy: 0.8357 - val_loss: 0.3539 - val_accuracy: 0.9000
# Epoch 40/400
# 9/9 [==============================] - 0s 7ms/step - loss: 0.4323 - accuracy: 0.8357 - val_loss: 0.3520 - val_accuracy: 0.9000
# Epoch 41/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.4306 - accuracy: 0.8357 - val_loss: 0.3505 - val_accuracy: 0.9000
# Epoch 42/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.4290 - accuracy: 0.8357 - val_loss: 0.3487 - val_accuracy: 0.9000
# Epoch 43/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.4274 - accuracy: 0.8357 - val_loss: 0.3472 - val_accuracy: 0.9000
# Epoch 44/400
# 9/9 [==============================] - 0s 8ms/step - loss: 0.4257 - accuracy: 0.8357 - val_loss: 0.3460 - val_accuracy: 0.9000
# Epoch 45/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.4240 - accuracy: 0.8357 - val_loss: 0.3448 - val_accuracy: 0.9000
# Epoch 46/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.4225 - accuracy: 0.8357 - val_loss: 0.3434 - val_accuracy: 0.9000
# Epoch 47/400
# 9/9 [==============================] - 0s 9ms/step - loss: 0.4208 - accuracy: 0.8357 - val_loss: 0.3418 - val_accuracy: 0.9000
# Epoch 48/400
# 9/9 [==============================] - 0s 7ms/step - loss: 0.4192 - accuracy: 0.8357 - val_loss: 0.3406 - val_accuracy: 0.9000
# Epoch 49/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.4176 - accuracy: 0.8357 - val_loss: 0.3395 - val_accuracy: 0.9000
# Epoch 50/400
# 9/9 [==============================] - 0s 8ms/step - loss: 0.4157 - accuracy: 0.8357 - val_loss: 0.3383 - val_accuracy: 0.9000
# Epoch 51/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.4141 - accuracy: 0.8357 - val_loss: 0.3373 - val_accuracy: 0.9000
# Epoch 52/400
# 9/9 [==============================] - 0s 8ms/step - loss: 0.4123 - accuracy: 0.8357 - val_loss: 0.3363 - val_accuracy: 0.9000
# Epoch 53/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.4105 - accuracy: 0.8357 - val_loss: 0.3351 - val_accuracy: 0.9000
# Epoch 54/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.4086 - accuracy: 0.8357 - val_loss: 0.3341 - val_accuracy: 0.9000
# Epoch 55/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.4067 - accuracy: 0.8357 - val_loss: 0.3328 - val_accuracy: 0.9000
# Epoch 56/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.4050 - accuracy: 0.8357 - val_loss: 0.3317 - val_accuracy: 0.9000
# Epoch 57/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.4032 - accuracy: 0.8357 - val_loss: 0.3309 - val_accuracy: 0.9000
# Epoch 58/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.4014 - accuracy: 0.8357 - val_loss: 0.3298 - val_accuracy: 0.9000
# Epoch 59/400
# 9/9 [==============================] - 0s 8ms/step - loss: 0.3996 - accuracy: 0.8357 - val_loss: 0.3286 - val_accuracy: 0.9000
# Epoch 60/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.3978 - accuracy: 0.8357 - val_loss: 0.3277 - val_accuracy: 0.9000
# Epoch 61/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.3958 - accuracy: 0.8357 - val_loss: 0.3269 - val_accuracy: 0.9000
# Epoch 62/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.3938 - accuracy: 0.8357 - val_loss: 0.3256 - val_accuracy: 0.9000
# Epoch 63/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.3919 - accuracy: 0.8357 - val_loss: 0.3244 - val_accuracy: 0.9000
# Epoch 64/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.3897 - accuracy: 0.8357 - val_loss: 0.3233 - val_accuracy: 0.9000
# Epoch 65/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.3877 - accuracy: 0.8357 - val_loss: 0.3222 - val_accuracy: 0.9000
# Epoch 66/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.3856 - accuracy: 0.8357 - val_loss: 0.3211 - val_accuracy: 0.9000
# Epoch 67/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.3835 - accuracy: 0.8357 - val_loss: 0.3199 - val_accuracy: 0.9000
# Epoch 68/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.3814 - accuracy: 0.8357 - val_loss: 0.3187 - val_accuracy: 0.9000
# Epoch 69/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.3793 - accuracy: 0.8357 - val_loss: 0.3178 - val_accuracy: 0.9000
# Epoch 70/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.3774 - accuracy: 0.8357 - val_loss: 0.3169 - val_accuracy: 0.9000
# Epoch 71/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.3753 - accuracy: 0.8357 - val_loss: 0.3161 - val_accuracy: 0.9000
# Epoch 72/400
# 9/9 [==============================] - 0s 11ms/step - loss: 0.3732 - accuracy: 0.8357 - val_loss: 0.3149 - val_accuracy: 0.9000
# Epoch 73/400
# 9/9 [==============================] - 0s 12ms/step - loss: 0.3712 - accuracy: 0.8357 - val_loss: 0.3140 - val_accuracy: 0.9000
# Epoch 74/400
# 9/9 [==============================] - 0s 8ms/step - loss: 0.3692 - accuracy: 0.8357 - val_loss: 0.3131 - val_accuracy: 0.9000
# Epoch 75/400
# 9/9 [==============================] - 0s 7ms/step - loss: 0.3671 - accuracy: 0.8357 - val_loss: 0.3120 - val_accuracy: 0.9000
# Epoch 76/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.3650 - accuracy: 0.8357 - val_loss: 0.3110 - val_accuracy: 0.9000
# Epoch 77/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.3628 - accuracy: 0.8357 - val_loss: 0.3099 - val_accuracy: 0.9000
# Epoch 78/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.3608 - accuracy: 0.8357 - val_loss: 0.3094 - val_accuracy: 0.9000
# Epoch 79/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.3587 - accuracy: 0.8357 - val_loss: 0.3085 - val_accuracy: 0.9000
# Epoch 80/400
# 9/9 [==============================] - 0s 8ms/step - loss: 0.3568 - accuracy: 0.8357 - val_loss: 0.3078 - val_accuracy: 0.9000
# Epoch 81/400
# 9/9 [==============================] - 0s 24ms/step - loss: 0.3547 - accuracy: 0.8357 - val_loss: 0.3067 - val_accuracy: 0.9000
# Epoch 82/400
# 9/9 [==============================] - 0s 7ms/step - loss: 0.3529 - accuracy: 0.8357 - val_loss: 0.3057 - val_accuracy: 0.9000
# Epoch 83/400
# 9/9 [==============================] - 0s 7ms/step - loss: 0.3510 - accuracy: 0.8357 - val_loss: 0.3052 - val_accuracy: 0.9000
# Epoch 84/400
# 9/9 [==============================] - 0s 8ms/step - loss: 0.3492 - accuracy: 0.8357 - val_loss: 0.3046 - val_accuracy: 0.9000
# Epoch 85/400
# 9/9 [==============================] - 0s 12ms/step - loss: 0.3473 - accuracy: 0.8357 - val_loss: 0.3040 - val_accuracy: 0.9000
# Epoch 86/400
# 9/9 [==============================] - 0s 10ms/step - loss: 0.3454 - accuracy: 0.8357 - val_loss: 0.3033 - val_accuracy: 0.9000
# Epoch 87/400
# 9/9 [==============================] - 0s 10ms/step - loss: 0.3436 - accuracy: 0.8357 - val_loss: 0.3023 - val_accuracy: 0.9000
# Epoch 88/400
# 9/9 [==============================] - 0s 7ms/step - loss: 0.3418 - accuracy: 0.8357 - val_loss: 0.3013 - val_accuracy: 0.9000
# Epoch 89/400
# 9/9 [==============================] - 0s 10ms/step - loss: 0.3400 - accuracy: 0.8357 - val_loss: 0.3005 - val_accuracy: 0.9000
# Epoch 90/400
# 9/9 [==============================] - 0s 7ms/step - loss: 0.3382 - accuracy: 0.8357 - val_loss: 0.2999 - val_accuracy: 0.9000
# Epoch 91/400
# 9/9 [==============================] - 0s 10ms/step - loss: 0.3364 - accuracy: 0.8357 - val_loss: 0.2992 - val_accuracy: 0.9000
# Epoch 92/400
# 9/9 [==============================] - 0s 7ms/step - loss: 0.3345 - accuracy: 0.8357 - val_loss: 0.2982 - val_accuracy: 0.9000
# Epoch 93/400
# 9/9 [==============================] - 0s 7ms/step - loss: 0.3327 - accuracy: 0.8357 - val_loss: 0.2974 - val_accuracy: 0.9000
# Epoch 94/400
# 9/9 [==============================] - 0s 7ms/step - loss: 0.3309 - accuracy: 0.8357 - val_loss: 0.2969 - val_accuracy: 0.9000
# Epoch 95/400
# 9/9 [==============================] - 0s 9ms/step - loss: 0.3291 - accuracy: 0.8357 - val_loss: 0.2962 - val_accuracy: 0.9000
# Epoch 96/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.3272 - accuracy: 0.8357 - val_loss: 0.2956 - val_accuracy: 0.9000
# Epoch 97/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.3255 - accuracy: 0.8357 - val_loss: 0.2947 - val_accuracy: 0.9000
# Epoch 98/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.3237 - accuracy: 0.8357 - val_loss: 0.2939 - val_accuracy: 0.9000
# Epoch 99/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.3220 - accuracy: 0.8357 - val_loss: 0.2934 - val_accuracy: 0.9000
# Epoch 100/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.3203 - accuracy: 0.8357 - val_loss: 0.2926 - val_accuracy: 0.9000
# Epoch 101/400
# 9/9 [==============================] - 0s 7ms/step - loss: 0.3187 - accuracy: 0.8357 - val_loss: 0.2919 - val_accuracy: 0.9000
# Epoch 102/400
# 9/9 [==============================] - 0s 8ms/step - loss: 0.3169 - accuracy: 0.8357 - val_loss: 0.2913 - val_accuracy: 0.9000
# Epoch 103/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.3152 - accuracy: 0.8357 - val_loss: 0.2906 - val_accuracy: 0.9000
# Epoch 104/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.3135 - accuracy: 0.8357 - val_loss: 0.2897 - val_accuracy: 0.9000
# Epoch 105/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.3118 - accuracy: 0.8357 - val_loss: 0.2890 - val_accuracy: 0.9000
# Epoch 106/400
# 9/9 [==============================] - 0s 7ms/step - loss: 0.3103 - accuracy: 0.8357 - val_loss: 0.2884 - val_accuracy: 0.9000
# Epoch 107/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.3087 - accuracy: 0.8357 - val_loss: 0.2880 - val_accuracy: 0.9000
# Epoch 108/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.3072 - accuracy: 0.8357 - val_loss: 0.2874 - val_accuracy: 0.9000
# Epoch 109/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.3059 - accuracy: 0.8357 - val_loss: 0.2870 - val_accuracy: 0.9000
# Epoch 110/400
# 9/9 [==============================] - 0s 7ms/step - loss: 0.3044 - accuracy: 0.8357 - val_loss: 0.2863 - val_accuracy: 0.9000
# Epoch 111/400
# 9/9 [==============================] - 0s 7ms/step - loss: 0.3031 - accuracy: 0.8357 - val_loss: 0.2856 - val_accuracy: 0.9000
# Epoch 112/400
# 9/9 [==============================] - 0s 9ms/step - loss: 0.3018 - accuracy: 0.8357 - val_loss: 0.2852 - val_accuracy: 0.9000
# Epoch 113/400
# 9/9 [==============================] - 0s 9ms/step - loss: 0.3005 - accuracy: 0.8357 - val_loss: 0.2847 - val_accuracy: 0.9000
# Epoch 114/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.2991 - accuracy: 0.8357 - val_loss: 0.2843 - val_accuracy: 0.9000
# Epoch 115/400
# 9/9 [==============================] - 0s 7ms/step - loss: 0.2978 - accuracy: 0.8357 - val_loss: 0.2840 - val_accuracy: 0.9000
# Epoch 116/400
# 9/9 [==============================] - 0s 8ms/step - loss: 0.2965 - accuracy: 0.8357 - val_loss: 0.2833 - val_accuracy: 0.9000
# Epoch 117/400
# 9/9 [==============================] - 0s 9ms/step - loss: 0.2952 - accuracy: 0.8357 - val_loss: 0.2827 - val_accuracy: 0.9000
# Epoch 118/400
# 9/9 [==============================] - 0s 8ms/step - loss: 0.2939 - accuracy: 0.8357 - val_loss: 0.2820 - val_accuracy: 0.9000
# Epoch 119/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.2926 - accuracy: 0.8357 - val_loss: 0.2815 - val_accuracy: 0.9000
# Epoch 120/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.2915 - accuracy: 0.8357 - val_loss: 0.2810 - val_accuracy: 0.9000
# Epoch 121/400
# 9/9 [==============================] - 0s 7ms/step - loss: 0.2903 - accuracy: 0.8357 - val_loss: 0.2801 - val_accuracy: 0.9000
# Epoch 122/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.2892 - accuracy: 0.8357 - val_loss: 0.2796 - val_accuracy: 0.9000
# Epoch 123/400
# 9/9 [==============================] - 0s 13ms/step - loss: 0.2880 - accuracy: 0.8357 - val_loss: 0.2793 - val_accuracy: 0.9000
# Epoch 124/400
# 9/9 [==============================] - 0s 9ms/step - loss: 0.2869 - accuracy: 0.8357 - val_loss: 0.2788 - val_accuracy: 0.9000
# Epoch 125/400
# 9/9 [==============================] - 0s 9ms/step - loss: 0.2857 - accuracy: 0.8357 - val_loss: 0.2783 - val_accuracy: 0.9000
# Epoch 126/400
# 9/9 [==============================] - 0s 7ms/step - loss: 0.2846 - accuracy: 0.8357 - val_loss: 0.2777 - val_accuracy: 0.9000
# Epoch 127/400
# 9/9 [==============================] - 0s 7ms/step - loss: 0.2835 - accuracy: 0.8357 - val_loss: 0.2776 - val_accuracy: 0.9000
# Epoch 128/400
# 9/9 [==============================] - 0s 8ms/step - loss: 0.2824 - accuracy: 0.8357 - val_loss: 0.2769 - val_accuracy: 0.9000
# Epoch 129/400
# 9/9 [==============================] - 0s 13ms/step - loss: 0.2814 - accuracy: 0.8357 - val_loss: 0.2762 - val_accuracy: 0.9000
# Epoch 130/400
# 9/9 [==============================] - 0s 7ms/step - loss: 0.2808 - accuracy: 0.8357 - val_loss: 0.2756 - val_accuracy: 0.9000
# Epoch 131/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.2799 - accuracy: 0.8357 - val_loss: 0.2751 - val_accuracy: 0.9000
# Epoch 132/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.2791 - accuracy: 0.8357 - val_loss: 0.2745 - val_accuracy: 0.9000
# Epoch 133/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.2782 - accuracy: 0.8357 - val_loss: 0.2744 - val_accuracy: 0.9000
# Epoch 134/400
# 9/9 [==============================] - 0s 13ms/step - loss: 0.2774 - accuracy: 0.8357 - val_loss: 0.2740 - val_accuracy: 0.9000
# Epoch 135/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.2765 - accuracy: 0.8357 - val_loss: 0.2735 - val_accuracy: 0.9000
# Epoch 136/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.2756 - accuracy: 0.8357 - val_loss: 0.2731 - val_accuracy: 0.9000
# Epoch 137/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.2749 - accuracy: 0.8357 - val_loss: 0.2723 - val_accuracy: 0.9000
# Epoch 138/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.2739 - accuracy: 0.8357 - val_loss: 0.2720 - val_accuracy: 0.9000
# Epoch 139/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.2731 - accuracy: 0.8357 - val_loss: 0.2717 - val_accuracy: 0.9000
# Epoch 140/400
# 9/9 [==============================] - 0s 12ms/step - loss: 0.2722 - accuracy: 0.8357 - val_loss: 0.2715 - val_accuracy: 0.9000
# Epoch 141/400
# 9/9 [==============================] - 0s 9ms/step - loss: 0.2713 - accuracy: 0.8357 - val_loss: 0.2709 - val_accuracy: 0.9000
# Epoch 142/400
# 9/9 [==============================] - 0s 7ms/step - loss: 0.2706 - accuracy: 0.8357 - val_loss: 0.2706 - val_accuracy: 0.8917
# Epoch 143/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.2697 - accuracy: 0.8393 - val_loss: 0.2699 - val_accuracy: 0.8917
# Epoch 144/400
# 9/9 [==============================] - 0s 8ms/step - loss: 0.2689 - accuracy: 0.8321 - val_loss: 0.2697 - val_accuracy: 0.8667
# Epoch 145/400
# 9/9 [==============================] - 0s 14ms/step - loss: 0.2683 - accuracy: 0.8607 - val_loss: 0.2692 - val_accuracy: 0.8833
# Epoch 146/400
# 9/9 [==============================] - 0s 7ms/step - loss: 0.2674 - accuracy: 0.8786 - val_loss: 0.2688 - val_accuracy: 0.8833
# Epoch 147/400
# 9/9 [==============================] - 0s 8ms/step - loss: 0.2666 - accuracy: 0.8857 - val_loss: 0.2682 - val_accuracy: 0.8750
# Epoch 148/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.2658 - accuracy: 0.8893 - val_loss: 0.2675 - val_accuracy: 0.8917
# Epoch 149/400
# 9/9 [==============================] - 0s 8ms/step - loss: 0.2651 - accuracy: 0.8857 - val_loss: 0.2670 - val_accuracy: 0.8833
# Epoch 150/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.2645 - accuracy: 0.8893 - val_loss: 0.2667 - val_accuracy: 0.8833
# Epoch 151/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.2637 - accuracy: 0.8857 - val_loss: 0.2661 - val_accuracy: 0.8833
# Epoch 152/400
# 9/9 [==============================] - 0s 8ms/step - loss: 0.2631 - accuracy: 0.8857 - val_loss: 0.2658 - val_accuracy: 0.8917
# Epoch 153/400
# 9/9 [==============================] - 0s 9ms/step - loss: 0.2624 - accuracy: 0.8857 - val_loss: 0.2653 - val_accuracy: 0.9000
# Epoch 154/400
# 9/9 [==============================] - 0s 13ms/step - loss: 0.2618 - accuracy: 0.8893 - val_loss: 0.2653 - val_accuracy: 0.9000
# Epoch 155/400
# 9/9 [==============================] - 0s 10ms/step - loss: 0.2610 - accuracy: 0.8893 - val_loss: 0.2649 - val_accuracy: 0.9000
# Epoch 156/400
# 9/9 [==============================] - 0s 7ms/step - loss: 0.2604 - accuracy: 0.8929 - val_loss: 0.2645 - val_accuracy: 0.9000
# Epoch 157/400
# 9/9 [==============================] - 0s 8ms/step - loss: 0.2598 - accuracy: 0.8893 - val_loss: 0.2641 - val_accuracy: 0.9000
# Epoch 158/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.2591 - accuracy: 0.8929 - val_loss: 0.2637 - val_accuracy: 0.9000
# Epoch 159/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.2585 - accuracy: 0.8929 - val_loss: 0.2634 - val_accuracy: 0.9000
# Epoch 160/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.2580 - accuracy: 0.8929 - val_loss: 0.2633 - val_accuracy: 0.9000
# Epoch 161/400
# 9/9 [==============================] - 0s 7ms/step - loss: 0.2572 - accuracy: 0.8929 - val_loss: 0.2630 - val_accuracy: 0.9000
# Epoch 162/400
# 9/9 [==============================] - 0s 7ms/step - loss: 0.2569 - accuracy: 0.8929 - val_loss: 0.2624 - val_accuracy: 0.9000
# Epoch 163/400
# 9/9 [==============================] - 0s 8ms/step - loss: 0.2561 - accuracy: 0.8929 - val_loss: 0.2623 - val_accuracy: 0.9000
# Epoch 164/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.2554 - accuracy: 0.8929 - val_loss: 0.2621 - val_accuracy: 0.9000
# Epoch 165/400
# 9/9 [==============================] - 0s 13ms/step - loss: 0.2549 - accuracy: 0.8929 - val_loss: 0.2614 - val_accuracy: 0.9000
# Epoch 166/400
# 9/9 [==============================] - 0s 10ms/step - loss: 0.2544 - accuracy: 0.8929 - val_loss: 0.2608 - val_accuracy: 0.9000
# Epoch 167/400
# 9/9 [==============================] - 0s 11ms/step - loss: 0.2541 - accuracy: 0.8929 - val_loss: 0.2607 - val_accuracy: 0.9000
# Epoch 168/400
# 9/9 [==============================] - 0s 12ms/step - loss: 0.2533 - accuracy: 0.8929 - val_loss: 0.2602 - val_accuracy: 0.9000
# Epoch 169/400
# 9/9 [==============================] - 0s 13ms/step - loss: 0.2527 - accuracy: 0.8929 - val_loss: 0.2604 - val_accuracy: 0.9000
# Epoch 170/400
# 9/9 [==============================] - 0s 19ms/step - loss: 0.2526 - accuracy: 0.8929 - val_loss: 0.2598 - val_accuracy: 0.9000
# Epoch 171/400
# 9/9 [==============================] - 0s 8ms/step - loss: 0.2520 - accuracy: 0.8929 - val_loss: 0.2596 - val_accuracy: 0.9000
# Epoch 172/400
# 9/9 [==============================] - 0s 7ms/step - loss: 0.2514 - accuracy: 0.8929 - val_loss: 0.2594 - val_accuracy: 0.9000
# Epoch 173/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.2510 - accuracy: 0.8929 - val_loss: 0.2591 - val_accuracy: 0.9000
# Epoch 174/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.2504 - accuracy: 0.8929 - val_loss: 0.2587 - val_accuracy: 0.9000
# Epoch 175/400
# 9/9 [==============================] - 0s 11ms/step - loss: 0.2501 - accuracy: 0.8929 - val_loss: 0.2581 - val_accuracy: 0.9000
# Epoch 176/400
# 9/9 [==============================] - 0s 9ms/step - loss: 0.2494 - accuracy: 0.8929 - val_loss: 0.2579 - val_accuracy: 0.9000
# Epoch 177/400
# 9/9 [==============================] - 0s 8ms/step - loss: 0.2491 - accuracy: 0.8929 - val_loss: 0.2574 - val_accuracy: 0.9000
# Epoch 178/400
# 9/9 [==============================] - 0s 7ms/step - loss: 0.2485 - accuracy: 0.8929 - val_loss: 0.2576 - val_accuracy: 0.9000
# Epoch 179/400
# 9/9 [==============================] - 0s 8ms/step - loss: 0.2481 - accuracy: 0.8893 - val_loss: 0.2568 - val_accuracy: 0.9000
# Epoch 180/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.2475 - accuracy: 0.8929 - val_loss: 0.2570 - val_accuracy: 0.9000
# Epoch 181/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.2474 - accuracy: 0.8929 - val_loss: 0.2567 - val_accuracy: 0.9000
# Epoch 182/400
# 9/9 [==============================] - 0s 7ms/step - loss: 0.2467 - accuracy: 0.8893 - val_loss: 0.2566 - val_accuracy: 0.9000
# Epoch 183/400
# 9/9 [==============================] - 0s 21ms/step - loss: 0.2462 - accuracy: 0.8893 - val_loss: 0.2565 - val_accuracy: 0.9000
# Epoch 184/400
# 9/9 [==============================] - 0s 17ms/step - loss: 0.2460 - accuracy: 0.8893 - val_loss: 0.2561 - val_accuracy: 0.9000
# Epoch 185/400
# 9/9 [==============================] - 0s 8ms/step - loss: 0.2454 - accuracy: 0.8893 - val_loss: 0.2557 - val_accuracy: 0.9000
# Epoch 186/400
# 9/9 [==============================] - 0s 12ms/step - loss: 0.2451 - accuracy: 0.8893 - val_loss: 0.2554 - val_accuracy: 0.9000
# Epoch 187/400
# 9/9 [==============================] - 0s 11ms/step - loss: 0.2449 - accuracy: 0.8893 - val_loss: 0.2547 - val_accuracy: 0.9000
# Epoch 188/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.2441 - accuracy: 0.8893 - val_loss: 0.2539 - val_accuracy: 0.9000
# Epoch 189/400
# 9/9 [==============================] - 0s 8ms/step - loss: 0.2438 - accuracy: 0.8893 - val_loss: 0.2537 - val_accuracy: 0.9000
# Epoch 190/400
# 9/9 [==============================] - 0s 8ms/step - loss: 0.2435 - accuracy: 0.8893 - val_loss: 0.2536 - val_accuracy: 0.9000
# Epoch 191/400
# 9/9 [==============================] - 0s 19ms/step - loss: 0.2432 - accuracy: 0.8893 - val_loss: 0.2529 - val_accuracy: 0.9000
# Epoch 192/400
# 9/9 [==============================] - 0s 7ms/step - loss: 0.2426 - accuracy: 0.8893 - val_loss: 0.2524 - val_accuracy: 0.9000
# Epoch 193/400
# 9/9 [==============================] - 0s 10ms/step - loss: 0.2423 - accuracy: 0.8893 - val_loss: 0.2517 - val_accuracy: 0.9000
# Epoch 194/400
# 9/9 [==============================] - 0s 14ms/step - loss: 0.2421 - accuracy: 0.8893 - val_loss: 0.2517 - val_accuracy: 0.9000
# Epoch 195/400
# 9/9 [==============================] - 0s 7ms/step - loss: 0.2418 - accuracy: 0.8893 - val_loss: 0.2518 - val_accuracy: 0.9000
# Epoch 196/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.2412 - accuracy: 0.8893 - val_loss: 0.2514 - val_accuracy: 0.9000
# Epoch 197/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.2408 - accuracy: 0.8893 - val_loss: 0.2510 - val_accuracy: 0.9000
# Epoch 198/400
# 9/9 [==============================] - 0s 15ms/step - loss: 0.2404 - accuracy: 0.8893 - val_loss: 0.2510 - val_accuracy: 0.9000
# Epoch 199/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.2401 - accuracy: 0.8893 - val_loss: 0.2507 - val_accuracy: 0.8917
# Epoch 200/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.2398 - accuracy: 0.8893 - val_loss: 0.2503 - val_accuracy: 0.8917
# Epoch 201/400
# 9/9 [==============================] - 0s 10ms/step - loss: 0.2394 - accuracy: 0.8857 - val_loss: 0.2502 - val_accuracy: 0.8917
# Epoch 202/400
# 9/9 [==============================] - 0s 7ms/step - loss: 0.2390 - accuracy: 0.8857 - val_loss: 0.2500 - val_accuracy: 0.8917
# Epoch 203/400
# 9/9 [==============================] - 0s 9ms/step - loss: 0.2388 - accuracy: 0.8857 - val_loss: 0.2499 - val_accuracy: 0.8833
# Epoch 204/400
# 9/9 [==============================] - 0s 8ms/step - loss: 0.2381 - accuracy: 0.8857 - val_loss: 0.2494 - val_accuracy: 0.8833
# Epoch 205/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.2378 - accuracy: 0.8857 - val_loss: 0.2488 - val_accuracy: 0.8833
# Epoch 206/400
# 9/9 [==============================] - 0s 8ms/step - loss: 0.2376 - accuracy: 0.8857 - val_loss: 0.2484 - val_accuracy: 0.8833
# Epoch 207/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.2371 - accuracy: 0.8857 - val_loss: 0.2480 - val_accuracy: 0.8833
# Epoch 208/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.2369 - accuracy: 0.8857 - val_loss: 0.2475 - val_accuracy: 0.8833
# Epoch 209/400
# 9/9 [==============================] - 0s 8ms/step - loss: 0.2366 - accuracy: 0.8857 - val_loss: 0.2476 - val_accuracy: 0.8833
# Epoch 210/400
# 9/9 [==============================] - 0s 8ms/step - loss: 0.2362 - accuracy: 0.8857 - val_loss: 0.2469 - val_accuracy: 0.8833
# Epoch 211/400
# 9/9 [==============================] - 0s 9ms/step - loss: 0.2360 - accuracy: 0.8857 - val_loss: 0.2466 - val_accuracy: 0.8833
# Epoch 212/400
# 9/9 [==============================] - 0s 7ms/step - loss: 0.2354 - accuracy: 0.8857 - val_loss: 0.2465 - val_accuracy: 0.8833
# Epoch 213/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.2351 - accuracy: 0.8857 - val_loss: 0.2466 - val_accuracy: 0.8833
# Epoch 214/400
# 9/9 [==============================] - 0s 10ms/step - loss: 0.2349 - accuracy: 0.8857 - val_loss: 0.2458 - val_accuracy: 0.8833
# Epoch 215/400
# 9/9 [==============================] - 0s 7ms/step - loss: 0.2345 - accuracy: 0.8857 - val_loss: 0.2454 - val_accuracy: 0.8833
# Epoch 216/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.2343 - accuracy: 0.8857 - val_loss: 0.2449 - val_accuracy: 0.8833
# Epoch 217/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.2339 - accuracy: 0.8857 - val_loss: 0.2448 - val_accuracy: 0.8833
# Epoch 218/400
# 9/9 [==============================] - 0s 8ms/step - loss: 0.2337 - accuracy: 0.8857 - val_loss: 0.2445 - val_accuracy: 0.8833
# Epoch 219/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.2334 - accuracy: 0.8857 - val_loss: 0.2443 - val_accuracy: 0.8833
# Epoch 220/400
# 9/9 [==============================] - 0s 7ms/step - loss: 0.2332 - accuracy: 0.8857 - val_loss: 0.2440 - val_accuracy: 0.8833
# Epoch 221/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2326 - accuracy: 0.8857 - val_loss: 0.2438 - val_accuracy: 0.8833
# Epoch 222/400
# 9/9 [==============================] - 0s 8ms/step - loss: 0.2327 - accuracy: 0.8857 - val_loss: 0.2432 - val_accuracy: 0.8833
# Epoch 223/400
# 9/9 [==============================] - 0s 7ms/step - loss: 0.2324 - accuracy: 0.8857 - val_loss: 0.2428 - val_accuracy: 0.8833
# Epoch 224/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.2319 - accuracy: 0.8857 - val_loss: 0.2432 - val_accuracy: 0.8833
# Epoch 225/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.2318 - accuracy: 0.8857 - val_loss: 0.2424 - val_accuracy: 0.8833
# Epoch 226/400
# 9/9 [==============================] - 0s 9ms/step - loss: 0.2314 - accuracy: 0.8857 - val_loss: 0.2423 - val_accuracy: 0.8833
# Epoch 227/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.2311 - accuracy: 0.8857 - val_loss: 0.2420 - val_accuracy: 0.8833
# Epoch 228/400
# 9/9 [==============================] - 0s 10ms/step - loss: 0.2309 - accuracy: 0.8857 - val_loss: 0.2413 - val_accuracy: 0.8833
# Epoch 229/400
# 9/9 [==============================] - 0s 7ms/step - loss: 0.2307 - accuracy: 0.8857 - val_loss: 0.2410 - val_accuracy: 0.8833
# Epoch 230/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.2304 - accuracy: 0.8857 - val_loss: 0.2406 - val_accuracy: 0.8833
# Epoch 231/400
# 9/9 [==============================] - 0s 8ms/step - loss: 0.2301 - accuracy: 0.8857 - val_loss: 0.2403 - val_accuracy: 0.8833
# Epoch 232/400
# 9/9 [==============================] - 0s 8ms/step - loss: 0.2298 - accuracy: 0.8857 - val_loss: 0.2399 - val_accuracy: 0.8833
# Epoch 233/400
# 9/9 [==============================] - 0s 7ms/step - loss: 0.2299 - accuracy: 0.8857 - val_loss: 0.2391 - val_accuracy: 0.8833
# Epoch 234/400
# 9/9 [==============================] - 0s 9ms/step - loss: 0.2295 - accuracy: 0.8857 - val_loss: 0.2389 - val_accuracy: 0.8833
# Epoch 235/400
# 9/9 [==============================] - 0s 7ms/step - loss: 0.2291 - accuracy: 0.8857 - val_loss: 0.2385 - val_accuracy: 0.8833
# Epoch 236/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.2292 - accuracy: 0.8857 - val_loss: 0.2386 - val_accuracy: 0.8833
# Epoch 237/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.2286 - accuracy: 0.8857 - val_loss: 0.2383 - val_accuracy: 0.8833
# Epoch 238/400
# 9/9 [==============================] - 0s 8ms/step - loss: 0.2284 - accuracy: 0.8857 - val_loss: 0.2381 - val_accuracy: 0.8833
# Epoch 239/400
# 9/9 [==============================] - 0s 7ms/step - loss: 0.2282 - accuracy: 0.8857 - val_loss: 0.2381 - val_accuracy: 0.8833
# Epoch 240/400
# 9/9 [==============================] - 0s 7ms/step - loss: 0.2281 - accuracy: 0.8857 - val_loss: 0.2376 - val_accuracy: 0.8833
# Epoch 241/400
# 9/9 [==============================] - 0s 7ms/step - loss: 0.2278 - accuracy: 0.8857 - val_loss: 0.2370 - val_accuracy: 0.8833
# Epoch 242/400
# 9/9 [==============================] - 0s 9ms/step - loss: 0.2275 - accuracy: 0.8857 - val_loss: 0.2368 - val_accuracy: 0.8833
# Epoch 243/400
# 9/9 [==============================] - 0s 8ms/step - loss: 0.2271 - accuracy: 0.8857 - val_loss: 0.2361 - val_accuracy: 0.8833
# Epoch 244/400
# 9/9 [==============================] - 0s 10ms/step - loss: 0.2267 - accuracy: 0.8857 - val_loss: 0.2358 - val_accuracy: 0.8833
# Epoch 245/400
# 9/9 [==============================] - 0s 7ms/step - loss: 0.2267 - accuracy: 0.8857 - val_loss: 0.2362 - val_accuracy: 0.8833
# Epoch 246/400
# 9/9 [==============================] - 0s 9ms/step - loss: 0.2264 - accuracy: 0.8893 - val_loss: 0.2356 - val_accuracy: 0.8833
# Epoch 247/400
# 9/9 [==============================] - 0s 7ms/step - loss: 0.2261 - accuracy: 0.8857 - val_loss: 0.2352 - val_accuracy: 0.8833
# Epoch 248/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.2259 - accuracy: 0.8893 - val_loss: 0.2347 - val_accuracy: 0.8833
# Epoch 249/400
# 9/9 [==============================] - 0s 9ms/step - loss: 0.2256 - accuracy: 0.8857 - val_loss: 0.2340 - val_accuracy: 0.8833
# Epoch 250/400
# 9/9 [==============================] - 0s 8ms/step - loss: 0.2257 - accuracy: 0.8893 - val_loss: 0.2338 - val_accuracy: 0.8833
# Epoch 251/400
# 9/9 [==============================] - 0s 8ms/step - loss: 0.2251 - accuracy: 0.8857 - val_loss: 0.2333 - val_accuracy: 0.8833
# Epoch 252/400
# 9/9 [==============================] - 0s 8ms/step - loss: 0.2251 - accuracy: 0.8857 - val_loss: 0.2332 - val_accuracy: 0.8833
# Epoch 253/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.2249 - accuracy: 0.8893 - val_loss: 0.2332 - val_accuracy: 0.8833
# Epoch 254/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.2245 - accuracy: 0.8893 - val_loss: 0.2327 - val_accuracy: 0.8833
# Epoch 255/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.2244 - accuracy: 0.8893 - val_loss: 0.2328 - val_accuracy: 0.8833
# Epoch 256/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.2242 - accuracy: 0.8929 - val_loss: 0.2325 - val_accuracy: 0.8833
# Epoch 257/400
# 9/9 [==============================] - 0s 10ms/step - loss: 0.2238 - accuracy: 0.8929 - val_loss: 0.2323 - val_accuracy: 0.8833
# Epoch 258/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.2238 - accuracy: 0.8893 - val_loss: 0.2320 - val_accuracy: 0.8833
# Epoch 259/400
# 9/9 [==============================] - 0s 8ms/step - loss: 0.2237 - accuracy: 0.8929 - val_loss: 0.2319 - val_accuracy: 0.8833
# Epoch 260/400
# 9/9 [==============================] - 0s 8ms/step - loss: 0.2233 - accuracy: 0.8929 - val_loss: 0.2316 - val_accuracy: 0.8833
# Epoch 261/400
# 9/9 [==============================] - 0s 12ms/step - loss: 0.2230 - accuracy: 0.8929 - val_loss: 0.2311 - val_accuracy: 0.8833
# Epoch 262/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.2230 - accuracy: 0.8893 - val_loss: 0.2309 - val_accuracy: 0.8833
# Epoch 263/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.2227 - accuracy: 0.8929 - val_loss: 0.2305 - val_accuracy: 0.8833
# Epoch 264/400
# 9/9 [==============================] - 0s 8ms/step - loss: 0.2228 - accuracy: 0.8929 - val_loss: 0.2302 - val_accuracy: 0.8833
# Epoch 265/400
# 9/9 [==============================] - 0s 10ms/step - loss: 0.2223 - accuracy: 0.8929 - val_loss: 0.2300 - val_accuracy: 0.8833
# Epoch 266/400
# 9/9 [==============================] - 0s 8ms/step - loss: 0.2223 - accuracy: 0.8929 - val_loss: 0.2298 - val_accuracy: 0.8833
# Epoch 267/400
# 9/9 [==============================] - 0s 9ms/step - loss: 0.2220 - accuracy: 0.8929 - val_loss: 0.2292 - val_accuracy: 0.8833
# Epoch 268/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.2217 - accuracy: 0.8893 - val_loss: 0.2294 - val_accuracy: 0.8833
# Epoch 269/400
# 9/9 [==============================] - 0s 8ms/step - loss: 0.2215 - accuracy: 0.8929 - val_loss: 0.2293 - val_accuracy: 0.8833
# Epoch 270/400
# 9/9 [==============================] - 0s 7ms/step - loss: 0.2214 - accuracy: 0.8929 - val_loss: 0.2288 - val_accuracy: 0.8833
# Epoch 271/400
# 9/9 [==============================] - 0s 8ms/step - loss: 0.2210 - accuracy: 0.8929 - val_loss: 0.2286 - val_accuracy: 0.8833
# Epoch 272/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.2208 - accuracy: 0.8929 - val_loss: 0.2282 - val_accuracy: 0.8833
# Epoch 273/400
# 9/9 [==============================] - 0s 8ms/step - loss: 0.2205 - accuracy: 0.8929 - val_loss: 0.2275 - val_accuracy: 0.8833
# Epoch 274/400
# 9/9 [==============================] - 0s 12ms/step - loss: 0.2203 - accuracy: 0.8929 - val_loss: 0.2276 - val_accuracy: 0.8833
# Epoch 275/400
# 9/9 [==============================] - 0s 8ms/step - loss: 0.2203 - accuracy: 0.8929 - val_loss: 0.2269 - val_accuracy: 0.8833
# Epoch 276/400
# 9/9 [==============================] - 0s 9ms/step - loss: 0.2200 - accuracy: 0.8929 - val_loss: 0.2270 - val_accuracy: 0.8833
# Epoch 277/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.2199 - accuracy: 0.8929 - val_loss: 0.2265 - val_accuracy: 0.8833
# Epoch 278/400
# 9/9 [==============================] - 0s 7ms/step - loss: 0.2195 - accuracy: 0.8929 - val_loss: 0.2259 - val_accuracy: 0.8833
# Epoch 279/400
# 9/9 [==============================] - 0s 8ms/step - loss: 0.2195 - accuracy: 0.8929 - val_loss: 0.2251 - val_accuracy: 0.8833
# Epoch 280/400
# 9/9 [==============================] - 0s 7ms/step - loss: 0.2190 - accuracy: 0.8929 - val_loss: 0.2249 - val_accuracy: 0.8833
# Epoch 281/400
# 9/9 [==============================] - 0s 12ms/step - loss: 0.2191 - accuracy: 0.8929 - val_loss: 0.2249 - val_accuracy: 0.8833
# Epoch 282/400
# 9/9 [==============================] - 0s 7ms/step - loss: 0.2186 - accuracy: 0.8929 - val_loss: 0.2249 - val_accuracy: 0.8833
# Epoch 283/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.2185 - accuracy: 0.8929 - val_loss: 0.2247 - val_accuracy: 0.8833
# Epoch 284/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.2185 - accuracy: 0.8929 - val_loss: 0.2238 - val_accuracy: 0.8833
# Epoch 285/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.2181 - accuracy: 0.8929 - val_loss: 0.2233 - val_accuracy: 0.8833
# Epoch 286/400
# 9/9 [==============================] - 0s 10ms/step - loss: 0.2180 - accuracy: 0.8929 - val_loss: 0.2234 - val_accuracy: 0.8833
# Epoch 287/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.2177 - accuracy: 0.8929 - val_loss: 0.2229 - val_accuracy: 0.8833
# Epoch 288/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.2176 - accuracy: 0.8929 - val_loss: 0.2227 - val_accuracy: 0.8833
# Epoch 289/400
# 9/9 [==============================] - 0s 9ms/step - loss: 0.2174 - accuracy: 0.8929 - val_loss: 0.2221 - val_accuracy: 0.8833
# Epoch 290/400
# 9/9 [==============================] - 0s 7ms/step - loss: 0.2171 - accuracy: 0.8929 - val_loss: 0.2217 - val_accuracy: 0.8833
# Epoch 291/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.2169 - accuracy: 0.8929 - val_loss: 0.2219 - val_accuracy: 0.8833
# Epoch 292/400
# 9/9 [==============================] - 0s 7ms/step - loss: 0.2169 - accuracy: 0.8929 - val_loss: 0.2213 - val_accuracy: 0.8833
# Epoch 293/400
# 9/9 [==============================] - 0s 7ms/step - loss: 0.2165 - accuracy: 0.8929 - val_loss: 0.2210 - val_accuracy: 0.8833
# Epoch 294/400
# 9/9 [==============================] - 0s 7ms/step - loss: 0.2163 - accuracy: 0.8929 - val_loss: 0.2210 - val_accuracy: 0.8833
# Epoch 295/400
# 9/9 [==============================] - 0s 8ms/step - loss: 0.2159 - accuracy: 0.8929 - val_loss: 0.2214 - val_accuracy: 0.8917
# Epoch 296/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.2162 - accuracy: 0.8929 - val_loss: 0.2210 - val_accuracy: 0.8917
# Epoch 297/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.2157 - accuracy: 0.8929 - val_loss: 0.2207 - val_accuracy: 0.8917
# Epoch 298/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.2154 - accuracy: 0.8964 - val_loss: 0.2199 - val_accuracy: 0.8917
# Epoch 299/400
# 9/9 [==============================] - 0s 8ms/step - loss: 0.2154 - accuracy: 0.8929 - val_loss: 0.2193 - val_accuracy: 0.8917
# Epoch 300/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.2151 - accuracy: 0.8964 - val_loss: 0.2188 - val_accuracy: 0.8917
# Epoch 301/400
# 9/9 [==============================] - 0s 9ms/step - loss: 0.2153 - accuracy: 0.8964 - val_loss: 0.2187 - val_accuracy: 0.8917
# Epoch 302/400
# 9/9 [==============================] - 0s 7ms/step - loss: 0.2148 - accuracy: 0.8964 - val_loss: 0.2183 - val_accuracy: 0.8917
# Epoch 303/400
# 9/9 [==============================] - 0s 7ms/step - loss: 0.2145 - accuracy: 0.8964 - val_loss: 0.2183 - val_accuracy: 0.8917
# Epoch 304/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.2145 - accuracy: 0.8964 - val_loss: 0.2177 - val_accuracy: 0.8917
# Epoch 305/400
# 9/9 [==============================] - 0s 8ms/step - loss: 0.2141 - accuracy: 0.8964 - val_loss: 0.2178 - val_accuracy: 0.8917
# Epoch 306/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.2141 - accuracy: 0.8964 - val_loss: 0.2176 - val_accuracy: 0.8917
# Epoch 307/400
# 9/9 [==============================] - 0s 9ms/step - loss: 0.2136 - accuracy: 0.8964 - val_loss: 0.2175 - val_accuracy: 0.8917
# Epoch 308/400
# 9/9 [==============================] - 0s 16ms/step - loss: 0.2136 - accuracy: 0.9000 - val_loss: 0.2168 - val_accuracy: 0.8917
# Epoch 309/400
# 9/9 [==============================] - 0s 7ms/step - loss: 0.2134 - accuracy: 0.9000 - val_loss: 0.2164 - val_accuracy: 0.8917
# Epoch 310/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.2135 - accuracy: 0.8964 - val_loss: 0.2162 - val_accuracy: 0.8917
# Epoch 311/400
# 9/9 [==============================] - 0s 9ms/step - loss: 0.2131 - accuracy: 0.9036 - val_loss: 0.2157 - val_accuracy: 0.8917
# Epoch 312/400
# 9/9 [==============================] - 0s 8ms/step - loss: 0.2129 - accuracy: 0.9000 - val_loss: 0.2152 - val_accuracy: 0.8917
# Epoch 313/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.2126 - accuracy: 0.9000 - val_loss: 0.2152 - val_accuracy: 0.8917
# Epoch 314/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.2123 - accuracy: 0.9000 - val_loss: 0.2153 - val_accuracy: 0.8917
# Epoch 315/400
# 9/9 [==============================] - 0s 8ms/step - loss: 0.2121 - accuracy: 0.9036 - val_loss: 0.2145 - val_accuracy: 0.8917
# Epoch 316/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.2118 - accuracy: 0.9036 - val_loss: 0.2137 - val_accuracy: 0.8917
# Epoch 317/400
# 9/9 [==============================] - 0s 7ms/step - loss: 0.2117 - accuracy: 0.9036 - val_loss: 0.2133 - val_accuracy: 0.8917
# Epoch 318/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.2115 - accuracy: 0.9036 - val_loss: 0.2135 - val_accuracy: 0.8917
# Epoch 319/400
# 9/9 [==============================] - 0s 9ms/step - loss: 0.2114 - accuracy: 0.9036 - val_loss: 0.2133 - val_accuracy: 0.8917
# Epoch 320/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.2111 - accuracy: 0.9036 - val_loss: 0.2128 - val_accuracy: 0.8917
# Epoch 321/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.2111 - accuracy: 0.9036 - val_loss: 0.2122 - val_accuracy: 0.8917
# Epoch 322/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.2107 - accuracy: 0.9036 - val_loss: 0.2116 - val_accuracy: 0.9083
# Epoch 323/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.2105 - accuracy: 0.9036 - val_loss: 0.2116 - val_accuracy: 0.9000
# Epoch 324/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.2102 - accuracy: 0.9036 - val_loss: 0.2112 - val_accuracy: 0.9083
# Epoch 325/400
# 9/9 [==============================] - 0s 7ms/step - loss: 0.2101 - accuracy: 0.9036 - val_loss: 0.2113 - val_accuracy: 0.8917
# Epoch 326/400
# 9/9 [==============================] - 0s 7ms/step - loss: 0.2095 - accuracy: 0.9071 - val_loss: 0.2109 - val_accuracy: 0.9000
# Epoch 327/400
# 9/9 [==============================] - 0s 10ms/step - loss: 0.2097 - accuracy: 0.9036 - val_loss: 0.2106 - val_accuracy: 0.9000
# Epoch 328/400
# 9/9 [==============================] - 0s 8ms/step - loss: 0.2093 - accuracy: 0.9036 - val_loss: 0.2108 - val_accuracy: 0.8917
# Epoch 329/400
# 9/9 [==============================] - 0s 7ms/step - loss: 0.2091 - accuracy: 0.9071 - val_loss: 0.2105 - val_accuracy: 0.8917
# Epoch 330/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.2088 - accuracy: 0.9071 - val_loss: 0.2100 - val_accuracy: 0.9000
# Epoch 331/400
# 9/9 [==============================] - 0s 8ms/step - loss: 0.2085 - accuracy: 0.9071 - val_loss: 0.2094 - val_accuracy: 0.9000
# Epoch 332/400
# 9/9 [==============================] - 0s 9ms/step - loss: 0.2085 - accuracy: 0.9071 - val_loss: 0.2093 - val_accuracy: 0.9000
# Epoch 333/400
# 9/9 [==============================] - 0s 8ms/step - loss: 0.2085 - accuracy: 0.9071 - val_loss: 0.2090 - val_accuracy: 0.9000
# Epoch 334/400
# 9/9 [==============================] - 0s 8ms/step - loss: 0.2080 - accuracy: 0.9071 - val_loss: 0.2087 - val_accuracy: 0.9000
# Epoch 335/400
# 9/9 [==============================] - 0s 7ms/step - loss: 0.2080 - accuracy: 0.9071 - val_loss: 0.2090 - val_accuracy: 0.8917
# Epoch 336/400
# 9/9 [==============================] - 0s 8ms/step - loss: 0.2074 - accuracy: 0.9071 - val_loss: 0.2090 - val_accuracy: 0.8917
# Epoch 337/400
# 9/9 [==============================] - 0s 9ms/step - loss: 0.2074 - accuracy: 0.9071 - val_loss: 0.2082 - val_accuracy: 0.9000
# Epoch 338/400
# 9/9 [==============================] - 0s 11ms/step - loss: 0.2073 - accuracy: 0.9071 - val_loss: 0.2079 - val_accuracy: 0.9000
# Epoch 339/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.2068 - accuracy: 0.9107 - val_loss: 0.2078 - val_accuracy: 0.9000
# Epoch 340/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.2069 - accuracy: 0.9071 - val_loss: 0.2078 - val_accuracy: 0.9000
# Epoch 341/400
# 9/9 [==============================] - 0s 9ms/step - loss: 0.2064 - accuracy: 0.9071 - val_loss: 0.2077 - val_accuracy: 0.8917
# Epoch 342/400
# 9/9 [==============================] - 0s 7ms/step - loss: 0.2067 - accuracy: 0.9071 - val_loss: 0.2080 - val_accuracy: 0.8917
# Epoch 343/400
# 9/9 [==============================] - 0s 7ms/step - loss: 0.2060 - accuracy: 0.9107 - val_loss: 0.2075 - val_accuracy: 0.8917
# Epoch 344/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.2060 - accuracy: 0.9071 - val_loss: 0.2075 - val_accuracy: 0.8917
# Epoch 345/400
# 9/9 [==============================] - 0s 7ms/step - loss: 0.2056 - accuracy: 0.9107 - val_loss: 0.2070 - val_accuracy: 0.8917
# Epoch 346/400
# 9/9 [==============================] - 0s 7ms/step - loss: 0.2057 - accuracy: 0.9107 - val_loss: 0.2065 - val_accuracy: 0.9000
# Epoch 347/400
# 9/9 [==============================] - 0s 7ms/step - loss: 0.2052 - accuracy: 0.9107 - val_loss: 0.2064 - val_accuracy: 0.9000
# Epoch 348/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.2051 - accuracy: 0.9107 - val_loss: 0.2061 - val_accuracy: 0.9000
# Epoch 349/400
# 9/9 [==============================] - 0s 9ms/step - loss: 0.2049 - accuracy: 0.9107 - val_loss: 0.2058 - val_accuracy: 0.9000
# Epoch 350/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.2046 - accuracy: 0.9107 - val_loss: 0.2058 - val_accuracy: 0.9000
# Epoch 351/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.2044 - accuracy: 0.9143 - val_loss: 0.2053 - val_accuracy: 0.9000
# Epoch 352/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.2042 - accuracy: 0.9107 - val_loss: 0.2048 - val_accuracy: 0.9000
# Epoch 353/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.2046 - accuracy: 0.9071 - val_loss: 0.2046 - val_accuracy: 0.9000
# Epoch 354/400
# 9/9 [==============================] - 0s 8ms/step - loss: 0.2040 - accuracy: 0.9036 - val_loss: 0.2046 - val_accuracy: 0.9000
# Epoch 355/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.2037 - accuracy: 0.9071 - val_loss: 0.2044 - val_accuracy: 0.9000
# Epoch 356/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.2033 - accuracy: 0.9143 - val_loss: 0.2040 - val_accuracy: 0.9000
# Epoch 357/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.2033 - accuracy: 0.9107 - val_loss: 0.2040 - val_accuracy: 0.9000
# Epoch 358/400
# 9/9 [==============================] - 0s 9ms/step - loss: 0.2030 - accuracy: 0.9107 - val_loss: 0.2034 - val_accuracy: 0.9000
# Epoch 359/400
# 9/9 [==============================] - 0s 8ms/step - loss: 0.2029 - accuracy: 0.9071 - val_loss: 0.2032 - val_accuracy: 0.9083
# Epoch 360/400
# 9/9 [==============================] - 0s 13ms/step - loss: 0.2025 - accuracy: 0.9071 - val_loss: 0.2027 - val_accuracy: 0.9083
# Epoch 361/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.2023 - accuracy: 0.9107 - val_loss: 0.2024 - val_accuracy: 0.9083
# Epoch 362/400
# 9/9 [==============================] - 0s 8ms/step - loss: 0.2022 - accuracy: 0.9107 - val_loss: 0.2022 - val_accuracy: 0.9083
# Epoch 363/400
# 9/9 [==============================] - 0s 7ms/step - loss: 0.2020 - accuracy: 0.9107 - val_loss: 0.2015 - val_accuracy: 0.9083
# Epoch 364/400
# 9/9 [==============================] - 0s 8ms/step - loss: 0.2016 - accuracy: 0.9107 - val_loss: 0.2016 - val_accuracy: 0.9083
# Epoch 365/400
# 9/9 [==============================] - 0s 9ms/step - loss: 0.2014 - accuracy: 0.9107 - val_loss: 0.2021 - val_accuracy: 0.9083
# Epoch 366/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.2010 - accuracy: 0.9107 - val_loss: 0.2016 - val_accuracy: 0.9083
# Epoch 367/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.2011 - accuracy: 0.9143 - val_loss: 0.2014 - val_accuracy: 0.9083
# Epoch 368/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.2010 - accuracy: 0.9143 - val_loss: 0.2007 - val_accuracy: 0.9083
# Epoch 369/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.2008 - accuracy: 0.9143 - val_loss: 0.2006 - val_accuracy: 0.9083
# Epoch 370/400
# 9/9 [==============================] - 0s 9ms/step - loss: 0.2005 - accuracy: 0.9143 - val_loss: 0.2004 - val_accuracy: 0.9083
# Epoch 371/400
# 9/9 [==============================] - 0s 9ms/step - loss: 0.2003 - accuracy: 0.9143 - val_loss: 0.2002 - val_accuracy: 0.9083
# Epoch 372/400
# 9/9 [==============================] - 0s 8ms/step - loss: 0.2005 - accuracy: 0.9179 - val_loss: 0.1999 - val_accuracy: 0.9083
# Epoch 373/400
# 9/9 [==============================] - 0s 10ms/step - loss: 0.1999 - accuracy: 0.9179 - val_loss: 0.1995 - val_accuracy: 0.9083
# Epoch 374/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.1997 - accuracy: 0.9179 - val_loss: 0.1994 - val_accuracy: 0.9083
# Epoch 375/400
# 9/9 [==============================] - 0s 12ms/step - loss: 0.1994 - accuracy: 0.9214 - val_loss: 0.1992 - val_accuracy: 0.9083
# Epoch 376/400
# 9/9 [==============================] - 0s 13ms/step - loss: 0.1993 - accuracy: 0.9214 - val_loss: 0.1984 - val_accuracy: 0.9083
# Epoch 377/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.1993 - accuracy: 0.9214 - val_loss: 0.1981 - val_accuracy: 0.9083
# Epoch 378/400
# 9/9 [==============================] - 0s 7ms/step - loss: 0.1992 - accuracy: 0.9214 - val_loss: 0.1976 - val_accuracy: 0.9083
# Epoch 379/400
# 9/9 [==============================] - 0s 7ms/step - loss: 0.1987 - accuracy: 0.9179 - val_loss: 0.1972 - val_accuracy: 0.9083
# Epoch 380/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.1986 - accuracy: 0.9179 - val_loss: 0.1973 - val_accuracy: 0.9083
# Epoch 381/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.1987 - accuracy: 0.9214 - val_loss: 0.1967 - val_accuracy: 0.9083
# Epoch 382/400
# 9/9 [==============================] - 0s 8ms/step - loss: 0.1982 - accuracy: 0.9214 - val_loss: 0.1967 - val_accuracy: 0.9083
# Epoch 383/400
# 9/9 [==============================] - 0s 7ms/step - loss: 0.1979 - accuracy: 0.9250 - val_loss: 0.1965 - val_accuracy: 0.9083
# Epoch 384/400
# 9/9 [==============================] - 0s 7ms/step - loss: 0.1982 - accuracy: 0.9214 - val_loss: 0.1970 - val_accuracy: 0.9083
# Epoch 385/400
# 9/9 [==============================] - 0s 10ms/step - loss: 0.1977 - accuracy: 0.9250 - val_loss: 0.1968 - val_accuracy: 0.9083
# Epoch 386/400
# 9/9 [==============================] - 0s 9ms/step - loss: 0.1976 - accuracy: 0.9250 - val_loss: 0.1964 - val_accuracy: 0.9083
# Epoch 387/400
# 9/9 [==============================] - 0s 8ms/step - loss: 0.1978 - accuracy: 0.9214 - val_loss: 0.1964 - val_accuracy: 0.9083
# Epoch 388/400
# 9/9 [==============================] - 0s 9ms/step - loss: 0.1970 - accuracy: 0.9250 - val_loss: 0.1960 - val_accuracy: 0.9083
# Epoch 389/400
# 9/9 [==============================] - 0s 8ms/step - loss: 0.1971 - accuracy: 0.9250 - val_loss: 0.1956 - val_accuracy: 0.9083
# Epoch 390/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.1968 - accuracy: 0.9250 - val_loss: 0.1960 - val_accuracy: 0.9000
# Epoch 391/400
# 9/9 [==============================] - 0s 9ms/step - loss: 0.1968 - accuracy: 0.9250 - val_loss: 0.1958 - val_accuracy: 0.9000
# Epoch 392/400
# 9/9 [==============================] - 0s 8ms/step - loss: 0.1966 - accuracy: 0.9250 - val_loss: 0.1961 - val_accuracy: 0.9000
# Epoch 393/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.1963 - accuracy: 0.9250 - val_loss: 0.1953 - val_accuracy: 0.9000
# Epoch 394/400
# 9/9 [==============================] - 0s 7ms/step - loss: 0.1965 - accuracy: 0.9250 - val_loss: 0.1955 - val_accuracy: 0.8917
# Epoch 395/400
# 9/9 [==============================] - 0s 18ms/step - loss: 0.1960 - accuracy: 0.9286 - val_loss: 0.1956 - val_accuracy: 0.8917
# Epoch 396/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.1959 - accuracy: 0.9250 - val_loss: 0.1958 - val_accuracy: 0.8917
# Epoch 397/400
# 9/9 [==============================] - 0s 7ms/step - loss: 0.1956 - accuracy: 0.9250 - val_loss: 0.1959 - val_accuracy: 0.8917
# Epoch 398/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.1958 - accuracy: 0.9250 - val_loss: 0.1960 - val_accuracy: 0.8917
# Epoch 399/400
# 9/9 [==============================] - 0s 7ms/step - loss: 0.1952 - accuracy: 0.9286 - val_loss: 0.1954 - val_accuracy: 0.8917
# Epoch 400/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.1956 - accuracy: 0.9250 - val_loss: 0.1955 - val_accuracy: 0.8917

# %%
predictions = model.predict(scaled_X_test)

# %%
preds = []
for x in predictions:
    if x >= 0.5:
        preds.append(1)
    else:
        preds.append(0)

# %%
from sklearn.metrics import classification_report,confusion_matrix

# %%
print(classification_report(y1_test,preds))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.96      0.92      0.94       108
#          1.0       0.47      0.67      0.55        12
#
#     accuracy                           0.89       120
#    macro avg       0.72      0.79      0.75       120
# weighted avg       0.91      0.89      0.90       120
