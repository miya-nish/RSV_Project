# %% [markdown]
# ## DNN Retry Min, Max & Mean
# Took out the data from 2020-2021, 2021-2022.

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
# %matplotlib inline
from statistics import mean
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.callbacks import EarlyStopping

# %%
import seaborn as sns
import numpy as np
import pandas as pd
from statistics import mean
import math

FUTURE_PREDICTION = 4

def findmax(x):
    maximum = 0
    for number in x:
        maximum = max(x)
    return maximum

def findmean(x):
    m = 0
    m = mean(x)
    return m

def findmin(x):
    m = 0
    m = min(x)
    return m

def CreateMean(dataframe,title,city):

    dataframe = dataframe.iloc[522:3924:1]
    dataframe.rename(columns = {f'{city}' : f'{title}_Mean'}, inplace = True)
    dataframe = dataframe.reset_index(drop=True)
    for x in dataframe.index:
        if x % 7 == 6:
            list = []
            mean = 0
            for y in range(x-6,x+1,1):
                list.append(dataframe.iloc[y][f'{title}_Mean'])
            mean = findmean(list)
            dataframe.at[x,f'{title}_Mean'] = mean
    for x in dataframe.index:
        if x % 7 != 6:
            dataframe.drop(index= x, inplace=True)
    dataframe = dataframe.reset_index(drop=True)
    return dataframe

def CreateMax(dataframe,title,city):

    dataframe = dataframe.iloc[522:3924:1]
    dataframe.rename(columns = {f'{city}' : f'{title}_Max'}, inplace = True)
    dataframe = dataframe.reset_index(drop=True)
    for x in dataframe.index:
        if x % 7 == 6:
            list = []
            maximum = 0
            for y in range(x-6,x+1,1):
                list.append(dataframe.iloc[y][f'{title}_Max'])
            maximum = findmax(list)
            dataframe.at[x,f'{title}_Max'] = maximum
    for x in dataframe.index:
        if x % 7 != 6:
            dataframe.drop(index= x, inplace=True)
    dataframe = dataframe.reset_index(drop=True)
    return dataframe

def CreateMin(dataframe,title,city):

    dataframe = dataframe.iloc[522:3924:1]
    dataframe.rename(columns = {f'{city}' : f'{title}_Min'}, inplace = True)
    dataframe = dataframe.reset_index(drop=True)
    for x in dataframe.index:
        if x % 7 == 6:
            list = []
            minimum = 0
            for y in range(x-6,x+1,1):
                list.append(dataframe.iloc[y][f'{title}_Min'])
            minimum = findmin(list)
            dataframe.at[x,f'{title}_Min'] = minimum
    for x in dataframe.index:
        if x % 7 != 6:
            dataframe.drop(index= x, inplace=True)
    dataframe = dataframe.reset_index(drop=True)
    return dataframe
    
def DataPreprocess(city):
    virus_df = pd.read_csv('Data/virus.csv')
    virus_df['Date'] = pd.to_datetime(virus_df['Date'])
    virus_df['year'] = virus_df['Date'].apply(lambda date: date.year)
    virus_df['month'] = virus_df['Date'].apply(lambda date: date.month)
    virus_df_new = virus_df[['Date','month','year',f'{city}']]
    virus_df_new.rename(columns = {f'{city}' : f'Virus_Count_{city}'}, inplace = True)

    temp_df = pd.read_csv(f'Data/{city}_temp.csv')
    pressure_df = pd.read_csv(f'Data/{city}_pressure.csv')
    hours_df = pd.read_csv(f'Data/{city}_hours.csv')
    rainfall_df = pd.read_csv(f'Data/{city}_rainfall.csv')

    temp_df['Date'] = pd.to_datetime(temp_df['Date'])
    temp_df['year'] = temp_df['Date'].apply(lambda date: date.year)
    temp_df['month'] = temp_df['Date'].apply(lambda date: date.month)

    pressure_df['Date'] = pd.to_datetime(pressure_df['Date'])
    pressure_df['year'] = pressure_df['Date'].apply(lambda date: date.year)
    pressure_df['month'] = pressure_df['Date'].apply(lambda date: date.month)
    pressure_df = pressure_df.sort_values(by="Date")
    pressure_df = pressure_df.reset_index(drop=True)

    hours_df['Date'] = pd.to_datetime(hours_df['Date'])
    hours_df['year'] = hours_df['Date'].apply(lambda date: date.year)
    hours_df['month'] = hours_df['Date'].apply(lambda date: date.month)
    hours_df = hours_df.sort_values(by="Date")
    hours_df = hours_df.reset_index(drop=True)

    rainfall_df['Date'] = pd.to_datetime(rainfall_df['Date'])
    rainfall_df['year'] = rainfall_df['Date'].apply(lambda date: date.year)
    rainfall_df['month'] = rainfall_df['Date'].apply(lambda date: date.month)
    rainfall_df = rainfall_df.sort_values(by="Date")
    rainfall_df = rainfall_df.reset_index(drop=True)

    list = []
    for x in temp_df.index:
        t = temp_df.iloc[x][f'{city}']
        svp = 6.1078*10**(7.5*t/(t+237.3))
        e = pressure_df.iloc[x][f'{city}']
        h = e/svp*100
        list.append(h)
        
    humidity_df = pd.DataFrame(data=list)
    humidity_df.rename(columns = {0:f'{city}'}, inplace = True)

    mean_temp_df = CreateMean(temp_df, 'Temperature',f'{city}')
    mean_pressure_df = CreateMean(pressure_df, 'Pressure',f'{city}')
    mean_hours_df = CreateMean(hours_df, 'Hours',f'{city}')
    mean_rainfall_df = CreateMean(rainfall_df, 'Rainfall',f'{city}')
    mean_humidity_df = CreateMean(humidity_df, 'Humidity',f'{city}')
    
    max_temp_df = CreateMax(temp_df, 'Temperature',f'{city}')
    max_pressure_df = CreateMax(pressure_df, 'Pressure',f'{city}')
    max_hours_df = CreateMax(hours_df, 'Hours',f'{city}')
    max_rainfall_df = CreateMax(rainfall_df, 'Rainfall',f'{city}')
    max_humidity_df = CreateMax(humidity_df, 'Humidity',f'{city}')
    
    min_temp_df = CreateMin(temp_df, 'Temperature',f'{city}')
    min_pressure_df = CreateMin(pressure_df, 'Pressure',f'{city}')
    min_hours_df = CreateMin(hours_df, 'Hours',f'{city}')
    min_rainfall_df = CreateMin(rainfall_df, 'Rainfall',f'{city}')
    min_humidity_df = CreateMin(humidity_df, 'Humidity',f'{city}')

    df = pd.concat([virus_df_new,mean_temp_df,mean_pressure_df,mean_hours_df,mean_rainfall_df,mean_humidity_df,max_temp_df,max_pressure_df,max_hours_df,max_rainfall_df,max_humidity_df,
                   min_temp_df, min_pressure_df,min_hours_df,min_rainfall_df,min_humidity_df], axis=1)
    
    df = df.loc[:,~df.columns.duplicated()]
    
    df['VirusCRM'] = df['Virus_Count_Tokyo'].rolling(14, center = True).mean()

    for i in df.index:
        if i == 0:
            df.at[i,'Gradient'] = 1
        else:
            if df.iloc[i-1]['VirusCRM'] == 0:
                if df.at[i,'VirusCDM'] > 0:
                    df.at[i,'Gradient'] = 1
                else:
                    df.at[i,'Gradient'] = 0
            else:
                grd = df.iloc[i]['VirusCRM']/(df.iloc[i-1]['VirusCRM'])
                df.at[i,'Gradient'] = grd
    
    for i in df.index:
        if (df.iloc[i]['Gradient'] >= 1.1) and (df.iloc[i+1]['Gradient'] >= 1.1) and (df.iloc[i+2]['Gradient'] >= 1.1):
            df.at[i,'Spreading'] = 1
        else:
            df.at[i,'Spreading'] = 0
    df = df.astype({'Spreading':'int8'})

    df_virus_count = df[f'Virus_Count_{city}']
    df.drop(columns=['VirusCRM',f'Virus_Count_{city}','year','Gradient'], axis=1, inplace=True)
    df_labels = df[['Date']]
    FUTURE_PREDICTION = 4
    for i in range(FUTURE_PREDICTION):
        df_labels[f"T+{(i+1)*7}"] = df_labels["Date"] + pd.DateOffset(days = (i+1)*7)
    temp = df[["Date", "Spreading"]]
    for i in range(FUTURE_PREDICTION):
        target_column = f"T+{(i+1)*7}"
        df_labels = df_labels.merge(temp, 
                                how ="left",
                                left_on = (target_column),
                                right_on=("Date"),
                                suffixes = ("","_y")
        )
        df_labels.rename(columns={"Spreading":f"{target_column}_Spreading"},inplace=True)
    df_labels.drop(columns=["Date_y"],inplace=True)

    for i in range(FUTURE_PREDICTION):
        df_labels.drop(columns =[f"T+{(i+1)*7}"],inplace=True,axis=1 )

    df = df.merge(df_labels,
             how='left',
             on = ["Date"])
    df.dropna(inplace=True)

    X = df.drop(columns=['T+7_Spreading','T+14_Spreading','T+21_Spreading','T+28_Spreading'],axis=1)
    y1 = df['T+21_Spreading']
    y2 = df['T+7_Spreading']
    y3 = df['T+14_Spreading']
    y4 = df['T+28_Spreading']

    return X, y1, y2, y3, y4, df, df_virus_count

# %%
X, y1, y2, y3, y4, df, df_virus_count = DataPreprocess('Tokyo')
# Out:
# /Users/miyanishio/opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py:5039: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(
# /var/folders/k5/3yc13bs57f7637937yjlstth0000gn/T/ipykernel_10885/999066033.py:178: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_labels[f"T+{(i+1)*7}"] = df_labels["Date"] + pd.DateOffset(days = (i+1)*7)

# %%
X = X.drop(columns=['Date'])

# %%
X = X[0:400] #until 2020 05-04
y1 = y1[0:400]
y2 = y2[0:400]
y3 = y2[0:400]
y4 = y2[0:400]

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

scaler = StandardScaler()
scaler1 = StandardScaler()
X_train, X_test = X[0:280], X[280:400]
y1_train, y1_test = y1[0:280], y1[280:400]

# %%
scaled_X_train = scaler1.fit_transform(X_train)
scaled_X_test = scaler1.transform(X_test)

# %%
model = Sequential()

model.add(Dense(12,activation="sigmoid"))
model.add(Dense(6,activation="sigmoid"))
model.add(Dense(3,activation="sigmoid"))

model.add(Dense(1, activation='sigmoid'))
model.compile(optimizer='rmsprop',loss='binary_crossentropy',metrics=['accuracy'])
# Out:
# 2022-12-14 13:00:31.161349: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
early_stop = EarlyStopping(monitor='val_loss',mode='min',verbose=1,patience=50)

# %%
model.fit(scaled_X_train,y1_train,epochs=400,validation_data=(scaled_X_test,y1_test),callbacks=[early_stop])
# Out:
# Epoch 1/400
# 9/9 [==============================] - 1s 29ms/step - loss: 0.9201 - accuracy: 0.1643 - val_loss: 0.9369 - val_accuracy: 0.1000
# Epoch 2/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.8891 - accuracy: 0.1643 - val_loss: 0.9088 - val_accuracy: 0.1000
# Epoch 3/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.8653 - accuracy: 0.1643 - val_loss: 0.8837 - val_accuracy: 0.1000
# Epoch 4/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.8437 - accuracy: 0.1643 - val_loss: 0.8610 - val_accuracy: 0.1000
# Epoch 5/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.8237 - accuracy: 0.1643 - val_loss: 0.8386 - val_accuracy: 0.1000
# Epoch 6/400
# 9/9 [==============================] - 0s 7ms/step - loss: 0.8044 - accuracy: 0.1643 - val_loss: 0.8176 - val_accuracy: 0.1000
# Epoch 7/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.7862 - accuracy: 0.1643 - val_loss: 0.7973 - val_accuracy: 0.1000
# Epoch 8/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.7685 - accuracy: 0.1643 - val_loss: 0.7778 - val_accuracy: 0.1000
# Epoch 9/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.7519 - accuracy: 0.1643 - val_loss: 0.7593 - val_accuracy: 0.1000
# Epoch 10/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.7363 - accuracy: 0.1643 - val_loss: 0.7423 - val_accuracy: 0.1000
# Epoch 11/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.7215 - accuracy: 0.1643 - val_loss: 0.7251 - val_accuracy: 0.1000
# Epoch 12/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.7071 - accuracy: 0.2321 - val_loss: 0.7089 - val_accuracy: 0.3083
# Epoch 13/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.6935 - accuracy: 0.5357 - val_loss: 0.6934 - val_accuracy: 0.6083
# Epoch 14/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.6808 - accuracy: 0.7286 - val_loss: 0.6788 - val_accuracy: 0.7083
# Epoch 15/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.6686 - accuracy: 0.8000 - val_loss: 0.6646 - val_accuracy: 0.7917
# Epoch 16/400
# 9/9 [==============================] - 0s 21ms/step - loss: 0.6570 - accuracy: 0.8571 - val_loss: 0.6513 - val_accuracy: 0.8250
# Epoch 17/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.6459 - accuracy: 0.8500 - val_loss: 0.6382 - val_accuracy: 0.9000
# Epoch 18/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.6354 - accuracy: 0.8357 - val_loss: 0.6257 - val_accuracy: 0.9000
# Epoch 19/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.6252 - accuracy: 0.8357 - val_loss: 0.6137 - val_accuracy: 0.9000
# Epoch 20/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.6155 - accuracy: 0.8357 - val_loss: 0.6022 - val_accuracy: 0.9000
# Epoch 21/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.6063 - accuracy: 0.8357 - val_loss: 0.5909 - val_accuracy: 0.9000
# Epoch 22/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.5974 - accuracy: 0.8357 - val_loss: 0.5803 - val_accuracy: 0.9000
# Epoch 23/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.5891 - accuracy: 0.8357 - val_loss: 0.5703 - val_accuracy: 0.9000
# Epoch 24/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.5813 - accuracy: 0.8357 - val_loss: 0.5608 - val_accuracy: 0.9000
# Epoch 25/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.5738 - accuracy: 0.8357 - val_loss: 0.5514 - val_accuracy: 0.9000
# Epoch 26/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.5665 - accuracy: 0.8357 - val_loss: 0.5427 - val_accuracy: 0.9000
# Epoch 27/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.5595 - accuracy: 0.8357 - val_loss: 0.5337 - val_accuracy: 0.9000
# Epoch 28/400
# 9/9 [==============================] - 0s 7ms/step - loss: 0.5528 - accuracy: 0.8357 - val_loss: 0.5255 - val_accuracy: 0.9000
# Epoch 29/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.5465 - accuracy: 0.8357 - val_loss: 0.5177 - val_accuracy: 0.9000
# Epoch 30/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.5406 - accuracy: 0.8357 - val_loss: 0.5100 - val_accuracy: 0.9000
# Epoch 31/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.5347 - accuracy: 0.8357 - val_loss: 0.5029 - val_accuracy: 0.9000
# Epoch 32/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.5293 - accuracy: 0.8357 - val_loss: 0.4962 - val_accuracy: 0.9000
# Epoch 33/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.5241 - accuracy: 0.8357 - val_loss: 0.4892 - val_accuracy: 0.9000
# Epoch 34/400
# 9/9 [==============================] - 0s 7ms/step - loss: 0.5191 - accuracy: 0.8357 - val_loss: 0.4830 - val_accuracy: 0.9000
# Epoch 35/400
# 9/9 [==============================] - 0s 17ms/step - loss: 0.5143 - accuracy: 0.8357 - val_loss: 0.4770 - val_accuracy: 0.9000
# Epoch 36/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.5099 - accuracy: 0.8357 - val_loss: 0.4712 - val_accuracy: 0.9000
# Epoch 37/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.5055 - accuracy: 0.8357 - val_loss: 0.4655 - val_accuracy: 0.9000
# Epoch 38/400
# 9/9 [==============================] - 0s 7ms/step - loss: 0.5012 - accuracy: 0.8357 - val_loss: 0.4601 - val_accuracy: 0.9000
# Epoch 39/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.4973 - accuracy: 0.8357 - val_loss: 0.4551 - val_accuracy: 0.9000
# Epoch 40/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.4935 - accuracy: 0.8357 - val_loss: 0.4501 - val_accuracy: 0.9000
# Epoch 41/400
# 9/9 [==============================] - 0s 9ms/step - loss: 0.4897 - accuracy: 0.8357 - val_loss: 0.4453 - val_accuracy: 0.9000
# Epoch 42/400
# 9/9 [==============================] - 0s 10ms/step - loss: 0.4862 - accuracy: 0.8357 - val_loss: 0.4406 - val_accuracy: 0.9000
# Epoch 43/400
# 9/9 [==============================] - 0s 9ms/step - loss: 0.4828 - accuracy: 0.8357 - val_loss: 0.4364 - val_accuracy: 0.9000
# Epoch 44/400
# 9/9 [==============================] - 0s 9ms/step - loss: 0.4797 - accuracy: 0.8357 - val_loss: 0.4321 - val_accuracy: 0.9000
# Epoch 45/400
# 9/9 [==============================] - 0s 8ms/step - loss: 0.4766 - accuracy: 0.8357 - val_loss: 0.4283 - val_accuracy: 0.9000
# Epoch 46/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.4737 - accuracy: 0.8357 - val_loss: 0.4244 - val_accuracy: 0.9000
# Epoch 47/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.4707 - accuracy: 0.8357 - val_loss: 0.4206 - val_accuracy: 0.9000
# Epoch 48/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.4679 - accuracy: 0.8357 - val_loss: 0.4171 - val_accuracy: 0.9000
# Epoch 49/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.4653 - accuracy: 0.8357 - val_loss: 0.4135 - val_accuracy: 0.9000
# Epoch 50/400
# 9/9 [==============================] - 0s 9ms/step - loss: 0.4626 - accuracy: 0.8357 - val_loss: 0.4102 - val_accuracy: 0.9000
# Epoch 51/400
# 9/9 [==============================] - 0s 7ms/step - loss: 0.4600 - accuracy: 0.8357 - val_loss: 0.4068 - val_accuracy: 0.9000
# Epoch 52/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.4576 - accuracy: 0.8357 - val_loss: 0.4037 - val_accuracy: 0.9000
# Epoch 53/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.4552 - accuracy: 0.8357 - val_loss: 0.4009 - val_accuracy: 0.9000
# Epoch 54/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.4528 - accuracy: 0.8357 - val_loss: 0.3979 - val_accuracy: 0.9000
# Epoch 55/400
# 9/9 [==============================] - 0s 8ms/step - loss: 0.4505 - accuracy: 0.8357 - val_loss: 0.3949 - val_accuracy: 0.9000
# Epoch 56/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.4483 - accuracy: 0.8357 - val_loss: 0.3922 - val_accuracy: 0.9000
# Epoch 57/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.4462 - accuracy: 0.8357 - val_loss: 0.3897 - val_accuracy: 0.9000
# Epoch 58/400
# 9/9 [==============================] - 0s 11ms/step - loss: 0.4442 - accuracy: 0.8357 - val_loss: 0.3873 - val_accuracy: 0.9000
# Epoch 59/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.4422 - accuracy: 0.8357 - val_loss: 0.3848 - val_accuracy: 0.9000
# Epoch 60/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.4402 - accuracy: 0.8357 - val_loss: 0.3826 - val_accuracy: 0.9000
# Epoch 61/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.4382 - accuracy: 0.8357 - val_loss: 0.3801 - val_accuracy: 0.9000
# Epoch 62/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.4363 - accuracy: 0.8357 - val_loss: 0.3780 - val_accuracy: 0.9000
# Epoch 63/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.4343 - accuracy: 0.8357 - val_loss: 0.3758 - val_accuracy: 0.9000
# Epoch 64/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.4322 - accuracy: 0.8357 - val_loss: 0.3736 - val_accuracy: 0.9000
# Epoch 65/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.4302 - accuracy: 0.8357 - val_loss: 0.3714 - val_accuracy: 0.9000
# Epoch 66/400
# 9/9 [==============================] - 0s 11ms/step - loss: 0.4282 - accuracy: 0.8357 - val_loss: 0.3693 - val_accuracy: 0.9000
# Epoch 67/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.4263 - accuracy: 0.8357 - val_loss: 0.3678 - val_accuracy: 0.9000
# Epoch 68/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.4245 - accuracy: 0.8357 - val_loss: 0.3661 - val_accuracy: 0.9000
# Epoch 69/400
# 9/9 [==============================] - 0s 8ms/step - loss: 0.4227 - accuracy: 0.8357 - val_loss: 0.3643 - val_accuracy: 0.9000
# Epoch 70/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.4208 - accuracy: 0.8357 - val_loss: 0.3625 - val_accuracy: 0.9000
# Epoch 71/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.4188 - accuracy: 0.8357 - val_loss: 0.3606 - val_accuracy: 0.9000
# Epoch 72/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.4170 - accuracy: 0.8357 - val_loss: 0.3590 - val_accuracy: 0.9000
# Epoch 73/400
# 9/9 [==============================] - 0s 8ms/step - loss: 0.4150 - accuracy: 0.8357 - val_loss: 0.3575 - val_accuracy: 0.9000
# Epoch 74/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.4131 - accuracy: 0.8357 - val_loss: 0.3557 - val_accuracy: 0.9000
# Epoch 75/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.4111 - accuracy: 0.8357 - val_loss: 0.3539 - val_accuracy: 0.9000
# Epoch 76/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.4092 - accuracy: 0.8357 - val_loss: 0.3526 - val_accuracy: 0.9000
# Epoch 77/400
# 9/9 [==============================] - 0s 8ms/step - loss: 0.4073 - accuracy: 0.8357 - val_loss: 0.3510 - val_accuracy: 0.9000
# Epoch 78/400
# 9/9 [==============================] - 0s 13ms/step - loss: 0.4054 - accuracy: 0.8357 - val_loss: 0.3494 - val_accuracy: 0.9000
# Epoch 79/400
# 9/9 [==============================] - 0s 9ms/step - loss: 0.4035 - accuracy: 0.8357 - val_loss: 0.3481 - val_accuracy: 0.9000
# Epoch 80/400
# 9/9 [==============================] - 0s 3ms/step - loss: 0.4015 - accuracy: 0.8357 - val_loss: 0.3466 - val_accuracy: 0.9000
# Epoch 81/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.3995 - accuracy: 0.8357 - val_loss: 0.3448 - val_accuracy: 0.9000
# Epoch 82/400
# 9/9 [==============================] - 0s 8ms/step - loss: 0.3975 - accuracy: 0.8357 - val_loss: 0.3433 - val_accuracy: 0.9000
# Epoch 83/400
# 9/9 [==============================] - 0s 9ms/step - loss: 0.3954 - accuracy: 0.8357 - val_loss: 0.3421 - val_accuracy: 0.9000
# Epoch 84/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.3933 - accuracy: 0.8357 - val_loss: 0.3405 - val_accuracy: 0.9000
# Epoch 85/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.3913 - accuracy: 0.8357 - val_loss: 0.3391 - val_accuracy: 0.9000
# Epoch 86/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.3892 - accuracy: 0.8357 - val_loss: 0.3375 - val_accuracy: 0.9000
# Epoch 87/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.3870 - accuracy: 0.8357 - val_loss: 0.3359 - val_accuracy: 0.9000
# Epoch 88/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.3850 - accuracy: 0.8357 - val_loss: 0.3343 - val_accuracy: 0.9000
# Epoch 89/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.3830 - accuracy: 0.8357 - val_loss: 0.3328 - val_accuracy: 0.9000
# Epoch 90/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.3810 - accuracy: 0.8357 - val_loss: 0.3314 - val_accuracy: 0.9000
# Epoch 91/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.3791 - accuracy: 0.8357 - val_loss: 0.3301 - val_accuracy: 0.9000
# Epoch 92/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.3771 - accuracy: 0.8357 - val_loss: 0.3287 - val_accuracy: 0.9000
# Epoch 93/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.3752 - accuracy: 0.8357 - val_loss: 0.3275 - val_accuracy: 0.9000
# Epoch 94/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.3732 - accuracy: 0.8357 - val_loss: 0.3264 - val_accuracy: 0.9000
# Epoch 95/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.3713 - accuracy: 0.8357 - val_loss: 0.3249 - val_accuracy: 0.9000
# Epoch 96/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.3694 - accuracy: 0.8357 - val_loss: 0.3237 - val_accuracy: 0.9000
# Epoch 97/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.3675 - accuracy: 0.8357 - val_loss: 0.3223 - val_accuracy: 0.9000
# Epoch 98/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.3655 - accuracy: 0.8357 - val_loss: 0.3209 - val_accuracy: 0.9000
# Epoch 99/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.3635 - accuracy: 0.8357 - val_loss: 0.3193 - val_accuracy: 0.9000
# Epoch 100/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.3615 - accuracy: 0.8357 - val_loss: 0.3180 - val_accuracy: 0.9000
# Epoch 101/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.3594 - accuracy: 0.8357 - val_loss: 0.3167 - val_accuracy: 0.9000
# Epoch 102/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.3573 - accuracy: 0.8357 - val_loss: 0.3155 - val_accuracy: 0.9000
# Epoch 103/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.3555 - accuracy: 0.8357 - val_loss: 0.3141 - val_accuracy: 0.9000
# Epoch 104/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.3537 - accuracy: 0.8357 - val_loss: 0.3128 - val_accuracy: 0.9000
# Epoch 105/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.3517 - accuracy: 0.8357 - val_loss: 0.3115 - val_accuracy: 0.9000
# Epoch 106/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.3498 - accuracy: 0.8357 - val_loss: 0.3102 - val_accuracy: 0.9000
# Epoch 107/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.3478 - accuracy: 0.8357 - val_loss: 0.3086 - val_accuracy: 0.9000
# Epoch 108/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.3459 - accuracy: 0.8357 - val_loss: 0.3073 - val_accuracy: 0.9000
# Epoch 109/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.3440 - accuracy: 0.8357 - val_loss: 0.3062 - val_accuracy: 0.9000
# Epoch 110/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.3422 - accuracy: 0.8357 - val_loss: 0.3048 - val_accuracy: 0.9000
# Epoch 111/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.3403 - accuracy: 0.8357 - val_loss: 0.3036 - val_accuracy: 0.9000
# Epoch 112/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.3384 - accuracy: 0.8357 - val_loss: 0.3025 - val_accuracy: 0.9000
# Epoch 113/400
# 9/9 [==============================] - 0s 3ms/step - loss: 0.3366 - accuracy: 0.8357 - val_loss: 0.3012 - val_accuracy: 0.9000
# Epoch 114/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.3346 - accuracy: 0.8357 - val_loss: 0.2999 - val_accuracy: 0.9000
# Epoch 115/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.3330 - accuracy: 0.8357 - val_loss: 0.2987 - val_accuracy: 0.9000
# Epoch 116/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.3313 - accuracy: 0.8357 - val_loss: 0.2976 - val_accuracy: 0.9000
# Epoch 117/400
# 9/9 [==============================] - 0s 3ms/step - loss: 0.3294 - accuracy: 0.8357 - val_loss: 0.2963 - val_accuracy: 0.9000
# Epoch 118/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.3276 - accuracy: 0.8357 - val_loss: 0.2952 - val_accuracy: 0.9000
# Epoch 119/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.3258 - accuracy: 0.8357 - val_loss: 0.2942 - val_accuracy: 0.9000
# Epoch 120/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.3240 - accuracy: 0.8357 - val_loss: 0.2929 - val_accuracy: 0.9000
# Epoch 121/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.3224 - accuracy: 0.8357 - val_loss: 0.2917 - val_accuracy: 0.9000
# Epoch 122/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.3207 - accuracy: 0.8357 - val_loss: 0.2904 - val_accuracy: 0.9000
# Epoch 123/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.3191 - accuracy: 0.8357 - val_loss: 0.2890 - val_accuracy: 0.9000
# Epoch 124/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.3174 - accuracy: 0.8357 - val_loss: 0.2877 - val_accuracy: 0.9000
# Epoch 125/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.3158 - accuracy: 0.8357 - val_loss: 0.2867 - val_accuracy: 0.9000
# Epoch 126/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.3142 - accuracy: 0.8357 - val_loss: 0.2855 - val_accuracy: 0.9000
# Epoch 127/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.3126 - accuracy: 0.8357 - val_loss: 0.2842 - val_accuracy: 0.9000
# Epoch 128/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.3109 - accuracy: 0.8357 - val_loss: 0.2833 - val_accuracy: 0.9000
# Epoch 129/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.3095 - accuracy: 0.8357 - val_loss: 0.2819 - val_accuracy: 0.9000
# Epoch 130/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.3079 - accuracy: 0.8357 - val_loss: 0.2806 - val_accuracy: 0.9000
# Epoch 131/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.3064 - accuracy: 0.8357 - val_loss: 0.2794 - val_accuracy: 0.9000
# Epoch 132/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.3049 - accuracy: 0.8357 - val_loss: 0.2784 - val_accuracy: 0.9000
# Epoch 133/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.3032 - accuracy: 0.8357 - val_loss: 0.2771 - val_accuracy: 0.9000
# Epoch 134/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.3015 - accuracy: 0.8357 - val_loss: 0.2758 - val_accuracy: 0.9000
# Epoch 135/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.3000 - accuracy: 0.8357 - val_loss: 0.2746 - val_accuracy: 0.9000
# Epoch 136/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2985 - accuracy: 0.8357 - val_loss: 0.2735 - val_accuracy: 0.9000
# Epoch 137/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2970 - accuracy: 0.8357 - val_loss: 0.2721 - val_accuracy: 0.9000
# Epoch 138/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2957 - accuracy: 0.8357 - val_loss: 0.2711 - val_accuracy: 0.9000
# Epoch 139/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2942 - accuracy: 0.8357 - val_loss: 0.2703 - val_accuracy: 0.9000
# Epoch 140/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2927 - accuracy: 0.8357 - val_loss: 0.2691 - val_accuracy: 0.9000
# Epoch 141/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2914 - accuracy: 0.8357 - val_loss: 0.2679 - val_accuracy: 0.9000
# Epoch 142/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2900 - accuracy: 0.8357 - val_loss: 0.2669 - val_accuracy: 0.9000
# Epoch 143/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2886 - accuracy: 0.8357 - val_loss: 0.2660 - val_accuracy: 0.9000
# Epoch 144/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2873 - accuracy: 0.8357 - val_loss: 0.2653 - val_accuracy: 0.9000
# Epoch 145/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.2860 - accuracy: 0.8357 - val_loss: 0.2641 - val_accuracy: 0.9000
# Epoch 146/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2848 - accuracy: 0.8357 - val_loss: 0.2634 - val_accuracy: 0.9000
# Epoch 147/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2836 - accuracy: 0.8357 - val_loss: 0.2621 - val_accuracy: 0.9000
# Epoch 148/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.2825 - accuracy: 0.8357 - val_loss: 0.2610 - val_accuracy: 0.9000
# Epoch 149/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2812 - accuracy: 0.8357 - val_loss: 0.2602 - val_accuracy: 0.9000
# Epoch 150/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.2800 - accuracy: 0.8357 - val_loss: 0.2591 - val_accuracy: 0.9000
# Epoch 151/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2788 - accuracy: 0.8357 - val_loss: 0.2576 - val_accuracy: 0.9000
# Epoch 152/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.2775 - accuracy: 0.8357 - val_loss: 0.2562 - val_accuracy: 0.9000
# Epoch 153/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.2762 - accuracy: 0.8357 - val_loss: 0.2554 - val_accuracy: 0.9000
# Epoch 154/400
# 9/9 [==============================] - 0s 8ms/step - loss: 0.2749 - accuracy: 0.8357 - val_loss: 0.2540 - val_accuracy: 0.9000
# Epoch 155/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.2736 - accuracy: 0.8357 - val_loss: 0.2530 - val_accuracy: 0.9000
# Epoch 156/400
# 9/9 [==============================] - 0s 9ms/step - loss: 0.2724 - accuracy: 0.8357 - val_loss: 0.2518 - val_accuracy: 0.9000
# Epoch 157/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.2712 - accuracy: 0.8357 - val_loss: 0.2506 - val_accuracy: 0.9000
# Epoch 158/400
# 9/9 [==============================] - 0s 7ms/step - loss: 0.2702 - accuracy: 0.8357 - val_loss: 0.2496 - val_accuracy: 0.9000
# Epoch 159/400
# 9/9 [==============================] - 0s 7ms/step - loss: 0.2692 - accuracy: 0.8357 - val_loss: 0.2487 - val_accuracy: 0.9000
# Epoch 160/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2680 - accuracy: 0.8429 - val_loss: 0.2475 - val_accuracy: 0.9000
# Epoch 161/400
# 9/9 [==============================] - 0s 3ms/step - loss: 0.2670 - accuracy: 0.8464 - val_loss: 0.2467 - val_accuracy: 0.9000
# Epoch 162/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2659 - accuracy: 0.8643 - val_loss: 0.2455 - val_accuracy: 0.8833
# Epoch 163/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2651 - accuracy: 0.8714 - val_loss: 0.2447 - val_accuracy: 0.8833
# Epoch 164/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2639 - accuracy: 0.8821 - val_loss: 0.2439 - val_accuracy: 0.8833
# Epoch 165/400
# 9/9 [==============================] - 0s 3ms/step - loss: 0.2628 - accuracy: 0.8929 - val_loss: 0.2433 - val_accuracy: 0.9083
# Epoch 166/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2619 - accuracy: 0.8929 - val_loss: 0.2420 - val_accuracy: 0.9167
# Epoch 167/400
# 9/9 [==============================] - 0s 8ms/step - loss: 0.2610 - accuracy: 0.8964 - val_loss: 0.2410 - val_accuracy: 0.9167
# Epoch 168/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.2598 - accuracy: 0.8964 - val_loss: 0.2399 - val_accuracy: 0.9167
# Epoch 169/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.2589 - accuracy: 0.8964 - val_loss: 0.2388 - val_accuracy: 0.9167
# Epoch 170/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2577 - accuracy: 0.9000 - val_loss: 0.2382 - val_accuracy: 0.9167
# Epoch 171/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.2567 - accuracy: 0.8964 - val_loss: 0.2371 - val_accuracy: 0.9167
# Epoch 172/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2559 - accuracy: 0.8964 - val_loss: 0.2360 - val_accuracy: 0.9167
# Epoch 173/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2551 - accuracy: 0.8964 - val_loss: 0.2357 - val_accuracy: 0.9083
# Epoch 174/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.2543 - accuracy: 0.8964 - val_loss: 0.2349 - val_accuracy: 0.9083
# Epoch 175/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2535 - accuracy: 0.8929 - val_loss: 0.2339 - val_accuracy: 0.9083
# Epoch 176/400
# 9/9 [==============================] - 0s 3ms/step - loss: 0.2524 - accuracy: 0.8929 - val_loss: 0.2330 - val_accuracy: 0.9083
# Epoch 177/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2518 - accuracy: 0.8929 - val_loss: 0.2325 - val_accuracy: 0.9083
# Epoch 178/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2509 - accuracy: 0.8929 - val_loss: 0.2317 - val_accuracy: 0.9083
# Epoch 179/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2500 - accuracy: 0.8964 - val_loss: 0.2314 - val_accuracy: 0.9083
# Epoch 180/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2494 - accuracy: 0.8964 - val_loss: 0.2305 - val_accuracy: 0.9083
# Epoch 181/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2485 - accuracy: 0.8929 - val_loss: 0.2294 - val_accuracy: 0.9083
# Epoch 182/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2476 - accuracy: 0.8929 - val_loss: 0.2282 - val_accuracy: 0.9083
# Epoch 183/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2468 - accuracy: 0.8929 - val_loss: 0.2273 - val_accuracy: 0.9083
# Epoch 184/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2460 - accuracy: 0.8929 - val_loss: 0.2269 - val_accuracy: 0.9083
# Epoch 185/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2456 - accuracy: 0.8964 - val_loss: 0.2258 - val_accuracy: 0.9083
# Epoch 186/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2445 - accuracy: 0.8929 - val_loss: 0.2255 - val_accuracy: 0.9083
# Epoch 187/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2439 - accuracy: 0.8929 - val_loss: 0.2251 - val_accuracy: 0.9083
# Epoch 188/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2432 - accuracy: 0.8929 - val_loss: 0.2250 - val_accuracy: 0.9000
# Epoch 189/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2425 - accuracy: 0.8929 - val_loss: 0.2243 - val_accuracy: 0.9000
# Epoch 190/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2419 - accuracy: 0.8929 - val_loss: 0.2235 - val_accuracy: 0.9000
# Epoch 191/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2412 - accuracy: 0.8929 - val_loss: 0.2222 - val_accuracy: 0.9000
# Epoch 192/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2407 - accuracy: 0.8929 - val_loss: 0.2223 - val_accuracy: 0.9000
# Epoch 193/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2401 - accuracy: 0.8929 - val_loss: 0.2219 - val_accuracy: 0.9000
# Epoch 194/400
# 9/9 [==============================] - 0s 7ms/step - loss: 0.2393 - accuracy: 0.8929 - val_loss: 0.2218 - val_accuracy: 0.9000
# Epoch 195/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.2385 - accuracy: 0.8929 - val_loss: 0.2204 - val_accuracy: 0.9000
# Epoch 196/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2380 - accuracy: 0.8929 - val_loss: 0.2201 - val_accuracy: 0.9000
# Epoch 197/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2373 - accuracy: 0.8929 - val_loss: 0.2198 - val_accuracy: 0.9000
# Epoch 198/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2369 - accuracy: 0.9000 - val_loss: 0.2185 - val_accuracy: 0.9000
# Epoch 199/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.2361 - accuracy: 0.9000 - val_loss: 0.2184 - val_accuracy: 0.9000
# Epoch 200/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.2357 - accuracy: 0.8964 - val_loss: 0.2182 - val_accuracy: 0.9000
# Epoch 201/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2349 - accuracy: 0.8964 - val_loss: 0.2173 - val_accuracy: 0.9000
# Epoch 202/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.2344 - accuracy: 0.8964 - val_loss: 0.2166 - val_accuracy: 0.9000
# Epoch 203/400
# 9/9 [==============================] - 0s 3ms/step - loss: 0.2338 - accuracy: 0.8929 - val_loss: 0.2161 - val_accuracy: 0.9000
# Epoch 204/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.2332 - accuracy: 0.8964 - val_loss: 0.2162 - val_accuracy: 0.9083
# Epoch 205/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2325 - accuracy: 0.8929 - val_loss: 0.2150 - val_accuracy: 0.9083
# Epoch 206/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.2320 - accuracy: 0.8929 - val_loss: 0.2138 - val_accuracy: 0.9083
# Epoch 207/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2313 - accuracy: 0.8929 - val_loss: 0.2128 - val_accuracy: 0.9083
# Epoch 208/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2307 - accuracy: 0.8893 - val_loss: 0.2124 - val_accuracy: 0.9083
# Epoch 209/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2303 - accuracy: 0.8929 - val_loss: 0.2126 - val_accuracy: 0.9167
# Epoch 210/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2295 - accuracy: 0.8893 - val_loss: 0.2121 - val_accuracy: 0.9167
# Epoch 211/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2290 - accuracy: 0.8893 - val_loss: 0.2115 - val_accuracy: 0.9167
# Epoch 212/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.2286 - accuracy: 0.8893 - val_loss: 0.2110 - val_accuracy: 0.9167
# Epoch 213/400
# 9/9 [==============================] - 0s 7ms/step - loss: 0.2279 - accuracy: 0.8893 - val_loss: 0.2106 - val_accuracy: 0.9167
# Epoch 214/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2276 - accuracy: 0.8893 - val_loss: 0.2098 - val_accuracy: 0.9167
# Epoch 215/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2269 - accuracy: 0.8893 - val_loss: 0.2087 - val_accuracy: 0.9167
# Epoch 216/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2265 - accuracy: 0.8893 - val_loss: 0.2085 - val_accuracy: 0.9167
# Epoch 217/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2260 - accuracy: 0.8893 - val_loss: 0.2084 - val_accuracy: 0.9167
# Epoch 218/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.2259 - accuracy: 0.8893 - val_loss: 0.2077 - val_accuracy: 0.9167
# Epoch 219/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2250 - accuracy: 0.8893 - val_loss: 0.2077 - val_accuracy: 0.9167
# Epoch 220/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.2243 - accuracy: 0.8893 - val_loss: 0.2071 - val_accuracy: 0.9167
# Epoch 221/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2240 - accuracy: 0.8893 - val_loss: 0.2064 - val_accuracy: 0.9167
# Epoch 222/400
# 9/9 [==============================] - 0s 3ms/step - loss: 0.2238 - accuracy: 0.8893 - val_loss: 0.2067 - val_accuracy: 0.9167
# Epoch 223/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2229 - accuracy: 0.8893 - val_loss: 0.2063 - val_accuracy: 0.9167
# Epoch 224/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2225 - accuracy: 0.8893 - val_loss: 0.2063 - val_accuracy: 0.9083
# Epoch 225/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2223 - accuracy: 0.8929 - val_loss: 0.2050 - val_accuracy: 0.9167
# Epoch 226/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2215 - accuracy: 0.8893 - val_loss: 0.2052 - val_accuracy: 0.9083
# Epoch 227/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2213 - accuracy: 0.8893 - val_loss: 0.2051 - val_accuracy: 0.9083
# Epoch 228/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2208 - accuracy: 0.8893 - val_loss: 0.2047 - val_accuracy: 0.9083
# Epoch 229/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.2204 - accuracy: 0.8929 - val_loss: 0.2036 - val_accuracy: 0.9167
# Epoch 230/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2200 - accuracy: 0.8929 - val_loss: 0.2036 - val_accuracy: 0.9083
# Epoch 231/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2194 - accuracy: 0.8929 - val_loss: 0.2029 - val_accuracy: 0.9167
# Epoch 232/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2190 - accuracy: 0.8929 - val_loss: 0.2023 - val_accuracy: 0.9167
# Epoch 233/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2186 - accuracy: 0.8929 - val_loss: 0.2018 - val_accuracy: 0.9167
# Epoch 234/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2181 - accuracy: 0.8929 - val_loss: 0.2014 - val_accuracy: 0.9167
# Epoch 235/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2176 - accuracy: 0.8929 - val_loss: 0.2009 - val_accuracy: 0.9167
# Epoch 236/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.2174 - accuracy: 0.8929 - val_loss: 0.2003 - val_accuracy: 0.9167
# Epoch 237/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.2169 - accuracy: 0.8929 - val_loss: 0.1999 - val_accuracy: 0.9167
# Epoch 238/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2163 - accuracy: 0.8929 - val_loss: 0.1989 - val_accuracy: 0.9167
# Epoch 239/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2160 - accuracy: 0.8929 - val_loss: 0.1982 - val_accuracy: 0.9167
# Epoch 240/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2155 - accuracy: 0.8929 - val_loss: 0.1988 - val_accuracy: 0.9167
# Epoch 241/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2152 - accuracy: 0.9000 - val_loss: 0.1986 - val_accuracy: 0.9167
# Epoch 242/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2148 - accuracy: 0.9000 - val_loss: 0.1980 - val_accuracy: 0.9167
# Epoch 243/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2146 - accuracy: 0.9000 - val_loss: 0.1978 - val_accuracy: 0.9167
# Epoch 244/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.2141 - accuracy: 0.9000 - val_loss: 0.1975 - val_accuracy: 0.9167
# Epoch 245/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2137 - accuracy: 0.8964 - val_loss: 0.1972 - val_accuracy: 0.9167
# Epoch 246/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2132 - accuracy: 0.9000 - val_loss: 0.1963 - val_accuracy: 0.9167
# Epoch 247/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2129 - accuracy: 0.8964 - val_loss: 0.1971 - val_accuracy: 0.9167
# Epoch 248/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2127 - accuracy: 0.9000 - val_loss: 0.1967 - val_accuracy: 0.9167
# Epoch 249/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2121 - accuracy: 0.9000 - val_loss: 0.1963 - val_accuracy: 0.9167
# Epoch 250/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2115 - accuracy: 0.9000 - val_loss: 0.1963 - val_accuracy: 0.9167
# Epoch 251/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.2115 - accuracy: 0.9000 - val_loss: 0.1958 - val_accuracy: 0.9167
# Epoch 252/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.2116 - accuracy: 0.9000 - val_loss: 0.1946 - val_accuracy: 0.9167
# Epoch 253/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2107 - accuracy: 0.9036 - val_loss: 0.1940 - val_accuracy: 0.9167
# Epoch 254/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2103 - accuracy: 0.9000 - val_loss: 0.1937 - val_accuracy: 0.9167
# Epoch 255/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.2100 - accuracy: 0.9036 - val_loss: 0.1932 - val_accuracy: 0.9167
# Epoch 256/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2095 - accuracy: 0.9036 - val_loss: 0.1927 - val_accuracy: 0.9167
# Epoch 257/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.2093 - accuracy: 0.9036 - val_loss: 0.1929 - val_accuracy: 0.9250
# Epoch 258/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2088 - accuracy: 0.9036 - val_loss: 0.1923 - val_accuracy: 0.9250
# Epoch 259/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2088 - accuracy: 0.9036 - val_loss: 0.1923 - val_accuracy: 0.9250
# Epoch 260/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.2081 - accuracy: 0.9000 - val_loss: 0.1931 - val_accuracy: 0.9250
# Epoch 261/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2079 - accuracy: 0.9036 - val_loss: 0.1928 - val_accuracy: 0.9250
# Epoch 262/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2073 - accuracy: 0.9036 - val_loss: 0.1919 - val_accuracy: 0.9250
# Epoch 263/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2072 - accuracy: 0.9036 - val_loss: 0.1917 - val_accuracy: 0.9250
# Epoch 264/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2069 - accuracy: 0.9036 - val_loss: 0.1911 - val_accuracy: 0.9250
# Epoch 265/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.2065 - accuracy: 0.9036 - val_loss: 0.1909 - val_accuracy: 0.9250
# Epoch 266/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2063 - accuracy: 0.9036 - val_loss: 0.1909 - val_accuracy: 0.9333
# Epoch 267/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2057 - accuracy: 0.9036 - val_loss: 0.1899 - val_accuracy: 0.9250
# Epoch 268/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2057 - accuracy: 0.9036 - val_loss: 0.1904 - val_accuracy: 0.9333
# Epoch 269/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2053 - accuracy: 0.9036 - val_loss: 0.1902 - val_accuracy: 0.9333
# Epoch 270/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.2050 - accuracy: 0.9036 - val_loss: 0.1894 - val_accuracy: 0.9333
# Epoch 271/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2046 - accuracy: 0.9036 - val_loss: 0.1894 - val_accuracy: 0.9333
# Epoch 272/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2043 - accuracy: 0.9036 - val_loss: 0.1886 - val_accuracy: 0.9250
# Epoch 273/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.2038 - accuracy: 0.9000 - val_loss: 0.1879 - val_accuracy: 0.9250
# Epoch 274/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2039 - accuracy: 0.9071 - val_loss: 0.1879 - val_accuracy: 0.9250
# Epoch 275/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2031 - accuracy: 0.9071 - val_loss: 0.1883 - val_accuracy: 0.9333
# Epoch 276/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2030 - accuracy: 0.9000 - val_loss: 0.1878 - val_accuracy: 0.9333
# Epoch 277/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2026 - accuracy: 0.9036 - val_loss: 0.1876 - val_accuracy: 0.9333
# Epoch 278/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2024 - accuracy: 0.9071 - val_loss: 0.1872 - val_accuracy: 0.9333
# Epoch 279/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2019 - accuracy: 0.9036 - val_loss: 0.1874 - val_accuracy: 0.9333
# Epoch 280/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2018 - accuracy: 0.9000 - val_loss: 0.1876 - val_accuracy: 0.9333
# Epoch 281/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2017 - accuracy: 0.9071 - val_loss: 0.1866 - val_accuracy: 0.9333
# Epoch 282/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.2010 - accuracy: 0.9071 - val_loss: 0.1863 - val_accuracy: 0.9333
# Epoch 283/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.2008 - accuracy: 0.9036 - val_loss: 0.1864 - val_accuracy: 0.9333
# Epoch 284/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.2006 - accuracy: 0.9071 - val_loss: 0.1866 - val_accuracy: 0.9333
# Epoch 285/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.2002 - accuracy: 0.9071 - val_loss: 0.1862 - val_accuracy: 0.9333
# Epoch 286/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.2000 - accuracy: 0.9036 - val_loss: 0.1860 - val_accuracy: 0.9333
# Epoch 287/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.1993 - accuracy: 0.9036 - val_loss: 0.1852 - val_accuracy: 0.9333
# Epoch 288/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.1994 - accuracy: 0.9143 - val_loss: 0.1858 - val_accuracy: 0.9333
# Epoch 289/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.1989 - accuracy: 0.9071 - val_loss: 0.1858 - val_accuracy: 0.9333
# Epoch 290/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.1988 - accuracy: 0.9071 - val_loss: 0.1856 - val_accuracy: 0.9333
# Epoch 291/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.1983 - accuracy: 0.9107 - val_loss: 0.1853 - val_accuracy: 0.9333
# Epoch 292/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.1982 - accuracy: 0.9143 - val_loss: 0.1846 - val_accuracy: 0.9333
# Epoch 293/400
# 9/9 [==============================] - 0s 3ms/step - loss: 0.1978 - accuracy: 0.9143 - val_loss: 0.1848 - val_accuracy: 0.9333
# Epoch 294/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.1974 - accuracy: 0.9143 - val_loss: 0.1847 - val_accuracy: 0.9333
# Epoch 295/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.1970 - accuracy: 0.9107 - val_loss: 0.1845 - val_accuracy: 0.9333
# Epoch 296/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.1970 - accuracy: 0.9143 - val_loss: 0.1838 - val_accuracy: 0.9333
# Epoch 297/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.1965 - accuracy: 0.9143 - val_loss: 0.1840 - val_accuracy: 0.9333
# Epoch 298/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.1963 - accuracy: 0.9143 - val_loss: 0.1842 - val_accuracy: 0.9333
# Epoch 299/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.1957 - accuracy: 0.9143 - val_loss: 0.1842 - val_accuracy: 0.9333
# Epoch 300/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.1958 - accuracy: 0.9179 - val_loss: 0.1845 - val_accuracy: 0.9333
# Epoch 301/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.1950 - accuracy: 0.9179 - val_loss: 0.1837 - val_accuracy: 0.9333
# Epoch 302/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.1950 - accuracy: 0.9179 - val_loss: 0.1825 - val_accuracy: 0.9333
# Epoch 303/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.1947 - accuracy: 0.9214 - val_loss: 0.1821 - val_accuracy: 0.9333
# Epoch 304/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.1944 - accuracy: 0.9250 - val_loss: 0.1817 - val_accuracy: 0.9333
# Epoch 305/400
# 9/9 [==============================] - 0s 7ms/step - loss: 0.1938 - accuracy: 0.9179 - val_loss: 0.1823 - val_accuracy: 0.9333
# Epoch 306/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.1937 - accuracy: 0.9214 - val_loss: 0.1820 - val_accuracy: 0.9333
# Epoch 307/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.1937 - accuracy: 0.9214 - val_loss: 0.1822 - val_accuracy: 0.9333
# Epoch 308/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.1931 - accuracy: 0.9214 - val_loss: 0.1813 - val_accuracy: 0.9333
# Epoch 309/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.1926 - accuracy: 0.9214 - val_loss: 0.1818 - val_accuracy: 0.9333
# Epoch 310/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.1924 - accuracy: 0.9214 - val_loss: 0.1815 - val_accuracy: 0.9333
# Epoch 311/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.1920 - accuracy: 0.9250 - val_loss: 0.1810 - val_accuracy: 0.9333
# Epoch 312/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.1923 - accuracy: 0.9250 - val_loss: 0.1806 - val_accuracy: 0.9333
# Epoch 313/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.1913 - accuracy: 0.9250 - val_loss: 0.1809 - val_accuracy: 0.9333
# Epoch 314/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.1913 - accuracy: 0.9250 - val_loss: 0.1814 - val_accuracy: 0.9333
# Epoch 315/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.1910 - accuracy: 0.9179 - val_loss: 0.1810 - val_accuracy: 0.9333
# Epoch 316/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.1909 - accuracy: 0.9250 - val_loss: 0.1804 - val_accuracy: 0.9333
# Epoch 317/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.1904 - accuracy: 0.9250 - val_loss: 0.1804 - val_accuracy: 0.9333
# Epoch 318/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.1903 - accuracy: 0.9214 - val_loss: 0.1804 - val_accuracy: 0.9333
# Epoch 319/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.1901 - accuracy: 0.9250 - val_loss: 0.1809 - val_accuracy: 0.9333
# Epoch 320/400
# 9/9 [==============================] - 0s 8ms/step - loss: 0.1895 - accuracy: 0.9214 - val_loss: 0.1807 - val_accuracy: 0.9333
# Epoch 321/400
# 9/9 [==============================] - 0s 7ms/step - loss: 0.1897 - accuracy: 0.9286 - val_loss: 0.1808 - val_accuracy: 0.9333
# Epoch 322/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.1891 - accuracy: 0.9214 - val_loss: 0.1810 - val_accuracy: 0.9333
# Epoch 323/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.1891 - accuracy: 0.9214 - val_loss: 0.1806 - val_accuracy: 0.9333
# Epoch 324/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.1888 - accuracy: 0.9214 - val_loss: 0.1811 - val_accuracy: 0.9333
# Epoch 325/400
# 9/9 [==============================] - 0s 9ms/step - loss: 0.1883 - accuracy: 0.9179 - val_loss: 0.1806 - val_accuracy: 0.9333
# Epoch 326/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.1880 - accuracy: 0.9250 - val_loss: 0.1805 - val_accuracy: 0.9333
# Epoch 327/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.1881 - accuracy: 0.9250 - val_loss: 0.1805 - val_accuracy: 0.9333
# Epoch 328/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.1878 - accuracy: 0.9214 - val_loss: 0.1803 - val_accuracy: 0.9333
# Epoch 329/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.1874 - accuracy: 0.9250 - val_loss: 0.1797 - val_accuracy: 0.9333
# Epoch 330/400
# 9/9 [==============================] - 0s 7ms/step - loss: 0.1870 - accuracy: 0.9214 - val_loss: 0.1792 - val_accuracy: 0.9333
# Epoch 331/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.1867 - accuracy: 0.9250 - val_loss: 0.1786 - val_accuracy: 0.9333
# Epoch 332/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.1863 - accuracy: 0.9250 - val_loss: 0.1785 - val_accuracy: 0.9333
# Epoch 333/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.1863 - accuracy: 0.9250 - val_loss: 0.1786 - val_accuracy: 0.9333
# Epoch 334/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.1864 - accuracy: 0.9250 - val_loss: 0.1786 - val_accuracy: 0.9333
# Epoch 335/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.1856 - accuracy: 0.9214 - val_loss: 0.1786 - val_accuracy: 0.9333
# Epoch 336/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.1860 - accuracy: 0.9214 - val_loss: 0.1790 - val_accuracy: 0.9333
# Epoch 337/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.1849 - accuracy: 0.9250 - val_loss: 0.1794 - val_accuracy: 0.9333
# Epoch 338/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.1855 - accuracy: 0.9250 - val_loss: 0.1796 - val_accuracy: 0.9333
# Epoch 339/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.1848 - accuracy: 0.9214 - val_loss: 0.1790 - val_accuracy: 0.9333
# Epoch 340/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.1845 - accuracy: 0.9250 - val_loss: 0.1794 - val_accuracy: 0.9333
# Epoch 341/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.1843 - accuracy: 0.9250 - val_loss: 0.1796 - val_accuracy: 0.9333
# Epoch 342/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.1841 - accuracy: 0.9250 - val_loss: 0.1791 - val_accuracy: 0.9333
# Epoch 343/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.1838 - accuracy: 0.9250 - val_loss: 0.1789 - val_accuracy: 0.9333
# Epoch 344/400
# 9/9 [==============================] - 0s 9ms/step - loss: 0.1840 - accuracy: 0.9250 - val_loss: 0.1791 - val_accuracy: 0.9333
# Epoch 345/400
# 9/9 [==============================] - 0s 8ms/step - loss: 0.1835 - accuracy: 0.9286 - val_loss: 0.1778 - val_accuracy: 0.9333
# Epoch 346/400
# 9/9 [==============================] - 0s 8ms/step - loss: 0.1828 - accuracy: 0.9250 - val_loss: 0.1779 - val_accuracy: 0.9333
# Epoch 347/400
# 9/9 [==============================] - 0s 11ms/step - loss: 0.1831 - accuracy: 0.9250 - val_loss: 0.1781 - val_accuracy: 0.9333
# Epoch 348/400
# 9/9 [==============================] - 0s 7ms/step - loss: 0.1825 - accuracy: 0.9250 - val_loss: 0.1779 - val_accuracy: 0.9333
# Epoch 349/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.1827 - accuracy: 0.9286 - val_loss: 0.1780 - val_accuracy: 0.9333
# Epoch 350/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.1826 - accuracy: 0.9250 - val_loss: 0.1785 - val_accuracy: 0.9333
# Epoch 351/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.1818 - accuracy: 0.9250 - val_loss: 0.1785 - val_accuracy: 0.9333
# Epoch 352/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.1821 - accuracy: 0.9286 - val_loss: 0.1781 - val_accuracy: 0.9333
# Epoch 353/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.1817 - accuracy: 0.9286 - val_loss: 0.1789 - val_accuracy: 0.9333
# Epoch 354/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.1813 - accuracy: 0.9286 - val_loss: 0.1783 - val_accuracy: 0.9333
# Epoch 355/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.1808 - accuracy: 0.9286 - val_loss: 0.1774 - val_accuracy: 0.9333
# Epoch 356/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.1806 - accuracy: 0.9286 - val_loss: 0.1769 - val_accuracy: 0.9333
# Epoch 357/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.1804 - accuracy: 0.9250 - val_loss: 0.1779 - val_accuracy: 0.9333
# Epoch 358/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.1799 - accuracy: 0.9286 - val_loss: 0.1773 - val_accuracy: 0.9333
# Epoch 359/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.1804 - accuracy: 0.9250 - val_loss: 0.1772 - val_accuracy: 0.9333
# Epoch 360/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.1795 - accuracy: 0.9286 - val_loss: 0.1768 - val_accuracy: 0.9333
# Epoch 361/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.1796 - accuracy: 0.9250 - val_loss: 0.1778 - val_accuracy: 0.9333
# Epoch 362/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.1793 - accuracy: 0.9286 - val_loss: 0.1778 - val_accuracy: 0.9333
# Epoch 363/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.1789 - accuracy: 0.9286 - val_loss: 0.1780 - val_accuracy: 0.9333
# Epoch 364/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.1785 - accuracy: 0.9286 - val_loss: 0.1774 - val_accuracy: 0.9333
# Epoch 365/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.1786 - accuracy: 0.9286 - val_loss: 0.1784 - val_accuracy: 0.9333
# Epoch 366/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.1782 - accuracy: 0.9286 - val_loss: 0.1775 - val_accuracy: 0.9333
# Epoch 367/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.1784 - accuracy: 0.9286 - val_loss: 0.1778 - val_accuracy: 0.9333
# Epoch 368/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.1777 - accuracy: 0.9286 - val_loss: 0.1782 - val_accuracy: 0.9333
# Epoch 369/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.1776 - accuracy: 0.9286 - val_loss: 0.1781 - val_accuracy: 0.9333
# Epoch 370/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.1774 - accuracy: 0.9286 - val_loss: 0.1778 - val_accuracy: 0.9333
# Epoch 371/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.1771 - accuracy: 0.9286 - val_loss: 0.1777 - val_accuracy: 0.9333
# Epoch 372/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.1767 - accuracy: 0.9286 - val_loss: 0.1768 - val_accuracy: 0.9333
# Epoch 373/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.1764 - accuracy: 0.9250 - val_loss: 0.1774 - val_accuracy: 0.9333
# Epoch 374/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.1764 - accuracy: 0.9250 - val_loss: 0.1775 - val_accuracy: 0.9333
# Epoch 375/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.1764 - accuracy: 0.9286 - val_loss: 0.1766 - val_accuracy: 0.9333
# Epoch 376/400
# 9/9 [==============================] - 0s 7ms/step - loss: 0.1762 - accuracy: 0.9250 - val_loss: 0.1772 - val_accuracy: 0.9333
# Epoch 377/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.1756 - accuracy: 0.9250 - val_loss: 0.1766 - val_accuracy: 0.9333
# Epoch 378/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.1754 - accuracy: 0.9250 - val_loss: 0.1766 - val_accuracy: 0.9333
# Epoch 379/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.1750 - accuracy: 0.9250 - val_loss: 0.1777 - val_accuracy: 0.9333
# Epoch 380/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.1749 - accuracy: 0.9250 - val_loss: 0.1777 - val_accuracy: 0.9333
# Epoch 381/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.1745 - accuracy: 0.9250 - val_loss: 0.1781 - val_accuracy: 0.9333
# Epoch 382/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.1744 - accuracy: 0.9250 - val_loss: 0.1764 - val_accuracy: 0.9333
# Epoch 383/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.1744 - accuracy: 0.9250 - val_loss: 0.1769 - val_accuracy: 0.9333
# Epoch 384/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.1738 - accuracy: 0.9250 - val_loss: 0.1768 - val_accuracy: 0.9333
# Epoch 385/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.1738 - accuracy: 0.9250 - val_loss: 0.1764 - val_accuracy: 0.9333
# Epoch 386/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.1732 - accuracy: 0.9250 - val_loss: 0.1764 - val_accuracy: 0.9333
# Epoch 387/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.1731 - accuracy: 0.9250 - val_loss: 0.1766 - val_accuracy: 0.9333
# Epoch 388/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.1733 - accuracy: 0.9250 - val_loss: 0.1769 - val_accuracy: 0.9333
# Epoch 389/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.1724 - accuracy: 0.9250 - val_loss: 0.1770 - val_accuracy: 0.9333
# Epoch 390/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.1728 - accuracy: 0.9250 - val_loss: 0.1764 - val_accuracy: 0.9333
# Epoch 391/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.1723 - accuracy: 0.9250 - val_loss: 0.1762 - val_accuracy: 0.9333
# Epoch 392/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.1717 - accuracy: 0.9250 - val_loss: 0.1770 - val_accuracy: 0.9333
# Epoch 393/400
# 9/9 [==============================] - 0s 5ms/step - loss: 0.1718 - accuracy: 0.9250 - val_loss: 0.1770 - val_accuracy: 0.9333
# Epoch 394/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.1716 - accuracy: 0.9250 - val_loss: 0.1778 - val_accuracy: 0.9333
# Epoch 395/400
# 9/9 [==============================] - 0s 4ms/step - loss: 0.1711 - accuracy: 0.9250 - val_loss: 0.1770 - val_accuracy: 0.9333
# Epoch 396/400
# 9/9 [==============================] - 0s 7ms/step - loss: 0.1709 - accuracy: 0.9250 - val_loss: 0.1770 - val_accuracy: 0.9333
# Epoch 397/400
# 9/9 [==============================] - 0s 6ms/step - loss: 0.1711 - accuracy: 0.9250 - val_loss: 0.1769 - val_accuracy: 0.9333
# Epoch 398/400
# 9/9 [==============================] - 0s 9ms/step - loss: 0.1707 - accuracy: 0.9250 - val_loss: 0.1782 - val_accuracy: 0.9333
# Epoch 399/400
# 9/9 [==============================] - 0s 9ms/step - loss: 0.1704 - accuracy: 0.9250 - val_loss: 0.1778 - val_accuracy: 0.9333
# Epoch 400/400
# 9/9 [==============================] - 0s 3ms/step - loss: 0.1709 - accuracy: 0.9250 - val_loss: 0.1765 - val_accuracy: 0.9333

# %%
predictions = model.predict(scaled_X_test)

# %%
preds = []
for x in predictions:
    if x >= 0.5:
        preds.append(1)
    else:
        preds.append(0)

# %%
from sklearn.metrics import classification_report,confusion_matrix

# %%
print(classification_report(y1_test,preds))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.98      0.94      0.96       108
#          1.0       0.62      0.83      0.71        12
#
#     accuracy                           0.93       120
#    macro avg       0.80      0.89      0.84       120
# weighted avg       0.95      0.93      0.94       120
